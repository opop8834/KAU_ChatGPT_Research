# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "자유전공학부_전계열_data"
number_html = 5
url = """http://college.kau.ac.kr/web/pages/gc74551h.do
http://college.kau.ac.kr/web/pages/gc93198h.do
http://college.kau.ac.kr/web/pages/gc87644h.do
http://college.kau.ac.kr/web/pages/gc89038h.do
http://college.kau.ac.kr/web/pages/gc19269h.do
http://college.kau.ac.kr/web/pages/gc81685h.do
http://college.kau.ac.kr/web/pages/gc88420h.do
http://college.kau.ac.kr/web/pages/gc10540h.do
http://college.kau.ac.kr/web/pages/gc96976h.do
http://college.kau.ac.kr/web/pages/gc84514h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 6:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc74551h.do', 'http://college.kau.ac.kr/web/pages/gc93198h.do', 'http://college.kau.ac.kr/web/pages/gc87644h.do', 'http://college.kau.ac.kr/web/pages/gc89038h.do', 'http://college.kau.ac.kr/web/pages/gc19269h.do', 'http://college.kau.ac.kr/web/pages/gc81685h.do', 'http://college.kau.ac.kr/web/pages/gc88420h.do', 'http://college.kau.ac.kr/web/pages/gc10540h.do', 'http://college.kau.ac.kr/web/pages/gc96976h.do', 'http://college.kau.ac.kr/web/pages/gc84514h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 26
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3>학부/과 소개</h3>', '</div>', '<div class="article_101">', '<span class="img_fl">', '<img src="/cmm_typeA/images/sample/sub_101_01.jpg"/>', '</span>', '<h4>자유전공학부</h4>', '<p>한국항공대학교는 미래 산업사회의 변화에 대비하여 학생들이 자기주도적으로 전공을 선택 하도록 하기 위해 2018년 자유전공학부를 신설하였습니다. <br/>자유전공학부 학생들은 대학 생활을 하면서 해당 분야 전공 교수님, 전문가, 여러 멘토들로부터 다양한 정보를 접하고 2학년때\xa0 주전공을\xa0 선택합니다.\xa0<br/><br/>\xa0</p></div><div class="sctn"><div class="article_101"><div style="text-align: center;">', '<table attr_no_border_tbl="1" border="0" cellpadding="1" cellspacing="0" class="__se_tbl" style="">\n<tbody align="center" style="text-align: center;">\n<tr style="height: 100px;"><td colspan="1" rowspan="7" style="width: 44px; height: 5px; background-color: rgb(24, 81, 150);"><div align="center" style="text-align: center;"><span style="color: rgb(255, 255, 255);">자</span><br/><span style="color: rgb(255, 255, 255);">유</span><br/><span style="color: rgb(255, 255, 255);">전</span><br/><span style="color: rgb(255, 255, 255);">공</span><br/><span style="color: rgb(255, 255, 255);">학</span><br/><span style="color: rgb(255, 255, 255);">부</span></div></td>\n<td style="width: 14px; height: 43px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 81px; height: 43px; background-color: rgb(201, 224, 240);"><p>비전</p></td>\n<td style="width: 14px; height: 43px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td colspan="5" rowspan="1" style="width: 480px; height: 43px; background-color: rgb(235, 235, 235);"><p>항공우주 분야를 비롯한 다양한 학문분야를 탐구하고, 문화적 포용력을 바탕으로 미래를 개척하고 인류에 기여할 인본주의적 소통형 글로벌 전문 인재 양성</p></td>\n</tr>\n<tr>\n<td style="width: 14px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 81px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 14px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 148px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 12px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 154px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 13px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 153px; height: 14px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n</tr>\n<tr style="height: 100px;">\n<td style="width: 14px; height: 74px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 81px; height: 74px; background-color: rgb(201, 224, 240);"><p>교육목표\xa0</p></td>\n<td style="width: 14px; height: 74px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 148px; height: 74px; background-color: rgb(235, 235, 235);"><p>다양한 인종과 국가의 경계를 넘어\xa0커뮤니게이션이 가능한 교육</p></td>\n<td style="width: 12px; height: 74px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 154px; height: 74px; background-color: rgb(235, 235, 235);"><p>산업체가 현장에서 필요로 하는 경험과 능력을 갖춘 전공 교육</p></td>\n<td style="width: 13px; height: 74px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 153px; height: 74px; background-color: rgb(235, 235, 235);"><p>다양한 문화를 이해하고 세계화를 지향하는 교육</p></td>\n</tr>\n<tr>\n<td style="width: 14px; height: 5px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 81px; height: 5px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 14px; height: 5px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 148px; height: 5px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 12px; height: 5px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td>\n<td style="width: 154px; height: 5px; background-color: rgb(255, 255, 255);"><p>\xa0</p></td ...
#
# $(document).ready(function() {
# });
#
# 학부/과 소개
#
# 자유전공학부
# 한국항공대학교는 미래 산업사회의 변화에 대비하여 학생들이 자기주도적으로 전공을 선택 하도록 하기 위해 2018년 자유전공학부를 신설하였습니다. 자유전공학부 학생들은 대학 생활을 하면서 해당 분야 전공 교수님, 전문가, 여러 멘토들로부터 다양한 정보를 접하고 2학년때  주전공을  선택합니다.
# 구분 : 자유전공학부
# 비전 : 항공우주 분야를 비롯한 다양한 학문분야를 탐구하고, 문화적 포용력을 바탕으로 미래를 개척하고 인류에 기여할 인본주의적 소통형 글로벌 전문 인재 양성
#
# 교육목표 : 다양한 인종과 국가의 경계를 넘어 커뮤니게이션이 가능한 교육, 산업체가 현장에서 필요로 하는 경험과 능력을 갖춘 전공 교육, 다양한 문화를 이해하고 세계화를 지향하는 교육
#
# 인재상 : 인본주의적 소통형 인재, 현장 중심의 전문적 인재, 글로벌 인재
#
# 전공능력 : 외국어 구사 능력, 사회지능, 전문 분야에서 업무를 수행할 수 있는 현장 적응력과 숙련도, 문화적 포용력과 글로벌 비전을 바탕으로 성과를 도출하는 실행력
#
# 자유전공학부 3대 가치:
# - 자율성(Autonomy): 경력 개발과 교과목 수강을 포함한 대학 생활을 스스로 결정하고 자기주도적으로 이끌어 간다.
# - 전문성(Mastery): 사회가 필요로 하는 전문성을 갖추고 숙련된 기술을 익힌다.
# - 인간성(Humanity): 다양한 가치와 문화를 인정하고 글로벌 비전으로 인류의 공존과 번영을 위해 함께 소통하며 학습한 지식을 공유한다.
# table {
# width: 90%;
# height: 200px;
# margin-left: auto;
# margin-right: auto;
# }
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 13
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<title>자유전공학부::인사말 및 교수진 소개</title>', '<meta content="Namo WebEditor(Trial)" name="generator"/>', '<table cellpadding="0" cellspacing="0" height="364" width="870"><tbody><tr><td height="52" width="597"><b style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 18.6667px;"><span style="font-family: 돋움체, DotumChe, AppleGothic;">■ 인사말</span></b><br/></td><td height="52" width="273"><span style="font-family: 돋움체, DotumChe, AppleGothic;">\xa0</span></td></tr><tr><td height="312" width="597"><span style="font-family: 돋움체, DotumChe, AppleGothic;">\n</span><p><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 10pt;"><span style="font-size: 12pt;">자유전공학부를 찾아주신 여러분 진심으로 환영합니다.</span><br/><span style="font-size: 12pt;">자유전공학부는 전공탐색을 통해 자신의 능력과 자질을 탐색하고 적성에 맞는 전공을 찾아가는 자아 발견을 핵심적인 가치로 추구하는 학부입니다.</span><br/><span style="font-size: 12pt;">또한 인본주의적 소통 능력과 문화 지능 개발을 통해 외국인 학생들을 포함한 모든 자유전공학부 구성원들의 글로벌 커뮤니케이션 역량을 극대화하고, 이와 같은 핵심 역량을 항공산업을 포함한 다양한 전문 산업 영역에서 발휘할 수 있도록 교육하고 있습니다.</span><br/><span style="font-size: 12pt;">여러분들의 성공과 행복한 삶을 위해 자유전공학부는 최선을 다하고 있습니다.</span><br/><span style="font-size: 12pt;">감사합니다.</span><br/><br/><span style="font-size: 12pt;">자유전공학부장 공은정 교수</span>\xa0</span></p></td><td height="312" width="273"></td></tr></tbody></table>', '</div>', '</body>']
# $(document).ready(function() {
# });
#
# 자유전공학부::인사말 및 교수진 소개
#
# 인사말 : 자유전공학부를 찾아주신 여러분 진심으로 환영합니다. 자유전공학부는 전공탐색을 통해 자신의 능력과 자질을 탐색하고 적성에 맞는 전공을 찾아가는 자아 발견을 핵심적인 가치로 추구하는 학부입니다. 또한 인본주의적 소통 능력과 문화 지능 개발을 통해 외국인 학생들을 포함한 모든 자유전공학부 구성원들의 글로벌 커뮤니케이션 역량을 극대화하고, 이와 같은 핵심 역량을 항공산업을 포함한 다양한 전문 산업 영역에서 발휘할 수 있도록 교육하고 있습니다. 여러분들의 성공과 행복한 삶을 위해 자유전공학부는 최선을 다하고 있습니다. 감사합니다. 자유전공학부장 공은정 교수
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 11
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p><b style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 18.6667px;">■ 자유전공학부 교수 소개</b><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;"><br/><br/>공은정 교수(학부장)</span><br/><br type="_moz"/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">\xa0 - 전공분야 : 언어학(영어학, 음향음성학)</span><br/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">\xa0 - 연구실 : 본관 501호</span><br/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">\xa0\xa0</span><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">- 메일 : ekong@kau.ac.kr</span><br/><br/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">강석진 교수</span><br/><br type="_moz"/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">\xa0 - 전공분야 : 영어영문학</span><br/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">\xa0 - 연구실 : 본관 302호</span><br/><span style="font-family: 돋움체, DotumChe, AppleGothic;"><span style="font-size: 16px;">\xa0 -\xa0</span></span><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 12pt;">메일 : sjkang@kau.ac.kr</span>\xa0</p>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# ■ 자유전공학부 교수 소개공은정 교수(학부장)  - 전공분야 : 언어학(영어학, 음향음성학)  - 연구실 : 본관 501호  - 메일 : ekong@kau.ac.kr강석진 교수  - 전공분야 : 영어영문학  - 연구실 : 본관 302호  - 메일 : sjkang@kau.ac.kr
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 10
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 3286
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p align="left" class="0" style="text-align: left; word-break: keep-all;"><b style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 18.6667px; text-align: start;">■ 자유전공학부 운영 내규<br/></b><span style="font-family: 굴림체, GulimChe;">\xa0</span><b style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 18.6667px; text-align: start;">\xa0</b></p><p class="0"><o:p></o:p></p><p class="0" style="text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 11pt;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: 굴림체, GulimChe;">1</span><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 11pt;">장 총칙</span></p><p class="0"><span style="font-family: 굴림체, GulimChe; font-weight: bold;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">1</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">조</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">목적</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">)</span><span lang="EN-US" style="font-family: 굴림체, GulimChe;"> </span><span style="font-family: 굴림체, GulimChe;">이 운영 내규는 자유전공학부의 교육 목표를 달성하기 위한 합리적인 학부운영을 위해 필요한 사항을 규정함을 목적으로 한다</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">.</span></p><p class="0"><span style="font-family: 굴림체, GulimChe;"> </span><span style="font-family: 굴림체, GulimChe;">\xa0</span><span style="font-family: 굴림체, GulimChe;"> </span><o:p></o:p></p><p class="0" style="text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 11pt;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: 굴림체, GulimChe;">2</span><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 11pt;">장 학</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 11pt;">부</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: 굴림체, GulimChe;">)</span><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 11pt;">과 선택</span></p><p class="0" style="word-break: keep-all;"><span style="font-family: 굴림체, GulimChe; font-weight: bold;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">2</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">조</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">학</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">부</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">)</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">과 선택 및 진입</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">)</span><span lang="EN-US" style="font-family: 굴림체, GulimChe;"> </span><span style="font-family: 굴림체, GulimChe;">본 학부에 입학하는 학년도의 "입학정원의 </span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">30%\xa0</span><span style="font-family: 굴림체, GulimChe;">이내"로 다음의 학</span><span lang="EN-US" style="l ...
# $(document).ready(function() {
# });
#
# ■ 자유전공학부 운영 내규  제1장 총칙제1조(목적) 이 운영 내규는 자유전공학부의 교육 목표를 달성하기 위한 합리적인 학부운영을 위해 필요한 사항을 규정함을 목적으로 한다.   제2장 학(부)과 선택제2조(학(부)과 선택 및 진입) 본 학부에 입학하는 학년도의 "입학정원의 30% 이내"로 다음의 학(부)과를 선택하여, 각 학(부)과의 선발 규정에 따라 진입할 수 있다. 휴학 등의 사유로 입학하는 학년도의 기준으로 진입하지 못할 경우, 진입하고자 하는 해당 학년도의 "입학정원의 30% 이내" 규정에 따른다. 단, 2023학번부터 적용하며 2018학번 ~ 2022학번은 선이수 과목 이수 여부 등을 확인 후 별도의 선발 규정 없이 진입한다.&lt;개정 2019. 12., 개정 2023. 2&gt;
# 구분 : 공과대학
# 학위 : 항공우주및기계공학부
# 비고 : 공학사
#
# 구분 : 공과대학
# 학위 : 항공전자정보공학부
# 비고 : 공학사
#
# 구분 : 공과대학
# 학위 : 신소재공학과
# 비고 : 공학사
#
# 구분 : AI융합대학
# 학위 : 소프트웨어학과
# 비고 : 공학사
#
# 구분 : AI융합대학
# 학위 : 스마트드론공학과
# 비고 : 공학사
#
# 구분 : AI융합대학
# 학위 : AI자율주행시스템공학과
# 비고 : 공학사
#
# 구분 : 항공·경영대학
# 학위 : 항공교통물류학부
# 비고 : 이학사
#
# 구분 : 항공·경영대학
# 학위 : 경영학부
# 비고 : 경영학사
#
# 구분 : 항공·경영대학
# 학위 : 항공운항학과
# 비고 : 이학사
# ※ 각 학(부)과 진입 후 다전공(융합전공 포함) 선택할 수 있으며 전과 규정에 따라 전과 할 수 있다.&lt;신설 2023. 2&gt;※ 항공운항학과 진입 가능 학번 : 2018학번, 2019학번, 2023학번 이후. &lt;신설 2023. 2&gt; 제3조(학(부)과 선택 및 시기) 자유전공학부 운영에 관한 규정 제8조 (희망 학(부)과 신청 및 전공지도교수 배정) 및 제9조 (주전공 학(부)과 선택)에 따른다.① 자유전공학부 신입생은 2학년 진급 전(총 2학기 이수자) 진입할 학(부)과를 선택하여 각 학(부)과의 선발 규정 및 일정에 따라 진입할 수 있다. 매 학기 자유전공학부에서 실시하는 학(부)과 진입을 위한 제반 절차를 이행하고 서류 등을 성실하게 제출한다.&lt;개정 2023. 2&gt;&lt;표 삭제&gt;② 2학년 진급 전 진입할 학(부)과를 선택하지 않은 자유전공학부생(총 2학기 이상 이수자)은 3학년 진급 전 진입할 학(부)과를 선택하여 각 학(부)과의 선발 규정 및 일정에 따라 진입할 수 있다. 매 학기 자유전공학부에서 실시하는 학(부)과 진입을 위한 제반 절차를 이행하고 서류 등을 성실하게 제출한다.&lt;개정 2023. 2&gt;③ 삭제&lt;2019. 12&gt;④ 편입생은 학교 정책에 따라 선발하며, 1학기 이상 이수 후 학(부)과를 선택하여 각 학(부)과의 선발 규정 및 일정에 따라 진입할 수 있다. 매 학기 자유전공학부에서 실시하는 학(부)과 진입을 위한 제반 절차를 이행하고 서류 등을 성실하게 제출한다.&lt;신설 2023. 2&gt;⑤ 엇학기(외국인 유학생, 재외국민전형) 신입생에 한하여 2학기 진입을 위한 선발을 진행할 수 있다.&lt;신설 2023. 2&gt;   제4조(학(부)과 미진입 자유전공학부 소속 학부생의 학(부)과 선택) 삭제&lt;2023. 2&gt;   제3장 졸업제5조(졸업학점) 학칙 제26조(졸업학점) 및 학칙 시행세칙 제34조 (졸업사정)과 진입한 해당 학(부)과의 운영 내규에 따른다. &lt;개정 2023. 2&gt;① 삭제 &lt;2023. 2&gt;② 삭제 &lt;2023. 2&gt;   제6조(학(부)과 진입 학부생 졸업요건) 학칙 및 학칙 시행세칙과 진입한 해당 학(부)과 운영 내규에 따른다. (학점이수 및 졸업요건 등) &lt;개정 2023. 2&gt;   제4장 교과과정제7조(교과과정 편성 및 심의) 교과과정 편성은 학칙 제18조 (교과편성)에 따르며 자유전공학부 전공필수과목인 전공탐색세미나를 수강한다. 단, 편입생과 외국인 유학생은 전공탐색세미나를 수강 여부를 선택할 수 있다. &lt;개정 2023. 2&gt;   제 5장 교과목 이수제8조(필수교양 과목이수) 본교 교과 과정과 진입하고자 하는 학(부)과의 운영 규정에 따른다.&lt;개정 2023. 2&gt; &lt;표 삭제&gt;①삭제&lt;2023. 2&gt; ②삭제&lt;2023. 2&gt;   제9조(각 학(부)과별 선수 및 선이수 교과목이수) 진입하고자 하는 학(부)과별 선수 및 선이수 교과목의 이수는 각 학(부)과의 운영 내규에 따른다. &lt;개정 2023. 2&gt; ① 삭제&lt;2023. 2&gt;   제6장 장학금제10조(장학금 수혜자격) 장학금의 지급은 학칙 제61조 (장학금의 지급)에 따르며 이는 자유전공학부 소속 학부생으로서 1학년에 한한다. 1. 직전학기 이수 학점이 12학점 이상인 자 2. 평점평균 3.5 이상인 자 &lt;개정 2023. 2&gt;     제11조(동점자 처리규정) 1. 총 이수학점이 많은 자 2. 누적 평점이 높은 자 3. 필수 이수학점이 많은 자(전필, 교필) 4. 영어성적 등급이 높은 자 &lt;신설 2023. 2&gt;      -부             칙-1. (시행일) 이 내규는 2018년 3월 1일부터 시행한다.2. (시행일) 이 내규는 2020년 3월 1일부터 시행한다.<!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.1",
# "an": "Hancom Office Hangul",
# "av": "11, 0, 0, 6402",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_10"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2023-02-22T20:54:06.914Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D946B46246B94000000068": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D946B46246B94000000069": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# },
# "01D946B46246B9400000006A": {
# "id": 3,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "rt": 1,
# "rw": 1,
# "rc": 0,
# "tt": 1,
# "tw": 1,
# "tc": 0,
# "bbt": 1,
# "bbw": 1,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# }
# },
# "cp": {
# "01D946B46246B9400000006B": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D946B46246B94000000069",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D946B46246B9400000006C": {
# "id": 1,
# "he": 1300,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D946B46246B94000000069",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D946B46246B9400000006D": {
# "id": 2,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D946B46246B94000000069",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D946B46246B9400000006E": {
# "id": 3,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D946B46246B94000000069",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D946B46246B9400000006F": {
# "id": 4,
# "he": 1200,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D946B46246B94000000069",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D946B46246B94000000070": {
# "id": 0,
# "al": true,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": {
# "01D946B46246B94000000071": {
# "id": 1,
# "sn": 0,
# "ph": [
# {
# "le": 1,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^1."
# },
# {
# "le": 2,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^2."
# },
# {
# "le": 3,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^3)"
# },
# {
# "le": 4,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^4)"
# },
# {
# "le": 5,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "(^5)"
# },
# {
# "le": 6,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "(^6)"
# },
# {
# "le": 7,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 1,
# "st": 1,
# "sf": "^7"
# },
# {
# "le": 8,
# "al": 0,
# "ui": false,
# "ai": false,
# "wa": 0,
# "tt": 0,
# "to": 0,
# "cp": "01D946B46246B9400000006B",
# "uf": 0,
# "st": 1,
# "sf": ""
# },
# {
# "le": 9,
# "al": 0,
# "ui": false,
# "ai": false,
# "wa": 0,
# "tt": 0,
# "to": 0,
# "cp": "01D946B46246B9400000006B",
# "uf": 0,
# "st": 1,
# "sf": ""
# },
# {
# "le": 10,
# "al": 0,
# "ui": false,
# "ai": false,
# "wa": 0,
# "tt": 0,
# "to": 0,
# "cp": "01D946B46246B9400000006B",
# "uf": 0,
# "st": 1,
# "sf": ""
# }
# ]
# }
# },
# "bu": { },
# "pp": {
# "01D946B46246B94000000072": {
# "id": 0,
# "ah": 3,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D946B46246B94000000070",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D946B46246B94000000069",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D946B46246B94000000073": {
# "id": 1,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D946B46246B94000000070",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D946B46246B94000000069",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D946B46246B94000000074": {
# "id": 2,
# "ah": 1,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D946B46246B94000000070",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D946B46246B94000000069",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D946B46246B94000000075": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D946B46246B94000000073",
# "cp": "01D946B46246B9400000006B",
# "ns": "01D946B46246B94000000075",
# "li": 1042,
# "lf": false
# }
# },
# "mp": {
# "01D946B46246E05000000076": {
# "id": 1,
# "wi": 15591,
# "lw": 1,
# "lt": 1,
# "lc": 0,
# "fc": 10092492,
# "ac": 10092543,
# "mt": 0
# }
# },
# "ro": {
# "hp": "01D946B462466B2000000003",
# "01D946B462466B2000000003": {
# "np": "01D946B462466B2000000004",
# "id": 0,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 3,
# "ru": [
# {
# "cp": "01D946B46246B9400000006C",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D946B46246441000000000"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D946B462466B2000000001"
# }
# ,
# {
# "t": "자유전공학부 운영내규"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000004": {
# "np": "01D946B462466B2000000005",
# "id": -2147483648,
# "pp": "01D946B46246B94000000073",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000005": {
# "np": "01D946B462466B2000000006",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006D",
# "ch": [
# {
# "t": "제1장 총칙"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000006": {
# "np": "01D946B462466B2000000007",
# "id": -2147483648,
# "pp": "01D946B46246B94000000073",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제1조(목적)"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 이 운영내규는 자유전공학부의 교육 목표를 달성하기 위한 합리적인 학부운영을 위해 필요한 사항을 규정함을 목적으로 한다."
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000007": {
# "np": "01D946B462466B2000000008",
# "id": -2147483648,
# "pp": "01D946B46246B94000000073",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000008": {
# "np": "01D946B462466B2000000009",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006D",
# "ch": [
# {
# "t": "제2장 학(부)과 선택"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000009": {
# "np": "01D946B462466B200000000A",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제2조(학(부)과 선택)"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 본 학부 입학정원의 30%이내로 다음의 학(부)과를 선택하여 진입할 수 있다. 단, 해당 학(부)과의 선발 규정에 따라 진입할 수 있다."
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "\u003C개정 2019. 12., 개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000000A": {
# "np": "01D946B462466B200000000B",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "cc": 11,
# "ci": 1952607264,
# "co": "01D946B462466B2000000002"
# }
# ,
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B200000000B": {
# "np": "01D946B462466B200000000C",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " ※ 각 학(부)과 진입 후 다전공(융합전공 포함) 선택할 수 있으며 전과 규정에 따라 전과할 수 있다.\u003C신설 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000000C": {
# "np": "01D946B462466B200000000D",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B200000000D": {
# "np": "01D946B462466B200000000E",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제3조(학부(과) 선택 및 시기)"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 자유전공학부 운영에 관한 규정 제8조 (희망 학(부)과 신청 및 전공지도교수 배정) 및 제9조 (주전공 학(부)과 선택)에 따른다."
# }
# ]
# }
# ]
# },
# "01D946B462466B200000000E": {
# "np": "01D946B462466B200000000F",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "① 자유전공학부생 신입생은 2학년 진급 전 진입할 학(부)과를 선택하여 각 학(부)과의 선발 규정에 의하여 진입할 수 있다. 매 학기 자유전공학부에서 실시하는 학(부)과 진입을 위한 제반 절차를 이행하고 서류 등을 성실하게 제출한다.\u003C개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000000F": {
# "np": "01D946B462466B2000000010",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "\u003C표 삭제\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000010": {
# "np": "01D946B462466B2000000011",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "② 2학년 진급 전 진입할 학(부)과를 선택하지 않은 자유전공학부생은 3학년 진급 전 진입할 학(부)과를 선택하여 각 학(부)과의 선발 규정에 의하여 진입할 수 있다. 매 학기 자유전공학부에서 실시하는 학(부)과 진입을 위한 제반 절차를 이행하고 서류 등을 성실하게 제출한다.\u003C개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000011": {
# "np": "01D946B462466B2000000012",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "③ 삭제\u003C2019. 12\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000012": {
# "np": "01D946B462466B2000000013",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "④ 편입생은 학교 정책에 따라 선발하며, 1학기 이상 이수 후 학(부)과를 선택하여 각 학(부)과의 선발 규정 의하여 진입할 수 있다. 매 학기 자유전공학부에서 실시하는 학(부)과 진입을 위한 제반 절차를 이행하고 서류 등을 성실하게 제출한다.\u003C신설 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000013": {
# "np": "01D946B462466B2000000014",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000014": {
# "np": "01D946B462466B2000000015",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제4조(학(부)과 미진입 자유전공학부 소속 학부생의 학(부)과 선택)"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 삭제\u003C2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000015": {
# "np": "01D946B462466B2000000016",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000016": {
# "np": "01D946B462466B2000000017",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006D",
# "ch": [
# {
# "t": "제3장 졸업"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000017": {
# "np": "01D946B462466B2000000018",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제5조(졸업학점) "
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "학칙 제26조(졸업학점) 및 학칙 시행세칙 제34조 (졸업사정), 진입한 해당 학(부)과의 운영내규에 따른다. \u003C개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000018": {
# "np": "01D946B462466B2000000019",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "① 삭제 \u003C2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000019": {
# "np": "01D946B462466B200000001A",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "② 삭제 \u003C2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000001A": {
# "np": "01D946B462466B200000001B",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B200000001B": {
# "np": "01D946B462466B200000001C",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제6조(학(부)과 진입 학부생 졸업요건) "
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "학칙 및 학칙 시행세칙, 진입한 해당 학(부)과 운영 내규에 따른다. (학점이수 및 졸업요건 등) \u003C개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000001C": {
# "np": "01D946B462466B200000001D",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B200000001D": {
# "np": "01D946B462466B200000001E",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006D",
# "ch": [
# {
# "t": "제4장 교과과정"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000001E": {
# "np": "01D946B462466B200000001F",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제7조(교과과정 편성 및 심의)"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 교과과정 편성은 학칙 제18조 (교과편성)에 따르며 자유전공학부 전공필수과목인 전공탐색세미나를 수강한다. 단, 편입생과 외국인 유학생은 전공탐색세미나를 수강 여부를 선택할 수 있다. \u003C개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000001F": {
# "np": "01D946B462466B2000000020",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000020": {
# "np": "01D946B462466B2000000021",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006D",
# "ch": [
# {
# "t": "제 5장 교과목 이수"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000021": {
# "np": "01D946B462466B2000000022",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제8조(필수교양 과목이수) "
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "본교 교과 과정과 진입하고자 하는 학(부)과의 운영 규정에 따른다.\u003C개정 2023. 2\u003E "
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000022": {
# "np": "01D946B462466B2000000023",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "\u003C표 삭제\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000023": {
# "np": "01D946B462466B2000000024",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "①삭제\u003C2023. 2\u003E "
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000024": {
# "np": "01D946B462466B2000000025",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "②삭제\u003C2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000025": {
# "np": "01D946B462466B2000000026",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000026": {
# "np": "01D946B462466B2000000027",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제9조(각 학(부)과별 선수 및 선이수 교과목이수) "
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "진입하고자 하는 학(부)과별 선수 및 선이수 교과목의 이수는 각 학(부)과의 운영 내규에 따른다. \u003C개정 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000027": {
# "np": "01D946B462466B2000000028",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " ① 삭제\u003C2023. 2\u003E"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000028": {
# "np": "01D946B462466B2000000029",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000029": {
# "np": "01D946B462466B200000002A",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006F",
# "ch": [
# {
# "t": "제6장 장학금"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000002A": {
# "np": "01D946B462466B200000002B",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제10조(장학금 수혜자격)"
# }
# ]
# }
# ,
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 장학금의 지급은 학칙 제61조 (장학금의 지급)에 따르며 이는 자유전공학부 소속 학부생으로서 1학년에 한한다."
# }
# ]
# }
# ]
# },
# "01D946B462466B200000002B": {
# "np": "01D946B462466B200000002C",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 1. 직전학기 이수 학점이 12학점 이상인 자"
# }
# ]
# }
# ]
# },
# "01D946B462466B200000002C": {
# "np": "01D946B462466B200000002D",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 2. 평점평균 3.5 이상인 자 \u003C개정 2023. 2\u003E "
# }
# ]
# }
# ]
# },
# "01D946B462466B200000002D": {
# "np": "01D946B462466B200000002E",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " "
# }
# ]
# }
# ]
# },
# "01D946B462466B200000002E": {
# "np": "01D946B462466B200000002F",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B200000002F": {
# "np": "01D946B462466B2000000030",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "제11조(동점자 처리규정)"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000030": {
# "np": "01D946B462466B2000000031",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 1. 총 이수학점이 많은 자"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000031": {
# "np": "01D946B462466B2000000032",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 2. 누적 평점이 높은 자"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000032": {
# "np": "01D946B462466B2000000033",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 3. 필수 이수학점이 많은 자(전필, 교필)"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000033": {
# "np": "01D946B462466B2000000034",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": " 4. 영어성적 등급이 높은 자 \u003C신설 2023. 2\u003E"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000034": {
# "np": "01D946B462466B2000000035",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000035": {
# "np": "01D946B462466B2000000036",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000036": {
# "np": "01D946B462466B2000000037",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "-부             칙-"
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000037": {
# "np": "01D946B462466B2000000038",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "1. (시행일) 이 내규는 2018년 3월 1일부터 시행한다."
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000038": {
# "np": "01D946B462466B2000000039",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "2. (시행일) 이 내규는 2020년 3월 1일부터 시행한다."
# }
# ]
# }
# ]
# },
# "01D946B462466B2000000039": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000074",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "3. (시행일) 이 내규는 2023년 3월 1일부터 시행한다. "
# }
# ]
# }
# ]
# }
# },
# "sl": {
# "01D946B462466B200000003A": {
# "co": "01D946B462466B2000000002",
# "id": 1,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 0,
# "ar": 0,
# "sc": 2,
# "sr": 1,
# "sw": 30964,
# "sh": 1282,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B200000003B"
# },
# "01D946B462466B200000003B": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "구분"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B200000003C": {
# "co": "01D946B462466B2000000002",
# "id": 2,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 2,
# "ar": 0,
# "sc": 1,
# "sr": 1,
# "sw": 11803,
# "sh": 1282,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B200000003D"
# },
# "01D946B462466B200000003D": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006E",
# "ch": [
# {
# "t": "학위"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B200000003E": {
# "co": "01D946B462466B2000000002",
# "id": 3,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 0,
# "ar": 1,
# "sc": 1,
# "sr": 3,
# "sw": 13218,
# "sh": 6393,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B200000003F"
# },
# "01D946B462466B200000003F": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "공과대학"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000040": {
# "co": "01D946B462466B2000000002",
# "id": 4,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 1,
# "ar": 1,
# "sc": 1,
# "sr": 1,
# "sw": 17746,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B2000000041"
# },
# "01D946B462466B2000000041": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "항공우주및기계공학부"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000042": {
# "co": "01D946B462466B2000000002",
# "id": 5,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 2,
# "ar": 1,
# "sc": 1,
# "sr": 1,
# "sw": 11803,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B2000000043"
# },
# "01D946B462466B2000000043": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "공학사"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000044": {
# "co": "01D946B462466B2000000002",
# "id": 6,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 1,
# "ar": 2,
# "sc": 1,
# "sr": 1,
# "sw": 17746,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B2000000045"
# },
# "01D946B462466B2000000045": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "항공전자정보공학부"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000046": {
# "co": "01D946B462466B2000000002",
# "id": 7,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 2,
# "ar": 2,
# "sc": 1,
# "sr": 1,
# "sw": 11803,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B2000000047"
# },
# "01D946B462466B2000000047": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "공학사"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000048": {
# "co": "01D946B462466B2000000002",
# "id": 8,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 1,
# "ar": 3,
# "sc": 1,
# "sr": 1,
# "sw": 17746,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B2000000049"
# },
# "01D946B462466B2000000049": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "신소재공학과"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B200000004A": {
# "co": "01D946B462466B2000000002",
# "id": 9,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 2,
# "ar": 3,
# "sc": 1,
# "sr": 1,
# "sw": 11803,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B200000004B"
# },
# "01D946B462466B200000004B": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "공학사"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B200000004C": {
# "co": "01D946B462466B2000000002",
# "id": 10,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 0,
# "ar": 4,
# "sc": 1,
# "sr": 3,
# "sw": 13218,
# "sh": 6393,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B200000004D"
# },
# "01D946B462466B200000004D": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "AI융합대학"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B200000004E": {
# "co": "01D946B462466B2000000002",
# "id": 11,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 1,
# "ar": 4,
# "sc": 1,
# "sr": 1,
# "sw": 17746,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B200000004F"
# },
# "01D946B462466B200000004F": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "소프트웨어학과"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000050": {
# "co": "01D946B462466B2000000002",
# "id": 12,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D946B46246B9400000006A",
# "ac": 2,
# "ar": 4,
# "sc": 1,
# "sr": 1,
# "sw": 11803,
# "sh": 2131,
# "ml": 510,
# "mr": 510,
# "mt": 141,
# "mb": 141
# },
# "hp": "01D946B462466B2000000051"
# },
# "01D946B462466B2000000051": {
# "np": "",
# "id": -2147483648,
# "pp": "01D946B46246B94000000072",
# "si": "01D946B46246B94000000075",
# "bf": 0,
# "ru": [
# {
# "cp": "01D946B46246B9400000006B",
# "ch": [
# {
# "t": "공학사"
# }
# ]
# }
# ]
# }
# ,
# "01D946B462466B2000000052": {
# "co": "01D946B462466B2000000002",
# "id": 13,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": false,
# "pr": false,
# ...
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "교양"
# }
# ]
# }
# ]
# }
# ,
# "01D919D2119E64C000000043": {
# "co": "01D919D2119E64C000000032",
# "id": 8,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": true,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D919D2119E64C000000052",
# "ac": 1,
# "ar": 2,
# "sc": 1,
# "sr": 1,
# "sw": 24949,
# "sh": 1350,
# "ml": 300,
# "mr": 300,
# "mt": 225,
# "mb": 150
# },
# "hp": "01D919D2119E64C000000044"
# },
# "01D919D2119E64C000000044": {
# "np": "01D919D2119E64C000000045",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[공통](KAU SPACE) 인성과 진로"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C000000045": {
# "np": "01D919D2119E64C000000046",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[공통]교양글쓰기"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C000000046": {
# "np": "01D919D2119E64C000000047",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[공통]영어커뮤니케이션 1(1학기)"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C000000047": {
# "np": "01D919D2119E64C000000048",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[공통]영어커뮤니케이션 2(2학기)"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C000000048": {
# "np": "01D919D2119E64C000000049",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[학문기초]항공우주학개론"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C000000049": {
# "np": "01D919D2119E64C00000004A",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[학문기초]항공우주산업개론"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C00000004A": {
# "np": "01D919D2119E64C00000004B",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "[학문기초]코딩입문(Python) 등등"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C00000004B": {
# "np": "01D919D2119E64C00000004C",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "각 영역별 교양선택 과목\n※영역별 교양과목 자세한 사항"
# }
# ]
# }
# ]
# },
# "01D919D2119E64C00000004C": {
# "np": "",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "☞["
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D919D2119E64C000000033"
# }
# ]
# }
# ,
# {
# "cp": "01D919D2119E64C000000057",
# "ch": [
# {
# "t": "바로가기"
# }
# ,
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D919D2119E8BD00000005F"
# }
# ]
# }
# ,
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "]"
# }
# ]
# }
# ,
# {
# "cp": "01D919D2119E8BD000000058",
# "ch": [
# {
# "t": "\n학번별, 학부(과)별로 상이하고\n위의 과목은 예시이므로\n각 과목별로 반드시 확인"
# }
# ]
# }
# ,
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# }
# ,
# "01D919D2119E64C00000004D": {
# "co": "01D919D2119E64C000000032",
# "id": 9,
# "td": 0,
# "lw": 0,
# "va": 1,
# "ll": "",
# "ln": "",
# "tc": {
# "he": false,
# "hm": true,
# "pr": false,
# "ed": false,
# "di": false,
# "bf": "01D919D2119E64C000000052",
# "ac": 2,
# "ar": 2,
# "sc": 1,
# "sr": 1,
# "sw": 9101,
# "sh": 1350,
# "ml": 300,
# "mr": 300,
# "mt": 225,
# "mb": 150
# },
# "hp": "01D919D2119E64C00000004E"
# },
# "01D919D2119E64C00000004E": {
# "np": "",
# "id": -2147483648,
# "pp": "01D919D2119E8BD00000005B",
# "si": "01D919D2119E8BD00000005E",
# "bf": 0,
# "ru": [
# {
# "cp": "01D919D2119E64C000000056",
# "ch": [
# {
# "t": "교양필수"
# }
# ]
# }
# ]
# }
# },
# "cs": {
# "01D919D2119E64C000000030": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -4,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D919D2119E64C00000004F",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D919D2119E64C00000004F",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D919D2119E64C00000004F",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D919D2119E64C000000031": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# ,
# "01D919D2119E64C000000032": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1095805507,
# "zo": 0,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 51075,
# "she": 25825,
# "swr": 4,
# "shr": 2,
# "spr": false,
# "pta": false,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 141,
# "ori": 141,
# "oto": 141,
# "obo": 141,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 3,
# "cco": 3,
# "cs": 0,
# "bf": "01D919D2119E64C000000051",
# "ile": 0,
# "iri": 0,
# "ito": 0,
# "ibo": 0,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D919D2119E64C000000035",
# "li": 1
# }
# ,
# {
# "so": "01D919D2119E64C000000037",
# "li": 2
# }
# ,
# {
# "so": "01D919D2119E64C000000039",
# "li": 3
# }
# ],
# [
# {
# "so": "01D919D2119E64C00000003B",
# "li": 4
# }
# ,
# {
# "so": "01D919D2119E64C00000003D",
# "li": 5
# }
# ,
# {
# "so": "01D919D2119E64C00000003F",
# "li": 6
# }
# ],
# [
# {
# "so": "01D919D2119E64C000000041",
# "li": 7
# }
# ,
# {
# "so": "01D919D2119E64C000000043",
# "li": 8
# }
# ,
# {
# "so": "01D919D2119E64C00000004D",
# "li": 9
# }
# ]
# ]
# }
# ,
# "01D919D2119E64C000000033": {
# "cc": 3,
# "ci": 627600491,
# "fb": {
# "id": 1095805508,
# "ty": 627600491,
# "ed": false,
# "la": 0,
# "di": true,
# "pa": {
# "fi": false,
# "pr": 0,
# "co": "https\\://www.kau.ac.kr/web/pages/gc15707h.do;1;0;0;"
# },
# "zo": 4294967295,
# "fi": 627600491
# }
# }
# ,
# "01D919D2119E8BD00000005F": {
# "fo": "01D919D2119E64C000000033",
# "cc": 4,
# "ci": 6843499,
# "zo": 4294967295
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->
#
# %%%%%%%%%%%%%%%%%%%
# -------8-------
# 11
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p class="0" style="text-align: center; word-break: keep-all;"><span style="font-family: 굴림체, GulimChe; font-weight: bold; font-size: 12pt;">장학금</span></p><p class="0" style="word-break: keep-all;"><span style="font-family: 굴림체, GulimChe; font-weight: bold;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">10</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">조</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">장학금 수혜자격</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">)</span><span lang="EN-US" style="font-family: 굴림체, GulimChe;">\xa0</span><span style="font-family: 굴림체, GulimChe;">장학금의 지급은 학칙 제</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">61</span><span style="font-family: 굴림체, GulimChe;">조\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe;">장학금의 지급</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">)</span><span style="font-family: 굴림체, GulimChe;">에 따르며 이는 자유전공학부 소속 학부생으로서\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">1</span><span style="font-family: 굴림체, GulimChe;">학년에 한한다</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">.</span></p><p class="0" style="word-break: keep-all;"><span lang="EN-US" style="font-family: 굴림체, GulimChe;"></span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">1.\xa0</span><span style="font-family: 굴림체, GulimChe;">직전학기 이수 학점이\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">12</span><span style="font-family: 굴림체, GulimChe;">학점 이상인 자</span></p><p class="0" style="word-break: keep-all;"><span lang="EN-US" style="font-family: 굴림체, GulimChe;"></span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">2.\xa0</span><span style="font-family: 굴림체, GulimChe;">평점평균\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">3.5\xa0</span><span style="font-family: 굴림체, GulimChe;">이상인 자\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">&lt;</span><span style="font-family: 굴림체, GulimChe;">개정\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">2023. 2&gt;</span></p><p class="0" style="word-break: keep-all;"><span lang="EN-US" style="font-family: 굴림체, GulimChe;"></span></p><p class="0" style="word-break: keep-all;"><span style="font-family: 굴림체, GulimChe;"></span><span style="font-family: 굴림체, GulimChe;">\xa0</span><span style="font-family: 굴림체, GulimChe;"></span><o:p></o:p></p><p class="0" style="word-break: keep-all;"><span style="font-family: 굴림체, GulimChe; font-weight: bold;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">11</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">조</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">(</span><span style="font-family: 굴림체, GulimChe; font-weight: bold;">동점자 처리규정</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-family: 굴림체, GulimChe;">)</span></p><p class="0" style="word-break: keep-all;"><span lang="EN-US" style="font-family: 굴림체, GulimChe;"></span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체, GulimChe;">1.\xa0</span><span style="font-family: 굴림체, GulimChe;">총 이수학점이 많은 자</span></p><p class="0" style="word-break: keep-all;"><span lang="EN-US" style="font-family: 굴림체, GulimChe;"></span><span lang="EN-US" style="letter-spa ...
#
# $(document).ready(function() {
# });
#
# 장학금제10조(장학금 수혜자격) 장학금의 지급은 학칙 제61조 (장학금의 지급)에 따르며 이는 자유전공학부 소속 학부생으로서 1학년에 한한다.1. 직전학기 이수 학점이 12학점 이상인 자2. 평점평균 3.5 이상인 자 &lt;개정 2023. 2&gt; 제11조(동점자 처리규정)1. 총 이수학점이 많은 자2. 누적 평점이 높은 자3. 필수 이수학점이 많은 자(전필, 교필)4. 영어성적 등급이 높은 자 &lt;신설 2023. 2&gt;교내장학금 바로가기교외장학금 바로가기
# %%%%%%%%%%%%%%%%%%%
# -------9-------
# 12
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 11pt;">■ 유고결석 처리안내</span><br/><br/><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 11pt;">★ 단순질병은 유고결석에 해당되지 않습니다.</span><br/><span style="color: rgb(255, 0, 0); font-size: 12pt;">\xa0</span></p><table border="0" cellpadding="0" cellspacing="0" class="__se_tbl" style="border:1px solid #cccccc; border-left:0; border-bottom:0;"><tbody>\n<tr><td class="" style="border-width: 0px 0px 1px 1px; border-bottom-style: solid; border-left-style: solid; border-bottom-color: rgb(204, 204, 204); border-left-color: rgb(204, 204, 204); border-image: initial; border-top-style: initial; border-top-color: initial; border-right-style: initial; border-right-color: initial; width: 760px; height: 96px; background-color: rgb(255, 255, 255);"><p align="center" style="text-align: center; "><span style="color: rgb(255, 0, 0); font-size: 12pt;"><br/>유고결석 신청은 전자출결 시스템에서 본인이 직접 항목별 구비서류를 제출기한 내 제출하십시오.</span></p><div align="center" style="text-align: center;">(1개의 파일만 올릴 수 있으므로 반드시 1개로 묶어서 제출-해당 서류 누락 시 처리 불가)<br/></div><div align="center" style="text-align: center;"><br/><span style="font-size: 10pt;">※단,\xa0</span><u><span style="font-size: 10pt;">부득이한 사유</span></u><span style="font-size: 10pt;">로 제출기한 내 제출이 지연되었을 경우, 학부 사무실로 결강계와 구비서류를 제출할 수 있습니다.</span><br/>\xa0</div></td>\n</tr>\n</tbody>\n}--></div><table style="border-collapse:collapse;table-layout:fixed;border-top:none;border-left:none;border-bottom:none;border-right:none;mso-table-overlap:never;"><tbody><tr><td style="width:34.05pt;height:22.31pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #000000 0.28pt;border-left:solid #000000 0.28pt;border-bottom:solid #000000 0.28pt;border-right:solid #000000 0.28pt;" valign="middle"><p class="0" style="line-height:130%;text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 11pt;">번호</span></p></td><td style="width:184.05pt;height:22.31pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #000000 0.28pt;border-left:solid #000000 0.28pt;border-bottom:solid #000000 0.28pt;border-right:solid #000000 0.28pt;" valign="middle"><p class="0" style="line-height:130%;text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 11pt;">유고결석 사유</span></p></td><td style="width:65.28pt;height:22.31pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #000000 0.28pt;border-left:solid #000000 0.28pt;border-bottom:solid #000000 0.28pt;border-right:solid #000000 0.28pt;" valign="middle"><p class="0" style="line-height:130%;text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 11pt;">제출기한</span></p></td><td style="width:178.67pt;height:22.31pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #000000 0.28pt;border-left:solid #000000 0.28pt;border-bottom:solid #000000 0.28pt;border-right:solid #000000 0.28pt;" valign="middle"><p class="0" style="line-height:130%;text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: 돋움체, DotumChe, AppleGothic; font-size: 11pt;">구비서류</span></p></td></tr><tr><td style="width:34.05pt;height:21.31pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #000000 0.28pt;border-left:solid #000000 0.28pt;border-bottom:solid #000000 0.28pt;border-right:solid #000000 0.28pt;" valign="middle"><p class="0" style="line-height:130%;text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span lang="EN-US" style="font-family: 돋 ...
# $(document).ready(function() {
# });
#
# 번호 : 1
# 유고결석 사유 : 직계존속 또는 형제자매의 사망
# 제출기한 : 1주 이내
# 구비서류 : 사망진단서, 가족관계증명원
#
# 번호 : 2
# 유고결석 사유 : 입원치료 또는 불가능한 질병의 치료
# 제출기한 : 3주 이내
# 구비서류 : 입퇴원 확인서, 진단서, 의사 소견서(결석일시, 치료 일자 및 요양 기간 등 명시)
#
# 번호 : 3
# 유고결석 사유 : 병역법에 의한 각종 징소집 및 징병검사
# 제출기한 : 당일
# 구비서류 : 정부기관 발행 공문서 또는 관련 통지서
#
# 번호 : 4
# 유고결석 사유 : 기타 총장이 허가한 경우
# 제출기한 : 1주 이내
# 구비서류 : 학(부)과 혹은 담당교수 지도의 교육실습, 현장견학 등 참가
#
# 번호 : 5
# 유고결석 사유 : 지도교수가 공식적으로 포함되어 있는 공모전, 경진대회, 학회 등 (시상식 포함)
# 제출기한 : 1주 이내
# 구비서류 : 학부에 요청에 따라 관련 서류가 추가 될 수 있으며 교내 행사의 경우, 해당 학(부)과 혹은 부서에서 학교 내 문서를 이용하여 일괄요청 가능
#
# 번호 : 6
# 유고결석 사유 : 개인적인 공모전, 경진대회, 학회 등 (시상식 포함)
# 제출기한 : 1주 이내
# 구비서류 : 학부에 요청에 따라 관련 서류가 추가 될 수 있으며 교내 행사의 경우, 해당 학(부)과 혹은 부서에서 학교 내 문서를 이용하여 일괄요청 가능
#
# 번호 : 7
# 유고결석 사유 : 학(부)과 혹은 담당교수 지도의 교육실습, 현장견학 등 참가
# 제출기한 : 1주 이내
# 구비서류 : 지도교수의 허가관련 증빙, 참가 확인서, 위의 항목에 준한 문서
#
# 번호 : 8
# 유고결석 사유 : 학교의 요청에 따른 교내외 주요행사 참가
# 제출기한 : 1주 이내
# 구비서류 : 학교의 승인 및 추천을 받아 학교 대표로 외부 교육, 연수, 훈련, 행사 참가
#
# 번호 : 9
# 유고결석 사유 : 취업 시험 또는 진학 시험에 응시
# 제출기한 : 당일
# 구비서류 : 없음
#
# 번호 : 10
# 유고결석 사유 : 취업 시험 또는 진학 시험에 응시
# 제출기한 : 당일
# 구비서류 : 없음
# }--><!--[data-hwpjson]{

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
