# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "항공전자정보공학부_data"

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url = """http://college.kau.ac.kr/web/pages/gc75207h.do
http://college.kau.ac.kr/web/pages/gc88320h.do
http://college.kau.ac.kr/web/pages/gc41450h.do
http://college.kau.ac.kr/web/pages/gc33586h.do
http://college.kau.ac.kr/web/pages/gc33107h.do
http://college.kau.ac.kr/web/pages/gc25269h.do
http://college.kau.ac.kr/web/pages/gc57133h.do
http://college.kau.ac.kr/web/pages/gc34148h.do
http://college.kau.ac.kr/web/pages/gc56242h.do
http://college.kau.ac.kr/web/pages/gc46574h.do
http://college.kau.ac.kr/web/pages/gc64611h.do
http://college.kau.ac.kr/web/pages/gc95126h.do
http://college.kau.ac.kr/web/pages/gc76002h.do
http://college.kau.ac.kr/web/pages/gc93262h.do
http://college.kau.ac.kr/web/pages/gc51872h.do
http://college.kau.ac.kr/web/pages/gc31236h.do
http://college.kau.ac.kr/web/pages/gc52423h.do
"""
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
    if jj == 9 or jj == 13:
        f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
        answer_db = csv.writer(f)
        answer_db.writerow([str(jj), "", url_list[jj]])
        f.close()
        continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < 6:
            tp += 1
        elif "<html lang" in temp_text and tp == 6:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == 6 and "</html>" in temp_text:
            break
        elif tp == 6 and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == 6 and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == 6 and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == 6 and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == 6:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc75207h.do', 'http://college.kau.ac.kr/web/pages/gc88320h.do', 'http://college.kau.ac.kr/web/pages/gc41450h.do', 'http://college.kau.ac.kr/web/pages/gc33586h.do', 'http://college.kau.ac.kr/web/pages/gc33107h.do', 'http://college.kau.ac.kr/web/pages/gc25269h.do', 'http://college.kau.ac.kr/web/pages/gc57133h.do', 'http://college.kau.ac.kr/web/pages/gc34148h.do', 'http://college.kau.ac.kr/web/pages/gc56242h.do', 'http://college.kau.ac.kr/web/pages/gc46574h.do', 'http://college.kau.ac.kr/web/pages/gc64611h.do', 'http://college.kau.ac.kr/web/pages/gc95126h.do', 'http://college.kau.ac.kr/web/pages/gc76002h.do', 'http://college.kau.ac.kr/web/pages/gc93262h.do', 'http://college.kau.ac.kr/web/pages/gc51872h.do', 'http://college.kau.ac.kr/web/pages/gc31236h.do', 'http://college.kau.ac.kr/web/pages/gc52423h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 32
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>학부장 인사말</h3>', '</div>', '<div class="article_102">', '<h4 style="font-size: 29px;">항공전자정보공학부<br/><br/><img alt="" src="data:image/png;base64,..."/><br style="clear: both;"/></h4><p style="line-height: 1.8;"><span style="font-size: 17px;">항공전자정보공학부는 1952년 개교와 함께 우리나라 최초의 전자통신 분야 학과로 출발하여 지금까지 우리나라의 전자, 통신, 컴퓨터 분야의 발전에 지대한 공헌을 해 왔으며, 오랜 전통 아래 우수한 연구와', '엄격한 전공 교육을 통하여 국내 관련 분야 발전을 선도하고 수많은 졸업생들을 배출함으로써 높은 명성을 유지하고 있습니다. 특히 우리 학부는 국가 전략사업의 핵심인 항공전자, 전자, 정보통신 분야에서', '중추적인 역할을 할 창의력과 실무능력을 갖춘 고급기술 인력을 양성하고 있으며 이를 위하여 항공전자 및 ICT 분야의 특성화된 교육을 하고 있습니다.</span></p><p style="line-height: 1.8; font-size: 17px;">', '<br/>', '현재 우리 학부는 2015년 기존의 항공전자 및 전자공학전공과 정보통신공학전공을 통합한 항공전자정보공학부로 새롭게 출범하여 새로운 도약을 추진해 나가고 있으며, 이러한 학부 통합을 통하여 변화하는', '사회를 선도해 나갈 창의적이고 융합적인 인재의 양성에 박차를 가하고 있습니다.<br/>', '<br/>', '우리 학부에 입학한 학생은 기초과학, 수학, 전산학 등으로 구성되는 전공 기초 과목을 수강한 후, 통신 및 신호처리, 마이크로파 및 집적회로, 항공전자 및 제어시스템, 컴퓨터시스템 및 네트워크, 반도체', '및 디스플레이의 5개 트랙으로 구성된 심화전공 교과과정에 따라 학생이 원하는 진로와 관심 분야에 부합하는 자율적이고 체계적인 교육을 받게 됩니다. 또한 특성화된 각 분야 교과과정마다 이론과 실험실습을', '병행하여 현장 적응능력을 향상시키고 요소설계 과목 및 종합설계 과목을 통한 설계 실습을 의무화 함으로써 공학자로서의 소양과 독자적인 설계능력을 갖춘 고급기술 인력을 육성하고 있습니다. 특히 차별화된', '항공전자 분야의 교과과정과 다양한 연계/융합전공 과정을 통하여 특성화되고 융합적 역량을 가진 경쟁력 있는 인재를 양성하고 있습니다. <br/>', '<br/>', '현재 항공전자정보공학부 졸업생들은 첨단 분야의 CEO 뿐만 아니라 국책연구기관 및 우수기업의 연구개발 분야에서 핵심적인 역할을 수행하면서 국가 산업발전에 크게 기여하고 있습니다. 우리 학부는 앞으로도', '창의적이고 융합적인 역량을 가진 미래의 지도적 인재 양성을 통하여 국가 발전에 계속 이바지할 것입니다.', '</p><p style="line-height: 1.8;">', '<br/>', '</p><h4 class="sign" style="text-align: center;"><p style="line-height: 1.8;"><span style="font-size: 14pt;">한국항공대학교 항공전자정보공학부 학부장 최희환</span></p></h4>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 학부장 인사말
#
# 항공전자정보공학부항공전자정보공학부는 1952년 개교와 함께 우리나라 최초의 전자통신 분야 학과로 출발하여 지금까지 우리나라의 전자, 통신, 컴퓨터 분야의 발전에 지대한 공헌을 해 왔으며, 오랜 전통 아래 우수한 연구와
# 엄격한 전공 교육을 통하여 국내 관련 분야 발전을 선도하고 수많은 졸업생들을 배출함으로써 높은 명성을 유지하고 있습니다. 특히 우리 학부는 국가 전략사업의 핵심인 항공전자, 전자, 정보통신 분야에서
# 중추적인 역할을 할 창의력과 실무능력을 갖춘 고급기술 인력을 양성하고 있으며 이를 위하여 항공전자 및 ICT 분야의 특성화된 교육을 하고 있습니다.
#
# 현재 우리 학부는 2015년 기존의 항공전자 및 전자공학전공과 정보통신공학전공을 통합한 항공전자정보공학부로 새롭게 출범하여 새로운 도약을 추진해 나가고 있으며, 이러한 학부 통합을 통하여 변화하는
# 사회를 선도해 나갈 창의적이고 융합적인 인재의 양성에 박차를 가하고 있습니다.
#
# 우리 학부에 입학한 학생은 기초과학, 수학, 전산학 등으로 구성되는 전공 기초 과목을 수강한 후, 통신 및 신호처리, 마이크로파 및 집적회로, 항공전자 및 제어시스템, 컴퓨터시스템 및 네트워크, 반도체
# 및 디스플레이의 5개 트랙으로 구성된 심화전공 교과과정에 따라 학생이 원하는 진로와 관심 분야에 부합하는 자율적이고 체계적인 교육을 받게 됩니다. 또한 특성화된 각 분야 교과과정마다 이론과 실험실습을
# 병행하여 현장 적응능력을 향상시키고 요소설계 과목 및 종합설계 과목을 통한 설계 실습을 의무화 함으로써 공학자로서의 소양과 독자적인 설계능력을 갖춘 고급기술 인력을 육성하고 있습니다. 특히 차별화된
# 항공전자 분야의 교과과정과 다양한 연계/융합전공 과정을 통하여 특성화되고 융합적 역량을 가진 경쟁력 있는 인재를 양성하고 있습니다.
#
# 현재 항공전자정보공학부 졸업생들은 첨단 분야의 CEO 뿐만 아니라 국책연구기관 및 우수기업의 연구개발 분야에서 핵심적인 역할을 수행하면서 국가 산업발전에 크게 기여하고 있습니다. 우리 학부는 앞으로도
# 창의적이고 융합적인 역량을 가진 미래의 지도적 인재 양성을 통하여 국가 발전에 계속 이바지할 것입니다.
#
# 한국항공대학교 항공전자정보공학부 학부장 최희환
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 32
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.article_102 .scroller { overflow-x: auto; }', '.article_102 .scroller table { min-width: 600px; }', '@media (max-width: 767px) {', '.article_102 h4 {', 'font-size: 20px;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>학부교육목표</h3>', '</div>', '<div class="article_102" style="padding-top: 0px;">', '<h4>학부 교육목적</h4>', '<p style="font-size: 17px; font-weight: 300; line-height: 26px;">항공전자정보공학부는 국가 전략산업인 항공우주산업, 전자산업,', 'IT산업의 핵심인 항공전자, 전자 및 정보통신분야에서 중추적인 역할을 할 창의력과 실무능력을 갖춘 고급기술인력을 양성하는 것을 목표로 한다.</p>', '<br/><br/>', '<h4 style="padding-bottom: 15px;">학부 교육목표</h4>', '<div class="scroller">', '<table class="table_01">\n<tbody><tr>\n<th style="font-weight: 400;">구분</th>\n<th colspan="2" style="font-weight: 400;">창의적 인재</th>\n<th colspan="2" style="font-weight: 400;">실용적 인재</th>\n<th colspan="2" style="font-weight: 400;">지도적 인재</th>\n</tr>\n<tr>\n<td>항공전자정보공학부</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 기반교육강화를 통해 공학이론 이해력과 응용력을 갖추고,\n체계화된 전공이론 및 설계실습 교육으로 문제해결 능력을 갖춘 창의적 공학자 양성</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 산업현장에서 능동적으로 실무를 담당할 수 있는 전문기술인 양성</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 항공우주기술의 발전에 기여할 합리적 인성, 의사전달 능력 및 사회적 책무성을 지닌 글로컬 리더 양성</td>\n</tr>\n<tr>\n<td>전자 및 항공전자공학전공</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 우주항공, 수학 및 기초 과학 지식을 습득하고 이를 활용할 수 있는 확고한 기반 능력을 갖춘 창의적 공학자 양성</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 일반적인 전자공학기술을 습득하고, 다양한 산업 표준 도구의 활용능력을 배양하여,\n요구된 조건에 부합하는 시스템 및 공정을 설계하고, 산업현장 문제에 적용할 수 있는 능동적인 실무 능력을 갖춘 전문기술인 양성<br/>\n<br/>\n- 항공우주기술의 발전에 기여할 수 있는 특성화된 전문기술인 양성<br/>\n</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 논리적 사고, 의사전달 능력 및 사회적 윤리의식을 갖추고\n공학 기술의 사회적 영향을 파악할 수 있는 사회 지도적 인성을 갖춘 글로컬 리더 양성</td>\n</tr>\n<tr>\n<td>정보통신공학전공</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 수학 및 기초과학 등 기반교육의 강화를 통해 전공이론을 체계적으로 습득하고 응용할 수 있는 능력을 갖춘 전문가 양성<br/>\n<br/>- 항공우주분야에 대한 기본 소양 및 지식을 갖춘 정보통신 전문가 양성<br/>\n<br/>- 통신 및 정보공학의 상호 유기적 교육을 통해 정보통신 분야의 복합적이고 창의적인 능력을 갖춘 전문가 양성</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 전공이론 및 실습, 설계에 대한 체계적 교육을 통해 이론을 실무에 응용할 수 있는 실무적 전문가 양성</td>\n<td colspan="2" style="line-height: 30px; text-align: left; padding: 19px;">- 합리적 사고, 의사전달 능력 및 사회적 책무성을 지닌 글로컬 전문가 양성</td>\n</tr>\n</tbody></table>', '</div>', '</div>', '</div>', '</body>']
# $(document).ready(function() {
# });
#
# .article_102 .scroller { overflow-x: auto; }
# .article_102 .scroller table { min-width: 600px; }
# @media (max-width: 767px) {
# .article_102 h4 {
# font-size: 20px;
# }
# }
#
# 학부교육목표
#
# 학부 교육목적
# 항공전자정보공학부는 국가 전략산업인 항공우주산업, 전자산업,
# IT산업의 핵심인 항공전자, 전자 및 정보통신분야에서 중추적인 역할을 할 창의력과 실무능력을 갖춘 고급기술인력을 양성하는 것을 목표로 한다.
#
# 학부 교육목표
#
# 구분 : 항공전자정보공학부
# 창의적 인재 : 기반교육강화를 통해 공학이론 이해력과 응용력을 갖추고, 체계화된 전공이론 및 설계실습 교육으로 문제해결 능력을 갖춘 창의적 공학자 양성
# 실용적 인재 : 산업현장에서 능동적으로 실무를 담당할 수 있는 전문기술인 양성
# 지도적 인재 : 항공우주기술의 발전에 기여할 합리적 인성, 의사전달 능력 및 사회적 책무성을 지닌 글로컬 리더 양성
#
# 구분 : 전자 및 항공전자공학전공
# 창의적 인재 : 우주항공, 수학 및 기초 과학 지식을 습득하고 이를 활용할 수 있는 확고한 기반 능력을 갖춘 창의적 공학자 양성
# 실용적 인재 : 일반적인 전자공학기술을 습득하고, 다양한 산업 표준 도구의 활용능력을 배양하여, 요구된 조건에 부합하는 시스템 및 공정을 설계하고, 산업현장 문제에 적용할 수 있는 능동적인 실무 능력을 갖춘 전문기술인 양성, 항공우주기술의 발전에 기여할 수 있는 특성화된 전문기술인 양성
# 지도적 인재 : 논리적 사고, 의사전달 능력 및 사회적 윤리의식을 갖추고 공학 기술의 사회적 영향을 파악할 수 있는 사회 지도적 인성을 갖춘 글로컬 리더 양성
#
# 구분 : 정보통신공학전공
# 창의적 인재 : 수학 및 기초과학 등 기반교육의 강화를 통해 전공이론을 체계적으로 습득하고 응용할 수 있는 능력을 갖춘 전문가 양성, 항공우주분야에 대한 기본 소양 및 지식을 갖춘 정보통신 전문가 양성, 통신 및 정보공학의 상호 유기적 교육을 통해 정보통신 분야의 복합적이고 창의적인 능력을 갖춘 전문가 양성
# 실용적 인재 : 전공이론 및 실습, 설계에 대한 체계적 교육을 통해 이론을 실무에 응용할 수 있는 실무적 전문가 양성
# 지도적 인재 : 합리적 사고, 의사전달 능력 및 사회적 책무성을 지닌 글로컬 전문가 양성
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 16
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>연혁</h3>', '</div>', '<div class="scroller">', '<table class="table_01">\n<tbody>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1952년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa06월 16일 개교 시 통신과 설치.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1959년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0응용전자과 신설.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1968년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0통신과를 항공통신공학과, 응용전자과를 항공전자공학과로 학과 명칭 변경.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1979년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0대학원 항공전자공학과 석사과정 설치.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1984년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0항공통신공학과를 항공통신정보공학과로 학과 명칭 변경.</td>\n</tr>\n<tr>\n<td rowspan="2" style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1988년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0대학원 항공통신정보공학과 석사과정, 항공전자공학과 박사과정 신설.</td>\n</tr>\n<tr>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0전자계산학과 신설.</td>\n</tr>\n<tr>\n<td rowspan="3" style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1994년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0전자계산학과를 컴퓨터공학과로 학과 명칭 변경.</td>\n</tr>\n<tr>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0대학원 컴퓨터공학과 석사과정 신설.</td>\n</tr>\n<tr>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0대학원 항공통신정보공학과 박사과정 신설.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">1996년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0대학원 컴퓨터공학과 박사과정 신설.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">2000년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0항공전자공학과, 항공통신공학과, 컴퓨터공학과를 "전자.정보통신.컴퓨터공학부"로 통합.<br/>\n"전자공학전공/항공전자공학전공/정보통신공학전공/컴퓨터공학전공"으로 4전공 신설</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">2002년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0전자공학전공/항공전자공학전공을 "전자 및 항공전자공학전공"으로 통합.</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">2004년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0전자.정보통신.컴퓨터공학부를 "항공전자 및 정보통신공학부"로 학부명칭 변경.<br/>\n컴퓨터공학전공을 "컴퓨터정보공학전공"으로 전공명칭 변경</td>\n</tr>\n<tr>\n<td style="padding: 9px; font-weight: 400; color: #185196; background-color: #f5f5f5;">2015년</td>\n<td colspan="6" style="text-align: left; font-weight: 400; padding: 9px;">\xa0"컴퓨터정보공학전공"을 소프트웨어학과로 분리.<br/>\n"전자 및 항공전자공학전공"과 "정보통신공학전공"을 항공전자정보공학부로 통합</td>\n</tr>\n</tbody>\n</table>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 연혁
#
# 구분 : 1952년
# 비고 : 6월 16일 개교 시 통신과 설치.
#
# 구분 : 1959년
# 비고 : 응용전자과 신설.
#
# 구분 : 1968년
# 비고 : 통신과를 항공통신공학과, 응용전자과를 항공전자공학과로 학과 명칭 변경.
#
# 구분 : 1979년
# 비고 : 대학원 항공전자공학과 석사과정 설치.
#
# 구분 : 1984년
# 비고 : 항공통신공학과를 항공통신정보공학과로 학과 명칭 변경.
#
# 구분 : 1988년
# 비고 : 대학원 항공통신정보공학과 석사과정, 항공전자공학과 박사과정 신설.
# 비고 : 전자계산학과 신설.
#
# 구분 : 1994년
# 비고 : 전자계산학과를 컴퓨터공학과로 학과 명칭 변경.
# 비고 : 대학원 컴퓨터공학과 석사과정 신설.
# 비고 : 대학원 항공통신정보공학과 박사과정 신설.
#
# 구분 : 1996년
# 비고 : 대학원 컴퓨터공학과 박사과정 신설.
#
# 구분 : 2000년
# 비고 : 항공전자공학과, 항공통신공학과, 컴퓨터공학과를 "전자.정보통신.컴퓨터공학부"로 통합.
# 비고 : "전자공학전공/항공전자공학전공/정보통신공학전공/컴퓨터공학전공"으로 4전공 신설.
#
# 구분 : 2002년
# 비고 : 전자공학전공/항공전자공학전공을 "전자 및 항공전자공학전공"으로 통합.
#
# 구분 : 2004년
# 비고 : 전자.정보통신.컴퓨터공학부를 "항공전자 및 정보통신공학부"로 학부명칭 변경.
# 비고 : 컴퓨터공학전공을 "컴퓨터정보공학전공"으로 전공명칭 변경.
#
# 구분 : 2015년
# 비고 : "컴퓨터정보공학전공"을 소프트웨어학과로 분리.
# 비고 : "전자 및 항공전자공학전공"과 "정보통신공학전공"을 항공전자정보공학부로 통합
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 447
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.prs_list .prs_info {', 'width: 260px;', '}', '#ljw {', 'font-size: small;', 'margin-bottom: 9px;', '}', '@media (max-width: 767px) {', '.prs_list .prs_info li {', 'margin-bottom: 3px;', 'font-size: 12px;', '}', '#ljw {', 'margin-bottom: 3px;', 'font-size: 10px;', '}', '}', '@media (max-width: 1199px) {', '#ljw {', 'margin-bottom: 3px;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>구성원</h3>', '</div>', '', '<ul class="menu_tab menu_tab2">', '<li><a class="selected" href="#panel_01">교수진</a></li>', '<li><a href="#panel_02">행정직원/학생회</a></li>', '</ul>', '<ul class="panel">', '', '<li id="panel_01">', '<ul class="prs_list">', '', '<li>', '', '<span class="portrait"> <img src="https://portal.kau.ac.kr/faculty/prof_RGE8VU.jpg"/> ', '</span>', '', '<h4>권용진<span>교수</span></h4>', '', '', '', '<ul class="prs_info" style="line-height: 1.2;">', '<li><span>학력 : </span>한국항공대학교 및 일본 교토대 대학원</li>', '', '<li><span>전공분야 : </span>논리회로설계, 정보보안, 정보검색</li>', '<li>전자관 217호</li>', '<li><span class="mail">yjkwon@kau.ac.kr</span></li>', '', '', '', '<li class="contact"> <a href="mailto:yjkwon@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a>', '', '</li>', '', '</ul>', '', '</li>', '', '', '<li>', '', '<span class="portrait"> <img src="/conts_img/eie_www/introduce/prof/김광은 교수.jpg"/> ', '</span>', '', '<h4>김광은<span>교수</span></h4>', '', '', '', '<ul class="prs_info" style="line-height: 1.2;">', '<li><span>학력 : </span>고려대, Univ. Wisconsin-Madison</li>', '', '<li><span>전공분야 : 반도체소자공정, 크린룸공정, 전력반도체</span></li>', '<li>전자관 303호</li>', '<li><span class="mail">kke@kau.ac.kr</span></li>', '', '<li class="homepage"><a href="https://eeb303.wixsite.com/eeb303">Homepage</a></li>', '', '<li class="contact"> <a href="mailto:kke@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a>', '<a href="https://eeb303.wixsite.com/eeb303"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a>--&gt;', '</li>', '', '</ul>', '', '</li>', '', '<li> <span class="portrait"> <img src="https://portal.kau.ac.kr/faculty/prof_BE6VTW.jpg"/> </span>', '<h4>김영진<span>교수</span></h4>', '<ul class="prs_info" style="line-height: 1.2;">', '<li><span>학력 : </span>경북대 및 한국과학기술원</li>', '<li><span>전공분야 : </span>RFIC 설계</li>', '<li>전자관 305호</li>', '<li><span class="mail">youngjinkim@kau.ac.kr</span></li>', '<li class="contact"> <a href="mailto:youngjinkim@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a>', '', '</li>', '</ul>', '</li>', '<li> <span class="portrait"> <img src="https://portal.kau.ac.kr/faculty/prof_PS5BOT.jpg"/> </span>', '<h4>김재곤<span>교수</span></h4>', '<ul class="prs_info" style="line-height: 1.1;">', '<li><span>학력 : </span>경북대학교 및 KAIST</li>', '<li><span>전공분야 : </span>비디오 신호처리/코딩, 디지털방송 미디어, 미디어 컨버전스</li>', '<li>전자관 312호</li>', '<li><span class="mail">jgkim@kau.ac.kr</span></li>', '<li class="homepage"><a href="http://mclab.kau.ac.kr" target="_blank">http://mclab.kau.ac.kr</a></li>', '<li class="contact"> <a href="mailto:jgkim@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="http://mclab.kau.ac.kr"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '<li> <span class="portrait"> <img src="https://portal.kau.ac.kr/faculty/prof_J99OQW.jpg"/> </span>', '<h4>김태환<span>교수</span></h4>', '<ul class="prs_info" style="line-height: 1.1;">', '<li><span>학력 : </span>연세대학교, KAIST</li>', '<li><span>전공분야 : </span>Microarchitectures for Special-purpose DSP System</li>', '<li>전자관 204호</li>', '<li><span class="mail">taehwan.kim@kau.ac.kr</span></li>', '<li class="homepage"><a href="http://cas.kau.ac.kr" target="_blank">http://cas.kau.ac.kr</a></li>', '<li class="contact"> <a href="mailto:taehwan.kim@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="http://cas.kau.ac.kr"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>',  ...
#
# $(document).ready(function() {
# });
#
# .prs_list .prs_info {
# width: 260px;
# }
# #ljw {
# font-size: small;
# margin-bottom: 9px;
# }
# @media (max-width: 767px) {
# .prs_list .prs_info li {
# margin-bottom: 3px;
# font-size: 12px;
# }
# #ljw {
# margin-bottom: 3px;
# font-size: 10px;
# }
# }
# @media (max-width: 1199px) {
# #ljw {
# margin-bottom: 3px;
# }
# }
#
# 구성원
#
# 교수진
# 행정직원/학생회
#
# 권용진교수
#
# 학력 : 한국항공대학교 및 일본 교토대 대학원
#
# 전공분야 : 논리회로설계, 정보보안, 정보검색
# 전자관 217호
# yjkwon@kau.ac.kr
#
# 이메일
#
# 김광은교수
#
# 학력 : 고려대, Univ. Wisconsin-Madison
#
# 전공분야 : 반도체소자공정, 크린룸공정, 전력반도체
# 전자관 303호
# kke@kau.ac.kr
#
# Homepage
#
# 이메일
# 홈페이지--&gt;
#
# 김영진교수
#
# 학력 : 경북대 및 한국과학기술원
# 전공분야 : RFIC 설계
# 전자관 305호
# youngjinkim@kau.ac.kr
# 이메일
#
# 김재곤교수
#
# 학력 : 경북대학교 및 KAIST
# 전공분야 : 비디오 신호처리/코딩, 디지털방송 미디어, 미디어 컨버전스
# 전자관 312호
# jgkim@kau.ac.kr
# http://mclab.kau.ac.kr
# 이메일 홈페이지
#
# 김태환교수
#
# 학력 : 연세대학교, KAIST
# 전공분야 : Microarchitectures for Special-purpose DSP System
# 전자관 204호
# taehwan.kim@kau.ac.kr
# http://cas.kau.ac.kr
# 이메일 홈페이지
#
# 나종화교수
#
# 학력 : Wayne State 및 Arizona 대학원
# 전공분야 : 컴퓨터구조, 광컴퓨터 시스템
# 전자관 311호
# jwna@kau.ac.kr
# 홈페이지
# 이메일 홈페이지
#
# 노영섭교수
#
# 학력 : KAIST, 고려대
# 전공분야 : 임베디드시스템/SW, 이동통신
# 전자관 201호
# youngroh@kau.ac.kr
# http://embedded.kau.ac.kr
# 이메일 홈페이지
#
# 도규봉교수
#
# 학력 : 미국 VIRGINIATECH
# 전공분야 : 광정보공학, 광통신, 전자홀로그램
# 전자관 218호
# kdoh@kau.ac.kr
# 이메일
#
# 박형래교수
#
# 학력 : 한국항공대학교, 연세대, 미국 Syracuse Univ
# 전공분야 : 이동통신, CDMA, 레이다 신호처리
# 전자관 210호
# hrpark@kau.ac.kr
# http://mercury.kau.ac.kr/hrpark
# 이메일 홈페이지
#
# 백중환교수
#
# 학력 : 한국항공대학교 및 미국 OKLAHOMA 주립대 대학원
# 전공분야 : 영상처리, 패턴인식
# 전자관 215호
# jhbaek@kau.ac.kr
# http://mercury.kau.ac.kr/cvip
# 이메일 홈페이지
#
# 신명훈교수
#
# 학력 : KAIST, KAIST
# 전공분야 : 박막 태양전지 및 광에너지 분야, 고속 광/전자 신호처리, LCD 및 정보 디스플레이 소자
# 전자관 303호
# mhshin@kau.ac.kr
# https://sites.google.com/site/kauenplab
# 이메일 홈페이지
#
# 안준선교수
#
# 학력 : 서울대 및 한국과학기술원
# 전공분야 : 프로그래밍언어, 프로그램분석, 병렬화컴파일러, 정보검색
# 전자관 219호
# jsahn@kau.ac.kr
# http://sslab.kau.ac.kr
# 이메일 홈페이지
#
# 오병태교수
#
# 학력 : 연세대, Univ. of Southern California
# 전공분야 : Multimedia processing &amp; codec, 3D video system
# 전자관 203호
# byungoh@kau.ac.kr
# http://multimedia.kau.ac.kr
# 이메일 홈페이지
#
# 이동준교수
#
# 학력 : KAIST, KAIST
# 전공분야 : 모바일 네트워크/서비스
# 전자관 212호
# ldj@kau.ac.kr
# 이메일
#
# 이명진교수
#
# 학력 : KAIST, KAIST
# 전공분야 : 멀티미디어 통신 시스템, 동영상 압축
# 전자관 206호
# artistic@kau.ac.kr
# https://sites.google.com/view/mclkau
# 이메일 홈페이지
#
# 이우경교수
#
# 학력 : KAIST, UCL
# 전공분야 : 인공위성 시스템, 위성전자탑재체, UWB 광대역 통신
# 전자관 319호
# wklee@kau.ac.krhttp://satecslab.kau.ac.kr
#
# 이재욱교수
#
# 학력 : 한양대 및 한국과학기술원
# 전공분야 : Microwave and Millimeterwave, EM Field Analysis and Simulation, High Power Amplifier Design, Microwave and Millimeter-Wave Packaging, High Power and Non-Planar Antenna &amp; UWB Antenna Design, Passive Component Design in Millimeter-Wave EMI/EMC
# 전자관 308호
# jwlee1@kau.ac.kr
# http://mercury.kau.ac.kr/mmsl
# 이메일 홈페이지
#
# 이재환교수
#
# 학력 : 서울대, University of Maryland
# 전공분야 : 분산 컴퓨팅, 빅데이터 및 클라우드
# 전자관 202호
# jlee@kau.ac.kr
# 이메일
#
# 이형근교수
#
# 학력 : 서울대, 서울대 대학원
# 전공분야 : 항법, 위치정보, 교통
# 전자관 318호hyknlee@kau.ac.krhttp://nisl.kau.ac.k
# 이메일
#
# 이효창교수
#
# 학력 : 한양대
# 전공분야 : 플라즈마, 반도체/디스플레이 공정
# 전자관 310호
# plasma@kau.ac.kr
# https://hclee1.wixsite.com/plasma
# 이메일 홈페이지
# 전재홍교수
#
# 학력 : 서울대 및 서울대 대학원
# 전공분야 : 디스플레이, 박막소자
# 전자관 306호
# jjh123@kau.ac.kr
# 이메일
#
# 정동원교수
#
# 학력 : 서울대학교, Georgia Tech
# 전공분야 : 무인항공기/로봇제어, 관성항법 및 센서
# 전자관 302호
# djung@kau.ac.krhttps://control.kau.ac.kr/
# 이메일    홈페이지
#
# 정영호교수
#
# 학력 : 한국과학기술원, 한국과학기술원
# 전공분야 : 이동 통신 시스템, 통신 신호처리
# 전자관 207호
# yhjung@kau.ac.kr
# 이메일
#
# 정윤호교수
#
# 학력 : 연세대학교
# 전공분야 : 정보통신용 SoC설계
# 전자관 304호
# yjung@kau.ac.kr
# http://soc.kau.ac.kr
# 이메일 홈페이지
#
# 조춘식교수
#
# 학력 : 서울대 및 미국 Colorado대 대학원
# 전공분야 : RF 및 Microwave 회로 설계
# 전자관 208호
# cscho@kau.ac.krhttps://sites.google.com/view/hfel이메일 홈페이지
#
# 최지훈교수
#
# 학력 : KAIST, KAIST
# 전공분야 : 통신신호처리, 통신모뎀설계, 러닝기반 신호처리
# 전자관 211호
# jihoon@kau.ac.krhttps://sites.google.com/view/jihoonkau/
# 이메일
#
# 최희환교수
#
# 학력 : KAIST, KAIST
# 전공분야 : Display, Plasma
# 전자관 307호
# choehh@kau.ac.kr
# 이메일
#
# 한정희교수
#
# 학력 : 서울대, University of Michigan, Ann Arbor
# 전공분야 : Self-organizing wireless networks, Bioinformatics grid computing
# 전자관 205호
# junghee@kau.ac.kr
# http://mercury.kau.ac.kr/mobicom
# 이메일
# 홈페이지
#
# 황진영교수
#
# 학력 : KAIST, University of Michigan, Ann Arbor
# 전공분야 : 반도체 소자
# 전자관 301호
# jinhwang@kau.ac.kr
# 이메일
#
# 김지혜행정직원
#
# 담당업무 : 교과편성, 장학, 학부 예산 편성
#
# 전자관 309호
# jhkim@kau.ac.kr
#
# 이메일
#
# 임수정행정직원
#
# 담당업무 : 학부행정, 대학원업무, 졸업 사정
# 전자관 309호
# sjlim@kau.ac.kr
# 이메일
#
# 이수정학생회장
#
# su000311@naver.com
# 이메일
#
# 권정욱부학생회장
#
# tslier@naver.com
# 이메일
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 14
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>학부 운영내규</h3>', '</div>', '<object data="/conts_img/eie_www/introduce/학부운영내규_2023.pdf" height="845" id="pdf" type="application/pdf" width="100%"></object>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 학부 운영내규
#
# %%%%%%%%%%%%%%%%%%%
# -------5-------
# 21
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.img {', 'display: block;', 'margin-left: auto;', 'margin-right: auto;', 'width: auto;', '}', '</style>', '<div class="sub_tit" style="margin-bottom: 10px;">', '<h3>조직도<br/><br type="_moz"/><img alt="" src="data:image/png;base64,..."/><br style="clear:both;"/></h3>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# .img {
# display: block;
# margin-left: auto;
# margin-right: auto;
# width: auto;
# }
#
# 조직도
#
# %%%%%%%%%%%%%%%%%%%
# -------6-------
# 48
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit" style="margin-bottom: 15px;">', '<h3>오시는 길</h3>', '</div>', '<div class="article_401 article_401_r" style="background-color: #ffffff;">', '<span class="img">', '', '<div class="root_daum_roughmap root_daum_roughmap_landing" id="daumRoughmapContainer1597373213005" style="margin-bottom: 25px;"></div>', '', '<script charset="UTF-8" class="daum_roughmap_loader_script" src="https://ssl.daumcdn.net/dmaps/map_js_init/roughmapLoader.js"></script>', '', '<script charset="UTF-8">', 'new daum.roughmap.Lander({', '"timestamp": "1597373213005",', '"key": "2znun",', '"mapWidth": "330",', '"mapHeight": "220"', '}).render();', '</script>', '</span>', '<h4 style="text-align: left; color: #24282c;">위치</h4>', '<br/>', '<p style="float: left; text-align: left; font-size: 16px;">(10540) 경기도 고양시 덕양구 항공대학로 76 한국항공대학교 전자관 309호</p>', '<br/>', '<br/>', '<p style="float: left; text-align: left; font-size: 16px; padding-bottom: 30px;">Room# 309, Electronics Building, Korea Aerospace University,', '76, Hanggongdaehak-ro, Deogyang-gu, Goyang-si, Gyeonggi-do, Republic of Korea', '</p>', '<br/>', '<h4 style="text-align: left; color: #24282c;">전화번호 / 이메일</h4>', '<br/>', '<p style="float: left; text-align: left; font-size: 16px;"><span style="font-weight: 500;">Call: </span>+82 –2-300–0120, 0130</p>', '<br/>', '<br/>', '<p style="float: left; text-align: left; font-size: 16px;"><span style="font-weight: 500;">Email: </span>jhkim@kau.ac.kr, sjlim@kau.ac.kr</p>', '<br/>', '<br/>', '<p style="float: left; text-align: left; font-size: 16px;"><span style="font-weight: 500;">Fax: </span>+82 –2-3159-9257</p>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 오시는 길
#
# new daum.roughmap.Lander({
# "timestamp": "1597373213005",
# "key": "2znun",
# "mapWidth": "330",
# "mapHeight": "220"
# }).render();
#
# 위치
#
# (10540) 경기도 고양시 덕양구 항공대학로 76 한국항공대학교 전자관 309호
#
# Room# 309, Electronics Building, Korea Aerospace University,
# 76, Hanggongdaehak-ro, Deogyang-gu, Goyang-si, Gyeonggi-do, Republic of Korea
#
# 전화번호 / 이메일
#
# Call: +82 –2-300–0120, 0130
#
# Email: jhkim@kau.ac.kr, sjlim@kau.ac.kr
#
# Fax: +82 –2-3159-9257
# %%%%%%%%%%%%%%%%%%%
# -------7-------
# 99
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.article_102 .status {', 'display: block;', 'margin-left: auto;', 'margin-right: auto;', 'width: auto;', '}', '.article_102 .chief {', 'display: block;', 'float: left;', 'width: auto;', 'height: auto;', 'max-width: 300px;', 'margin-left: 0;', 'margin-right: 15px;', 'margin-bottom: 16px;', '}', '.article_102 {', 'padding-top: 0px;', '}', '.article_102 h4 {', 'padding-bottom: 13px;', '}', '.article_102 p {', 'font-size: 17px;', '}', '#conmajorul {', 'font-size: 17px;', 'font-weight: normal;', 'margin: 10px;', 'line-height: 2;', '}', '#conmajorli {', 'list-style-type: square;', 'list-style-position: inside;', '}', '@media (max-width: 767px) {', '.article_102 .chief {', 'float: none;', 'display: block;', 'margin: 0 auto;', 'margin-bottom: 20px;', 'width: 77%;', '}', '.article_102 h4{', 'font-size: 20px;', '}', '.menu_tab4 li {', 'width: 50%;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>전공 소개</h3>', '</div>', '', '<ul class="menu_tab menu_tab4">', '<li><a href="#panel_02">전자 및 항공전자공학 전공</a></li>', '<li><a href="#panel_03">정보통신공학 전공</a></li>', '</ul>', '<ul class="panel">', '<li id="panel_01">', '<div class="article_102">', '</div>', '</li>', '<li id="panel_02">', '<div class="article_102">', '<h4>전자 및 항공전자공학 전공</h4>', '<p>', '전자및항공전자공학 전공에서는 국가 전략사업인 항공산업, 전자 및 ICT 산업의 핵심인 항공전자 분야와 전자공학분야에서', '중추적인 역할을 할 창의력과 실무능력을 갖춘 고급기술 인력을 양성 하고 있습니다.', '전자공학 분야인 반도체, 컴퓨터, 통신, 자동제어, 마이크로파 및 안테나, 영상처리, VLSI회로설계 관련 내용과 항공전자 분야인', '위성항행시스템(GPS), 레이다, 전파항행, 항공기전자장치, 항공통신시스템, 자동항행시스템, 차세대 항행시스템, 무인기 등과', '관련한 이론과 실험실습을 병행함으로써 현장 적응능력을 향상시키고 종합설계 등 설계 실습을 의무화 함으로써,', '공학자로서의 소양과 독자적인 설계능력을 갖춘 고급기술 인력을 육성하고 있습니다.', '</p>', '</div>', '</li>', '<li id="panel_03">', '<div class="article_102">', '<h4>정보통신공학 전공</h4>', '<p>', '정보통신공학 전공에서는 ICT 산업 및 4차 산업혁명의 핵심인 정보통신 분야에서 중추적인 역할을 할', '창의력과 실무능력을 갖춘 고급기술 인력을 양성 하고 있습니다.', '컴퓨터네트워크, IoT, 빅데이터, 정보보안, 하드웨어설계, 시스템소프트웨어, 멀티미디어, 인공지능, 이동통신,', '신호처리, 방송 미디어 기술 등 다양한 ICT 융합분야와 관련된 이론과 실험실습을 병행함으로써 현장 적응능력을 향상시키고', '종합설계 등 설계 실습을 의무화 함으로써, 공학자로서의 소양과 독자적인 설계능력을 갖춘 고급기술 인력을 육성하고 있습니다.', '</p></div></li>', '</ul>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# .article_102 .status {
# display: block;
# margin-left: auto;
# margin-right: auto;
# width: auto;
# }
# .article_102 .chief {
# display: block;
# float: left;
# width: auto;
# height: auto;
# max-width: 300px;
# margin-left: 0;
# margin-right: 15px;
# margin-bottom: 16px;
# }
# .article_102 {
# padding-top: 0px;
# }
# .article_102 h4 {
# padding-bottom: 13px;
# }
# .article_102 p {
# font-size: 17px;
# }
# #conmajorul {
# font-size: 17px;
# font-weight: normal;
# margin: 10px;
# line-height: 2;
# }
# #conmajorli {
# list-style-type: square;
# list-style-position: inside;
# }
# @media (max-width: 767px) {
# .article_102 .chief {
# float: none;
# display: block;
# margin: 0 auto;
# margin-bottom: 20px;
# width: 77%;
# }
# .article_102 h4{
# font-size: 20px;
# }
# .menu_tab4 li {
# width: 50%;
# }
# }
#
# 전공 소개
#
# 전자 및 항공전자공학 전공
# 정보통신공학 전공
#
# 전자 및 항공전자공학 전공
#
# 전자및항공전자공학 전공에서는 국가 전략사업인 항공산업, 전자 및 ICT 산업의 핵심인 항공전자 분야와 전자공학분야에서
# 중추적인 역할을 할 창의력과 실무능력을 갖춘 고급기술 인력을 양성 하고 있습니다.
# 전자공학 분야인 반도체, 컴퓨터, 통신, 자동제어, 마이크로파 및 안테나, 영상처리, VLSI회로설계 관련 내용과 항공전자 분야인
# 위성항행시스템(GPS), 레이다, 전파항행, 항공기전자장치, 항공통신시스템, 자동항행시스템, 차세대 항행시스템, 무인기 등과
# 관련한 이론과 실험실습을 병행함으로써 현장 적응능력을 향상시키고 종합설계 등 설계 실습을 의무화 함으로써,
# 공학자로서의 소양과 독자적인 설계능력을 갖춘 고급기술 인력을 육성하고 있습니다.
#
# 정보통신공학 전공
#
# 정보통신공학 전공에서는 ICT 산업 및 4차 산업혁명의 핵심인 정보통신 분야에서 중추적인 역할을 할
# 창의력과 실무능력을 갖춘 고급기술 인력을 양성 하고 있습니다.
# 컴퓨터네트워크, IoT, 빅데이터, 정보보안, 하드웨어설계, 시스템소프트웨어, 멀티미디어, 인공지능, 이동통신,
# 신호처리, 방송 미디어 기술 등 다양한 ICT 융합분야와 관련된 이론과 실험실습을 병행함으로써 현장 적응능력을 향상시키고
# 종합설계 등 설계 실습을 의무화 함으로써, 공학자로서의 소양과 독자적인 설계능력을 갖춘 고급기술 인력을 육성하고 있습니다.
#
# %%%%%%%%%%%%%%%%%%%
# -------8-------
# 328
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.menu_tab li {', 'width: 50%;', '}', '.table_01 th {', 'font-weight: 400;', 'color: #244b85;', '}', '.table_01 td {', 'padding: 7px;', 'color: #000000;', '}', '.article_303 ul li {', 'color: #000000;', '}', '@media (max-width: 767px) {', '.menu_tab li {', 'width: 100%;', '}', '.menu_tab li a {', 'height: 30px;', 'line-height: 28px;', '}', '#pnp {', 'padding: 0;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>세부 전공별 교과과정 및 진로</h3>', '</div>', '', '<ul class="menu_tab menu_tab5">', '<li><a class="selected" href="#panel_01">항공전자 및 제어시스템</a></li>', '<li><a href="#panel_02">마이크로파 및 집적회로</a></li>', '<li><a href="#panel_03">반도체 및 디스플레이</a></li>', '<li><a href="#panel_04">통신시스템 및 멀티미디어</a></li>', '<li><a href="#panel_05">컴퓨터정보시스템 및 네트워크</a></li>', '</ul>', '<ul class="panel">', '', '<li id="panel_01">', '<div class="article_303">', '<h4>개요</h4>', '<ul>', '<li>- 항공 우주 기술은 국가 전략 6대 기술 분야의 하나로서', '향후 10여년간 기술개발 예산이 12조원으로 계획되어 있는 전략 기술임</li>', '<li>- 항공우주기술은 국가와 민족의 생존에 필수적인 국방전략기술로서 자력 확보의 필요성이 있음</li>', '<li>- 본 대학교는 학칙 제1조에 명시된 "항공우주과학을 중심으로 한" 교육이념과 체계를 지향하여 왔음.', '개교 이래 52년을 통해서 배출된 졸업생들이(1만 4천여명) 국가 항공우주산업 발전에 기여한 실적과, 교직원, 동문', '및 학생들의 높은 소명의식을 바탕으로 항공우주분야의 전문가를 양성하는 특화된 환경을 제공함</li>', '<li>- 실시간성과 고신뢰성 특성을 갖는 항공전자 및 위성 연구개발 인력양성을 위한 전문화된 교육 체계를 갖추고 있음</li>', '</ul>', '</div>', '<div class="article_303">', '<h4>필요 능력</h4>', '<ul>', '<li>(1) 항공 및 위성체 탑재 전자장치 시스템의 이해<br/>', '- 레이더, 항법 및 인공위성, 위성항행에 사용되는 이론을 이해하고 이를 바탕으로 시스템을 분석하거나 설계할 수 있는 기초 지식을 갖추어야 함.</li>', '<br/>', '<li>(2) 항공전자 및 인공위성 탑재체, 레이다 운용 시나리오 및 SW/HW 설계 구현 능력<br/>', '- GNSS, 공항감시레이다, 방위 및 거리 측정장치, 로봇제어 시스템에 사용되는 운용 시나리오를 구현하는 알고리즘을 설계하고', '이를 실현하는 장치를 설계, 구현할 수 있는 시스템 분석 능력을 겸비</li>', '<br/>', '<li>(3) 관련 교과목<br/>', '- 우주/항공/제어 분야에 특화되어 있는 교과목 체계에서 일정 학점 이상을 수강해야 함.<br/>', '- 항공/위성전자 시스템 개요를 소개하는 기본 교과목을 필수적으로 수강하고 항행/레이다/제어 분야로 세분화되는 특화과목을 통해 심도 깊은 내용을 수강하게 됨.', '(예시: 위성전자시스템, 항공전자시스템, 항공통신공학, 항공항법전자, 레이더공학, 제어시스템설계, 위성통신공학, 원격탐사센서공학)</li>', '<br/>', '<li>(4) 기타 사항<br/>', '- 항공우주 사업은 고도의 전문성을 갖춘 인력을 요구하며 진입장벽이 높은 특화된 분야이고 향후 꾸준하게 신규인력의 수요가 있을 것으로 예상됨.<br/>', '- 한국항공대학교는 국내 유일하게 항공 및 우주 분야에 특화된 교과과정을 제공하여 전문성을 갖춘 인재 양성을 위한 교과과정을 제공하고 있음.</li>', '</ul>', '</div>', '<div class="article_303">', '<h4>관련 직업</h4>', '<ul>', '<li>공항공사 관리직, 항공우주분야 연구원, 군수업체,', '국방/군 연구기관 연구원, 항공기술자, 대기업 연구원</li>', '</ul>', '</div>', '<div class="article_303">', '<h4>취업 가능처 / 창업 가능분야</h4>', '<ul>', '<li>대기업 및 중견기업, 정부출연 연구소, 공공기관 (예: 삼성탈레스, LIG넥스원,', '국방과학기술연구소(ADD), 대한항공, 한국전자통신연구원, 세트렉아이, 한화그룹, 기상청, KAI, 한국공항공사)</li>', '</ul>', '</div>', '<div class="article_303">', '<h4>교과과정<br/></h4>', '<div class="scroller">', '<a href="/web/cmm/imageSrc.do?path=f3315a1280302f24b8b90d14775e2deb&amp;physical=723c0489371c528b87db6272d7f093bc26d9648f470735edd06ee97750e8d2fbd0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" target="_blank"></a><a href="/web/cmm/imageSrc.do?path=f3315a1280302f24b8b90d14775e2deb&amp;physical=103431536b8171dccea5d9b62f45a8c44e424bf68b75a4a76dd5d6b6b59e3c0cd0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" target="_blank"><img src="/web/cmm/imageSrc.do?path=f3315a1280302f24b8b90d14775e2deb&amp;physical=103431536b8171dccea5d9b62f45a8c44e424bf68b75a4a76dd5d6b6b59e3c0cd0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" title="????001.jpg" width="100%"/></a><br style="clear: both;"/><br style="clear: both;"/>', '</div>', '</div>', '</li>', '', '<li id="panel_02">', '<div class="article_303">', '<h4>개요</h4>', '<ul>', '<li>- 앞으로 다가올 세대는 무수하고 다양한 무선 및 전파 환경 속에서 상호간(사람과 사람, 사람과 사물, 사물과 사물)', '의 지속적인 연결 속에서 살게 될 것이며 이의 효과적이고 효율적인 이용 방안 및 관리가 필요함.</li>', '<li>- 최근, 차세대 무선 환경에 필요한 고성능 RF집적회로기술, 사물통신에 필요한 극소형RF집적회로 기술,', '무선 센서네트워크를 위한 저전력의 RF집적회로기술, 바이오 및 헬스케어, 자동차, 항공기, 우주산업, 군사용 및 무인이동체', '등에 필요한 특수집약화된 RF집적회로기술 등이 미래기술로 각광을 받을 것으로 판 ...
#
# $(document).ready(function() {
# });
#
# .menu_tab li {
# width: 50%;
# }
# .table_01 th {
# font-weight: 400;
# color: #244b85;
# }
# .table_01 td {
# padding: 7px;
# color: #000000;
# }
# .article_303 ul li {
# color: #000000;
# }
# @media (max-width: 767px) {
# .menu_tab li {
# width: 100%;
# }
# .menu_tab li a {
# height: 30px;
# line-height: 28px;
# }
# #pnp {
# padding: 0;
# }
# }
#
# 세부 전공별 교과과정 및 진로
#
# 항공전자 및 제어시스템
# 마이크로파 및 집적회로
# 반도체 및 디스플레이
# 통신시스템 및 멀티미디어
# 컴퓨터정보시스템 및 네트워크
#
# 개요
#
# - 항공 우주 기술은 국가 전략 6대 기술 분야의 하나로서
# 향후 10여년간 기술개발 예산이 12조원으로 계획되어 있는 전략 기술임
# - 항공우주기술은 국가와 민족의 생존에 필수적인 국방전략기술로서 자력 확보의 필요성이 있음
# - 본 대학교는 학칙 제1조에 명시된 "항공우주과학을 중심으로 한" 교육이념과 체계를 지향하여 왔음.
# 개교 이래 52년을 통해서 배출된 졸업생들이(1만 4천여명) 국가 항공우주산업 발전에 기여한 실적과, 교직원, 동문
# 및 학생들의 높은 소명의식을 바탕으로 항공우주분야의 전문가를 양성하는 특화된 환경을 제공함
# - 실시간성과 고신뢰성 특성을 갖는 항공전자 및 위성 연구개발 인력양성을 위한 전문화된 교육 체계를 갖추고 있음
#
# 필요 능력
#
# (1) 항공 및 위성체 탑재 전자장치 시스템의 이해
# - 레이더, 항법 및 인공위성, 위성항행에 사용되는 이론을 이해하고 이를 바탕으로 시스템을 분석하거나 설계할 수 있는 기초 지식을 갖추어야 함.
#
# (2) 항공전자 및 인공위성 탑재체, 레이다 운용 시나리오 및 SW/HW 설계 구현 능력
# - GNSS, 공항감시레이다, 방위 및 거리 측정장치, 로봇제어 시스템에 사용되는 운용 시나리오를 구현하는 알고리즘을 설계하고
# 이를 실현하는 장치를 설계, 구현할 수 있는 시스템 분석 능력을 겸비
#
# (3) 관련 교과목
# - 우주/항공/제어 분야에 특화되어 있는 교과목 체계에서 일정 학점 이상을 수강해야 함.
# - 항공/위성전자 시스템 개요를 소개하는 기본 교과목을 필수적으로 수강하고 항행/레이다/제어 분야로 세분화되는 특화과목을 통해 심도 깊은 내용을 수강하게 됨.
# (예시: 위성전자시스템, 항공전자시스템, 항공통신공학, 항공항법전자, 레이더공학, 제어시스템설계, 위성통신공학, 원격탐사센서공학)
#
# (4) 기타 사항
# - 항공우주 사업은 고도의 전문성을 갖춘 인력을 요구하며 진입장벽이 높은 특화된 분야이고 향후 꾸준하게 신규인력의 수요가 있을 것으로 예상됨.
# - 한국항공대학교는 국내 유일하게 항공 및 우주 분야에 특화된 교과과정을 제공하여 전문성을 갖춘 인재 양성을 위한 교과과정을 제공하고 있음.
#
# 관련 직업
#
# 공항공사 관리직, 항공우주분야 연구원, 군수업체,
# 국방/군 연구기관 연구원, 항공기술자, 대기업 연구원
#
# 취업 가능처 / 창업 가능분야
#
# 대기업 및 중견기업, 정부출연 연구소, 공공기관 (예: 삼성탈레스, LIG넥스원,
# 국방과학기술연구소(ADD), 대한항공, 한국전자통신연구원, 세트렉아이, 한화그룹, 기상청, KAI, 한국공항공사)
#
# 교과과정
#
# 개요
#
# - 앞으로 다가올 세대는 무수하고 다양한 무선 및 전파 환경 속에서 상호간(사람과 사람, 사람과 사물, 사물과 사물)
# 의 지속적인 연결 속에서 살게 될 것이며 이의 효과적이고 효율적인 이용 방안 및 관리가 필요함.
# - 최근, 차세대 무선 환경에 필요한 고성능 RF집적회로기술, 사물통신에 필요한 극소형RF집적회로 기술,
# 무선 센서네트워크를 위한 저전력의 RF집적회로기술, 바이오 및 헬스케어, 자동차, 항공기, 우주산업, 군사용 및 무인이동체
# 등에 필요한 특수집약화된 RF집적회로기술 등이 미래기술로 각광을 받을 것으로 판단되며,
# 마이크로파뿐만 아니라 밀리미터파 나아가 테라헤르츠파 기술이 광범위하게 회로 및 시스템 설계에 적용될 것으로 보임.
# - 취업은 일반 대기업, 대기업내의 연구소, 중견기업, 공공기관, 정부출연 연구소 등 매우 다양
#
# 필요 능력
#
# (1) 마이크로파의 기본원리 및 회로설계 능력
# - 전파의 기본원리 및 전파의 전달특성, IC 및 부품레벨에서의 설계방법, 시스템레벨로의 응용 확장능력이 요구됨.
# 이를 위해 다양한 상용 설계 툴 경험 및 제작경험이 필요함. 또한 인턴 수행을 통해 현장 경험을 쌓는 것도 중요함
#
# (2) 관련 교과목
# - 학교 수업은 기본적으로 전자파 개념과 회로설계 관련 수업을 많이 수강하는 것이 좋고, 특별히 회로 및 전파시스템 설계경험을 많이 할 수 있는 과목을 수강할 것을 권장함.
# - 기초적인 통신 및 신호전달 지식도 필요하므로 신호 및 시스템, 레이다 공학 관련 과목을 수강할 것을 권장함
# - 소자 및 부품레벨의 특성파악도 중요하므로 반도체 및 디스플레이분야의 수강도 권장함.
#
# (3) 영어
# - 기업마다 다소 차이는 있으나 TOEIC 800점 이상은 안정권
# - 중요한 국제문서 및 최신기술의 분석능력 및 현황파악능력, 논문작성에 필수적임.
#
# (4) 기타 사항
# - 하드웨어 및 시스템 분석에 관심 있는 학생에게 적합함.
# - 국외/내적으로 전문 인력이 많지 않은 상황이므로 인력수요가 증가할 것으로 보임
#
# 관련 직업
#
# 회로설계, 안테나설계, 마이크로파 부품, 시스템설계 능력을 요구하는 회사
#
# 취업 가능처 / 창업 가능분야
#
# 공공기관, 정부출연 연구소, 전기전자 부문 제조업, 항공/자동차 제조업,
# 각종 부품/소재 제조업, 회로설계 회사, Fabless 회사, ICT 및 부품관련 공공 연구원,
# IoT 관련 기업, 의료기기 제조업, 바이오 ICT 제조업, 안테나 제조업
#
# 교과과정
#
# 개요
#
# - 반도체 분야는 반도체 재료를 활용하여 전통적으로 마이크로프로세서, 메모리 등에 활용되는 미세한 반도체 소자를 연구하며,
# 반도체 소자 및 제작 공정은 최근 디스플레이 및 태양전지 분야에도 응용이 되고 있음.
# - 반도체 및 디스플레이 분야는 각종 재료의 물성, 전기 및 광학적 특성에 대한 이해를 바탕으로 하며 소자의 설계 기술, 공정 기술과 평가 기술 등이 있음.
# - 국내 반도체 및 디스플레이 산업은 자동차 산업(완성차+부품)보다 규모가 크고, 관련된 부품, 소재, 장비산업과 함께 한국경제에서 중요한 비중을 차지하고 있음
# (2013년 관세청 품목별 수출액 기준).
# - 전 세계적으로 기술 및 인력 수요가 많고, 관련 산업의 규모가 클 뿐만 아니라 기술 발전의 속도가 빠름.
#
# 필요 능력
#
# (1) 전공 분야의 이해
# - 반도체 및 디스플레이 분야는 아날로그 및 디지털시스템, AC/DC회로, 소자, 공정, 품질과 연계되기 때문에 전공 지식에 대한 이해와 활용 능력이 중요함.
# - 개별 교과에 대한 이해와 더불어 여러 교과를 통합적으로 이해하고 활용할 줄 하는 능력이 필요함.
#
# (2) 관련 교과목
# - 학교 수업은 기본적으로 항공전자정보공학부에 개설된 반도체 및 디스플레이 분야의 전문화 및 실무과정의 교과목을 수강하는 것이 좋음.
# - 기초 지식이 필수적이므로 관련 기초 및 발전영역의 선택 과목을 수강할 것을 권장함.
# - 논리적 사고 및 수식에 대한 해석과 이해가 정확하고 빠르면 유리하므로, 관련 교과에 대한 수강을 권장함.
#
# (3) 영어
# - 외국 서적이나 문서를 읽고 이해하기에 어려움이 없어야 함.
#
# (4) 기타 사항
# - 분석적 사고방식과 통합적 사고방식이 동시에 요구되는 경우가 많음.
# - 협업이 필요한 경우가 많기 때문에 전공에 기반한 지식, 유연한 사고, 도전적 사고방식, 리더쉽, 인접 학문 분야에 대한 이해도가 요구됨.
#
# 관련 직업
#
# 반도체/디스플레이/태양광 분야의 소자 설계직, 공정직, 평가직
#
# 취업 가능처 / 창업 가능분야
#
# 공공기관, 정부출연 연구소, 반도체공정 개발회사, 디스플레이 제조업,
# 소재 개발 회사, 회로설계 회사, 부품 및 소재 관련 분야, 항공 및 자동차 소재 개발 분야,
# 의료기기 제조업, 바이오 산업
#
# 교과과정
#
# 개요
#
# - 통신 분야는 고부가 가치의 ICT 분야로 우리나라가 세계적인 경쟁력을 가지고 있는 산업분야로, 5G 등 미래 기술도 국내 기술이 선도하고 있음
# - 멀티미디어(영상, 음성/음향) 분야는 디지털 방송, 모바일 비디오, 인터넷 스트리밍 등 고화질의 비디오 서비스가 확산되고 있으며,
# 자동차, 공장 자동화, 보안 등 산업 전반에 음성/영상/비젼 기술이 적용되고 있음
# - 특히, 이동통신, 스마트폰, 디지털TV 등 통신 인프라 산업 발전과 더불어 고화질 비디오 등 멀티미디어 서비스가 고부가가치 산업으로 부각되고 있음
# - 취업은 일반 대기업(통신사, 가전사, 자동차 등), 대기업내의 연구소, 지상파 방송사, 케이블TV, IPTV, 중견기업, 공공기관, 정부출연 연구소 등 매우 다양
#
# 필요 능력
#
# (1) 통신/멀티미디어 기본원리 및 기본 프로그래밍 능력
# - 멀티미디어신호처리 및 통신이론에 대한 기본 원리에 대한 이해와 이를 바탕으로 알고리즘을 구현할 수 있는 기본적인 프로그래밍 능력이 요구됨
#
# (2) 알고리즘 설계, 임베디드SW 및 HW 설계구현 능력의 겸비
# - 알고리즘을 설계하고 이를 실현하는 음성/음향, 영상 및 통신 부품 및 시스템을 설계, 구현할 수 있는 임베디드SW 능력과 HW 설계 능력을 겸비하는 것이 중요함
#
# (3) 관련 교과목
# - 기본적으로 수학 및 신호처리 관련 기본 교과목을 수강하는 것이 필요하고, 멀티미디어 신호처리 또는 통신이론/시스템의 전공 교과목 수강이 필요함
# - 프로그래밍, 임베디드SW, 회로설계 등 SW/HW 설계 및 구현 관련 교과목을 수강할 것을 권장함
#
# (4) 영어
# - 기업마다 다소 차이는 있으나 TOEIC 800점 이상은 안정권
# - 중요한 국제문서 및 최신기술의 분석능력 및 현황파악능력, 논문작성에 필수적임
#
# (5) 기타 사항
# - 일반적으로 통신시스템 분야와 멀티미디어 분야 중 하나의 분야로 진로를 선택함
# - 통신 및 멀티미디어 분야는 국내 기술이 세계적인 경쟁력을 가지고 있는 분야로 지속적인 인력수요가 많은 분야임
# - 특히, 멀티미디어는 산업 전반에 활용되는 핵심 기술 분야로 다양한 분야로 진출 할 수 있음
#
# 관련 직업
#
# 무선통신/유선통신, 영상/음성/음향, 영상통신 관련 알고리즘 설계,
# 임베디드SW/HW 설계 및 구현 연구 개발자, 통신 및 멀티미디어 서비스 회사 종사자, 방송국 기술자
#
# 취업 가능처 / 창업 가능분야
#
# 공공기관, 정부출연 연구소, 관련분야 대기업 및 벤처기업, 통신 및 멀티미디어 서비스업,
# 항공/자동차 산업, 방송/미디어 관련 산업, 멀티미디어 시스템 및 컨텐츠 개발
#
# 교과과정
#
# 개요
#
# - 산업체의 IT 분야의 전문가 양성 요구가 매우 높아지고 있으나 관련 고급 인력이 부족한 상황
# - 컴퓨터 하드웨어/소프트웨어의 융합형 교육을 통한 차별화된 전문가 양성 필요
# - 비 메모리 시스템 반도체 설계 전문 인력 양성을 위해서는 컴퓨터시스템의 교육이 필요
# - 진화하는 네트워크 및 정보 통신 환경을 위한 전문가 양성의 필요성이 증가하고 있음
# - 자동차, 항공 등의 임베디드 시스템 전문가 인력이 부족함
# - 컴퓨터 시스템 및 통신망에서 발생하는 정보 누출, 도청 등의 공격과 위협을 예방하고
# 전자적 침해 행위를 대비하기 위한 컴퓨터 보안 전문 인력 양성의 필요가 대두됨
#
# 필요 능력
#
# (1) 컴퓨터 하드웨어, 시스템 반도체 설계 및 임베디드 시스템 개발 능력
# - 디지털 논리회로, 컴퓨터 구조, SoC 구조 등의 기본 이론 학습, Verilog HD에 기반한 디지털 시스템 설계 과정 실습, 임베디드 시스템 설계 및 개발
#
# (2) 소프트웨어설계, 개발 및 테스팅 경험
# - 기본적으로 C, Java 등의 프로그래밍 경험이 있어야 함. 이를 위해 다양한 소프트웨어 개발 프로젝트를 경험해보는 것이 필요함
# - 컴퓨터 알고리즘, 자료구조에 대한 설계 및 분석 능력이 필요함
# - 인턴 수행을 통해 현장 경험을 쌓는 것이 중요함
#
# (3) 네트워크 및 정보통신 망 설계, 개발 및 시뮬레이션 경험
# - 물리계층부터 응용 계층까지 전반적인 네트워크 계층에 대한 깊은 지식과 이해가 필요함
# - 네트워크 프로토콜 설계, 실습 및 시뮬레이션 경험 필요
#
# (4) 정보보호 및 보안에 대한 전문 지식 및 능력
# - 컴퓨터 및 통신망에 대한 기초 지식을 기반으로 문제 분석 능력을 익혀야 함
# - 네트워크 및 시스템 보안, 암호 기술 등에 대한 기본 지식과 실습 경험이 필요
#
# (5) 관련 교과목
# - 학교 수업은 컴퓨터 하드웨어/소프트웨어 시스템, 통신망에 대한 기반 지식을 습득할 수 있는 과목을 수강할 것을 권장함
# - 또한, 실습 경험이 중요하므로, 텀프로젝트 및 실험, 실습이 포함된 과목을 수강할 것
#
# (6) 영어
# - 기업마다 다소 차이는 있으나 TOEIC 800점 이상 필요함
#
# 관련 직업
#
# 컴퓨터 시스템 개발자 및 관리자, 컴퓨터 소프트웨어 프로그래머, 통신망 개발자 및 관리자,
# 정보 보호 및 보안 전문가, 자동차/항공 등의 임베디드 시스템 개발자, 디지털 시스템 반도체 개발자
#
# 취업 가능처 / 창업 가능분야
#
# 공공기관, 정부출연 연구소, 관련분야 대기업 및 벤처기업, ICT서비스,
# 금융서비스, 통신서비스, 항공/자동차 전장 시스템, 인터넷서비스 및 게임 산업,
# 모바일 앱 개발, 정보보호 서비스 및 관련 시스템 소프트웨어, 반도체 설계 관련 분야
#
# 교과과정
#
# %%%%%%%%%%%%%%%%%%%
# -------10-------
# 34
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.table_01 th {', 'font-weight: 400;', 'color: #244b85;', '}', '.table_01 td {', 'color: #000000;', '}', '.article_102 .scroller { overflow-x: auto; }', '.article_102 .scroller table { min-width: 600px; }', '@media (max-width: 767px) {', '#no_padding {', 'padding: 0;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>졸업요건</h3>', '</div>', '<div class="article_102" style="padding-top: 0px;">', '<div class="scroller">', '<table class="table_01">\n<tbody>\n<tr>\n<th rowspan="2">학부(과)</th>\n<th rowspan="2">학번구분</th>\n<th colspan="3">학칙/학칙 시행세칙</th>\n<th colspan="3">학부 운영내규</th>\n<th rowspan="2">비고</th>\n</tr>\n<tr>\n<th>졸업학점</th>\n<th>편입생<br/>졸업학점</th>\n<th>교양이수학점<br/>(편입생제외)</th>\n<th colspan="3">소속 전공학점<br/>(전필+전선)</th>\n</tr>\n<tr>\n<td rowspan="12">항공전자정보공학부</td>\n<td>2012 및 이전</td>\n<td>140</td>\n<td>70</td>\n<td id="no_padding">교양필수</td>\n<td colspan="3" rowspan="2">60<br/>(학부 내 타전공 9학점 인정)</td>\n<td></td>\n</tr>\n<tr>\n<td id="no_padding">2013~2017</td>\n<td rowspan="2">130</td>\n<td>65</td>\n<td>19</td>\n<td></td>\n</tr>\n<tr>\n<td>2018</td>\n<td>65</td>\n<td>37</td>\n<td colspan="3">66<br/>(2016학번 편입생 60)</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="6"></td>\n</tr>\n<tr>\n<th rowspan="2">학번구분</th>\n<th rowspan="2">졸업학점</th>\n<th rowspan="2">교양이수학점<br/>(편입생제외)</th>\n<th colspan="1">단일전공</th>\n<th colspan="3">다전공</th>\n<th rowspan="2">비고</th>\n</tr>\n<tr>\n<th>심화전공</th>\n<th>복수전공</th>\n<th>부전공</th>\n<th>연계.융합전공</th>\n</tr>\n<tr>\n<td>2019</td>\n<td rowspan="2">130</td>\n<td>37</td>\n<td rowspan="2">69</td>\n<td rowspan="2">87</td>\n<td rowspan="2">69</td>\n<td rowspan="2">81</td>\n<td></td>\n</tr>\n<tr>\n<td>2020</td>\n<td>39</td>\n<td></td>\n</tr>\n<tr>\n<td>2014 및 이후</td>\n<td colspan="6">4학년 전공 1과목(3학점) 이상 이수<br/>\n(종합설계/창업형종합설계I,II, 현장실습 관련 과목 제외)</td>\n<td></td>\n</tr>\n<tr>\n<td>2014 및 이전</td>\n<td colspan="6">졸업인증제 기준점수 토익 600점</td>\n<td></td>\n</tr>\n<tr>\n<td>2015 및 이후</td>\n<td colspan="6">졸업인증제 기준점수 토익 730점<br/></td>\n<td></td>\n</tr>\n<tr>\n<td>2018 및 이후</td>\n<td colspan="6">SPACE인증 5개 분야 중 2개 이상 인증 취득<br/>\n(단, \'글로벌소통역량인증(토익 730점)\'은 필수 인증 취득)<br/>(단, 편입생 적용은 2016학번부터 적용)</td>\n<td></td>\n</tr>\n</tbody>\n</table>', '</div>', '</div>', '</div>', '</body>']
# $(document).ready(function() {
# });
#
# .table_01 th {
# font-weight: 400;
# color: #244b85;
# }
# .table_01 td {
# color: #000000;
# }
# .article_102 .scroller { overflow-x: auto; }
# .article_102 .scroller table { min-width: 600px; }
# @media (max-width: 767px) {
# #no_padding {
# padding: 0;
# }
# }
#
# 졸업요건
#
# 학부(과) : 항공전자정보공학부
# 학번구분 : 2012 및 이전
# 졸업학점 : 140
# 편입생 졸업학점 : 70
# 교양이수학점(편입생제외) : 교양필수
# 소속 전공학점(전필+전선) : 60 (학부 내 타전공 9학점 인정)
#
# 학번구분 : 2013~2017
# 졸업학점 : 130
# 교양이수학점(편입생제외) : 65
# 단일전공 심화전공 : 19
# 다전공 복수전공 :
# 다전공 부전공 :
# 다전공 연계.융합전공 :
# 비고 :
#
# 학번구분 : 2018
# 졸업학점 : 130
# 교양이수학점(편입생제외) : 65
# 소속 전공학점(전필+전선) : 37
# 소속 전공학점(전필+전선) : 66 (2016학번 편입생 60)
# 비고 :
#
# 학번구분 : 2019
# 졸업학점 : 130
# 교양이수학점(편입생제외) : 37
# 단일전공 심화전공 : 69
# 다전공 복수전공 : 87
# 다전공 부전공 : 69
# 다전공 연계.융합전공 : 81
# 비고 :
#
# 학번구분 : 2020
# 졸업학점 : 130
# 교양이수학점(편입생제외) : 37
# 단일전공 심화전공 : 69
# 비고 :
#
# 2014 및 이후 : 4학년 전공 1과목(3학점) 이상 이수 (종합설계/창업형종합설계I,II, 현장실습 관련 과목 제외)
# 졸업인증제 기준점수 토익 600점 (2014 및 이전)
# 졸업인증제 기준점수 토익 730점 (2015 및 이후)
# SPACE인증 5개 분야 중 2개 이상 인증 취득 (단, '글로벌소통역량인증(토익 730점)'은 필수 인증 취득) (단, 편입생 적용은 2016학번부터 적용) (2018 및 이후)
#
# %%%%%%%%%%%%%%%%%%%
# -------11-------
# 49
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.article_102 .chief {', 'display: block;', 'float: left;', 'width: auto;', 'height: auto;', 'max-width: 300px;', 'margin-left: 0;', 'margin-right: 15px;', 'margin-bottom: 40px;', '}', '@media (max-width: 767px) {', '.article_102 h4 {', 'font-size: 22px;', '}', '.article_102 .chief {', 'float: none;', 'display: block;', 'margin: 0 auto;', 'margin-bottom: 20px;', 'width: 77%;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>대학원 소개</h3>', '</div>', '<div class="article_102" style="padding-top: 0px;">', '<h4 style="padding-bottom: 13px;">항공전자정보공학과</h4>', '<p style="font-size: 17px;">', '본 대학원 학과는 미래 첨단 산업의 핵심기술인 통신, 자동제어, 전자파,', '영상처리, VLSI 회로설계, 레이다, 인공지능, 반도체, 컴퓨터를 포함하는 전자공학 분야와', '이들 세부 전공의 종합체로서의 항공전자공학분야의 이론롸 실험을 통한 첨단 기술개발 능력의', '배양을 통해 첨단전자 및 항공전자 관련 산업체, 연구소 및 대학교에서 지도자적 역할을 담당할', '수 있는 고급인력의 양성을 목표로 합니다. 이를 위하여 석사과정 및 박사과정 대학원생을 대상으로', '심도 있는 연구와 교육을 실시하고 있습니다.', '</p>', '</div>', '<br/><br/><br/><br/><br/><br/>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# .article_102 .chief {
# display: block;
# float: left;
# width: auto;
# height: auto;
# max-width: 300px;
# margin-left: 0;
# margin-right: 15px;
# margin-bottom: 40px;
# }
# @media (max-width: 767px) {
# .article_102 h4 {
# font-size: 22px;
# }
# .article_102 .chief {
# float: none;
# display: block;
# margin: 0 auto;
# margin-bottom: 20px;
# width: 77%;
# }
# }
#
# 대학원 소개
#
# 항공전자정보공학과
#
# 본 대학원 학과는 미래 첨단 산업의 핵심기술인 통신, 자동제어, 전자파,
# 영상처리, VLSI 회로설계, 레이다, 인공지능, 반도체, 컴퓨터를 포함하는 전자공학 분야와
# 이들 세부 전공의 종합체로서의 항공전자공학분야의 이론롸 실험을 통한 첨단 기술개발 능력의
# 배양을 통해 첨단전자 및 항공전자 관련 산업체, 연구소 및 대학교에서 지도자적 역할을 담당할
# 수 있는 고급인력의 양성을 목표로 합니다. 이를 위하여 석사과정 및 박사과정 대학원생을 대상으로
# 심도 있는 연구와 교육을 실시하고 있습니다.
#
# %%%%%%%%%%%%%%%%%%%
# -------12-------
# 213
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.article_303 ul li {', 'color: #000000;', '}', '.table_01 th {', 'font-weight: 400;', 'color: #244b85;', '}', '.table_01 td {', 'color: #000000;', '}', '.table_01 td a {', 'color: #24282c;', '}', '.menu_tab li {', 'width: 50%;', '}', '.img_c {', '/*width: 90%;*/', 'margin: auto;', 'padding: 5px;', '}', '@media (max-width: 767px) {', '.article_303 ul {', 'padding-left: 5px;', '}', '.menu_tab li {', 'width: 100%;', '}', '.menu_tab li a {', 'height: 30px;', 'line-height: 28px;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>연구그룹 소개</h3>', '</div>', '', '<ul class="menu_tab menu_tab5">', '<li><a class="selected" href="#panel_01">항공전자 및 제어시스템</a></li>', '<li><a href="#panel_02">마이크로파 및 집적회로</a></li>', '<li><a href="#panel_03">반도체 및 디스플레이</a></li>', '<li><a href="#panel_04">통신시스템 및 멀티미디어</a></li>', '<li><a href="#panel_05">컴퓨터정보시스템 및 네트워크</a></li>', '</ul>', '<ul class="panel">', '', '<li id="panel_01">', '<div class="article_303">', '<h4>연구 분야 설명</h4>', '<ul>', '<li>- 실시간성과 고신뢰성 특성을 갖는 항공전자 및 인공위성 시스템에 대한 특성화 연구</li>', '<li>- 미래의 인공위성 시스템 개발 및 활용을 위한 전자탑재체 장치 연구</li>', '<li>- 영상기반 무인항공기 유도 및 제어 기법 연구</li>', '<li>- 나노위성 3축 자세제어를 위한 가변속 제어모멘트자이로 연구 및 개발<br/>- UAM/AAM/위성 탑재용 안전인증 하드웨어 및 소프트웨어 연구 개발</li>', '</ul>', '</div>', '<div class="article_303">', '<h4>주요 연구 테마</h4>', '<ul>', '<li>- 레이다, 항공통신, 위성전자, 인공위성시스템, 위성항행시스템 등<br/><br/><img src="data:image/png;base64,..."/></li>', '<div class="img_c">', '</div>', '</ul>', '</div>', '<div class="article_303">', '<h4>연구진 구성</h4>', '<div class="scroller">', '<strong>', '</strong><strong>', '</strong><strong>', '</strong><table class="table_01">\n<tbody>\n<tr>\n<th>교수명</th>\n<th colspan="3">연구실명</th>\n<th colspan="2">홈페이지</th>\n</tr>\n\n<tr>\n<td>나종화</td>\n<td colspan="3">고신뢰성 임베디드 시스템<br/>(Dependable Embedded Systems Lab)</td>\n<td colspan="2"><a 0px;="" 255);"="" 255,="" background-color:="" baseline;="" courier="" data-auth="NotApplicable" data-linkindex="1" font-feature-settings:="" font-kerning:="" font-optical-sizing:="" font-variation-settings:="" href="https://sites.google.com/view/dependable-systems-kau/dependable-systems-lab?authuser=0" inherit;="" margin:="" monospace;="" new",="" padding:="" rel="noopener noreferrer" rgb(255,="" style="border: 0px; font-variant-numeric: inherit; font-variant-east-asian: inherit; font-variant-alternates: inherit; font-stretch: inherit; font-size: small; line-height: inherit; font-family: " target="_blank" vertical-align:="">https://sites.google.com/view/dependable-systems-kau/dependable-systems-lab?authuser=0</a><br/></td>\n</tr>\n<tr>\n<td>이우경</td>\n<td colspan="3">위성전자연구실<br/>(Satellite Electronics System Lab)</td>\n<td colspan="2"><span style="font-family: Calibri, Arial, Helvetica, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);"><a href="http://satecslab.kau.ac.kr">http://satecslab.kau.ac.kr</a></span></td>\n</tr>\n<tr>\n<td>이형근</td>\n<td colspan="3">항법 및 정보시스템 연구실</td>\n<td colspan="2"><a href="http://nisl.kau.ac.kr" target="_blank">http://nisl.kau.ac.kr</a></td></tr>\n<tr>\n<td>정동원</td>\n<td colspan="3">무인시스템 제어연구실<br/>(Unmanned Systems Control Lab, USCL)</td>\n<td colspan="2"><a href="https://control.kau.ac.kr/" target="_self"><span style="color: rgb(0, 102, 204);">https://control.kau.ac.kr/</span></a><span style="text-decoration: none;">\xa0</span></td></tr></tbody></table><strong>', '</strong></div><strong>', '</strong></div><strong>', '</strong></li><strong>', '', '</strong><li id="panel_02"><strong>', '</strong><div class="article_303"><strong>', '</strong><h4>연구 분야 설명</h4>', '<ul>', '<li>- 마이크로웨이브 기술을 이용하여 위성 및 우주시스템, 통신시스템, 레이다 시스템(차량 및 우주위성 포함),', '근/장거리 센서 및 모니터링 시스템, 의공학 시스템(의료진단 및 건강상태 체크)에 필요한 소자/부품/시스템을 설계하는 연구</li>', '<li>- 시스템 반도체 및 집적화 회로 기술을 이용하여 스마트폰, 테블릿 및 컴퓨터, TV를 비롯한 가전제품,', '자동차, 항공기에 필요한 SoC (System-on-Chip) 및 고급 RF/Analog 집적 회로 설계 기술에 관 ...
# $(document).ready(function() {
# });
#
# .article_303 ul li {
# color: #000000;
# }
# .table_01 th {
# font-weight: 400;
# color: #244b85;
# }
# .table_01 td {
# color: #000000;
# }
# .table_01 td a {
# color: #24282c;
# }
# .menu_tab li {
# width: 50%;
# }
# .img_c {
# /*width: 90%;*/
# margin: auto;
# padding: 5px;
# }
# @media (max-width: 767px) {
# .article_303 ul {
# padding-left: 5px;
# }
# .menu_tab li {
# width: 100%;
# }
# .menu_tab li a {
# height: 30px;
# line-height: 28px;
# }
# }
#
# 연구그룹 소개
#
# 항공전자 및 제어시스템
# 마이크로파 및 집적회로
# 반도체 및 디스플레이
# 통신시스템 및 멀티미디어
# 컴퓨터정보시스템 및 네트워크
#
# 연구 분야 설명
#
# - 실시간성과 고신뢰성 특성을 갖는 항공전자 및 인공위성 시스템에 대한 특성화 연구
# - 미래의 인공위성 시스템 개발 및 활용을 위한 전자탑재체 장치 연구
# - 영상기반 무인항공기 유도 및 제어 기법 연구
# - 나노위성 3축 자세제어를 위한 가변속 제어모멘트자이로 연구 및 개발- UAM/AAM/위성 탑재용 안전인증 하드웨어 및 소프트웨어 연구 개발
#
# 주요 연구 테마
#
# - 레이다, 항공통신, 위성전자, 인공위성시스템, 위성항행시스템 등
#
# 연구진 구성
#
# 교수명 : 나종화
# 연구실명 : 고신뢰성 임베디드 시스템 (Dependable Embedded Systems Lab)
# 홈페이지 : [https://sites.google.com/view/dependable-systems-kau/dependable-systems-lab?authuser=0](https://sites.google.com/view/dependable-systems-kau/dependable-systems-lab?authuser=0)
#
# 교수명 : 이우경
# 연구실명 : 위성전자연구실 (Satellite Electronics System Lab)
# 홈페이지 : [http://satecslab.kau.ac.kr](http://satecslab.kau.ac.kr)
#
# 교수명 : 이형근
# 연구실명 : 항법 및 정보시스템 연구실
# 홈페이지 : [http://nisl.kau.ac.kr](http://nisl.kau.ac.kr)
#
# 교수명 : 정동원
# 연구실명 : 무인시스템 제어연구실 (Unmanned Systems Control Lab, USCL)
# 홈페이지 : [https://control.kau.ac.kr/](https://control.kau.ac.kr/)
#
# 연구 분야 설명
#
# - 마이크로웨이브 기술을 이용하여 위성 및 우주시스템, 통신시스템, 레이다 시스템(차량 및 우주위성 포함),
# 근/장거리 센서 및 모니터링 시스템, 의공학 시스템(의료진단 및 건강상태 체크)에 필요한 소자/부품/시스템을 설계하는 연구
# - 시스템 반도체 및 집적화 회로 기술을 이용하여 스마트폰, 테블릿 및 컴퓨터, TV를 비롯한 가전제품,
# 자동차, 항공기에 필요한 SoC (System-on-Chip) 및 고급 RF/Analog 집적 회로 설계 기술에 관한 연구
#
# 주요 연구 테마
#
# - Microwave and RF Active/Passive Circuits, Satellite Antenna and Radar System
# - EMI/EMC/EMP Analysis and High Power System
# - Radio Frequency Analog Circuit and System Design (LNA, HPA, MIXER, VCO, …)
# - SoC Design for Wireless Communication/Multimedia/Sensor/Medical Systems
#
# 연구진 구성
#
# 교수명 : 조춘식
# 연구실명 : High Frequency Electronics Lab. (고주파회로연구실)
#
# 교수명 : 이재욱
# 연구실명 : Microwave and Millimeter Solution Lab. (마이크로파 및 밀리미터파 연구실)
# 홈페이지 : http://mercury.kau.ac.kr/mmsl
#
# 교수명 : 김영진
# 연구실명 : Nanowave Integrated Circuit and System (NICS) Lab.
#
# 교수명 : 정윤호
# 연구실명 : System on Chip (SoC) Lab. (SoC 설계 연구실)
# 홈페이지 : http://soc.kau.ac.kr
#
# 연구 분야 설명
#
# - 나노 반도체 소자, 저차원 소재를 접목한 반도체 소자의 특성 해석
# - 플라즈마를 이용한 반도체 공정 및 설비, 디스플레이 소자, 산화물 TFT
# - 태양전지 및 신재생에너지, 반도체 광소자 (OLED, LED), 광학 센서 (항공기, 정밀계측)
#
# 주요 연구 테마
#
# - Compact 모델을 이용한 10-nm CNTFET의 특성 향상에 대한 시뮬레이션
# - TFT-LCD 공정용 plasma reactor modeling, 에너지 기술개발사업: Non-CO2 처리
# - 산화물 TFT 열화 mechansim 규명 및 신뢰성 향상
# - 창호형 박막 태양전지 및 광변환 이미징 센서 등
# - 1차원 나노선(1D-Nanowire) 유연투명전극, 양자점(Quantum Dot) IB 태양 전지
#
# 교수명 : 이효창, 신명훈
# 연구실명 : Energy & Photonics Lab
# 홈페이지 : https://sites.google.com/site/kauenplab
#
# 교수명 : 전재홍
# 연구실명 : 디스플레이 소자연구실
#
# 교수명 : 최희환
# 연구실명 : 플라즈마 및 디스플레이 공정 연구실
# 홈페이지 : http://www.kau.ac.kr/page/dept/eie/research/lab_chh.pdf
#
# 교수명 : 김광은
#
# 교수명 : 황진영
# 연구실명 : 나노전자소자 연구실
# 홈페이지 : https://sites.google.com/site/nedl2017jh
#
# 연구 분야 설명
#
# [통신 분야]
# - 5G 이동통신, 무선통신, 무인기 통신, 무인기 군집 비행 통신, 항공 통신
# - 통신신호처리: 레이다 신호처리, 무선 전력 및 정보 전송, 물리계층 보안 통신, 위치 추정
# [멀티미디어 분야]
# - 대분류: 영상처리, 컴퓨터비전, 영상부호화, 멀티미디어통신
# - 소분류: 가상/증강현실(AR/VR), 무인기/항공영상처리, 라이트필드/홀로그램 등의 3차원영상,
# 멀티미디어 포렌식, 영상보안, 차세대 비디오 코덱 표준, 360 비디오/VR, 웨어러블/IoT 미디어 표준
#
# 주요 연구 테마
#
# [통신 분야]
# - 5G 이동통신, 무선통신, 통신신호처리, 무인기 통신, 무인기 군집 비행 통신, 항공 통신
#
# [멀티미디어 분야]
# - 영상처리 및 비전, 3차원 영상, 가상/증강/혼합현실 (VR/AR/MR),
# 무인기/항공기 영상 분석, 차세대 비디오 부호화, 멀티미디어 포렌식
#
# 연구진 구성
#
# 교수명 : 김재곤
# 연구실명 : Media Communication Lab (MCL)
# 홈페이지 : http://mclab.kau.ac.kr
#
# 교수명 : 도규봉
#
# 교수명 : 박형래
# 연구실명 : 이동통신연구실 (MCL)
# 홈페이지 : http://mercury.kau.ac.kr/hrpark
#
# 교수명 : 백중환
# 연구실명 : Computer Vision & Image Processing Lab (CVIP Lab)
# 홈페이지 : https://sites.google.com/site/kaucvlab
#
# 교수명 : 오병태
# 연구실명 : Media Processing Lab. (MPL)
# 홈페이지 : http://multimedia.kau.ac.kr
#
# 교수명 : 이명진
# 연구실명 : 멀티미디어통신연구실 (MCL)
# 홈페이지 : http://sites.google.com/view/mclkau
#
# 교수명 : 정영호
# 연구실명 : 디지털통신실험실 (DCL)
# 홈페이지 : https://sites.google.com/site/profyhj
#
# 교수명 : 최지훈
# 연구실명 : 통신신호처리 연구실 (CSPLAB)
#
# 연구 분야 설명
#
# - 프로그램 자동 분석/검증 기술을 기반으로, 안전(해킹 방지)하고 강건(비정상적 동작 및 종료 방지)한 소프트웨어를 개발
# - 자율주행, 드론, IoT, 의료, 항공우주 및 차량/철도/전력/산업 등에 필수 분야인 미래 컴퓨터 시스템,
# 임베디드 시스템, 센서 네트워크 등의 안전성을 향상시키기 위한 분석 및 개발 연구
# - IoT (Internet of Things), WoT (Web of Things), 유무선 통신 네트워크 및 서비스, 실시간 네트워크 및 정보통신 망 설계
# - 무선 통신 및 멀티미디어 신호처리를 위한 고성능, 저전력의 디지털 집적회로 및 SoC 설계, 임베디드 시스템 설계
# - 빅데이터 기반 대용량 딥러닝 컴퓨팅 시스템을 위한 S/W 기술
# - 시간 민감형 통신망(Time Sensitive Network) 기반의 자동차/항공기 내부 제어 통신 및 센서기반의 IoT 응용 기술을 다룸.
#
# 주요 연구 테마
#
# - 소스/목적 코드 보안취약점 자동 검출, 프로그램 자동 해킹, 모바일 앱 테스팅, 멀웨어 검출
# - 신뢰성 평가 및 항공우주/차량 임베디드 시스템 장비 (항공기 대기자료컴퓨터, 충돌검출 및 회피컴퓨터) 개발
# - MAC/routing protocol in Communication Network/ Real time Transmission protocol/UAC Network
# - High-Performance &amp; Low-Power Digital VLSI &amp; Embedded Systems for Wireless Communication &amp; Multimedia Applications
# - 빅데이터, 인공지능, 분산컴퓨팅, 슈퍼컴퓨팅
# - Time Sensitive Network over Ethernet for Automotive and IoT
# - Ambient Service and Augmented Reality, 정보 검색, 데이터 사이언스, VR/AR 융합 컨텐츠
#
# 연구진 구성
#
# 교수명 : 권용진
# 연구실명 : 논리회로연구실
# 홈페이지 : 없음
#
# 교수명 : 김태환
# 연구실명 : 회로 및 시스템 연구실 (Circuits & Systems Lab.)
# 홈페이지 : http://cas.kau.ac.kr
#
# 교수명 : 안준선
# 연구실명 : 시스템소프트웨어연구실 (System Software Lab)
# 홈페이지 : http://sslab.kau.ac.kr
#
# 교수명 : 윤종호
# 연구실명 : 응용네트워크연구실 (Applied Network Research Lab)
# 홈페이지 : 없음
#
# 교수명 : 이동준
# 연구실명 : 통신정보시스템연구실 (Communication & Information System Lab)
# 홈페이지 : 없음
#
# 교수명 : 이성창
# 연구실명 : 창의융합 연구실 (Creative Convergence Research Lab)
# 홈페이지 : 없음
#
# 교수명 : 이재환
# 연구실명 : 분산 빅데이터 연구실 (Distributed Infrastructure for Data Intelligence)
# 홈페이지 : http://bigdata.kau.ac.kr
#
# 교수명 : 한정희
# 연구실명 : 모바일컴퓨팅 및 네트워크 연구실 (Mobile Computing and Network)
# 홈페이지 : http://mercury.kau.ac.kr/mobicom
#
# %%%%%%%%%%%%%%%%%%%
# -------14-------
# 14
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>대학원 운영내규</h3>', '</div>', '<object data="/conts_img/eie_www/introduce/대학원운영내규.pdf" height="845" id="pdf" type="application/pdf" width="100%"></object>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 대학원 운영내규
#
# %%%%%%%%%%%%%%%%%%%
# -------15-------
# 31
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.table_01 th {', 'font-weight: 400;', 'color: #244b85;', '}', '.table_01 td {', 'color: #000000;', '}', '@media (max-width: 767px) {', '.article_102 .scroller { overflow-x: auto; }', '.article_102 .scroller table { min-width: 600px; }', '}', '</style>', '<div class="sub_tit">', '<h3>장학제도 안내</h3>', '</div>', '<div class="article_102" style="padding-top: 0px;">', '<div class="scroller">', '<table class="table_01">\n<tbody>\n<tr>\n<th colspan="4">장학종류</th>\n<th colspan="3">장학금액</th>\n<th colspan="4">장학생 선발</th>\n</tr>\n\n<tr>\n<td colspan="2" rowspan="2">특별장학</td>\n<td colspan="2">석사특별장학</td>\n<td colspan="3">수업료의 50%</td>\n<td colspan="4">지도교수 1인당 석사과정 1명 추천</td>\n</tr>\n<tr>\n<td colspan="2">박사특별장학</td>\n<td colspan="3">수업료의 50%</td>\n<td colspan="4">지도교수 1인당 박사과정 1명 추천</td>\n</tr>\n\n<tr>\n<td colspan="2" rowspan="2">조교장학</td>\n<td colspan="2">TA장학</td>\n<td colspan="3">수업료의 20%</td>\n<td colspan="4" rowspan="2">\n<ul>\n<li>강의 및 실험·실습 보조</li>\n<li>TA장학과 RA장학 중복 수혜 가능</li>\n</ul>\n</td>\n</tr>\n<tr>\n<td colspan="2">RA장학</td>\n<td colspan="3">수업료의 40%</td>\n</tr>\n\n<tr>\n<td colspan="2" rowspan="4">신입생장학</td>\n<td colspan="2">신입생성적우수장학</td>\n<td colspan="3">1,000,000원</td>\n<td colspan="4">\n<ul>\n<li>석사 지원자 : 학부 성적 3.7/4.5 이상</li>\n<li>박사 지원자 : 석사 성적 4.0/4.5 이상</li>\n<li>특별장학 및 RA장학과 중복수혜 불가</li>\n</ul>\n</td>\n</tr>\n<tr>\n<td colspan="2">성적최우수장학<br/>(본교 출신만 해당)</td>\n<td colspan="3">등록금 전액</td>\n<td colspan="4">\n<ul>\n<li>석사, 박사 지원자중 학부성적 평점 4.0/4.5 이상자에게 전원 지급함</li>\n<li>입학 후 최초 1학기만 지급함</li>\n</ul>\n</td>\n</tr>\n<tr>\n<td colspan="2">학∙석사연계장학</td>\n<td colspan="3">입학금 전액</td>\n<td colspan="4">학·석사연계과정으로 석사과정에 입학한 자</td>\n</tr>\n<tr>\n<td colspan="2">석∙박사연계장학</td>\n<td colspan="3">입학금 전액</td>\n<td colspan="4">박사과정 합격자 중 본교 석사과정 출신자<br/>(학위 취득 후 6개월 이내 진학한 자에 한함)</td>\n</tr>\n\n<tr>\n<td colspan="2" rowspan="2">기타장학</td>\n<td colspan="2">총학생회간부장학</td>\n<td colspan="3">1,500,000원</td>\n<td colspan="4">총학생회 간부</td>\n</tr>\n<tr>\n<td colspan="2">산학연장학</td>\n<td colspan="3">장학규정에 의함</td>\n<td colspan="4">본교와 산학연 협약을 체결한 기관의 재직자</td>\n</tr>\n</tbody>\n</table>', '</div>', '</div>', '</div>', '</body>']
# $(document).ready(function() {
# });
#
# .table_01 th {
# font-weight: 400;
# color: #244b85;
# }
# .table_01 td {
# color: #000000;
# }
# @media (max-width: 767px) {
# .article_102 .scroller { overflow-x: auto; }
# .article_102 .scroller table { min-width: 600px; }
# }
#
# 장학제도 안내
#
# 장학종류 : 특별장학 - 석사특별장학
# 장학금액 : 수업료의 50%
# 장학생 선발 : 지도교수 1인당 석사과정 1명 추천
#
# 장학종류 : 특별장학 - 박사특별장학
# 장학금액 : 수업료의 50%
# 장학생 선발 : 지도교수 1인당 박사과정 1명 추천
#
# 장학종류 : 조교장학 - TA장학
# 장학금액 : 수업료의 20%
# 비고 : 강의 및 실험·실습 보조, TA장학과 RA장학 중복 수혜 가능
#
# 장학종류 : 조교장학 - RA장학
# 장학금액 : 수업료의 40%
#
# 장학종류 : 신입생장학 - 신입생성적우수장학
# 장학금액 : 1,000,000원
# 비고 : 석사 지원자 : 학부 성적 3.7/4.5 이상, 박사 지원자 : 석사 성적 4.0/4.5 이상, 특별장학 및 RA장학과 중복수혜 불가
#
# 장학종류 : 신입생장학 - 성적최우수장학 (본교 출신만 해당)
# 장학금액 : 등록금 전액
# 비고 : 석사, 박사 지원자중 학부성적 평점 4.0/4.5 이상자에게 전원 지급함, 입학 후 최초 1학기만 지급함
#
# 장학종류 : 신입생장학 - 학∙석사연계장학
# 장학금액 : 입학금 전액
# 비고 : 학·석사연계과정으로 석사과정에 입학한 자
#
# 장학종류 : 신입생장학 - 석∙박사연계장학
# 장학금액 : 입학금 전액
# 비고 : 박사과정 합격자 중 본교 석사과정 출신자 (학위 취득 후 6개월 이내 진학한 자에 한함)
#
# 장학종류 : 기타장학 - 총학생회간부장학
# 장학금액 : 1,500,000원
# 장학생 선발 : 총학생회 간부
#
# 장학종류 : 기타장학 - 산학연장학
# 장학금액 : 장학규정에 의함
# 장학생 선발 : 본교와 산학연 협약을 체결한 기관의 재직자
#
# %%%%%%%%%%%%%%%%%%%
# -------16-------
# 110
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.article_303 .table_01 td {', 'border: 1px solid #dedede;', 'font-weight: 400;', 'padding: 9px;', '}', '#year {', 'color: #185196;', 'background-color: #f5f5f5;', '}', '#history {', 'text-align: left;', 'padding-left: 15px;', '}', '.article_102 .chief {', 'float: left;', 'margin-left: 5px;', 'margin-right: 20px;', 'margin-top: 10px;', 'margin-bottom: 16px;', '}', '#summary {', 'font-size: 16px;', 'padding-right: 18px;', 'padding-left: 0;', '}', '#summary-bold {', 'font-size: 16px;', 'font-weight: bold;', 'padding-right: 18px;', 'padding-left: 0;', '}', '@media (max-width: 767px) {', '.article_102 .chief {', 'float: none;', 'display: block;', 'margin: 0 auto;', 'margin-bottom: 20px;', 'width: 77%;', '}', '.article_303 .table_01 td:first-child {', 'padding-left: 0;', 'padding-right: 0;', '}', '}', '</style>', '<div class="sub_tit">', '<h3>연구소 소개</h3>', '</div>', '', '<ul class="menu_tab menu_tab2">', '<li><a class="selected" href="#panel_01">항공전자연구소</a></li>', '<li><a href="#panel_02">통신방송기술연구소</a></li>', '</ul>', '<ul class="panel">', '<li id="panel_01">', '<div class="article_303">', '<h4>홈페이지</h4>', '<a href="http://aerc.kau.ac.kr" style="color: #666666; font-weight: bold;" target="_blank">\xa0http://aerc.kau.ac.kr</a>', '</div>', '<div class="article_303">', '<h4>연혁</h4>', '<table class="table_01">\n<tbody>\n<tr>\n<td id="year" rowspan="2">1986. 09</td>\n<td colspan="6" id="history">한국항공대학교 부설 전자정보통신개발 연구소로 발족</td>\n</tr>\n<tr>\n<td colspan="6" id="history">김원후 초대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">1990. 09</td>\n<td colspan="6" id="history">황병원 2대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">1994. 09</td>\n<td colspan="6" id="history">조성준 3대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">1996. 09</td>\n<td colspan="6" id="history">이 진 4대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2000. 09</td>\n<td colspan="6" id="history">백중환 5대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year" rowspan="2">2001. 07</td>\n<td colspan="6" id="history">곽영길 6대 연구소장 취임</td>\n</tr>\n<tr>\n<td colspan="6" id="history">전자정보통신개발 연구소 명칭을 \'항공전자연구소\'로 변경</td>\n</tr>\n<tr>\n<td id="year">2007. 08</td>\n<td colspan="6" id="history">정대권 7대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2009. 08</td>\n<td colspan="6" id="history">임상석 8대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2011. 09</td>\n<td colspan="6" id="history">이택경 9대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2012. 11</td>\n<td colspan="6" id="history">항공전자연구소 소식지 창간호 발간</td>\n</tr>\n<tr>\n<td id="year">2013. 09</td>\n<td colspan="6" id="history">정대권 10대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2015. 03</td>\n<td colspan="6" id="history">임상석 11대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2016. 07</td>\n<td colspan="6" id="history">나종화 12대 연구소장 취임</td>\n</tr>\n<tr>\n<td id="year">2017. 05</td>\n<td colspan="6" id="history">항공전자연구소 소식지 제10호 발간</td>\n</tr>\n</tbody>\n</table>', '</div>', '<div class="article_303">', '<h4>설립목적(개요)</h4>', '<div class="article_102">', '<img class="chief" src="http://www.kau.ac.kr/dept/etce1/img/research/aerc_03.gif" style="max-width: 270px; width: auto; height: auto; display: block; margin-bottom: 14px;"/>', '<p id="summary">본 연구소는', '<b style="font-weight: 500;">항공 및 우주 관련 전자, 통신 전반에 걸친 과학기술을 연구하여 국가 산업 발전에 이바지함을 목적</b>', '으로 설립된 연구소로서', '<b style="font-weight: 500;">항공 우주 관련 기술정책, 시스템, 통신(C: Communication),', '항행(N: Navigation), 레이다(S: Surveillance), 기반 핵심 기술 연구실</b>', '을 두고, 각 연구실에서는', '<b style="font-weight: 500;">전자, 통신, 컴퓨터 전 분야에 대한 자료의 수집,', '조사 연구 및 기술개발, 연구 자료집과 도서, 연구 논문지 발간, 연구 발표회 개최, 산학협동연구 및 위탁연구,', '타기관과의 공동연구 및 산업체 기술지도 등을 수행</b>', '한다.</p>', '</div>', '</div>', '<div class="article_303">', '<h4>주요연구실적</h4>', '<h5>국내학술대회 개최실적</h5>', '<ul>', '<li>① 2001.11 제1회 항공전자연구심포지엄 / 주제:항공우주기술과 항공전자의 역할</li>', '<li>② 2002.05 제2회 항공전자연구심포지엄 / 주제:국가 위성개발 현황과 전망</li>', '<li>③ 2002.11 한국항공대학교 개교 50주년 기념 국제항공우주학술회의</li>', '<li>④ 2003.1 ...
#
# $(document).ready(function() {
# });
#
# .article_303 .table_01 td {
# border: 1px solid #dedede;
# font-weight: 400;
# padding: 9px;
# }
# #year {
# color: #185196;
# background-color: #f5f5f5;
# }
# #history {
# text-align: left;
# padding-left: 15px;
# }
# .article_102 .chief {
# float: left;
# margin-left: 5px;
# margin-right: 20px;
# margin-top: 10px;
# margin-bottom: 16px;
# }
# #summary {
# font-size: 16px;
# padding-right: 18px;
# padding-left: 0;
# }
# #summary-bold {
# font-size: 16px;
# font-weight: bold;
# padding-right: 18px;
# padding-left: 0;
# }
# @media (max-width: 767px) {
# .article_102 .chief {
# float: none;
# display: block;
# margin: 0 auto;
# margin-bottom: 20px;
# width: 77%;
# }
# .article_303 .table_01 td:first-child {
# padding-left: 0;
# padding-right: 0;
# }
# }
#
# 연구소 소개
#
# 항공전자연구소
# 통신방송기술연구소
#
# 홈페이지
# http://aerc.kau.ac.kr
#
# 연혁
# 1986년 9월, 한국항공대학교 부설 전자정보통신개발 연구소가 발족되었습니다. 김원후씨가 초대 연구소장으로 취임하였습니다. 1990년 9월에는 황병원씨가 2대 연구소장으로 취임하였고, 1994년 9월에는 조성준씨가 3대 연구소장으로 취임하였습니다. 1996년 9월에는 이 진씨가 4대 연구소장으로 취임하였고, 2000년 9월에는 백중환씨가 5대 연구소장으로 취임하였습니다. 2001년 7월에는 곽영길씨가 6대 연구소장으로 취임하였고, 동시에 전자정보통신개발 연구소의 명칭이 '항공전자연구소'로 변경되었습니다. 2007년 8월에는 정대권씨가 7대 연구소장으로 취임하였고, 2009년 8월에는 임상석씨가 8대 연구소장으로 취임하였습니다. 2011년 9월에는 이택경씨가 9대 연구소장으로 취임하였고, 2012년 11월에는 항공전자연구소 소식지의 창간호가 발간되었습니다. 2013년 9월에는 정대권씨가 10대 연구소장으로 취임하였고, 2015년 3월에는 임상석씨가 11대 연구소장으로 취임하였습니다. 2016년 7월에는 나종화씨가 12대 연구소장으로 취임하였고, 2017년 5월에는 항공전자연구소 소식지의 제10호가 발간되었습니다.
#
# 설립목적(개요)
#
# 본 연구소는
# 항공 및 우주 관련 전자, 통신 전반에 걸친 과학기술을 연구하여 국가 산업 발전에 이바지함을 목적
# 으로 설립된 연구소로서
# 항공 우주 관련 기술정책, 시스템, 통신(C: Communication),
# 항행(N: Navigation), 레이다(S: Surveillance), 기반 핵심 기술 연구실
# 을 두고, 각 연구실에서는
# 전자, 통신, 컴퓨터 전 분야에 대한 자료의 수집,
# 조사 연구 및 기술개발, 연구 자료집과 도서, 연구 논문지 발간, 연구 발표회 개최, 산학협동연구 및 위탁연구,
# 타기관과의 공동연구 및 산업체 기술지도 등을 수행
# 한다.
#
# 주요연구실적
# 국내학술대회 개최실적
#
# ① 2001.11 제1회 항공전자연구심포지엄 / 주제:항공우주기술과 항공전자의 역할
# ② 2002.05 제2회 항공전자연구심포지엄 / 주제:국가 위성개발 현황과 전망
# ③ 2002.11 한국항공대학교 개교 50주년 기념 국제항공우주학술회의
# ④ 2003.10 2003 레이다 워크샵 / 주제:국가전략기술정책과 레이다기술 발전방향
# ⑤ 2003.11 제3회 항공전자연구심포지엄 / 주제:무인항공기 항공전자 기술과 발전방향
# ⑥ 2003.11 Korea Air Show / 주제:산자부 과제 항공탑재 레이다시스템 모델전시
#
# 연혁
# 2010년 3월에 통신방송기술연구소가 개소되었고, 이때 초대 연구소장으로 이병섭 교수가 취임하였습니다. 그리고 2013년 3월에는 2대 연구소장으로 도규봉 교수가 취임하였습니다.

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
