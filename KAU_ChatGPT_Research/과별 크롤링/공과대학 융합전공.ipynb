# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "공과대학_융합전공_data"
number_html = 6
url = """http://college.kau.ac.kr/web/pages/gc72431h.do
http://college.kau.ac.kr/web/pages/gc42544h.do
http://college.kau.ac.kr/web/pages/gc22056h.do
http://college.kau.ac.kr/web/pages/gc75660h.do
http://college.kau.ac.kr/web/pages/gc83898h.do
http://college.kau.ac.kr/web/pages/gc29719h.do
http://college.kau.ac.kr/web/pages/gc95364h.do
http://college.kau.ac.kr/web/pages/gc33311h.do
http://college.kau.ac.kr/web/pages/gc99839h.do
http://college.kau.ac.kr/web/pages/gc97450h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
    if jj == 6:
        f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
        answer_db = csv.writer(f)
        answer_db.writerow([str(jj), "", url_list[jj]])
        f.close()
        continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc72431h.do', 'http://college.kau.ac.kr/web/pages/gc42544h.do', 'http://college.kau.ac.kr/web/pages/gc22056h.do', 'http://college.kau.ac.kr/web/pages/gc75660h.do', 'http://college.kau.ac.kr/web/pages/gc83898h.do', 'http://college.kau.ac.kr/web/pages/gc29719h.do', 'http://college.kau.ac.kr/web/pages/gc95364h.do', 'http://college.kau.ac.kr/web/pages/gc33311h.do', 'http://college.kau.ac.kr/web/pages/gc99839h.do', 'http://college.kau.ac.kr/web/pages/gc97450h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 1859
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p class="0" style="line-height: 2;"><span style="font-family:함초롬돋움;mso-fareast-font-family:함초롬돋움;font-size:11.0pt;">\xa0<br style="clear:both;"/><span style="font-size: 14pt; color: rgb(0, 117, 200); font-family: Verdana;"><b>한국항공대학교 공과대학 융합전공 홈페이지 방문을 환영합니다</b></span></span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 14pt; color: rgb(0, 117, 200);"><b>.</b></span></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 12pt;">미래 산업사회는 창의</span><span style="font-family: Verdana; letter-spacing: 0pt; font-size: 12pt;">・</span><span style="font-family: Verdana; font-size: 12pt;">융합적인 인재를 요구하고 있습니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 12pt;">. </span></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 12pt;">우리대학 공과대학 융합전공은 미래형 융합산업을 주도할 통섭형 전문 인재를 양성하기 위하여 </span><span style="font-family: Verdana; font-size: 12pt;">학습 역량 강화에 힘쓰고 있습니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 12pt;">. </span></p><p class="0" style="font-size: 11pt; line-height: 2;"><span style="font-size: 12pt; font-family: Verdana;"> </span><span style="font-size: 12pt; font-family: Verdana;">\xa0</span><span style="font-size: 12pt; font-family: Verdana;"> </span><o:p></o:p></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 12pt;">국내 민간 항공정비산업과\xa0</span><span style="font-family: Verdana; font-size: 12pt;">반도체공정산업의 현장 실무를 선도할 전문인력 양성을 위하여 관련 전문지식을 습득할 수 있는 효율적이고 체계적인 현장실무 중심의 교육을 진행하고 있습니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 12pt;">.</span></p><div class="hwp_editor_board_content" data-hjsonver="1.0" data-jsonlen="54055" id="hwpEditorBoardContent"><!--[data-hwpjson]{', '"documentPr": {', '"di": "",', '"dp": {', '"dn": "test.hwp",', '"ta": 1,', '"d1": 5,', '"d2": 1,', '"dv": 0,', '"dr": 1,', '"do": 1,', '"vj": "1.0",', '"an": "Hancom Office Hangul",', '"av": "9, 6, 1, 9963",', '"ao": "WIN",', '"ab": "32",', '"ar": "LE",', '"as": "Windows_Unknown_Version"', '},', '"dis": false,', '"ds": {', '"ti": "",', '"la": "ko",', '"cr": "",', '"su": "",', '"de": "",', '"cd": "2022-04-22T11:05:09.620Z",', '"md": "1601-01-01T09:00:00.000Z",', '"pd": "1601-01-01T09:00:00.000Z",', '"ke": ""', '}', '},', '"dh": {', '"do": {', '"pa": 1,', '"fo": 1,', '"en": 1,', '"pi": 1,', '"tb": 1,', '"eq": 1', '},', '"fo": [ ],', '"cd": {', '"tp": 0,', '"lc": {', '"af": false,', '"ui": false,', '"fu": false,', '"dn": false,', '"ul": false,', '"el": false,', '"at": false,', '"tq": false,', '"da": false,', '"dw": false,', '"dj": false,', '"bc": false,', '"bu": false,', '"al": false,', '"ab": false,', '"ap": false,', '"an": false,', '"aa": false,', '"ds": false,', '"de": false,', '"as": false,', '"cp": false,', '"ao": false,', '"et": false,', '"ay": false,', '"am": false,', '"a1": false,', '"bt": false,', '"av": false,', '"dh": false,', '"dp": false,', '"d1": false,', '"mf": false,', '"bl": false,', '"ag": false,', '"dg": false,', '"ae": false,', '"df": false,', '"do": false,', '"dl": false,', '"di": false,', '"d2": false,', '"d3": false,', '"ob": false,', '"d4": false,', '"ev": false,', '"d5": false,', '"d6": false,', '"a2": false,', '"dc": false', '}', '},', '"ld": {', '"pa": "",', '"pi": true,', '"fo": false', '}', '},', '"bf": {', '"01D855ED65D94EA00000003E": {', '"id": 1,', '"td": false,', '"sh": false,', '"st": 0,', '"sc": 0,', '"si": false,', '"bt": 0,', '"bi": false,', '"cl": 0,', '"bc": false,', '"lt": 0,', '"lw": 0,', '"lc": 0,', '"rt": 0,', '"rw": 0,', '"rc": 0,', '"tt": 0,', '"tw": 0,', '"tc": 0,', '"bbt": 0,', '"bbw": 0,', '"bbc": 0,', '"dt": 1,', '"dw": 0,', '"dc": 0,', '"fi": { }', '},', '"01D855ED65D94EA00000003F": {', '"id": 2,', '"td": false,', '"sh": false,' ...
#
# $(document).ready(function() {
# });
#
# 한국항공대학교 공과대학 융합전공 홈페이지 방문을 환영합니다.미래 산업사회는 창의・융합적인 인재를 요구하고 있습니다. 우리대학 공과대학 융합전공은 미래형 융합산업을 주도할 통섭형 전문 인재를 양성하기 위하여 학습 역량 강화에 힘쓰고 있습니다.    국내 민간 항공정비산업과 반도체공정산업의 현장 실무를 선도할 전문인력 양성을 위하여 관련 전문지식을 습득할 수 있는 효율적이고 체계적인 현장실무 중심의 교육을 진행하고 있습니다.<!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 9963",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2022-04-22T11:05:09.620Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D855ED65D94EA00000003E": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D855ED65D94EA00000003F": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D855ED65D94EA000000040": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D855ED65D94EA00000003F",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D855ED65D94EA000000041": {
# "id": 1,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D855ED65D94EA00000003F",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D855ED65D94EA000000042": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D855ED65D94EA000000043": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D855ED65D94EA000000042",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D855ED65D94EA00000003F",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D855ED65D94EA000000044": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D855ED65D94EA000000043",
# "cp": "01D855ED65D94EA000000040",
# "ns": "01D855ED65D94EA000000044",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D855ED65D94EA000000038",
# "01D855ED65D94EA000000038": {
# "np": "01D855ED65D94EA000000039",
# "id": 0,
# "pp": "01D855ED65D94EA000000043",
# "si": "01D855ED65D94EA000000044",
# "bf": 3,
# "ru": [
# {
# "cp": "01D855ED65D94EA000000041",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D855ED65D94EA000000034"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D855ED65D94EA000000035"
# }
# ,
# {
# "t": "한국항공대학교 공학융합학부 홈페이지 방문을 환영합니다."
# }
# ]
# }
# ]
# },
# "01D855ED65D94EA000000039": {
# "np": "01D855ED65D94EA00000003A",
# "id": -2147483648,
# "pp": "01D855ED65D94EA000000043",
# "si": "01D855ED65D94EA000000044",
# "bf": 0,
# "ru": [
# {
# "cp": "01D855ED65D94EA000000041",
# "ch": [
# {
# "t": "미래 산업사회는 창의・융합적인 인재를 요구하고 있습니다. "
# }
# ]
# }
# ]
# },
# "01D855ED65D94EA00000003A": {
# "np": "01D855ED65D94EA00000003B",
# "id": -2147483648,
# "pp": "01D855ED65D94EA000000043",
# "si": "01D855ED65D94EA000000044",
# "bf": 0,
# "ru": [
# {
# "cp": "01D855ED65D94EA000000041",
# "ch": [
# {
# "t": "우리대학 공학융합학부는 미래형 융합산업을 주도할 통섭형 전문 인재를 양성하기 위하여 2016학년도부터 항공정비시스템융합전공, 무인기융합전공, 자율주행융합전공을 개설하여 운영하고 있으며, 2022학년도부터 반도체융합전공 신설을 통하여 다변화하는 시장 변동에 대응하기 위한 학습 역량 강화에 힘쓰고 있습니다. "
# }
# ]
# }
# ]
# },
# "01D855ED65D94EA00000003B": {
# "np": "01D855ED65D94EA00000003C",
# "id": -2147483648,
# "pp": "01D855ED65D94EA000000043",
# "si": "01D855ED65D94EA000000044",
# "bf": 0,
# "ru": [
# {
# "cp": "01D855ED65D94EA000000041",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D855ED65D94EA00000003C": {
# "np": "01D855ED65D94EA00000003D",
# "id": -2147483648,
# "pp": "01D855ED65D94EA000000043",
# "si": "01D855ED65D94EA000000044",
# "bf": 0,
# "ru": [
# {
# "cp": "01D855ED65D94EA000000041",
# "ch": [
# {
# "t": "국내 민간 항공정비 사업의 활성화 및 신성장동력으로 꼽히는 무인기와 자율주행차, 반도체공정산업의 현장 실무를 선도할 전문인력 양성을 위하여 관련 전문지식을 습득할 수 있는 효율적이고 체계적인 교육과정과 현장실무 중심의 교육을 진행하고 있습니다."
# }
# ]
# }
# ]
# },
# "01D855ED65D94EA00000003D": {
# "np": "",
# "id": -2147483648,
# "pp": "01D855ED65D94EA000000043",
# "si": "01D855ED65D94EA000000044",
# "bf": 0,
# "ru": [
# {
# "cp": "01D855ED65D94EA000000041",
# "ch": [
# {
# "cc": 11,
# "ci": 1735618336,
# "co": "01D855ED65D94EA000000036"
# }
# ,
# {
# "t": "아울러, 기존 학부(과)의 주전공 외의 융합전공을 이수함으로써 융・복합적 지식과 역량을 갖추고 진로선택의 폭을 넓힐 수 있습니다. 항공정비・무인기・자율주행차・반도체 전문가로서의 꿈을 공학융합학부에서 펼쳐 가시기 바랍니다."
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D855ED65D94EA000000034": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D855ED65D94EA00000003E",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D855ED65D94EA00000003E",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D855ED65D94EA00000003E",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D855ED65D94EA000000035": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# ,
# "01D855ED65D94EA000000036": {
# "cc": 11,
# "ci": 1735618336,
# "id": 1954150532,
# "zo": 18,
# "nt": 1,
# "tw": 3,
# "tf": 0,
# "lo": false,
# "swi": 11382,
# "she": 4586,
# "swr": 4,
# "shr": 2,
# "spr": false,
# "pta": false,
# "pal": false,
# "pvr": 2,
# "phr": 2,
# "pva": 0,
# "ph1": 0,
# "pvo": 3646,
# "ph2": 37752,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 0,
# "ori": 0,
# "oto": 0,
# "obo": 0,
# "ca": { },
# "sc": "그림입니다.\r\n원본 그림의 이름: CLP0000274806e5.bmp\r\n원본 그림의 크기: 가로 165pixel, 세로 66pixel"
# ,
# "rc": {
# "cc": 11,
# "ci": 611346787,
# "hr": "",
# "gl": 0,
# "ii": 880408709,
# "ox": -978,
# "oy": -394,
# "ow": 12360,
# "oh": 4980,
# "cw": 11382,
# "ch": 4586,
# "fh": false,
# "fv": false,
# "ra": 0,
# "rcx": 5691,
# "rcy": 2293,
# "rc": false,
# "ri": true,
# "in": {
# "ma": false,
# "rb": false,
# "tm": {
# "e1": 1.000000,
# "e2": 0.000000,
# "e3": -978.000000,
# "e4": 0.000000,
# "e5": 1.000000,
# "e6": -394.000000
# },
# "re": [
# {
# "sm": {
# "e1": 0.920874,
# "e2": 0.000000,
# "e3": 978.000000,
# "e4": 0.000000,
# "e5": 0.920884,
# "e6": 394.000000
# },
# "ro": {
# "e1": 1.000000,
# "e2": 0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 1.000000,
# "e6": 0.000000
# }
# }
# ]
# }
# ,
# "re": false,
# "ls": { },
# "iw": 12360,
# "ih": 4980,
# "ix0": 0,
# "iy0": 0,
# "ix1": 12360,
# "iy1": 0,
# "ix2": 12360,
# "iy2": 4980,
# "ix3": 0,
# "iy3": 4980,
# "il": 0,
# "ir": 12360,
# "it": 0,
# "ib": 4980,
# "ml": 0,
# "mr": 0,
# "mt": 0,
# "mb": 0,
# "img": {
# "br": 0,
# "co": 0,
# "ef": 0,
# "al": 0,
# "ie": true,
# "bi": "01D855ED65D975B000000045.bmp"
# },
# "ef": {
# "sh": { },
# "gl": { },
# "se": { },
# "re": { }
# }
# }
# }
# },
# "bi": [
# {
# "ty": "image/bmp",
# "sr": "01D855ED65D975B000000045.bmp"
# }
# ],
# "bidt": {
# "01D855ED65D975B000000045.bmp": "..."
# }
# }-->아울러, 기존 학부(과)의 주전공 외의 융합전공을 이수함으로써 융・복합적 지식과 역량을 갖추고 진로선택의 폭을 넓힐 수 있습니다. 항공정비・반도체 전문가로서의 꿈을 공과대학 융합전공에서 펼쳐 가시기 바랍니다.   <!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 9963",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2022-04-22T11:06:58.236Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D855EDA680F93000000053": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D855EDA680F93000000054": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D855EDA680F93000000055": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D855EDA680F93000000054",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D855EDA680F93000000056": {
# "id": 1,
# "he": 1300,
# "tc": 10066329,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D855EDA680F93000000054",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D855EDA680F93000000057": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D855EDA680F93000000058": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D855EDA680F93000000057",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D855EDA680F93000000054",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D855EDA680F93000000059": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D855EDA680F93000000058",
# "cp": "01D855EDA680F93000000055",
# "ns": "01D855EDA680F93000000059",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D855EDA680F93000000052",
# "01D855EDA680F93000000052": {
# "np": "",
# "id": 0,
# "pp": "01D855EDA680F93000000058",
# "si": "01D855EDA680F93000000059",
# "bf": 3,
# "ru": [
# {
# "cp": "01D855EDA680F93000000056",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D855EDA680F93000000050"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D855EDA680F93000000051"
# }
# ,
# {
# "t": "공학융합학부장"
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D855EDA680F93000000050": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D855EDA680F93000000053",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D855EDA680F93000000053",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D855EDA680F93000000053",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D855EDA680F93000000051": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }--><!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 9963",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2022-04-22T11:06:03.004Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D855ED858D9C1000000049": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D855ED858D9C100000004A": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D855ED858D9C100000004B": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D855ED858D9C100000004A",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D855ED858D9C100000004C": {
# "id": 1,
# "he": 1300,
# "tc": 10066329,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D855ED858D9C100000004A",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D855ED858D9C100000004D": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D855ED858D9C100000004E": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D855ED858D9C100000004D",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D855ED858D9C100000004A",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D855ED858D9C100000004F": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D855ED858D9C100000004E",
# "cp": "01D855ED858D9C100000004B",
# "ns": "01D855ED858D9C100000004F",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D855ED858D9C1000000048",
# "01D855ED858D9C1000000048": {
# "np": "",
# "id": 0,
# "pp": "01D855ED858D9C100000004E",
# "si": "01D855ED858D9C100000004F",
# "bf": 3,
# "ru": [
# {
# "cp": "01D855ED858D9C100000004C",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D855ED858D9C1000000046"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D855ED858D9C1000000047"
# }
# ,
# {
# "t": "공학융합학부장"
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D855ED858D9C1000000046": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D855ED858D9C1000000049",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D855ED858D9C1000000049",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D855ED858D9C1000000049",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D855ED858D9C1000000047": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 66
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교수진</h3>', '</div>', '<ul class="menu_tab menu_tab2">', '<li><a class="selected" href="#panel_01">항공정비시스템 융합전공</a></li>', '<li><a href="#panel_02">반도체 융합전공</a></li>', '</ul>', '<ul class="panel">', '<li id="panel_01">', '<ul class="prs_list">', '<li>', '<span class="portrait"> <img src="/conts_img/sme_www/introduce/prof/김기홍 교수님.jpg"/></span>', '<h4>김기홍 <span>주임교수</span></h4>', '<p>항공우주 및 기계공학부</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>항공전자공학</li>', '<li>기계관 225호</li>', '<li>02-300-0287 / kihkim@kau.ac.kr</li>', '</ul>', '</li>', '<li>', '<span class="portrait"> <img src="/conts_img/sme_www/introduce/prof/임기현 교수님.jpg"/></span>', '<h4>임기현\xa0<span>교수</span></h4>', '<p>항공우주 및 기계공학부</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>항공기계공학</li>', '<li>본관 420호</li>', '<li>02-300-0174 / kihlim@kau.ac.kr</li>', '</ul>', '</li>', '<li>', '<span class="portrait"> <img src="/conts_img/sme_www/introduce/prof/신성재 교수님.jpg"/></span>', '<h4>신성재\xa0<span>교수</span></h4>', '<p>항공우주 및 기계공학부</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>항공기계공학</li>', '<li>기계관 : 422호</li>', '<li>02-300-0106 / sjshin86@kau.ac.kr</li>', '</ul>', '</li>', '</ul>', '</li>', '<li id="panel_02">', '<ul class="prs_list">', '<li>', '<span class="portrait"> <img src="/conts_img/sme_www/introduce/prof/김영진 교수님.jpg"/></span>', '<h4>김영진 <span>주임교수</span></h4>', '<p>항공전자정보공학부</p>', '<ul class="prs_info">', '<li><span>학력 : </span>경북대 및 한국과학기술원</li>', '<li><span>전공분야 : </span>RFIC 설계</li>', '<li>전자관 305호</li>', '<li>youngjinkim@kau.ac.kr</li></ul></li></ul></li></ul><ul class="prs_list"><li><ul class="prs_info">', '</ul>', '</li>', '</ul>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 교수진
#
# 항공정비시스템 융합전공
# 반도체 융합전공
#
# 김기홍 주임교수
# 항공우주 및 기계공학부
#
# 전공분야 : 항공전자공학
# 기계관 225호
# 02-300-0287 / kihkim@kau.ac.kr
#
# 임기현 교수
# 항공우주 및 기계공학부
#
# 전공분야 : 항공기계공학
# 본관 420호
# 02-300-0174 / kihlim@kau.ac.kr
#
# 신성재 교수
# 항공우주 및 기계공학부
#
# 전공분야 : 항공기계공학
# 기계관 : 422호
# 02-300-0106 / sjshin86@kau.ac.kr
#
# 김영진 주임교수
# 항공전자정보공학부
#
# 학력 : 경북대 및 한국과학기술원
# 전공분야 : RFIC 설계
# 전자관 305호
# youngjinkim@kau.ac.kr
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 11
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3>행정실</h3></div><ul class="prs_list"><li><span class="portrait"><img src="http://college.kau.ac.kr/conts_img/sme_www/introduce/prof/%ED%95%9C%EC%A7%80%EC%9B%90%20%EC%A7%81%EC%9B%90.jpg"/></span><h4>한지원 <span style="font-size: 11pt;">직원</span></h4><ul class="prs_info"><li>기계관 103호</li><li>Tel 02)300-0450\xa0 \xa0FAX 02)3158-4429</li><li>hanjw@kau.ac.kr</li><li>업무시간\xa0 9:00 ~ 18:00<br/>(점심 12:00 ~ 13:00, 방학 중 동일)</li></ul></li></ul>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 행정실한지원 직원기계관 103호Tel 02)300-0450   FAX 02)3158-4429hanjw@kau.ac.kr업무시간  9:00 ~ 18:00(점심 12:00 ~ 13:00, 방학 중 동일)
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 47
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3>공과대학 운영내규</h3></div><p class="0" style="line-height: 1.8; font-size: 11pt;"><br/><br/>\xa0</p>', '<table style="border-collapse: collapse; table-layout: fixed; border-width: initial; border-style: none; border-color: initial;"><tbody><tr><td style="width: 252.67pt; height: 33.63pt; padding: 1.41pt 5.1pt; border-top: none; border-left: none; border-bottom: 1.7pt solid rgb(97, 130, 214); border-right: none;" valign="middle"><p class="0" style="margin-left: 10.7pt; line-height: 1.8; text-indent: -10.7pt;"><span style="font-family: Verdana; font-weight: bold; font-size: 12pt;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 12pt; font-family: Verdana;">1</span><span style="font-family: Verdana; font-weight: bold; font-size: 12pt;">조\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 12pt; font-family: Verdana;">(</span><span style="font-family: Verdana; font-weight: bold; font-size: 12pt;">목적</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 12pt; font-family: Verdana;">)</span><span lang="EN-US" style="font-size: 11pt; font-family: 나눔고딕, NanumGothic;"></span></p></td></tr></tbody></table>', '<p style="line-height: 1.8;"><span style="font-family: Verdana; font-size: 11pt;">이 내규는\xa0</span><span style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">「</span><span style="font-family: Verdana; font-size: 11pt;">학칙</span><span style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">」\xa0</span><span style="font-family: Verdana; font-size: 11pt;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">37</span><span style="font-family: Verdana; font-size: 11pt;">조</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">(</span><span style="font-family: Verdana; font-size: 11pt;">다전공</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">),\xa0</span><span style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">「</span><span style="font-family: Verdana; font-size: 11pt;">학칙시행세칙</span><span style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">」\xa0</span><span style="font-family: Verdana; font-size: 11pt;">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">24</span><span style="font-family: Verdana; font-size: 11pt;">조</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">(</span><span style="font-family: Verdana; font-size: 11pt;">다전공</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">)</span><span style="font-family: Verdana; font-size: 11pt;">에 의한 공과대학 융합전공\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">(</span><span style="font-family: Verdana; font-size: 11pt;">이하\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">“</span><span style="font-family: Verdana; font-size: 11pt;">본 전공</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">”</span><span style="font-family: Verdana; font-size: 11pt;">으로 한다</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">)</span><span style="font-family: Verdana; font-size: 11pt;">의 운영에 필요한 세부사항을 규정함을 목적으로 한다</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">.\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">&lt;</span><span style="font-family: Verdana; font-size: 11pt;">개정\xa0</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">2021.11.09, 20 ...
# $(document).ready(function() {
# });
#
# 공과대학 운영내규
# 제1조 (목적)
# 이 내규는 「학칙」 제37조(다전공), 「학칙시행세칙」 제24조(다전공)에 의한 공과대학 융합전공 (이하 “본 전공”으로 한다)의 운영에 필요한 세부사항을 규정함을 목적으로 한다. &lt;개정 2021.11.09, 2023.02.16&gt;
# 제2조 (전공)
# 본 전공에서는 다음 각 호의 융합전공을 운영한다.   1. 항공정비시스템융합전공   2. &lt;삭제 2023.02.16&gt;   3. &lt;삭제 2023.02.16&gt;   4. 반도체융합전공 &lt;신설 2021.11.09&gt;
# 제 3조 (운영위원회)
# ① 본 전공 운영에 관한 사항을 심의하기 위하여 운영위원회(이하 “위원회”라 한다)를 구성하고 운영한다. &lt;개정 2023.02.16&gt;② 운영위원회의 위원장은 공과대학장으로 하며, 당연직 위원과 필요에 따라 임명직 위원으로 구성할 수 있다. &lt;개정 2021.01.20, 2023.02.16&gt;③ 당연직 위원은 공과대학 소속 학부(과)장, 각 융합전공 주임교수로 하며, 임명직 위원은 공과대학장이 위촉하는 약간 명의 교원으로 한다. &lt;개정 2023.02.16&gt;④ 운영위원회의 기능은 다음 각 호와 같다.   1. 융합전공 운영내규 개정에 관한 사항 &lt;개정 2023.02.16&gt;   2. 교과과정 운영 등 중요사항 논의⑤ 운영위원회 회의는 공과대학장이 소집하고 재적위원 과반수 이상의 출석과 출석위원 과반수 이상의 찬성으로 의결한다. &lt;개정 2023.02.16&gt;
# 제 4조 (교과과정 편성)
# ① 융합전공의 교과과정은 융합전공별 참여 학부(과)에 이미 편성된 교과목으로 구성하되, 필요 시 교육품질혁신위원회의 승인을 받아 융합전공 신규 교과목을 편성할 수 있다.② 융합전공의 교과목 등 기타 운영에 관한 세부사항은 별도로 정한다.
# 제5조 (모집정원)
# 모집정원은 융합전공별 연 30명 내외로 하여 참여 학부(과)의 수용능력 및 특성을 감안하여 정한다.
# 제6조 (신청자격)
# 본 대학교 모든 학부(과)의 1학년 과정 이상 수료 재학생은 공과대학 내 각 융합전공을 신청할 수 있다. 단, 각 융합전공의 특성에 따라 신청대상을 제한할 수 있으며, 세부 신청자격은 융합전공별로 따로 정한다. &lt;개정 2020.05.06, 2023.02.16&gt;
# 제7조 (신청 및 이수허가 절차)
# ① 융합전공을 신청하려는 학생은 매 학기 개강 전 소정의 신청 기간에 융합전공 신청원(별지서식1)을 작성하여 제1전공 학부(과)장을 경유하여 공과대학 행정실에 제출하여야 한다. &lt;개정 2023.02.16&gt;② 제출된 융합전공 신청원은 각 융합전공별 주임교수의 심사절차를 거치며 본 전공은 심사 통과자 명단을 교무처에 제출한다. &lt;개정 2023.02.16&gt;③ 교무처는 심사 통과자에 대한 총장의 승인을 받아 이수 허가자를 최종 확정한다.
# 제 8조 (이수기간)
# 융합전공 이수는 승인받은 학기부터 시작하여 제1전공 졸업 시까지 완료하여야 한다.
# 제 9조 (이수요건)
# ① 융합전공 이수학점은 36학점 이상으로 하며 융합전공별 최소 전공이수학점은 다음 각 호와 같이 한다.   1. 항공정비시스템융합전공 : 36학점 이상   2. &lt;삭제 2023.02.16&gt;   3. &lt;삭제 2023.02.16&gt;   4. 반도체융합전공 : 36학점 이상  &lt;신설 2021.11.09&gt;② 융합전공 이수기간 동안 요구되는 학점 이외에 전공별 추가 이수요건이 있는 경우 그 기준을 충족시켜야 한다.
# 제 10조 (이수 및 학점인정)
# ① 매 학기 수강신청 학점 및 이수학점 인정은 제1전공 이수와 동일한 절차를 따른다.② 제1전공에서 이수한 교과목과 융합전공 교과목이 중복될 경우 학점을 중복인정 할 수 있으며 융합전공별 최대 중복인정 학점은 다음 각 호와 같이 한다.   1. 항공정비시스템융합전공 : 12학점 이내   2. &lt;삭제 2023.02.16&gt;   3. &lt;삭제 2023.02.16&gt;   4. 반도체융합전공 : 12학점 이내  &lt;신설 2021.11.09&gt;③ 융합전공 이수 허가 이전에 이수한 융합전공 교과목도 융합전공으로 이수한 것으로 인정한다.④ 융합전공 이수를 위하여 취득한 학점은 제1전공 졸업학점에 포함한다.⑤ 융합전공 이수를 위하여 취득한 학점은 제14조에 따른 졸업사정을 마친 후 융합전공 교과목 및 학점으로 최종 인정한다.
# 제 11조 (학사지도)
# 융합전공을 이수하는 학생은 융합전공별 주임교수에게 수강지도, 학업상담 등의 학사지도를 받는다.
# 제 12조 (장학금)
# ① 장학금의 지급은 장학금 지급 규정에 따르며 장학생은 다음 각 호의 조건을 모두 만족하는 학생 중에서 선발한다.   1. 직전학기 전체 교과목을 12학점 이상 이수하고 이수평점이 3.5 이상인 자   2. 융합전공을 1개 학기 이상 이수한 자   3. 직전학기 융합전공 교과목을 6학점 이상 이수한 자   4. 직전학기 융합전공 교과목 이수평점이 3.5 이상인 자 &lt;개정 2023.02.16.&gt;② 제1항을 만족하는 자로서 두 명 이상의 성적이 동일한 경우 다음 각 호와 같이 우선순위를 정한다.   1. 융합전공 교과목의 이수평점이 높은 자   2. 융합전공 교과목의 이수학점이 높은 자   3. 융합전공 교과목 누적 이수학점이 높은 자 &lt;개정 2023.02.16&gt;   4. 융합전공 주임교수의 지도·상담 결과 학업이 더 우수하다고 인정되는 자③ 그 밖의 장학관계사항은 운영위원회의 결정에 따른다.
# 제 12조의 1(장학금의 반환)
# 선정된 장학생이 다음 각 호에 해당하는 경우 수혜자는 등록금 보전 목적의 장학금을 전액 반환하여야 한다.   1. 장학금 지급 학기인 당해 학기에 융합전공을 포기한 자   2. 장학금 받은 학기에 자퇴 또는 제적된 자   3. 미등록 휴학한 자 &lt;신설 2021.01.20&gt;
# 제 13조 (이수포기)
# ① 융합전공의 이수를 포기하고자 하는 자는 해당 학기 말 1개월 전까지 융합전공 포기신청원을 공과대학 행정실에 제출하여야 한다. &lt;개정 2023.02.16&gt;② 융합전공을 포기한 경우 이미 이수한 융합전공 교과목은 일반선택 학점으로 인정한다.
# 제 14조 (졸업사정)
# ① 융합전공을 위한 소정의 교과과정 이수를 완료한 학생(해당 학기 완료예정인 학생을 포함한다)은 제1전공 졸업사정기간에 융합전공 이수확인서를 공과대학 행정실에 제출하여야 한다. &lt;개정 2023.02.16&gt;② 제출된 융합전공 이수확인서는 각 융합전공 주임교수의 심사절차를 거치며 본 전공은 심사 통과자 명단을 교무처에 제출한다. &lt;개정 2023.02.16&gt;③ 교무처는 심사 통과자에 대한 졸업사정위원회 및 총장의 승인을 받아 졸업 허가자를 최종 확정한다.
# 제 15조 (졸업유보)
# 제1전공 졸업 시까지 융합전공 학점을 모두 이수하지 못한 경우 본인의 희망에 따라 융합전공 이수를 완료할 때까지 제1전공 학부(과)의 졸업을 유보할 수 있다.
# 제 16조 (학위수여)
# 졸업요건이 충족된 융합전공 이수자에게는 제1전공 학위명과 다음 각 호의 융합전공별 학위명을 병행 표기한 학위증서를 수여한다.   1. 항공정비시스템융합전공 : 공학사   2. &lt;삭제 2023.02.16&gt;   3. &lt;삭제 2023.02.16&gt;   4. 반도체융합전공 : 공학사  &lt;신설 2021.11.09&gt;
# 제 17조 (기타)
# 이 내규에 정하지 아니한 사항은 「학칙」, 「학칙시행세칙」 및 관련 학사 규정에 따른다.  부 칙 (시행일) 이 내규는 2019년 3월 1일부터 시행한다.(시행일) 이 개정 내규는 2020년 5월 6일부터 시행하되, 2020학년도 2학기부터 적용한다.(시행일) 이 개정 내규는 2021년 1월 20일부터 시행하되, 2021학년도 1학기부터 적용한다.(시행일) 이 개정 내규는 2021년 11월 9일부터 시행하되, 2022학년도 1학기부터 적용한다.(시행일) 이 개정 내규는 2023년 2월 16일부터 시행하되, 2023학년도 1학기부터 적용한다.
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 21
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '}--></div><h3><p class="0"><span lang="EN-US" style="mso-fareast-font-family:함초롬돋움;font-family:함초롬돋움;mso-ascii-font-family:함초롬돋움;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;color:#999999;"><i>Interdisciplinary Program of Aviation Maintenance System Engineering</i></span></p><div class="hwp_editor_board_content" data-hjsonver="1.0" data-jsonlen="6337" id="hwpEditorBoardContent"><!--[data-hwpjson]{', '}--></div><br/><span style="font-family: Verdana; font-size: 14pt; color: rgb(0, 0, 0);">전공소개</span></h3><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 11pt;">향후 계속 증가할 것이 예상되는 아시아 지역의 항공 수요와 저가 항공사를 포함하는 국내 항공사 항공기 대수 증가를 고려할 때 항공정비분야 전문 인력 수요도 늘어날 것이 예상됩니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">.</span></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 11pt;">이에 항공기의 기술적 지식 및 관리능력을 보유한 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">MRO </span><span style="font-family: Verdana; font-size: 11pt;">관리 엔지니어 양성을 위한 필수 소양을 교육하고자 합니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">. </span></p><p class="0" style="line-height: 2;"><span lang="EN-US" style="font-size: 11pt; font-family: Verdana;"> </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">*<b> </b></span><b><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(10, 10, 255);">MRO </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">: </span></b><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(10, 10, 255);"><b>M</b></span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">aintenance, </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(10, 10, 255);"><b>R</b></span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">epair and </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(10, 10, 255);"><b>O</b></span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">verhaul(</span><span style="font-family: Verdana; font-size: 11pt;">항공정비산업</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">)</span></p><p class="0" style="font-size: 11pt; line-height: 2;"><span style="font-family: Verdana; font-size: 12pt;"> </span><span style="font-family: Verdana; font-size: 12pt;">\xa0</span><span style="font-family: Verdana; font-size: 12pt;"> </span><o:p></o:p></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-weight: bold; font-size: 14pt; color: rgb(0, 0, 0);">참여학부</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-weight: bold; font-size: 14pt; color: rgb(0, 0, 0);">(</span><span style="font-family: Verdana; font-weight: bold; font-size: 14pt; color: rgb(0, 0, 0);">과</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-weight: bold; font-size: 14pt; color: rgb(0, 0, 0);">)</span></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 11pt;">항공우주 및 기계공학부</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">, </span><span style="font-family: Verdana; font-size: 11pt;">항공전자정보공학부</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">, </span><span style="font-family: Verdana; font-size: 11pt;">신소재공학과</span></p><p class="0" style="font-size: 11pt; line-height: 2;"><span style="font-family: Verdana; font-s ...
# $(document).ready(function() {
# });
#
# }-->Interdisciplinary Program of Aviation Maintenance System Engineering<!--[data-hwpjson]{
# }-->전공소개향후 계속 증가할 것이 예상되는 아시아 지역의 항공 수요와 저가 항공사를 포함하는 국내 항공사 항공기 대수 증가를 고려할 때 항공정비분야 전문 인력 수요도 늘어날 것이 예상됩니다.이에 항공기의 기술적 지식 및 관리능력을 보유한 MRO 관리 엔지니어 양성을 위한 필수 소양을 교육하고자 합니다.  * MRO : Maintenance, Repair and Overhaul(항공정비산업)   참여학부(과)항공우주 및 기계공학부, 항공전자정보공학부, 신소재공학과   진출분야항공정비사, 항공기제작업체, 지상조업업체 등(대한항공 등 항공사, 한국공항, 정부산하연구소 등)   <!--[data-hwpjson]{
# }-->교과과정 구성현황<!--[data-hwpjson]{
# }-->
# 구분 : 항공우주 및 기계공학부
# 과목 수 : 8과목
#
# 구분 : 항공전자정보공학부
# 과목 수 : 1과목
#
# 구분 : 신소재공학과
# 과목 수 : 3과목
#
# 구분 : 공과대학 융합전공
# 과목 수 : 13과목
#
# 합계 : 25과목
# 주요교과목 (2023학년도 기준 / 전필과목)
# 학년 : 3
# 학기 : 1
# 학점 : 3
# 시수 : 3
# 이수구분 : 전필
# 학수번호 : MI3308
# 주요교과목 : 항공기엔진구조
# 대체인정 : 왕복기관(AM4316) & 가스터빈기관(AM4320)
#
# 학년 : 3
# 학기 : 1
# 학점 : 3
# 시수 : 3
# 이수구분 : 전필
# 학수번호 : MI3303
# 주요교과목 : 항공전기전자시스템
# 대체인정 :
#
# 학년 : 3
# 학기 : 2
# 학점 : 3
# 시수 : 3
# 이수구분 : 전필
# 학수번호 : MI3304
# 주요교과목 : 항공기 MRO 실습 I-A
# 대체인정 :
#
# 학년 : 3
# 학기 : 2
# 학점 : 3
# 시수 : 3
# 이수구분 : 전필
# 학수번호 : MI3305
# 주요교과목 : 항공기 MRO 실습 I-B
# 대체인정 :
#
# 학년 : 4
# 학기 : 1
# 학점 : 4
# 시수 : 3
# 이수구분 : 전필
# 학수번호 : MI3302
# 주요교과목 : 비행항공역
# <!--[data-hwpjson]{
# }-->* 항우기 학생 외 타학부(과) 학생 또한 항우기 대체과목 인정이 가능하며 수강신청 기간 내 융합전공 사무실에 알려주시기 바랍니다.<!--[data-hwpjson]{
# }-->   ※ 이수조건 : 총 36학점 이상 (전필 30학점 + 전선 6학점 이상)-&gt; 주전공 이수과목과 최대 12학점까지 중복 인정(융합전공 이수학점에 포함)   ☞ 다운로드 : 학년도별 전공 교과과정표 (자료실 &gt; 교과과정표) <!--[data-hwpjson]{
# }--><!--[data-hwpjson]{
#
# %%%%%%%%%%%%%%%%%%%
# -------5-------
# 20
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '}--></div><div class="hwp_editor_board_content" data-hjsonver="1.0" data-jsonlen="7457" id="hwpEditorBoardContent"></div><div class="hwp_editor_board_content" data-hjsonver="1.0" data-jsonlen="9456" id="hwpEditorBoardContent"><!--[data-hwpjson]{', '}--></div><h3><br/></h3><p class="0" style="line-height: 1.8;"><span style="font-family: 나눔고딕, NanumGothic; font-weight: bold; font-size: 12pt; color: rgb(0, 0, 255);"><span style="color: rgb(58, 50, 195); font-family: Verdana;"><span style="font-size: 14pt; color: rgb(0, 0, 0); font-family: Verdana;">\xa0교통안전공단 항공정비사 자격취득 절차</span>\xa0</span></span></p><div align="center" style="text-align: center;"><img alt="" src="data:image/png;base64,..." style="font-family: 돋움, Dotum, Helvetica, sans-serif; font-size: 12px;"/></div><p class="0" style="line-height: 1.8;"><span style="font-family:함초롬돋움;mso-fareast-font-family:함초롬돋움;font-weight:bold;font-size:11.0pt;color:#0000ff;"><br/><br/><span style="font-size: 14pt; font-family: Verdana; color: rgb(0, 0, 0);">응시자격 </span></span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(125, 125, 125);">(</span><span style="font-family: Verdana; font-size: 11pt; color: rgb(125, 125, 125);">항공안전법 시행규칙 제</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(125, 125, 125);">75</span><span style="font-family: Verdana; font-size: 11pt; color: rgb(125, 125, 125);">조 및 별표 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt; color: rgb(125, 125, 125);">4)</span></p><p align="left" class="0" style="text-align: left; line-height: 1.8;"><span style="font-family: Verdana; font-size: 11pt;">☞ 항공기종류한정 조건 중 관련대학 이수사항 충족 시 응시자격 신청이 가능합니다.\xa0</span></p><p class="0" style="line-height: 1.8;"><span style="font-family: Verdana; font-size: 11pt;">\xa0 \xa0 이외 기타 조건은 교통안전공단 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">“</span><span style="font-family: Verdana; font-size: 11pt;">항공정비사 항공자격안내" 참조</span></p><div class="hwp_editor_board_content" data-hjsonver="1.0" data-jsonlen="8944" id="hwpEditorBoardContent"><!--[data-hwpjson]{', '}--></div><p style="line-height: 1.8;"><span lang="EN-US" style=""><span style="color: rgb(0, 0, 255); font-family: Verdana; font-size: 11pt; letter-spacing: 0pt;">\xa0 \xa0 \xa0</span><span style="color: rgb(0, 0, 255); font-family: Verdana; font-size: 11pt; letter-spacing: 0pt;">(</span><span style="font-family: 나눔고딕, NanumGothic; color: rgb(0, 0, 238);"><span style="font-size: 14.6667px; font-family: Verdana;"><a href="https://www.kotsa.or.kr/portal/contents.do?menuCode=02010200">https://www.kotsa.or.kr/portal/contents.do?menuCode=02010200</a></span></span><span style="font-family: 함초롬돋움; color: rgb(0, 0, 255);"><span style="font-size: 11pt; letter-spacing: 0pt;"><span style="font-family: Verdana;">)<br/></span></span></span></span>\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0<img alt="" src="data:image/png;base64,..." style="text-align: center;"/></p><span style="font-family: 함초롬돋움; color: rgb(0, 0, 255);"><span style="font-size: 11pt; letter-spacing: 0pt;"><br/></span></span><span style="font-family: Verdana; font-size: 14pt; font-weight: bold;"><br/><br/>항공정비사 자격시험 인정 학부\xa0교과목</span><p class="0"><span lang="EN-US" style="font-family: 함초롬돋움; letter-spacing: 0pt; font-size: 11pt; color: rgb(0, 0, 255);"><u></u></span></p><div align="center" style="text-align: center;"><div align="left" style="text-align: left; line-height: 1.8;"><b><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 12pt; color: rgb(239, 0, 124);">[2011 ~ 2016</span><span style="font-family: Verdana; font-size: 12pt; color: rgb(239, 0, 124);">학번</span><span lang="EN-US" style ...
# $(document).ready(function() {
# });
#
# }--><!--[data-hwpjson]{
# }--> 교통안전공단 항공정비사 자격취득 절차 응시자격 (항공안전법 시행규칙 제75조 및 별표 4)☞ 항공기종류한정 조건 중 관련대학 이수사항 충족 시 응시자격 신청이 가능합니다.     이외 기타 조건은 교통안전공단 “항공정비사 항공자격안내" 참조<!--[data-hwpjson]{
# }-->     (https://www.kotsa.or.kr/portal/contents.do?menuCode=02010200)                                   항공정비사 자격시험 인정 학부 교과목[2011 ~ 2016학번]
# 항공법 지정과목 : 항공법
# 교과목명 : 항공법
# 학년/학기 : 3/2
# 비고 :
#
# 항공법 지정과목 : 항공법규
# 교과목명 : 항공법
# 학년/학기 : 3/1
# 비고 :
#
# 항공법 지정과목 : 항공역학
# 교과목명 : 항공역학
# 학년/학기 : 3/1
# 비고 : 인적요소 포함 / 1과목 택일
#
# 항공법 지정과목 : 항공기성능
# 교과목명 : 항공기성능
# 학년/학기 : 4/1
# 비고 :
#
# 항공법 지정과목 : 항공우주구조역학
# 교과목명 : 항공우주구조역학
# 학년/학기 : 3/1
# 비고 : 1과목 택일
#
# 항공법 지정과목 : 응용구조역학
# 교과목명 : 응용구조역학
# 학년/학기 : 3/2
# 비고 :
#
# 항공법 지정과목 : 왕복기관
# 교과목명 : 왕복기관
# 학년/학기 : 3/1
# 비고 : 모두 이수
#
# 항공법 지정과목 : 가스터빈기관
# 교과목명 : 가스터빈기관
# 학년/학기 : 3/2
# 비고 : 1과목 택일
#
# ...
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D98A2C2EEF0230000003A0",
# "01D98A2C2EEF0230000003A0": {
# "np": "01D98A2C2EEF0230000003A1",
# "id": 0,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 3,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D98A2C2EEF02300000039E"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D98A2C2EEF02300000039F"
# }
# ,
# {
# "t": "4) 유의사항"
# }
# ]
# }
# ]
# },
# "01D98A2C2EEF0230000003A1": {
# "np": "01D98A2C2EEF0230000003A2",
# "id": -2147483648,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "t": "   - 융합전공의 전필과 전필선은 반드시 이수하되, 주전공 교과목을 우선으로 이수하여야 함"
# }
# ]
# }
# ]
# },
# "01D98A2C2EEF0230000003A2": {
# "np": "01D98A2C2EEF0230000003A3",
# "id": -2147483648,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "t": "     (단, 주전공 교과목을 우선 이수 후 모자란 학점은 타학부(과) 교과목으로 이수하여야 함)"
# }
# ]
# }
# ]
# },
# "01D98A2C2EEF0230000003A3": {
# "np": "01D98A2C2EEF0230000003A4",
# "id": -2147483648,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "t": "   - 융합전공의 총 36학점은 전체 졸업이수 학점 130 ~ 140학점에 포함되며, "
# }
# ]
# }
# ]
# },
# "01D98A2C2EEF0230000003A4": {
# "np": "01D98A2C2EEF0230000003A5",
# "id": -2147483648,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "t": "     중복학점(최대 12학점)은 융합전공의 총 36학점 및 주전공 총 취득학점에 포함됨"
# }
# ]
# }
# ]
# },
# "01D98A2C2EEF0230000003A5": {
# "np": "01D98A2C2EEF0230000003A6",
# "id": -2147483648,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "t": "     (단, 대체과목은 중복학점으로 인정 불가)"
# }
# ]
# }
# ]
# },
# "01D98A2C2EEF0230000003A6": {
# "np": "",
# "id": -2147483648,
# "pp": "01D98A2C2EEF0230000003AC",
# "si": "01D98A2C2EEF0230000003AD",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2C2EEF0230000003AA",
# "ch": [
# {
# "t": "   - 즉, 중복학점 12학점을 제외하고 실제 융합전공 학점은 24학점(전필+전필선+전선) 이상 취득 해야함"
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D98A2C2EEF02300000039E": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D98A2C2EEF0230000003A7",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D98A2C2EEF0230000003A7",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D98A2C2EEF0230000003A7",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D98A2C2EEF02300000039F": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->  <!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 10418",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2023-05-19T17:26:33.209Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D98A2B9F3815A00000035F": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D98A2B9F3815A000000360": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D98A2B9F3815A000000361": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D98A2B9F3815A000000360",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D98A2B9F3815A000000362": {
# "id": 1,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D98A2B9F3815A000000360",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D98A2B9F3815A000000363": {
# "id": 2,
# "he": 1100,
# "tc": 255,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D98A2B9F3815A000000360",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D98A2B9F3815A000000364": {
# "id": 3,
# "he": 1100,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D98A2B9F3815A000000360",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 1,
# "us": 1,
# "uc": 16711680,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D98A2B9F3815A000000365": {
# "id": 4,
# "he": 1100,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D98A2B9F3815A000000360",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D98A2B9F3815A000000366": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D98A2B9F3815A000000367": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D98A2B9F3815A000000366",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D98A2B9F3815A000000360",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D98A2B9F3815A000000368": {
# "id": 1,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D98A2B9F3815A000000366",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D98A2B9F3815A000000360",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D98A2B9F3815A000000369": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D98A2B9F3815A000000367",
# "cp": "01D98A2B9F3815A000000361",
# "ns": "01D98A2B9F3815A000000369",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D98A2B9F3815A000000353",
# "01D98A2B9F3815A000000353": {
# "np": "01D98A2B9F3815A000000354",
# "id": 0,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 3,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000365",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D98A2B9F3815A000000350"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D98A2B9F3815A000000351"
# }
# ,
# {
# "t": "졸업이수학점"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A000000354": {
# "np": "01D98A2B9F3815A000000355",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": "졸업이수학점 = 주전공학점(심화전공 학점) + 교양학점 + 다전공학점(부전공/복수전공/융합전공 등)"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A000000355": {
# "np": "01D98A2B9F3815A000000356",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": " * 2012학번까지 : 총 140학점 이상 (학석사연계과정생은 134학점, 대학원과목 6학점)"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A000000356": {
# "np": "01D98A2B9F3815A000000357",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": " * 2013학번부터 : 총 130학점 이상 (학석사연계과정생은 124학점, 대학원과목 6학점)"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A000000357": {
# "np": "01D98A2B9F3815A000000359",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000368",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": "   (참조 : "
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D98A2B9F3815A000000352"
# }
# ]
# }
# ,
# {
# "cp": "01D98A2B9F3815A000000364",
# "ch": [
# {
# "t": "http://www.kau.ac.kr/web/pages/gc86720h.do"
# }
# ]
# }
# ,
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D98A2B9F3815A000000358"
# }
# ,
# {
# "t": ")"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A000000359": {
# "np": "01D98A2B9F3815A00000035A",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000368",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": " "
# }
# ]
# }
# ,
# {
# "cp": "01D98A2B9F3815A000000363",
# "ch": [
# {
# "t": "* 2019학번부터 : 주전공+심화전공 또는 주전공+다전공을 이수해야 졸업 가능"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A00000035A": {
# "np": "01D98A2B9F3815A00000035B",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000368",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000363",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A00000035B": {
# "np": "01D98A2B9F3815A00000035C",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000365",
# "ch": [
# {
# "t": "융합전공 이수 학점"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A00000035C": {
# "np": "01D98A2B9F3815A00000035D",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": "1) 총 취득학점 : 총 36학점 이상 (전필+전필선+전선)"
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A00000035D": {
# "np": "01D98A2B9F3815A00000035E",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": "   * 중복 12학점을 제외한 24학점은 졸업 시 전공구분이 ”융합전공“으로 표시 되며, 융합전공으로 인정된 학점은 주전공 학점과 구분됨."
# }
# ]
# }
# ]
# },
# "01D98A2B9F3815A00000035E": {
# "np": "",
# "id": -2147483648,
# "pp": "01D98A2B9F3815A000000367",
# "si": "01D98A2B9F3815A000000369",
# "bf": 0,
# "ru": [
# {
# "cp": "01D98A2B9F3815A000000362",
# "ch": [
# {
# "t": "2) 대체과목 : 융합전공에서 지정한 주전공의 과목. 대체과목 이수 시 융합전공 학점으로 인정 (단, 중복학점으로 인정 불가)"
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D98A2B9F3815A000000350": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D98A2B9F3815A00000035F",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D98A2B9F3815A00000035F",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D98A2B9F3815A00000035F",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D98A2B9F3815A000000351": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# ,
# "01D98A2B9F3815A000000352": {
# "cc": 3,
# "ci": 627600491,
# "fb": {
# "id": 1219091276,
# "ty": 627600491,
# "ed": false,
# "la": 5,
# "di": true,
# "pa": {
# "fi": false,
# "pr": 0,
# "co": "http\\://www.kau.ac.kr/web/pages/gc86720h.do;1;0;0;"
# },
# "zo": 4294967295,
# "fi": 627600491
# }
# }
# ,
# "01D98A2B9F3815A000000358": {
# "fo": "01D98A2B9F3815A000000352",
# "cc": 4,
# "ci": 6843499,
# "zo": 4294967295
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
