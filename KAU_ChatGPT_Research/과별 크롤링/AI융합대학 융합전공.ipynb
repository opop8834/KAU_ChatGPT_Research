# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "AI융합대학_융합전공_data"
number_html = 6
url = """http://college.kau.ac.kr/web/pages/gc92570h.do
http://college.kau.ac.kr/web/pages/gc994h.do
http://college.kau.ac.kr/web/pages/gc96575h.do
http://college.kau.ac.kr/web/pages/gc46200h.do
http://college.kau.ac.kr/web/pages/gc50493h.do
http://college.kau.ac.kr/web/pages/gc67219h.do
http://college.kau.ac.kr/web/pages/gc93840h.do
http://college.kau.ac.kr/web/pages/gc7781h.do
http://college.kau.ac.kr/web/pages/gc44253h.do
http://college.kau.ac.kr/web/pages/gc16264h.do
http://college.kau.ac.kr/web/pages/gc96015h.do
http://college.kau.ac.kr/web/pages/gc73408h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 6:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc92570h.do', 'http://college.kau.ac.kr/web/pages/gc994h.do', 'http://college.kau.ac.kr/web/pages/gc96575h.do', 'http://college.kau.ac.kr/web/pages/gc46200h.do', 'http://college.kau.ac.kr/web/pages/gc50493h.do', 'http://college.kau.ac.kr/web/pages/gc67219h.do', 'http://college.kau.ac.kr/web/pages/gc93840h.do', 'http://college.kau.ac.kr/web/pages/gc7781h.do', 'http://college.kau.ac.kr/web/pages/gc44253h.do', 'http://college.kau.ac.kr/web/pages/gc16264h.do', 'http://college.kau.ac.kr/web/pages/gc96015h.do', 'http://college.kau.ac.kr/web/pages/gc73408h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 13
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3><p style="line-height: 1.8;">AI융합전공 소개<br/><br/>', '<span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">AI</span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">융합전공은\xa0</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">4</span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">차 산업 혁명 시대를 대비하는 융합형 인재를 양성하기 위하여 경영</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">, </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">공학</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">, </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">물류 교통</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">, </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">운항 등의 다양한 산업분야의 전공 기술에 </span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">AI·DATA·SW</span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">기술을 적용할 수 있도록 첨단 융합 및 실무 역량을 학생들에게 배양하는 것을 목표로 한다</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">. </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">본 전공은\xa0</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">2021</span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">학년부터 경영</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">, </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">신소재</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">, </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">물류 관련 </span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-font-width: 100%; mso-text-raise: 0pt;">AI </span><span style="color: rgb(37, 37, 37); font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">융합전공을 개설하여 운영하고 있으며</span><span lang="EN-US" style="color: rgb(37, 37, 37); letter-spacing: 0pt; font-family: 돋움,Dotum; font-size: 12pt; mso-fareast-font-family: 함초롬바탕; mso-fo ...
#
# $(document).ready(function() {
# });
#
# AI융합전공 소개
# AI융합전공은 4차 산업 혁명 시대를 대비하는 융합형 인재를 양성하기 위하여 경영, 공학, 물류 교통, 운항 등의 다양한 산업분야의 전공 기술에 AI·DATA·SW기술을 적용할 수 있도록 첨단 융합 및 실무 역량을 학생들에게 배양하는 것을 목표로 한다. 본 전공은 2021학년부터 경영, 신소재, 물류 관련 AI 융합전공을 개설하여 운영하고 있으며, 주요 참여 학부(과)는 소프트웨어학과, AI자율주행시스템공학과, 항공전자정보공학부, 경영학부, 신소재공학과, 항공교통물류학부이다.AI융합학부 전공   ● AI융합경영전공  ●  AI융합신소재전공   ●  AI융합 물류전공  ●  IT-BIZ융합전공  ●  자율주행 융합전공
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 106
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교수진</h3>', '</div>', '', '<ul class="prs_list">', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/ai_www/prof/이인복_교수.jpg"/>', '</span>', '<h4>이인복<span>교수</span></h4>', '<p>AI융합전공 총괄 주임교수</p>', '', '<ul class="prs_info">', '<li>알고리즘 / 이산수학, 문제해결기법 분야<br/></li>', '<li>전자관 409호<br/>', '</li>', '<li>(02)300-0412</li>', '<li>inboklee@kau.ac.kr</li>', '</ul>', '', '</li>', '', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/biz_www/introduce/김진기.jpg"/>', '</span>', '', '<h4>김진기<span>교수</span></h4>', '<p>AI융합경영전공 주임교수</p>', '', '<ul class="prs_info">', '<li>경영학 분야</li>', '<li>본관 309호</li>', '<li>(02)300-0353</li>', '<li>kimjk@kau.ac.kr</li>', '</ul>', '', '</li>', '', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/송보미.jpg"/>', '</span>', '', '<h4>송보미<span>교수</span></h4>', '<p>AI융합물류전공 주임교수</p>', '<ul class="prs_info">', '<li>산업공학 / 데이터 애널리틱스 분야</li>', '<li>본관 411호</li>', '<li>(02)300-0347</li>', '<li>bmsong@kau.ac.kr</li>', '</ul>', '</li>', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/materials_www/introduce/prof/윤요한%20교수님.jpg"/></span>', '', '<h4>윤요한<span>교수</span></h4>', '<p>AI융합신소재전공 주임교수</p>', '', '<ul class="prs_info">', '<li>전자 / 광학재료 분야</li>', '<li>기계관 414호</li>', '<li>(02)300-0162</li>', '<li>yyoon@kau.ac.kr</li>', '</ul>', '', '</li>', '', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/ai_www/prof/김필은_교수.jpg"/>', '</span>', '', '<h4>김필은<span>교수</span></h4>', '<p>AI자율주행융합전공 주임교수</p>', '<ul class="prs_info">', '<li>모바일 로봇 경로 계획 / 자율주행 시스템 설계 분야</li>', '<li>기계관 211호</li>', '<li>(02)300-0173</li>', '<li>pkkim@kau.ac.kr</li>', '</ul>', '</li>', '', '</ul>', '', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 교수진
#
# 이인복교수
# AI융합전공 총괄 주임교수
#
# 알고리즘 / 이산수학, 문제해결기법 분야
# 전자관 409호
#
# (02)300-0412
# inboklee@kau.ac.kr
#
# 김진기교수
# AI융합경영전공 주임교수
#
# 경영학 분야
# 본관 309호
# (02)300-0353
# kimjk@kau.ac.kr
#
# 송보미교수
# AI융합물류전공 주임교수
#
# 산업공학 / 데이터 애널리틱스 분야
# 본관 411호
# (02)300-0347
# bmsong@kau.ac.kr
#
# 윤요한교수
# AI융합신소재전공 주임교수
#
# 전자 / 광학재료 분야
# 기계관 414호
# (02)300-0162
# yyoon@kau.ac.kr
#
# 김필은교수
# AI자율주행융합전공 주임교수
#
# 모바일 로봇 경로 계획 / 자율주행 시스템 설계 분야
# 기계관 211호
# (02)300-0173
# pkkim@kau.ac.kr
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 16
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>AI융합전공 운영내규<br/>', '<br type="_moz"/>', '</h3>', '</div>', '<br/><strong>제1조\xa0(목적</strong>)이\xa0내규는\xa0「학칙」\xa0제37조(다\xa0전공),\xa0「학칙\xa0시행세칙」\xa0제24조(다\xa0전공)에\xa0의한\xa0AI\xa0융합전공(이하\xa0“본 전공”으로\xa0한다)의\xa0운영에\xa0필요한\xa0세부\xa0사항을\xa0규정함을\xa0목적으로\xa0한다.<br/><br/><strong>제2조\xa0(전공</strong>)\xa0본 전공에서는\xa0다음\xa0각\xa0호의 세부 융합전공을\xa0운영한다.<br/>\xa0\xa01.\xa0AI융합경영전공\xa0<br/>\xa0\xa02.\xa0AI융합신소재전공<br/>\xa0\xa03.\xa0AI융합물류전공<br/>\xa0\xa04.\xa0IT-Biz\xa0융합전공<br/>\xa0 5. 자율주행융합전공<br/>\xa0<br/><strong>제3조</strong>\xa0<strong>(운영위원회)</strong>\xa0①\xa0본 전공의\xa0운영에\xa0관한\xa0사항을\xa0심의하기\xa0위하여\xa0운영위원회(이하\xa0“위원회”라\xa0한다)를\xa0구성하고\xa0운영한다.\xa0<br/>\xa0\xa0②\xa0운영위원회의\xa0위원장은 융합전공 주임교수로\xa0하며,\xa0당연직\xa0위원과\xa0필요에\xa0따라\xa0임명직\xa0위원으로\xa0구성할\xa0수\xa0있다.<br/>\xa0\xa0③\xa0당연직\xa0위원은 융합전공\xa0주임교수로\xa0하며,\xa0임명직\xa0위원은 각 융합전공별 주임교수(이하 "전공주임교수"으로 한다) 및 위촉하는\xa0<br/>\xa0 \xa0 \xa0 약간\xa0명의\xa0교원으로\xa0한다.<br/>\xa0\xa0④\xa0운영위원회의\xa0기능은\xa0다음\xa0각호와\xa0같다.<br/>\xa0 \xa0 \xa01. 전공\xa0주임교수\xa0선임<br/>\xa0 \xa0 \xa02.\xa0교과과정\xa0운영\xa0등\xa0중요한\xa0논의\xa0<br/>\xa0\xa0⑤\xa0운영위원회\xa0회의는\xa0본 융합전공 주임교수가 소집하고\xa0재적\xa0위원\xa0과반수의\xa0출석과\xa0출석위원\xa0과 반수의\xa0찬성으로\xa0의결한다.<br/><br/><strong>제4조</strong>\xa0<strong>(교과과정\xa0편성)</strong>\xa0①\xa0융합전공의\xa0교과과정은\xa0융합\xa0전공별\xa0참여\xa0학부(과)에\xa0이미\xa0편성된\xa0교과목으로\xa0구성하되,\xa0필요하면\xa0운영위원회의\xa0승인을\xa0받아\xa0융합전공\xa0신규\xa0교과목을\xa0편성할\xa0수\xa0있다.<br/>\xa0\xa0②\xa0융합전공의\xa0교과목\xa0등\xa0기타\xa0운영에\xa0관한\xa0세부사항은\xa0AI\xa0융합전공 운영세칙으로\xa0정한다.<br/><br/><strong>제5조\xa0(모집정원)</strong>\xa0모집정원은\xa0융합\xa0전공별\xa0연\xa060명\xa0내외로하여\xa0참여\xa0학부(과)의\xa0수용\xa0능력\xa0및\xa0특성을\xa0고려하여\xa0정한다.<br/><br/><strong>제6조</strong>\xa0<strong>(신청자격)</strong>\xa0본\xa0대학교\xa0모든\xa0학부(과)의\xa01학년\xa0과정을\xa0수료한\xa0재학생은 AI융합대학 융합전공을\xa0신청할\xa0수\xa0있다.\xa0<br/>\xa0\xa0단,\xa0각 융합전공의\xa0특성에\xa0따라\xa0신청\xa0대상을\xa0제한할\xa0수\xa0있으며,\xa0세부\xa0신청\xa0자격은\xa0융합\xa0전공별로\xa0따로\xa0정한다.\xa0<br/><br/><strong>제7조</strong>\xa0<strong>(신청\xa0및\xa0이수\xa0허가\xa0절차)</strong>\xa0①\xa0융합전공을\xa0신청하려는\xa0학생은\xa0매\xa0학기\xa0개강\xa0전\xa0소정의\xa0신청\xa0기간에\xa0융합전공\xa0신청원을\xa0작성하여\xa0주전공\xa0학부(과)장을\xa0거쳐\xa0본 전공 행정부서에\xa0제출하여야\xa0한다.<br/>\xa0\xa0②\xa0제출된\xa0융합전공\xa0신청원은 세부 전공\xa0주임교수와 융합전공 주임교수의\xa0심사\xa0절차를\xa0거치며\xa0본 전공 행정부서는\xa0심사\xa0통과자\xa0<br/>\xa0 \xa0 \xa0 명단을\xa0교무처에\xa0제출한다.<br/>\xa0\xa0③\xa0교무처는\xa0심사\xa0통과자에\xa0대한\xa0총장의\xa0승인을\xa0받아\xa0이수\xa0허가자를\xa0최종적으로\xa0확정한다.<br/>\xa0<br/><strong>제8조\xa0(이수기간)</strong>\xa0융합전공\xa0이수는\xa0승인받은\xa0학기부터\xa0시작하여\xa0주전공\xa0졸업\xa0시까지\xa0완료하여야\xa0한다.<br/><br/><strong>제9조\xa0(이수요건)</strong>\xa0①\xa0융합전공\xa0이수학점은\xa036학점\xa0이상으로\xa0하며\xa0융합\xa0전공별\xa0최소\xa0전공\xa0이수학점은\xa0다음\xa0각\xa0호와\xa0같이한다.<br/>\xa0\xa01.\xa0AI융합경영전공\xa0:\xa036학점\xa0이상<br/>\xa0\xa02.\xa0AI융합신소재전공\xa0:\xa036학점\xa0이상<br/>\xa0\xa03.\xa0AI융합물류전공\xa0:\xa036학점\xa0이상<br/>\xa0\xa04.\xa0IT-Biz\xa0융합전공\xa0:\xa036학점\xa0이상<br/>\xa0 5. 자율주행융합전공 : 36학점 이상<br/>\xa0\xa0②\xa0융합전공\xa0이수하는\xa0동안\xa0요구되는\xa0학점\xa0이외에\xa0전공별\xa0추가\xa0이수요건이\xa0있는\xa0경우\xa0그\xa0기준을\xa0충족시켜야\xa0한다.<br/><br/><strong>제10조</strong>\xa0<strong>(이수\xa0및\xa0학점인정)</strong>\xa0①\xa0매\xa0학기\xa0수강\xa0신청\xa0학점\xa0및\xa0이수학점\xa0인정은\xa0주전공\xa0이수와\xa0같은\xa0절차를\xa0따른다.<br/>\xa0\xa0②\xa0주전공에서\xa0이수한\xa0교과목과\xa0융합전공\xa0교과목이\xa0중복되면\xa0학점을\xa0중복인정\xa0할\xa0수\xa0있으며\xa0융합\xa0전공별\xa0최대\xa0중복인정\xa0학점은\xa0다음\xa0각\xa0호와\xa0같다.<br/>\xa0\xa01.\xa0AI융합경영전공\xa0:\xa012학점\xa0이내<br/>\xa0\xa02.\xa0AI융합신소재전공\xa0:\xa012학점\xa0이내<br/>\xa0\xa03.\xa0AI융합물류전공\xa0:\xa012학점\xa0이내<br/>\xa0\xa04.\xa0IT-Biz\xa0융합전공\xa0:\xa012학점\xa0이내<br/>\xa0 5. 자율주행융합전공 : 12학점 이내<br/>\xa0\xa0③\xa0융합전공\xa0이수허가\xa0이전에\xa0이수한\xa0융합전공\xa0교과목도\xa0융합전공으로\xa0이수한\xa0것으로\xa0인정한다.<br/>\xa0\xa0④\xa0융합전공\xa0이수를\xa0위하여\xa0취득한\xa0학점은\xa0제14조에\xa0따른\xa0졸업 사정을\xa0마친후\xa0융합 전공\xa0교과목 및 학점으로\xa0인정<br/>\xa0 \xa0 \xa0 한다.<br/><br/><strong>제11조</strong>\xa0<strong>(학사지도)</strong>\xa0융합전공을\xa0이수하는\xa0학생은 융합\xa0전공별\xa0주임교수에게\x ...
#
# $(document).ready(function() {
# });
#
# AI융합전공 운영내규
#
# 제1조 (목적)이 내규는 「학칙」 제37조(다 전공), 「학칙 시행세칙」 제24조(다 전공)에 의한 AI 융합전공(이하 “본 전공”으로 한다)의 운영에 필요한 세부 사항을 규정함을 목적으로 한다.제2조 (전공) 본 전공에서는 다음 각 호의 세부 융합전공을 운영한다.  1. AI융합경영전공   2. AI융합신소재전공  3. AI융합물류전공  4. IT-Biz 융합전공  5. 자율주행융합전공 제3조 (운영위원회) ① 본 전공의 운영에 관한 사항을 심의하기 위하여 운영위원회(이하 “위원회”라 한다)를 구성하고 운영한다.   ② 운영위원회의 위원장은 융합전공 주임교수로 하며, 당연직 위원과 필요에 따라 임명직 위원으로 구성할 수 있다.  ③ 당연직 위원은 융합전공 주임교수로 하며, 임명직 위원은 각 융합전공별 주임교수(이하 "전공주임교수"으로 한다) 및 위촉하는       약간 명의 교원으로 한다.  ④ 운영위원회의 기능은 다음 각호와 같다.     1. 전공 주임교수 선임     2. 교과과정 운영 등 중요한 논의   ⑤ 운영위원회 회의는 본 융합전공 주임교수가 소집하고 재적 위원 과반수의 출석과 출석위원 과 반수의 찬성으로 의결한다.제4조 (교과과정 편성) ① 융합전공의 교과과정은 융합 전공별 참여 학부(과)에 이미 편성된 교과목으로 구성하되, 필요하면 운영위원회의 승인을 받아 융합전공 신규 교과목을 편성할 수 있다.  ② 융합전공의 교과목 등 기타 운영에 관한 세부사항은 AI 융합전공 운영세칙으로 정한다.제5조 (모집정원) 모집정원은 융합 전공별 연 60명 내외로하여 참여 학부(과)의 수용 능력 및 특성을 고려하여 정한다.제6조 (신청자격) 본 대학교 모든 학부(과)의 1학년 과정을 수료한 재학생은 AI융합대학 융합전공을 신청할 수 있다.   단, 각 융합전공의 특성에 따라 신청 대상을 제한할 수 있으며, 세부 신청 자격은 융합 전공별로 따로 정한다. 제7조 (신청 및 이수 허가 절차) ① 융합전공을 신청하려는 학생은 매 학기 개강 전 소정의 신청 기간에 융합전공 신청원을 작성하여 주전공 학부(과)장을 거쳐 본 전공 행정부서에 제출하여야 한다.  ② 제출된 융합전공 신청원은 세부 전공 주임교수와 융합전공 주임교수의 심사 절차를 거치며 본 전공 행정부서는 심사 통과자       명단을 교무처에 제출한다.  ③ 교무처는 심사 통과자에 대한 총장의 승인을 받아 이수 허가자를 최종적으로 확정한다. 제8조 (이수기간) 융합전공 이수는 승인받은 학기부터 시작하여 주전공 졸업 시까지 완료하여야 한다.제9조 (이수요건) ① 융합전공 이수학점은 36학점 이상으로 하며 융합 전공별 최소 전공 이수학점은 다음 각 호와 같이한다.  1. AI융합경영전공 : 36학점 이상  2. AI융합신소재전공 : 36학점 이상  3. AI융합물류전공 : 36학점 이상  4. IT-Biz 융합전공 : 36학점 이상  5. 자율주행융합전공 : 36학점 이상  ② 융합전공 이수하는 동안 요구되는 학점 이외에 전공별 추가 이수요건이 있는 경우 그 기준을 충족시켜야 한다.제10조 (이수 및 학점인정) ① 매 학기 수강 신청 학점 및 이수학점 인정은 주전공 이수와 같은 절차를 따른다.  ② 주전공에서 이수한 교과목과 융합전공 교과목이 중복되면 학점을 중복인정 할 수 있으며 융합 전공별 최대 중복인정 학점은 다음 각 호와 같다.  1. AI융합경영전공 : 12학점 이내  2. AI융합신소재전공 : 12학점 이내  3. AI융합물류전공 : 12학점 이내  4. IT-Biz 융합전공 : 12학점 이내  5. 자율주행융합전공 : 12학점 이내  ③ 융합전공 이수허가 이전에 이수한 융합전공 교과목도 융합전공으로 이수한 것으로 인정한다.  ④ 융합전공 이수를 위하여 취득한 학점은 제14조에 따른 졸업 사정을 마친후 융합 전공 교과목 및 학점으로 인정      한다.제11조 (학사지도) 융합전공을 이수하는 학생은 융합 전공별 주임교수에게 수강지도, 학업상담 등의 학사지도를 받는다.제12조 (장학금) ① 장학금의 지급은 장학금 지급 규정에 따르며 장학생은 다음 각호의 조건을 모두 만족하는 학생 중에서 선발한다.  1. 직전 학기 전체 교과목을 12학점 이상 이수하고 이수 평점이 3.5 이상인 자  2. 융합전공을 1개 학기 이상 이수한 자  3. 직전 학기 융합전공 교과목을 6학점 이상 이수한 자  ② 제1항을 만족하는 자로서 두 명 이상의 성적이 같은 경우 다음 각 호와 같이 우선순위를 정한다.  1. 융합전공 교과목의 이수평점이 높은 자  2. 융합전공 교과목의 이수학점이 높은 자  3. 융합전공 교과목 누적 이수학점이 높은 자  4. 융합전공 주임교수의 지도·상담 결과 학업이 더 우수하다고 인정되는 자  ③ 그 밖의 장학관계사항은 운영위원회의 결정에 따른다.제12조의1(장학금의 반환) 선정된 장학생이 다음 각 호에 해당하면 수혜자는 등록금 보전 목적의 장학금을 전액 반환하여야 한다.  1. 장학금 지급 학기인 당해 학기에 융합전공을 포기한 자  2. 장학금 받은 학기에 자퇴 또는 제적된 자  3. 미등록 휴학한 자제13조 (이수포기) ① 융합전공의 이수를 포기하고자 하는 자는 해당 학기 말 1개월 전까지 융합전공 포기 신청원을 본 융합 전공 행정부서에 제출하여야 한다.  ② 융합전공을 포기하면 이미 이수한 융합전공 교과목은 일반선택 학점으로 인정한다.제14조 (졸업사정) ① 융합전공을 위한 소정의 교과과정 이수를 완료한 학생(해당 학기 완료 예정인 학생을 포함한다)은 주전공 졸업 사정 기간에 융합전공 이수 확인서를 본 융합전공 행정부서에 제출하여야 한다.  ② 제출된 융합전공 이수확인서는 전공 주임교수와 융합전공 주임교수의 심사 절차를 거치며 융합전공 행정부서는 심사 통과자       명단을 교무처에 제출한다.  ③ 교무처는 심사 통과자에 대한 졸업 사정위원회나 총장의 승인을 받아 졸업 허가자를 확정한다.제15조 (졸업유보) 주전공 졸업 때까지 융합전공 학점을 모두 이수하지 못한 경우 본인의 희망에 따라 융합전공 이수를 완료할 때까지 주전공 학부(과)의 졸업을 유보할 수 있다.제16조 (학위수여) 졸업요건이 충족된 융합전공 이수자에게는 주전공 학위명과 다음 각 호의 융합 전공별 학위명을 병행 표기한 학위 증서를 수여 한다.  1. AI융합경영전공 : 공학트랙-공학사, 경영트랙-경영학사  2. AI융합신소재전공 : 공학사  3. AI융합물류전공 : 이학사  4. IT-Biz 융합전공 : 공학트랙-공학사, 경영트랙-경영학사  5. 자율주행융합전공 : 공학사제17조 (기타) 이 내규에 정하지 아니한 사항은 「학칙」, 「학칙 시행세칙」및 관련 학사 규정에 따른다.부    칙1. (시행일) 이 내규는 2021년 8월 1일부터 시행한다.2. (시행일) 이 개정된 내규는 2022년 11월 22일부터 시행하되, 2022년 9월 1일부터 적용한다
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 16
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3>행정실</h3></div><p>\xa0김용범</p>', '<table class="table_01"><tbody><tr><th>담당업무</th><td style="text-align: left;">융합전공 업무 총괄</td></tr><tr><th>이메일</th><td style="text-align: left;"><a href="mailto:hschang@kau.ac.kr">kimyb@kau.ac.kr</a></td></tr><tr><th>연락처</th><td style="text-align: left;">02- 300 - 0259\xa0 /\xa0FAX \xa002 - 300 - 0379</td></tr><tr><th>사무실</th><td style="text-align: left;">기계관 428호</td></tr></tbody></table>', '<p><br/><br/>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0<span class="portrait"><br/>', '<br/>', '<br/>', '<br/></span></p>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 행정실 김용범
# 담당업무 : 융합전공 업무 총괄
# 이메일 : kimyb@kau.ac.kr
# 연락처 : 02-300-0259 / FAX 02-300-0379
# 사무실 : 기계관 428호
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 2756
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit" style="box-sizing: border-box; margin: 0px 0px 45px; padding: 0px; border: 0px; position: relative; color: rgb(51, 51, 51); font-family: NotoSans, HelveticaNeue-Light, AppleSDGothicNeo-Light, Arial, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);"><h3 style="box-sizing: border-box; margin: 0px; padding: 0px 10px 0px 0px; border: 0px; font-size: 30px; display: inline-block; color: rgb(60, 82, 155); position: relative; z-index: 1;">융합전공 신청안내</h3></div><div class="article_banner_02 m_mb_01" style="box-sizing: border-box; margin: 0px; padding: 0px; border: 0px; color: rgb(51, 51, 51); font-family: NotoSans, HelveticaNeue-Light, AppleSDGothicNeo-Light, Arial, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);"><div class="misc_dgn_02" style="box-sizing: border-box; margin: 0px; padding: 0px; border: 0px;"><h4 style="box-sizing: border-box; margin: 0px; padding: 0px; border: 0px; font-weight: normal; font-size: 16pt;"><p class="0" style="line-height:130%;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;">2023</span><span style="font-family:맑은 고딕;mso-fareast-font-family:맑은 고딕;font-size:11.0pt;">학년도 2</span><span style="font-family:맑은 고딕;mso-fareast-font-family:맑은 고딕;font-size:11.0pt;">학기 </span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;">AI</span><span style="font-family:맑은 고딕;mso-fareast-font-family:맑은 고딕;font-size:11.0pt;">융합대학 </span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;">AI</span><span style="font-family:맑은 고딕;mso-fareast-font-family:맑은 고딕;font-size:11.0pt;">융합전공 신청을 다음과 같이 안내하오니 관심 있는 학생들은 신청하여 주시기 바랍니다</span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;">.</span></p><p class="0" style="line-height:130%;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;font-size:11.0pt;"> \xa0 <o:p></o:p></p><p class="0" style="line-height:130%;text-align:center;word-break:keep-all;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-size:11.0pt;"> </span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;">- </span><span style="font-family:맑은 고딕;mso-fareast-font-family:맑은 고딕;font-size:11.0pt;">다\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 음 </span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-size:11.0pt;">-</span></p><p class="0" style="line-height:130%;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;font-size:11.0pt;"> \xa0 <o:p></o:p></p><p class="0" style="line-height:130%;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-family:맑은 고딕;mso-ascii-font-family:맑은 고딕;mso-font-width:100%;letter-spacing:0pt;mso-text-raise:0pt;font-weight:bold;font-size:12.0pt;">1. </span><span style="font-family:맑은 고딕;mso-fareast-font-family:맑은 고딕;font-weight:bold;font-size:12.0pt;">신청 대상</span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕;font-size:11.0pt;"> </span><span lang="EN-US" style="mso-fareast-font-family:맑은 고딕; ...
#
# $(document).ready(function() {
# });
#
# 융합전공 신청안내2023학년도 2학기 AI융합대학 AI융합전공 신청을 다음과 같이 안내하오니 관심 있는 학생들은 신청하여 주시기 바랍니다.    - 다            음 -   1. 신청 대상 : 2023학년도 2학기 기준 1학년 이상 수료한 학부 재학생    단, 8학기 이상 이수자 중 당해 학기 졸업요건 충족자는 지원 불가   2. 대상 전공   ○ AI융합경영전공, AI융합물류전공, AI융합신소재전공, IT-Biz융합전공 , 자율주행 융합전공  ○ 전공별 소개 자료: 학교 홈페이지&gt;AI융합대학&gt;AI융합전공 소개 참조      ☞ http://college.kau.ac.kr/web/pages/gc7781h.do   3. 선발 일정  ○ 신청 기간 : 2023. 6. 1(목) ~ 2023. 6. 30(금)    ○ 제출서류    - 융합전공 신청원 1부    - 성적증명서(열람용) 1부  ○ 제출 방법 : 학부 사무실(기계관 428호), 이메일 접수(aicon@kau.ac.kr)    ※ 이메일 전송 후 반드시 유선(02-300-0259)으로 본인 접수내역 확인 요망   ○ 승인자 발표 : 2023. 7. 28(금) 예정, 개별 문자 통지     ※ 선발 일정은 진행 상황에 따라 변경될 수 있음    4. 신청 절차    ① 신청원 작성(별첨, 성적증명서 첨부) → ② 주전공 학부(과)장 확인 → ③ 신청서제출     [e-mail : aicon@kau.ac.kr, 또는 융합전공 사무실(기428호)]          ※ 융합전공 신청원 제출시 "주전공 소속 학부(과)장 확인 및 서명(날인) 필수"   5. 문의 사항   ○ 신청에 대한 문의는 AI융합전공 02-300-0259 /aicon@kau.ac.kr   ○ 각 전공별 문의는 해당 전공주임교수    - AI융합경영전공     김진기 교수(kimjk@kau.ac.kr)     - AI융합물류전공 채준재 교수(jchae@kau.ac.kr)     - AI융합신소재전공   윤요한 교수(yyoon@kau.ac.kr)     - IT-Biz융합전공      김진기 교수(kimjk@kau.ac.kr)       - 자율주행융합전공   김필은 교수(pkim@kau.ac.kr)<!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.1",
# "an": "Hancom Office Hangul",
# "av": "11, 0, 0, 6350",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_10"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2022-12-19T09:58:53.097Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D913451492DAA00000009D": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D913451492DAA00000009E": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 10066329,
# "al": 0,
# "hs": -1
# }
# }
# },
# "01D913451492DAA00000009F": {
# "id": 3,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 0,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D91345149301B0000000A0": {
# "id": 0,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A1": {
# "id": 1,
# "he": 1200,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A2": {
# "id": 2,
# "he": 1100,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 1,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A3": {
# "id": 3,
# "he": 1100,
# "tc": 255,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 1,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A4": {
# "id": 4,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A5": {
# "id": 5,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009F",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A6": {
# "id": 6,
# "he": 1100,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009F",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 1,
# "us": 1,
# "uc": 16711680,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A7": {
# "id": 7,
# "he": 1100,
# "tc": 255,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A8": {
# "id": 8,
# "he": 1100,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 1,
# "us": 1,
# "uc": 16711680,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000A9": {
# "id": 9,
# "he": 1200,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000AA": {
# "id": 10,
# "he": 1100,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000AB": {
# "id": 11,
# "he": 600,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D91345149301B0000000AC": {
# "id": 12,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D913451492DAA00000009E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D91345149301B0000000AD": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D91345149301B0000000AE": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 130,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D91345149301B0000000AF": {
# "id": 1,
# "ah": 3,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 130,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D91345149301B0000000B0": {
# "id": 2,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 100,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D91345149301B0000000B1": {
# "id": 3,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 150,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D91345149301B0000000B2": {
# "id": 4,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D91345149301B0000000B3": {
# "id": 5,
# "ah": 1,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D91345149301B0000000B4": {
# "id": 6,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D91345149301B0000000AD",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D913451492DAA00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D91345149301B0000000B5": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D91345149301B0000000B4",
# "cp": "01D91345149301B0000000AC",
# "ns": "01D91345149301B0000000B5",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D913451492DAA000000078",
# "01D913451492DAA000000078": {
# "np": "01D913451492DAA000000079",
# "id": 0,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 3,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D913451492DAA00000006E"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D913451492DAA00000006F"
# }
# ,
# {
# "t": "2023학년도 1학기 AI융합대학 AI융합전공 신청을 다음과 같이 안내하오니 관심 있는 학생들은 신청하여 주시기 바랍니다."
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000079": {
# "np": "01D913451492DAA00000007A",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000007A": {
# "np": "01D913451492DAA00000007B",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AF",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": " - 다      음 -"
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000007B": {
# "np": "01D913451492DAA00000007C",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000007C": {
# "np": "01D913451492DAA00000007D",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": "1. 신청 대상"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": " : 2023학년도 1학기 기준"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A2",
# "ch": [
# {
# "t": " "
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A3",
# "ch": [
# {
# "t": "1학년 이상 수료"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "한 학부 재학생"
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000007D": {
# "np": "01D913451492DAA00000007E",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   단, 8학기 이상 이수자 중 당해 학기 졸업요건 충족자는 지원 불가"
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000007E": {
# "np": "01D913451492DAA00000007F",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000007F": {
# "np": "01D913451492DAA000000080",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": "2. 대상 전공 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000080": {
# "np": "01D913451492DAA000000081",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   "
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A4",
# "ch": [
# {
# "t": "AI융합경영전공, AI융합물류전공, AI융합신소재전공, IT-Biz융합전공 , 자율주행 융합전공"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000081": {
# "np": "01D913451492DAA000000082",
# "id": -1212493672,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   전공별 소개 자료: 학교 홈페이지"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A5",
# "ch": [
# {
# "t": "\u003EAI융합대학\u003EAI융합전공 소개 참조 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000082": {
# "np": "01D913451492DAA000000083",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A5",
# "ch": [
# {
# "t": "     ☞ "
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D913451492DAA000000070"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A6",
# "ch": [
# {
# "t": "http://college.kau.ac.kr/web/pages/gc7781h.do"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A5",
# "ch": [
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D91345149301B0000000B6"
# }
# ,
# {
# "t": " "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000083": {
# "np": "01D913451492DAA000000084",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": " "
# }
# ,
# {
# "cc": 9,
# "wi": 3452,
# "le": 0,
# "ty": 1
# }
# ,
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000084": {
# "np": "01D913451492DAA000000085",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": "3. 선발 일정"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000085": {
# "np": "01D913451492DAA000000086",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "  "
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A7",
# "ch": [
# {
# "t": " 신청 기간 : 2022. 12. 26(월) ~ 2023. 1. 18(수)  "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000086": {
# "np": "01D913451492DAA000000087",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   제출서류"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000087": {
# "np": "01D913451492DAA000000088",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "    - 융합전공 신청원 1부"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000088": {
# "np": "01D913451492DAA000000089",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "    - 성적증명서(열람용) 1부"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000089": {
# "np": "01D913451492DAA00000008A",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   제출 방법 : 학부 사무실(기계관 428호), 이메일 접수("
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A8",
# "ch": [
# {
# "t": "aicon@kau.ac.kr"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": ")"
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000008A": {
# "np": "01D913451492DAA00000008B",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "     ※ 이메일 전송 후 반드시 유선(02-300-0259)으로 본인 접수내역 확인 요망 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000008B": {
# "np": "01D913451492DAA00000008C",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   "
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A7",
# "ch": [
# {
# "t": "승인자 발표 : 2023. 1. 31(화) 예정"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": ", 개별 문자 통지 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000008C": {
# "np": "01D913451492DAA00000008D",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "     ※ 선발 일정은 진행 상황에 따라 변경될 수 있음 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000008D": {
# "np": "01D913451492DAA00000008E",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000008E": {
# "np": "01D913451492DAA00000008F",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": "4. 신청 절차  "
# }
# ]
# }
# ]
# },
# "01D913451492DAA00000008F": {
# "np": "01D913451492DAA000000090",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A9",
# "ch": [
# {
# "t": "  ① 신청원 작성(별첨, 성적증명서 첨부) → ② 주전공 학부(과)장 확인 → ③ 신청서 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000090": {
# "np": "01D913451492DAA000000091",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A9",
# "ch": [
# {
# "t": "     제출[e-mail : "
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D913451492DAA000000071"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A8",
# "ch": [
# {
# "t": "aicon@kau.ac.kr"
# }
# ,
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D91345149301B0000000B7"
# }
# ,
# {
# "t": ","
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000AA",
# "ch": [
# {
# "t": " "
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A9",
# "ch": [
# {
# "t": "또는 융합전공 사무실(기428호)]"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000091": {
# "np": "01D913451492DAA000000092",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000092": {
# "np": "01D913451492DAA000000093",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B0",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000AB",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000093": {
# "np": "01D913451492DAA000000094",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B1",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": " ※ "
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A3",
# "ch": [
# {
# "t": "융합전공 신청원 제출시 하단 주전공 소속 학부(과)장 확인 및 서명(날인) 필수"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000094": {
# "np": "01D913451492DAA000000095",
# "id": -2147483648,
# "pp": "01D91345149301B0000000AE",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000095": {
# "np": "01D913451492DAA000000096",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B2",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A1",
# "ch": [
# {
# "t": "5. 문의 사항 "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000096": {
# "np": "01D913451492DAA000000097",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B3",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   신청에 대한 문의는 AI융합전공 02-300-0259 /"
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D913451492DAA000000072"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A8",
# "ch": [
# {
# "t": "aicon@kau.ac.kr"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D91345149301B0000000B8"
# }
# ,
# {
# "t": " "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000097": {
# "np": "01D913451492DAA000000098",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B3",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "   각 전공별 문의는 해당 전공주임교수"
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000098": {
# "np": "01D913451492DAA000000099",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B2",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "    - AI융합경영전공     김진기 교수("
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D913451492DAA000000073"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A8",
# "ch": [
# {
# "t": "kimjk@kau.ac.kr"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D91345149301B0000000B9"
# }
# ,
# {
# "t": ") "
# }
# ]
# }
# ]
# },
# "01D913451492DAA000000099": {
# "np": "01D913451492DAA00000009A",
# "id": -2147483648,
# "pp": "01D91345149301B0000000B2",
# "si": "01D91345149301B0000000B5",
# "bf": 0,
# "ru": [
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "t": "    - AI융합물류전공     송보미 교수("
# }
# ,
# {
# "cc": 3,
# "ci": 627600491,
# "co": "01D913451492DAA000000074"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A8",
# "ch": [
# {
# "t": "bmsong@kau.ac.kr"
# }
# ]
# }
# ,
# {
# "cp": "01D91345149301B0000000A0",
# "ch": [
# {
# "cc": 4,
# "ci": 6843499,
# "co": "01D91345149301B0000000BA"
# }
# ,
# {
# "t": ") "
# }
# ]
# ...
# .table_01 td + td { border-left: 1px solid #ccc; }
# .table_01  td span.clr_gray { margin-left: 10px; }
# .table_01 .clr_gray { color: #666; }
# .table_01 .clr_red { color: #ff2828; }
# .table_01 .ta_center { text-align: center; }
#
# AI융합경영전공
#
# 전공 소개
# AI∙SW 기술이 산업 전분야에 활용도가 높아지면서, AI∙SW 기술과 경영에 대한 이해를 함께 갖춘 전문인력에 대한 수요가 높아지고 있습니다. SW학문을 전공하는 학생들은 경영 분야를 배울 수 있는 기회(Business트랙)를, 경영학을 전공하는 학생들은 첨단 SW기술을 배울 수 있는 기회(AI트랙)를 제공하기 위하여 AI융합경영전공 과정을 개설하였습니다
# 전공 소개 동영상
#
# 교육 목표
# 제 4차 산업혁명 시대에 AI비즈니스를 주도할 융합형 미래 전문인재 육성
#
# 1.  인공지능(AI) 기술을 이해하는 전문 경영인 육성
# 2.  경영마인드를 가진 인공지능(AI) 기술인력 육성
#
# 미래 유망산업인 데이터과학(data science)를 주도할 data scientist를 육성하여 향후 데이터 기반 경영의 핵심 인력을 양성
#
# 교육 과정
# [이수체계도]
#
# 더 자세한 내용은 아래 자료를 다운로드 받아 확인하세요AI융합경영전공 &amp; IT-Biz융합전공 소개 자료.pdf* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조상담이 필요하면 융합전공주임 교수님께 연락하기 바랍니다. (김진기 교수: kimjk@kau.ac.kr , 내선: 353)
#
# %%%%%%%%%%%%%%%%%%%
# -------8-------
# 49
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style>', '.table_01 { border-top: 2px solid #40368a; margin: 10px 0; width: 100%; }', '.table_01 th { border-bottom: 1px solid #40368a; font-size: 20px; font-weight: bold; color: #40368a; text-align: center; padding: 19px 0; }', '.table_01 th + th { border-left: 1px solid #ccc; }', '.table_01 td { font-size: 18px; color: #000; padding: 15px; text-align: left; vertical-align: middle; border-bottom: 1px solid #ccc; word-break: keep-all;}', '.table_01 td + td { border-left: 1px solid #ccc; }', '.table_01  td span.clr_gray { margin-left: 10px; }', '.table_01 .clr_gray { color: #666; }', '.table_01 .clr_red { color: #ff2828; }', '.table_01 .ta_center { text-align: center; }', '</style>', '<div class="sub_tit">', '<h3>AI융합신소재전공<br type="_moz"/></h3>', '</div>', '<div class="article_banner_02 m_mb_01">', '<div class="misc_dgn_02">', '<h4 style="font-size: 16pt;"><b>전공 소개</b></h4>', '<p>\xa0인공지능(AI), 빅데이터활용, 스마트모빌리티 및 에너지 기술이 제 4차 혁명시대의 경제 성장을 주도할 것으로 예상되면서, 첨단산업의 출발점인 인공지능 뉴로모픽 반도체, 지능형 센서 및 5G/B5G 통신부품소재, 차세대 에너지변환 및 저장기술 및 관련 신소재 개발/연구가 매우 중요합니다. 국내 대표적 산업(반도체, 자동차 및 철강 등)의 제조 공정에서 AI 기술의 적용이 빠르게 진행되고, 빅 데이터 기반의 인공지능 학습 기술과 연계한 신소재 연구방법론이 급부상함에 따라, 이러한 패러다임 변화에 대응할 수 있는 AI∙SW 융합형 신소재 전문인력을 양성하기 위해, AI융합신소재전공을 개설하였습니다', '<br/>', '<a href="https://web.microsoftstream.com/video/7a3b4d58-e86a-44db-ab93-7cc4e35783a2"><b>전공 소개 동영상</b></a>', '</p>', '</div>', '</div>', '<br/><br/>', '<div class="article_box">', '<h4><span style="font-size: 16pt;"><b>교육 목표</b></span></h4>', '<p style="margin-left: 0px;">\xa0AI∙SW 기술과 신소재공학에 대한 통섭적 이해를 바탕으로 차세대 전자-반도체 소자개발을 이끌어 갈 SW/HW 융합형 창의인재 양성', '</p>', '<p>빅데이터와 AI 기반의 신소재 개발 패러다임 변화를 선도하는 소재정보기술(Materials Informatics) 전문인재 양성', '</p>', '</div>', '<br/><br/>', '<div class="article_box">', '<h4><span style="font-size: 16pt;"><b>교육 과정</b></span><br type="_moz"/></h4>', '<p style="margin-left: 0px; font-size: 12pt;"><br/>[이수체계도]<br/><br/><a href="/web/cmm/imageSrc.do?path=a779cc26e5bce5bb1328df0a38323187&amp;physical=a65612bc3b8c47c9dfef9b5277fbd0314a37a1884b5d8f8ae57cbea04b1fa53cd0409bec8def4267276dc76cf51873f6&amp;contentType=bdbc03257919f336778bcb6e5c07cb8b" target="_blank"><img src="/web/cmm/imageSrc.do?path=a779cc26e5bce5bb1328df0a38323187&amp;physical=a65612bc3b8c47c9dfef9b5277fbd0314a37a1884b5d8f8ae57cbea04b1fa53cd0409bec8def4267276dc76cf51873f6&amp;contentType=bdbc03257919f336778bcb6e5c07cb8b" title="image.png" width="100%"/></a><br style="clear:both;"/><br/><br/>', '</p>', '<p>', '더 자세한 내용은 아래 자료를 다운로드 받아 확인하세요<br/><a href="http://college.kau.ac.kr/conts_img/ai_www/AI_M_1.pdf" target="_blank">AI융합신소재전공 소개 발표자료 pdf</a><br/>* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조<br/><br/>상담이 필요하면 융합전공주임 교수님께 연락하기 바랍니다. (윤요한 교수: yyoon@kau.ac.kr , 내선: 162)<br/></p>', '</div><div id="gtx-trans" style="position: absolute; left: 4px; top: 227.925px;"><div class="gtx-trans-icon"></div></div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# .table_01 { border-top: 2px solid #40368a; margin: 10px 0; width: 100%; }
# .table_01 th { border-bottom: 1px solid #40368a; font-size: 20px; font-weight: bold; color: #40368a; text-align: center; padding: 19px 0; }
# .table_01 th + th { border-left: 1px solid #ccc; }
# .table_01 td { font-size: 18px; color: #000; padding: 15px; text-align: left; vertical-align: middle; border-bottom: 1px solid #ccc; word-break: keep-all;}
# .table_01 td + td { border-left: 1px solid #ccc; }
# .table_01  td span.clr_gray { margin-left: 10px; }
# .table_01 .clr_gray { color: #666; }
# .table_01 .clr_red { color: #ff2828; }
# .table_01 .ta_center { text-align: center; }
#
# AI융합신소재전공
#
# 전공 소개
# 인공지능(AI), 빅데이터활용, 스마트모빌리티 및 에너지 기술이 제 4차 혁명시대의 경제 성장을 주도할 것으로 예상되면서, 첨단산업의 출발점인 인공지능 뉴로모픽 반도체, 지능형 센서 및 5G/B5G 통신부품소재, 차세대 에너지변환 및 저장기술 및 관련 신소재 개발/연구가 매우 중요합니다. 국내 대표적 산업(반도체, 자동차 및 철강 등)의 제조 공정에서 AI 기술의 적용이 빠르게 진행되고, 빅 데이터 기반의 인공지능 학습 기술과 연계한 신소재 연구방법론이 급부상함에 따라, 이러한 패러다임 변화에 대응할 수 있는 AI∙SW 융합형 신소재 전문인력을 양성하기 위해, AI융합신소재전공을 개설하였습니다
#
# 전공 소개 동영상
#
# 교육 목표
# AI∙SW 기술과 신소재공학에 대한 통섭적 이해를 바탕으로 차세대 전자-반도체 소자개발을 이끌어 갈 SW/HW 융합형 창의인재 양성
#
# 빅데이터와 AI 기반의 신소재 개발 패러다임 변화를 선도하는 소재정보기술(Materials Informatics) 전문인재 양성
#
# 교육 과정
# [이수체계도]
#
# 더 자세한 내용은 아래 자료를 다운로드 받아 확인하세요AI융합신소재전공 소개 발표자료 pdf* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조상담이 필요하면 융합전공주임 교수님께 연락하기 바랍니다. (윤요한 교수: yyoon@kau.ac.kr , 내선: 162)
#
# %%%%%%%%%%%%%%%%%%%
# -------9-------
# 36
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>AI융합물류전공<br type="_moz"/></h3>', '</div>', '<div class="article_banner_02 m_mb_01">', '<div class="misc_dgn_02">', '<h4 style="font-size: 16pt;"><b>전공 소개</b></h4>', '<p>\xa0AI, 데이터 분석, IoT, 자율주행 등 4차 산업혁명기술의 발전에 따라 물류 분야의 ‘디지털화’와 ‘스마트화’가 급속도로 진행 중입니다. 따라서 물류 분야 지식과 AI∙SW 활용 역량을 갖춘 융합형 인재에 대한 수요가 급증하고 있습니다. AI융합물류전공은 이러한 사회변화와 요구에 대응할 수 있는 “AI∙SW 친화적 융합형 창의 물류인재”를 양성하기 위한 전공입니다.', '<br/>', '<a href="https://web.microsoftstream.com/video/2d9f949d-44e4-46c6-9995-9b52d195326c"><b>전공 소개 동영상</b></a>', '</p>', '</div>', '</div>', '<br/><br/>', '<div class="article_box">', '<h4><span style="font-size: 16pt;"><b>교육 목표</b></span></h4>', '<p style="margin-left: 0px;">\xa0물류 분야 지식을 바탕으로 물류 4.0의 핵심기술인 빅데이터, AI, IoT, 블록체인 등 핵심 SW ∙AI 기술에 대한 기본적인 이해와 구현 능력을 겸비하여 물류 문제의 창의적 해결이 가능한 융합 인재 양성', '</p>', '</div>', '<br/><br/>', '<div class="article_box">', '<h4><span style="font-size: 16pt;"><b>교육 과정</b></span><br type="_moz"/></h4>', '<p style="margin-left: 0px; font-size: 12pt;"><br/>[이수체계도]<br/><br/><a href="/web/cmm/imageSrc.do?path=0344ce6bab3f5b06f55dca8159845fc9&amp;physical=1daf03a35f94fc97b3d44cb821d87b4cc4eff585fee4c4f0db1388b8e571abcad0409bec8def4267276dc76cf51873f6&amp;contentType=bdbc03257919f336778bcb6e5c07cb8b" target="_blank"><img src="/web/cmm/imageSrc.do?path=0344ce6bab3f5b06f55dca8159845fc9&amp;physical=1daf03a35f94fc97b3d44cb821d87b4cc4eff585fee4c4f0db1388b8e571abcad0409bec8def4267276dc76cf51873f6&amp;contentType=bdbc03257919f336778bcb6e5c07cb8b" title="??3.png" width="100%"/></a><br style="clear:both;"/><br style="clear:both;"/><br/><br/>', '</p>', '<p>', '더 자세한 내용은 아래 자료를 다운로드 받아 확인하세요<br/><a href="http://college.kau.ac.kr/conts_img/ai_www/AI_L_1.pdf" target="_blank">AI융합물류전공 소개 발표자료 pdf</a><br/>* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조<br/><br/>상담이 필요하면 융합전공주임 교수님께 연락하기 바랍니다. (채준재 교수: jchae@kau.ac.kr , 내선: 372)<br/></p>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# AI융합물류전공
#
# 전공 소개
# AI, 데이터 분석, IoT, 자율주행 등 4차 산업혁명기술의 발전에 따라 물류 분야의 ‘디지털화’와 ‘스마트화’가 급속도로 진행 중입니다. 따라서 물류 분야 지식과 AI∙SW 활용 역량을 갖춘 융합형 인재에 대한 수요가 급증하고 있습니다. AI융합물류전공은 이러한 사회변화와 요구에 대응할 수 있는 “AI∙SW 친화적 융합형 창의 물류인재”를 양성하기 위한 전공입니다.
#
# 전공 소개 동영상
#
# 교육 목표
# 물류 분야 지식을 바탕으로 물류 4.0의 핵심기술인 빅데이터, AI, IoT, 블록체인 등 핵심 SW ∙AI 기술에 대한 기본적인 이해와 구현 능력을 겸비하여 물류 문제의 창의적 해결이 가능한 융합 인재 양성
#
# 교육 과정
# [이수체계도]
#
# 더 자세한 내용은 아래 자료를 다운로드 받아 확인하세요AI융합물류전공 소개 발표자료 pdf* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조상담이 필요하면 융합전공주임 교수님께 연락하기 바랍니다. (채준재 교수: jchae@kau.ac.kr , 내선: 372)
# %%%%%%%%%%%%%%%%%%%
# -------10-------
# 14
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<strong><span style="color: rgb(31, 6, 231);"></span>\u200b</strong><h3>IT-Biz 융합전공<br/><br/>\xa0</h3><div class="article_banner_02 m_mb_01"><div class="misc_dgn_02"><h4 style="font-size: 16pt;"><span style="color: rgb(0, 0, 0);">전공 소개</span><br/></h4></div><h4 style="font-size: 16pt;"></h4></div><h4><div class="misc_dgn_02"></div></h4><div class="misc_dgn_02"><strong></strong></div><div class="article_banner_02 m_mb_01"><strong></strong></div><div class="article_banner_02 m_mb_01"><div class="misc_dgn_02"><p><strong> </strong><strong><span style="font-family: 돋움,Dotum; font-size: 9pt;">미래 융합시대는 디지털기술을 기반으로 다양한 학문분야가 융합·결합하는 시대로 다양한 결합형 산업이 등장할 것으로 전망됩니다.</span><br/><span style="font-family: 돋움,Dotum; font-size: 9pt;">융합시대 디지털경제를 주도할 전문인력은 다양한 학문분야에 대한 기본적인 이해가 필요하며 공학을 전공하는 학생들은 경영(management)을 배울 수 있는 기회를 갖고 (경영트랙), 경영학을 전공하는 학생들은 기술 (technology)을 이해할 수 있는 기회를 갖도록 교육 프로그램을 제공 (공학트랙)하기 위하여 IT-Biz융합전공 과정을 개설하였습니다.</span></strong><span style="font-family: 돋움체,DotumChe,AppleGothic; font-size: 9pt;"> </span><br/><u><b><span style="color: rgb(58, 50, 195); background-color: rgb(255, 255, 255);"><u><br/>전공소개\xa0</u></span><a href="https://web.microsoftstream.com/video/7a3b4d58-e86a-44db-ab93-7cc4e35783a2"><span style="color: rgb(255, 255, 255); background-color: rgb(51, 51, 204);"><u><span style="color: rgb(58, 50, 195); background-color: rgb(255, 255, 255);"><u>동영상<br/></u></span></u></span></a></b></u></p><p class="" style="margin: 0cm 0cm 0.0001pt 38pt; text-indent: -18pt; text-align: justify; font-size: 10pt; font-family: " 고딕";"="" 맑은=""><b><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">1.<span style="font-variant-numeric: normal; font-variant-east-asian: normal; font-stretch: normal; font-size: 11pt; font-family: 돋움, Dotum;">\xa0</span></span><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">KAU AI </span><span style="font-family: 돋움, Dotum; font-size: 11pt;">융합전공</span><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">: IT-BIZ </span><span style="font-family: 돋움, Dotum; font-size: 11pt;">취업에 활용하기</span><span lang="EN-US"><br/><a href="https://www.youtube.com/watch?v=rd62Y75t8Nc"><span style="font-family: 돋움, Dotum; font-size: 11pt; color: rgb(31, 6, 231);">\xa0https://www.youtube.com/watch?v=rd62Y75t8Nc</span></a><o:p></o:p></span></b></p><p class="" style="margin: 0cm 0cm 0.0001pt 38pt; text-indent: -18pt; text-align: justify; font-size: 10pt; font-family: " 고딕";"="" 맑은=""><b><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">2.<span style="font-variant-numeric: normal; font-variant-east-asian: normal; font-stretch: normal; font-size: 11pt; font-family: 돋움, Dotum;">\xa0</span></span><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">KAU AI </span><span style="font-family: 돋움, Dotum; font-size: 11pt;">융합전공</span><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">: </span><span style="font-family: 돋움, Dotum; font-size: 11pt;">선배가 후배에게</span><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;"> IT-BIZ</span><span style="font-family: 돋움, Dotum; font-size: 11pt;">를 말한다</span><span lang="EN-US"><br/></span></b><span lang="EN-US" style="font-size: 11pt; font-family: 돋움, Dotum;"><b style="font-family: 돋움, Dotum, Helvetica, sans-serif; font-size: 13.3333px;"><span lang="EN-US" style="color: rgb(31, 6, 231);">\xa0</span></b><a href="https://youtu.be/zQ-G29I6DIM"><b><span style="color: rgb(31, 6, 231);">https://youtu.be/zQ-G29I6DIM</span></b></a></span><b><span lang="EN-US"><br/><o:p></o:p></span></b></p><p class="" style="margin: 0cm 0cm 0.0001pt 38pt; text-indent: -18pt; text-align: justify; font-size: 10pt; font-family: " 고딕";"="" 맑은=""><b><span lang="EN-US" style="font-family: 돋움, Dotum; font-size: 11pt;">3.\xa0</span><span lang="EN-US" style="font-family: 돋움, Dot ...
# $(document).ready(function() {
# });
#
# ​IT-Biz 융합전공 전공 소개 미래 융합시대는 디지털기술을 기반으로 다양한 학문분야가 융합·결합하는 시대로 다양한 결합형 산업이 등장할 것으로 전망됩니다.융합시대 디지털경제를 주도할 전문인력은 다양한 학문분야에 대한 기본적인 이해가 필요하며 공학을 전공하는 학생들은 경영(management)을 배울 수 있는 기회를 갖고 (경영트랙), 경영학을 전공하는 학생들은 기술 (technology)을 이해할 수 있는 기회를 갖도록 교육 프로그램을 제공 (공학트랙)하기 위하여 IT-Biz융합전공 과정을 개설하였습니다. 전공소개 동영상1. KAU AI 융합전공: IT-BIZ 취업에 활용하기 https://www.youtube.com/watch?v=rd62Y75t8Nc2. KAU AI 융합전공: 선배가 후배에게 IT-BIZ를 말한다 https://youtu.be/zQ-G29I6DIM3. KAU AI 융합전공: 데이터 분야 공부하기 https://www.youtube.com/watch?v=1rGNiS8fNHI
# 교육 목표4차 혁명의 시대에 융합형 인재, 경영능력을 갖춘 전문기술인, 기술을 이해하는 전문경영인 육성을 교육목표로 전공을 운영하고 있습니다.진출 분야글로벌ICT전문기업, 스마트관련 전문기업, ICT기업, SI기업, 온라인비즈니스기업, ICT활용 기업 등교과 과정
# 융합전공명 : IT-Biz
# 참여학부(과) : 항공전자정보공학부, 소프트웨어학과, 경영학부
# 주요 교과목 : 데이터사이언스, 자바와 객체지향프로그래밍, 재무관리, 경영정보관리
# AI융합경영전공 &amp; IT-Biz융합전공 소개 자료.pdf* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조상담이 필요하면 융합전공주임 교수님께 연락하기 바랍니다. (김진기 교수: kimjk@kau.ac.kr , 내선: 353)
#
# %%%%%%%%%%%%%%%%%%%
# -------11-------
# 12
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<h4 style="font-size: 16pt;"><b>자율주행 융합전공<br/>\xa0</b></h4><p>자율주행차가 미래자동차 산업의 큰 화두로 떠오르고 있습니다. 전통적인 자동차기업들과 선도 IT기업들이 자율주행차를 연구하고 있고, 삼성전자 / LG전자 역시 전장 관련 사업을 진행 중 입니다. 향후 자율주행차 수요가 더욱 증가할 것으로 예상되어 이 분야의 전문 인재양성을 위하여 연계교육트랙을 운영합니다.<br/>\xa0</p>', '<div align="center" style="text-align: center;"><iframe allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="320" src="https://www.youtube.com/embed/V9wS_U4txX0" title="자율주행융합전공소개" width="640"></iframe></div><p><span 12pt;="" ar-sa;"="" calibri",sans-serif;="" en-us;="" font-size:="" ko;="" lang="EN-US" mso-ansi-language:="" mso-bidi-language:="" mso-fareast-font-family:="" mso-fareast-language:="" style="color: black; font-family: " 굴림;=""><span 12pt;="" ar-sa;"="" calibri",sans-serif;="" en-us;="" font-size:="" ko;="" lang="EN-US" mso-ansi-language:="" mso-bidi-language:="" mso-fareast-font-family:="" mso-fareast-language:="" style="color: black; font-family: " 굴림;=""><br/></span></span>\xa0</p><div class="article_box"><h4><span style="font-size: 16pt;"><b>교육목표</b></span></h4><p style="margin-left: 0px;">자율주행차 개발은 기계, 전기전자, 통신, 소프트웨어 등 다양한 공학 분야가 융합되어야 가능한 분야입니다. <br/>따라서, 해당 전문 인재 양성을 위하여 자율주행차 개발에 필요한 다양한 공학 요소를 종합적으로 교육하고자 합니다.\xa0\xa0\xa0\xa0 </p></div><p><br/>\xa0</p><h4><span style="font-size: 16pt;">교육과정<br/><br/></span><img alt="" src="data:image/png;base64,..."/><span style="font-size: 16pt;">\xa0</span></h4><div class="article_box"><h4><span style="font-size: 16pt;"><br style="clear: both;"/><p class="clr_gray"><sup class="clr_red"><span style="color: rgb(0, 0, 0); font-size: 11pt;">＊</span></sup><span style="color: rgb(0, 0, 0); font-size: 11pt;">전필선 1, 2, 3 과목 중 파트별 1개 택일하여 수강하시기 바랍니다. (중복 수강 할 경우 나머지 과목은 전선으로 인정)</span></p><br/><p class="clr_blue"><span style="color: rgb(0, 0, 0); font-size: 11pt;">※ 이수조건 : 총 36학점 이상 (전필 6학점 + 전필선 12학점 + 전선 9학점 이상)</span><br/><span style="color: rgb(0, 0, 0); font-size: 11pt;">--&gt; 주전공 이수과목과 최대 12학점까지 중복 인정 (융합전공 이수학점에 포함)</span></p></span><br/>* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조<span style="font-size: 16pt;"><br/></span><br type="_moz"/></h4><p style="font-size: 12pt; margin-left: 0px;"><strong>\xa0</strong></p></div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 자율주행 융합전공 자율주행차가 미래자동차 산업의 큰 화두로 떠오르고 있습니다. 전통적인 자동차기업들과 선도 IT기업들이 자율주행차를 연구하고 있고, 삼성전자 / LG전자 역시 전장 관련 사업을 진행 중 입니다. 향후 자율주행차 수요가 더욱 증가할 것으로 예상되어 이 분야의 전문 인재양성을 위하여 연계교육트랙을 운영합니다.
# 교육목표자율주행차 개발은 기계, 전기전자, 통신, 소프트웨어 등 다양한 공학 분야가 융합되어야 가능한 분야입니다. 따라서, 해당 전문 인재 양성을 위하여 자율주행차 개발에 필요한 다양한 공학 요소를 종합적으로 교육하고자 합니다.      교육과정 ＊전필선 1, 2, 3 과목 중 파트별 1개 택일하여 수강하시기 바랍니다. (중복 수강 할 경우 나머지 과목은 전선으로 인정)※ 이수조건 : 총 36학점 이상 (전필 6학점 + 전필선 12학점 + 전선 9학점 이상)--&gt; 주전공 이수과목과 최대 12학점까지 중복 인정 (융합전공 이수학점에 포함)* 각 전공별 교과과정표는 "정보센터 - 자료실" 참조

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
