# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "인문자연학부_data"
number_html = 5
url = """http://college.kau.ac.kr/web/pages/gc11109h.do
http://college.kau.ac.kr/web/pages/gc81110h.do
http://college.kau.ac.kr/web/pages/gc29132h.do
http://college.kau.ac.kr/web/pages/gc51336h.do
http://college.kau.ac.kr/web/pages/gc7306h.do
http://college.kau.ac.kr/web/pages/gc59142h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 6:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc11109h.do', 'http://college.kau.ac.kr/web/pages/gc81110h.do', 'http://college.kau.ac.kr/web/pages/gc29132h.do', 'http://college.kau.ac.kr/web/pages/gc51336h.do', 'http://college.kau.ac.kr/web/pages/gc7306h.do', 'http://college.kau.ac.kr/web/pages/gc59142h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 44
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<style type="text/css">', '.imginmoon{}', '</style>', '<div class="sub_tit">', '<h3>학부/과 소개</h3>', '</div>', '<div class="article_101">', '<span class="img_fl">', '<img src="/cmm_typeA/images/sample/sub_101_01.jpg"/>', '</span>', '<h4>인문자연학부</h4>', '<p>\xa0 \xa0인문자연학부는 1971년 1학기부터 본격적으로 교양 교육을 전담하는 교양과정부로 출발하여, 교양학부, 교양 학과를 거쳐 현재 인문자연학부로 편제되어 있다. 인문자연학부는, 본 대학 학생들로', '하여금 전문인으로서 사회적 역할을 충실히 수행하고 자연인으로서 행복을 추구할 수 있도록, 전공 이수에 필요한 기초과목과 지성인으로서 갖추어야 할 인문 사회 교양 과목을 교육하고 있다. 인문자연학부의', '교육과정은, 초창기에는 주로 국어, 수학, 영어 등 기본과목으로 한정되어 있었으나 해를 거듭하면서 물리, 체육을 비롯하여 인문 사회 과학 분야의 다양한 과목 등으로 그 범위가 확대되어', '왔다.<br/><br/>', '</p>', '</div>', '<br/>', '<br/>', '<div class="article_101">', '<img src="/conts_img/ct_www/introduce/인문자연학부-교육과정.jpg" style="margin-right: 25px; float: right;"/>', '<h4>교육과정</h4>', '<p>\xa0<br/>\xa0 \xa0현재 교양과정은, 교육목표, 인재상, 핵심역량을 실현하기 위해 공통교양, 학문 기초 교양, 선택 교양으로 나누어지며, 선택 교양은 철학과 역사, 문학과 예술, 인간과 사회, 자연과 과학, 세계와 문화,', '소양, 자기계발 영역으로 개설·운영하고 있다.<br/></p>', '</div>', '<br/>', '<br/>', '<div class="article_101">', '<span class="img_fl">', '<img src="/cmm_typeA/images/sample/sub_101_03.jpg"/>', '</span>', '<h4>교육과정 편성</h4>', '<p>\xa0인문자연학부의 교과과정 편성은 매4년마다 개편된다. 시대의 목소리에 귀 기울이면서, 학내의 다양한 의견을 합리적으로 수렴하고자, 개편은 기초교양교육원-교양분과위원회-교육품질혁신위원회 등의 기구를 거쳐 이루어진다.<br/><br/>☎ 인문자연학부 02-300-0330 / 기초교양교육원 02-300-0014<br/></p>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# .imginmoon{}
#
# 학부/과 소개
#
# 인문자연학부
# 인문자연학부는 1971년 1학기부터 본격적으로 교양 교육을 전담하는 교양과정부로 출발하여, 교양학부, 교양 학과를 거쳐 현재 인문자연학부로 편제되어 있다. 인문자연학부는, 본 대학 학생들로
# 하여금 전문인으로서 사회적 역할을 충실히 수행하고 자연인으로서 행복을 추구할 수 있도록, 전공 이수에 필요한 기초과목과 지성인으로서 갖추어야 할 인문 사회 교양 과목을 교육하고 있다. 인문자연학부의
# 교육과정은, 초창기에는 주로 국어, 수학, 영어 등 기본과목으로 한정되어 있었으나 해를 거듭하면서 물리, 체육을 비롯하여 인문 사회 과학 분야의 다양한 과목 등으로 그 범위가 확대되어
# 왔다.
#
# 교육과정
# 현재 교양과정은, 교육목표, 인재상, 핵심역량을 실현하기 위해 공통교양, 학문 기초 교양, 선택 교양으로 나누어지며, 선택 교양은 철학과 역사, 문학과 예술, 인간과 사회, 자연과 과학, 세계와 문화,
# 소양, 자기계발 영역으로 개설·운영하고 있다.
#
# 교육과정 편성
# 인문자연학부의 교과과정 편성은 매4년마다 개편된다. 시대의 목소리에 귀 기울이면서, 학내의 다양한 의견을 합리적으로 수렴하고자, 개편은 기초교양교육원-교양분과위원회-교육품질혁신위원회 등의 기구를 거쳐 이루어진다.☎ 인문자연학부 02-300-0330 / 기초교양교육원 02-300-0014
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 25
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>학장 인사말</h3>', '</div>', '<div class="article_102">', '<h4>인문자연학부</h4>', '<p>', '인문자연학부는, 고도산업사회에서 창의적 역할을 담당할 지성인이 갖추어야 할 교양과 지식을 교육하고 있습니다. 우리 대학 교양 교육의 교육목표는, 대학 인재상과 5대 핵심역량(SPACE)을 기반으로 올바른 인성 형성과 창의적 기초능력 함양, 통섭과 융합능력을 함양하는 魂·創·通(혼·창·통) 일체형 교양 교육을 수행하는 것입니다.<br/>', '</p>', '</div>', '<div class="article_102">', '', '', '<br/>', '<h4 class="sign" style="text-align: center; ">한국항공대학교 인문자연학부 학부장 <span>공은정</span></h4>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 학장 인사말
#
# 인문자연학부
#
# 인문자연학부는, 고도산업사회에서 창의적 역할을 담당할 지성인이 갖추어야 할 교양과 지식을 교육하고 있습니다. 우리 대학 교양 교육의 교육목표는, 대학 인재상과 5대 핵심역량(SPACE)을 기반으로 올바른 인성 형성과 창의적 기초능력 함양, 통섭과 융합능력을 함양하는 魂·創·通(혼·창·통) 일체형 교양 교육을 수행하는 것입니다.
#
# 한국항공대학교 인문자연학부 학부장 공은정
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 245
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<span id="husky_bookmark_start_1678783292943"></span><span id="husky_bookmark_end_1678783292943"></span><div class="sub_tit">', '<h3>교수진</h3>', '</div>', '', '<ul class="menu_tab menu_tab2">', '<li><a class="selected" href="#panel_01">인문자연학부</a></li>', '<li><a href="#panel_02">영어학과</a></li>', '</ul>', '<ul class="panel">', '', '<li id="panel_01">', '<ul class="prs_list">', '', '<li>', '', '<span class="portrait">', '<a href="/web/cmm/imageSrc.do?path=02be27d3a5c3745f6123343f28385774&amp;physical=29e138c0dbd92ed7b07d7c1ecfde8d6799d9386818f0d2cb1fe8f33a3617cecbd0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" target="_blank"><img src="/web/cmm/imageSrc.do?path=02be27d3a5c3745f6123343f28385774&amp;physical=29e138c0dbd92ed7b07d7c1ecfde8d6799d9386818f0d2cb1fe8f33a3617cecbd0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" title="EKONG%20-%20???.jpg" width="100%"/></a><br style="clear:both;"/></span><h4>공은정(학부장)<span style="font-weight: normal; font-size: 11pt;">교수<br/></span></h4><h4><p style="font-weight: 400;">Ohio State University</p><ul class="prs_info" style="font-weight: 400;"><li>전공분야 :\xa0영어 음성학</li><li>연구실 :\xa0본관 501호</li><li>02)-300-0338<span class="mail">/ ekong@kau.ac.kr<br/>\xa0</span><a data-auth="NotApplicable" data-linkindex="0" href="https://sites.google.com/view/eunjongkong/home" id="LPlnk115906" rel="noopener noreferrer" style="margin: 0px; padding: 0px; border: 0px; font-variant-numeric: inherit; font-variant-east-asian: inherit; font-stretch: inherit; font-size: 15px; line-height: inherit; font-family: arial, helvetica, sans-serif; vertical-align: baseline; background-color: rgb(255, 255, 255);" target="_blank">https://sites.google.com/view/eunjongkong/home</a></li><li class="contact"><a href="http://college.kau.ac.kr/cmm/resource/se2/smart_editor2_inputarea.html#"><img src="http://college.kau.ac.kr/cmm_typeA/images/icon_mail.png"/>이메일</a>\xa0<a href="http://college.kau.ac.kr/cmm/resource/se2/smart_editor2_inputarea.html#"><img src="http://college.kau.ac.kr/cmm_typeA/images/icon_homepage.png"/></a></li></ul></h4></li>', '<li>', '<span class="portrait">', '<img src="/conts_img/ct_www/introduce/김경식.jpg"/>', '</span>', '<h4>김경식<span>교수</span></h4>', '<p>중앙대 및 중앙대학원 / Univ. of Ohio </p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>물리학</li>', '<li><span>연구실 : </span>본관 513호</li>', '<li>02)-300-0062<span class="mail">\xa0/ kyungsik@kau.ac.kr</span></li>', '<li class="homepage">블로그주소</li>', '<li class="contact">', '<a href="#"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a>', '<a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a>', '</li>', '</ul>', '</li> <li>', '<span class="portrait">', '<img src="/conts_img/ct_www/introduce/김경중.jpg"/>', '</span>', '<h4>김경중<span>교수</span></h4>', '<p>연세대 및 연세대학원</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>수치해석</li>', '<li><span>연구실 : </span>본관 519호</li>', '<li>02)-300-0061<span class="mail"> / kj_kim@kau.ac.kr</span></li>', '<li class="homepage">블로그 주소</li>', '<li class="contact">', '<a href="#"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a>', '<a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a>', '</li>', '</ul>', '</li>', '<li>', '<span class="portrait">', '<img src="/conts_img/ct_www/introduce/김이준.png"/>', '</span>', '<h4>김이준<span>교수</span></h4>', '<p>숙명여자대학교</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>진로상담</li>', '<li><span>연구실 : 본관423</span>호</li>', '<li>02)-300-0066<span class="mail"> / career337@kau.ac.kr</span></li>', '<li class="homepage">블로그 주소</li>', '<li class="contact">', '<a href="#"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a>', '<a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a>', '</li>', '</ul>', '</li>', '<li><span class="portrait"><a href="/web/cmm/imageSrc. ...
#
# $(document).ready(function() {
# });
#
# 교수진
#
# 인문자연학부
# 영어학과
#
# 공은정(학부장)교수Ohio State University전공분야 : 영어 음성학연구실 : 본관 501호02)-300-0338/ ekong@kau.ac.kr https://sites.google.com/view/eunjongkong/home이메일
#
# 김경식교수
# 중앙대 및 중앙대학원 / Univ. of Ohio
#
# 전공분야 : 물리학
# 연구실 : 본관 513호
# 02)-300-0062 / kyungsik@kau.ac.kr
# 블로그주소
#
# 이메일
# 홈페이지
#
# 김경중교수
# 연세대 및 연세대학원
#
# 전공분야 : 수치해석
# 연구실 : 본관 519호
# 02)-300-0061 / kj_kim@kau.ac.kr
# 블로그 주소
#
# 이메일
# 홈페이지
#
# 김이준교수
# 숙명여자대학교
#
# 전공분야 : 진로상담
# 연구실 : 본관423호
# 02)-300-0066 / career337@kau.ac.kr
# 블로그 주소
#
# 이메일
# 홈페이지
#
# 손달임교수이화여자대학교전공분야 : 국어국문학(음운론)연구실 : 본관 508호02)-300-0071 / milkyway0822@kau.ac.kr블로그 주소이메일 홈페이지
#
# 송미경교수
# 고려대학교
#
# 전공분야 : 국어국문학(고전문학)
# 연구실 : 본관 506호
# 02)-300-0075 / firmamento@kau.ac.kr
# 블로그 주소
#
# 이메일
# 홈페이지
#
# 우실하교수연세대 및 연세대학원전공분야 : 사회학연구실 : 본관 514호02)-300-0069 / woosilha@kau.ac.kr블로그 주소 www.gaonnuri.co.kr이메일 홈페이지
# 유병길교수연세대 및 연세대학원전공분야 : 물리학연구실 : 본관 522호02)-300-0070 / bgyu@kau.ac.kr블로그 주소이메일 홈페이지
# 윤아나교수고려대학교전공분야 : 응용수학연구실 : 본관 509호02)-300-0065 / anayun@kau.ac.kr블로그 주소이메일 홈페이지이승준교수고려대 및 고려대학원전공분야 : 국문학(현대문학)연구실 : 본관 509호02)-300-0063 / sjune@kau.ac.kr블로그 주소이메일 홈페이지
# 정민석교수서강대학교전공분야 : 조합 수학연구실 : 본관 518호02)-300-0064 / poset@kau.ac.kr블로그 주소이메일 홈페이지
#
# 조정은교수
# SOAS Univ. of London
#
# 전공분야 : 중국철학
# 연구실 : 본관 504호
# 02)-300-0072 / jungeunjo@kau.ac.kr
# 블로그 주소
#
# 이메일
# 홈페이지
#
# 최기석교수
# Univ. of Graz
#
# 전공분야 : 물리학(핵물리학 이론)
# 연구실 : 본관 523호
# 02)-300-0074
# 블로그 주소
#
# 이메일
# 홈페이지
#
# 최승회교수울산대 및 연세대학원전공분야 : 통계학연구실 : 본관 521호02)-300-0073 / shchoi@kau.ac.kr블로그 주소이메일 홈페이지Aldo Hawkes교수Queensland University of Technology전공분야 : Education연구실 : 본관 507호02)-300-0332블로그 주소이메일 홈페이지Solomon Hakim교수State Univ. of New York at Binghamton전공분야 : Political Science연구실 : 본관 502호02)-300-0335블로그 주소이메일 홈페이지Summer Brooke Lee교수Arizona State University전공분야 : curriculum and instruction early childhood education연구실 : 본관 511호02)-300-0341블로그 주소이메일 홈페이지
#
# 공은정(학과장)교수
# Ohio State University
#
# 전공분야 : 영어 음성학
# 연구실 : 본관 501호
# 02)-300-0338 / ekong@kau.ac.kr https://sites.google.com/view/eunjongkong/home
#
# 이메일
#
# Brian Magliaro교수
# Macquarie University
#
# 전공분야 : 응용언어학(Applied Linguistics)
# 연구실 : 본관 510호
# 02)-300-0337
# 블로그 주소
#
# 이메일
# 홈페이지
#
# Eunice Jo교수
# Columbia University
#
# 전공분야 : 응용언어학
# 연구실 : 본관 511호
# 02)-300-0341
# 블로그 주소
#
# 이메일
# 홈페이지
#
# Michael Burkhardt교수
# University of Wisconsin
#
# 전공분야 : 건축공학
# 연구실 : 본관 510호
# 02)-300-0346
# 블로그 주소
#
# 이메일
# 홈페이지
#
# Robert Burns교수
# Yale 및 Concordia Univ
#
# 전공분야 : 언어학
# 연구실 : 본관 502호
# 02)-300-0335
# 블로그 주소
#
# 이메일
# 홈페이지
#
# Thunder Storm VanBrocklin교수
# MIT 및 Framingham State University
#
# 전공분야 : City Planning / Education
# 연구실 : 본관 505호
# 02)-300-0333
# 블로그 주소
#
# 이메일
# 홈페이지
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 83
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>졸업요건</h3>', '</div>', '<div class="article_303">', '<h4>졸업학점</h4>', '<p>정규 8학기이상 등록한 재학생 또는 수료생(단, 조기졸업자는 졸업예정학기에 포함)</p>', '<p>※ 졸업학점을 모두 이수하였어도 휴학중에는 졸업 불가함.</p>', '<table class="table_01">\n<tbody><tr>\n<th>대상학번</th>\n<th>졸업이수학점</th>\n</tr>\n<tr>\n<td>2012학번까지</td>\n<td>총\xa0140학점 이상 (단,\xa0학석사연계과정생은\xa0134학점,\xa0대학원과목\xa06학점)</td>\n</tr>\n<tr>\n<td>2013학번부터</td>\n<td>총\xa0130학점 이상 (단,\xa0학석사연계과정생은\xa0124학점,\xa0대학원과목\xa06학점)</td>\n</tr>\n</tbody></table>', '</div>', '<div class="article_303">', '<h4>학번 및 학(부)과 별 교양 이수학점', '</h4><p>재학기간 중 다음의 졸업인증 취득요건 갖춘 자에게 "졸업인증"자격을 부여한다.<br/><br/><span style="color: rgb(255, 0, 0); font-size: 10pt;"><strong>※ 세부영역별 교과목 확인은 교과과정표 참조</strong></span><br/></p><br/>', '<h5>1) 2023학번</h5><h5> <div class="scroller" style="font-size: 12px; font-weight: 400;">', '<table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br/>2) 문학과 예술<br/>3) 인간과 사회<br/>4) 자연과 과학<br/>5)세계와 문화</td><td>9 학점 이상<br/>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br/>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br/>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table>', '</div></h5><h5>2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller" style="font-size: 12px; font-weight: 400;">', '<table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br/>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>-</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table>', '<p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br/><br type="_moz"/></p></div>2) 2022학번 </h5>', '<div class="scroller">', '<table class="table_01">\n<tbody><tr>\n<th>대영역</th>\n<th>세부영역</th>\n<th colspan="2">학점</th>\n</tr>\n<tr>\n<td>공통교양</td>\n<td> - </td>\n<td colspan="2">11~13학점</td>\n</tr>\n<tr>\n<td>학문기초교양</td>\n<td> - </td>\n<td colspan="2">12~20학점</td>\n</tr>\n<tr>\n<td rowspan="2">선택교양</td>\n<td>1) 철학과 역사<br/>2) 문학과 예술<br/>3) 인간과 사회<br/>4) 자연과 과학<br/>5)세계와 문화</td>\n<td>9 학점 이상<br/>(최소 3개 영역 선택)</td>\n<td rowspan="2">12 학점<br/>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td>\n</tr>\n<tr>\n<td>6) 소양     <br/>7) 자기계발</td>\n<td>자유이수</td>\n</tr>\n<tr>\n<td colspan="2">계</td>\n<td colspan="2">39 학점 이상</td>\n</tr>\n</tbody></table>', '</div>', '', '<h5> 2022학번 학부(과) 별 교양이수학점</h5>', '<div class="scroller">', '<table class="table_01">\n<tbody><tr>\n<th>학부/과</th>\n<th>공통교양</th>\n<th>학문기초교양</th>\n<th>선택교양</th>\n<th>추가이수<br/>교양학점*</th>\n<th>계</th>\n</tr>\n<tr>\n<td>항공우주 및 기계공학부</td>\n<td>11</td>\n<td> 20 </td>\n<td> 12 </td>\n<td> - </td>\n<td> 43</td>\n</tr>\n<tr>\n<td>항공전자정보공학부</td>\n<td>11</td>\n<td>18</td>\n<td> 12 </td>\n<td>-</td>\n<td>41</td>\n</tr>\n<tr>\n<td>신소재공학과</td>\n<td>11</td>\n<td>15</td>\n<td> 12 </td>\n<td>1</td>\n<td> 39 </td>\n</tr>\n<tr>\n<td>소프트웨어학과</td>\n<td>13</td>\n<td>12</td>\n<td> 12 </td>\n<td>2</td>\n<td> 39 </td>\n</tr>\n<tr>\n<td>스마트드론공학과</td>\n<td> 12</td>\n<td>18</td>\n<td> 12 </td>\n<td>-</td>\n<td>42</td>\n</ ...
# $(document).ready(function() {
# });
#
# 졸업요건
#
# 졸업학점
# 정규 8학기이상 등록한 재학생 또는 수료생(단, 조기졸업자는 졸업예정학기에 포함)
# ※ 졸업학점을 모두 이수하였어도 휴학중에는 졸업 불가함.
# 대상학번 : 2012학번까지
# 졸업이수학점 : 총 140학점 이상 (단, 학석사연계과정생은 134학점, 대학원과목 6학점)
#
# 대상학번 : 2013학번부터
# 졸업이수학점 : 총 130학점 이상 (단, 학석사연계과정생은 124학점, 대학원과목 6학점)
#
# 학번 및 학(부)과 별 교양 이수학점
# 재학기간 중 다음의 졸업인증 취득요건 갖춘 자에게 "졸업인증"자격을 부여한다.※ 세부영역별 교과목 확인은 교과과정표 참조
# 1) 2023학번
# 대영역 : 공통교양
# 세부영역 : -
# 학점 : 10~13학점
#
# 대영역 : 학문기초교양
# 세부영역 : -
# 학점 : 13~21학점
#
# 대영역 : 선택교양
# 세부영역 :
# 1) 철학과 역사
# 2) 문학과 예술
# 3) 인간과 사회
# 4) 자연과 과학
# 5) 세계와 문화
# 학점 : 9 학점 이상 (최소 3개 영역 선택)
# 비고 : 12 학점(1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수
#
# 대영역 : 선택교양
# 세부영역 :
# 6) 소양
# 7) 자기계발
# 학점 : 자유이수
#
# 계 : 39 학점 이상
# 2023학번 학부(과) 별 교양이수학점
# 학부/과 : 항공우주 및 기계공학부
# 공통교양 : 11
# 학문기초교양 : 21
# 선택교양 : 12
# 계 : 44
#
# 학부/과 : 항공전자정보공학부
# 공통교양 : 11
# 학문기초교양 : 20
# 선택교양 : 12
# 계 : 43
#
# 학부/과 : 신소재공학과
# 공통교양 : 11
# 학문기초교양 : 17
# 선택교양 : 12
# 계 : 40
#
# 학부/과 : 소프트웨어학과
# 공통교양 : 13
# 학문기초교양 : 13
# 선택교양 : 12
# 계 : 39
#
# 학부/과 : 스마트드론공학과
# 공통교양 : 10
# 학문기초교양 : 19
# 선택교양 : 12
# 계 : 41
#
# 학부/과 : AI자율주행시스템공학과
# 공통교양 : 12
# 학문기초교양 : 16
# 선택교양 : 12
# 계 : 40
#
# 학부/과 : 항공교통물류학부
# 공통교양 : 11
# 학문기초교양 : 15
# 선택교양 : 12
# 추가이수 교양학점* : 1
# 계 : 39
#
# 학부/과 : 항공운항학과
# 공통교양 : 11
# 학문기초교양 : 15
# 선택교양 : 12
# 추가이수 교양학점* : 1
# 계 : 39
#
# 학부/과 : 경영학부
# 공통교양 : 11
# 학문기초교양 : 15
# 선택교양 : 12
# 추가이수 교양학점* : 1
# 계 : 39
# * 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨2) 2022학번
#
# 대영역 : 공통교양
# 세부영역 : -
# 학점 : 11~13학점
#
# 대영역 : 학문기초교양
# 세부영역 : -
# 학점 : 12~20학점
#
# 대영역 : 선택교양
# 세부영역 :
# 1) 철학과 역사
# 2) 문학과 예술
# 3) 인간과 사회
# 4) 자연과 과학
# 5) 세계와 문화
# 학점 : 9 학점 이상 (최소 3개 영역 선택)
# 비고 : 12 학점(1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수
#
# 대영역 : 선택교양
# 세부영역 :
# 6) 소양
# 7) 자기계발
# 학점 : 자유이수
#
# 계 : 39 학점 이상
#
# 2022학번 학부(과) 별 교양이수학점
#
# 학부/과 : 항공우주 및 기계공학부
# 공통교양 : 11
# 학문기초교양 : 20
# 선택교양 : 12
# 추가이수 교양학점* : -
# 계 : 43
#
# 학부/과 : 항공전자정보공학부
# 공통교양 : 11
# 학문기초교양 : 18
# 선택교양 : 12
# 추가이수 교양학점* : -
# 계 : 41
#
# 학부/과 : 신소재공학과
# 공통교양 : 11
# 학문기초교양 : 15
# 선택교양 : 12
# 추가이수 교양학점* : 1
# 계 : 39
#
# 학부/과 : 소프트웨어학과
# 공통교양 : 13
# 학문기초교양 : 12
# 선택교양 : 12
# 추가이수 교양학점* : 2
# 계 : 39
#
# 학부/과 : 스마트드론공학과
# 공통교양 : 12
# 학문기초교양 : 18
# 선택교양 : 12
# 추가이수 교양학점* : -
# 계 : 42
#
# 학부/과 : AI자율주행시스템공학과
# 공통교양 : 12
# 학문기초교양 : 15
# 선택교양 : 12
# 추가이수 교양학점* : -
# 계 : 39
#
# 학부/과 : 항공교통물류학부
# 공통교양 : 11
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 3
# 계 : 39
#
# 학부/과 : 항공운항학과
# 공통교양 : 11
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 3
# 계 : 39
#
# 학부/과 : 경영학부
# 공통교양 : 11
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 5
# 계 : 39
# * 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨
#
# 3) 2021학번
#
# 대영역 : 공통교양
# 세부영역 : -
# 학점 : 9~11학점
#
# 대영역 : 학문기초교양
# 세부영역 : -
# 학점 : 12~20학점
#
# 대영역 : 선택교양
# 세부영역 :
# 1) 철학과 역사
# 2) 문학과 예술
# 3) 인간과 사회
# 4) 자연과 과학
# 5) 세계와 문화
# 학점 : 9 학점 이상 (최소 3개 영역 선택)
# 비고 : 12 학점(1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수
#
# 대영역 : 선택교양
# 세부영역 :
# 6) 소양
# 7) 자기계발
# 학점 : 자유이수
#
# 계 : 39 학점 이상
#
# 2021학번 학부(과) 별 교양이수학점
#
# 학부/과 : 항공우주 및 기계공학부
# 공통교양 : 9
# 학문기초교양 : 20
# 선택교양 : 12
# 추가이수 교양학점* : -
# 계 : 41
#
# 학부/과 : 항공전자정보공학부
# 공통교양 : 9
# 학문기초교양 : 16
# 선택교양 : 12
# 추가이수 교양학점* : 2
# 계 : 39
#
# 학부/과 : 신소재공학과
# 공통교양 : 9
# 학문기초교양 : 15
# 선택교양 : 12
# 추가이수 교양학점* : 3
# 계 : 39
#
# 학부/과 : 소프트웨어학과
# 공통교양 : 11
# 학문기초교양 : 12
# 선택교양 : 12
# 추가이수 교양학점* : 4
# 계 : 39
#
# 학부/과 : 스마트드론공학과
# 공통교양 : 10
# 학문기초교양 : 10
# 선택교양 : 12
# 추가이수 교양학점* : 6
# 계 : 39
#
# 학부/과 : 항공교통물류학부
# 공통교양 : 9
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 5
# 계 : 39
#
# 학부/과 : 항공운항학과
# 공통교양 : 9
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 5
# 계 : 39
#
# 학부/과 : 경영학부
# 공통교양 : 9
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 5
# 계 : 39
# * 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨
#
# 4) 2020학번
#
# 대영역 : 공통교양
# 세부영역 : -
# 학점 : 7학점
#
# 대영역 : 학문기초교양
# 세부영역 : -
# 학점 : 12~20학점
#
# 대영역 : 선택교양
# 세부영역 :
# 1) 철학과 역사
# 2) 문학과 예술
# 3) 인간과 사회
# 4) 자연과 과학
# 5) 세계와 문화
# 6) 소양
# 7) 자기계발
# 학점 : 9 학점 이상 (최소 3개 영역 선택)
# 비고 : 12 학점(1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수
#
# 계 : 39 학점 이상
#
# 2020학번 학부(과)별 교양이수학점
#
# 학부/과 : 항공우주 및 기계공학부
# 공통교양 : 7
# 학문기초교양 : 20
# 선택교양 : 12
# 추가이수 교양학점* : -
# 계 : 39
#
# 학부/과 : 항공전자정보공학부
# 공통교양 : 7
# 학문기초교양 : 18
# 선택교양 : 12
# 추가이수 교양학점* : 2
# 계 : 39
#
# 학부/과 : 소프트웨어학과
# 공통교양 : 7
# 학문기초교양 : 14
# 선택교양 : 12
# 추가이수 교양학점* : 6
# 계 : 39
#
# 학부/과 : 항공재료공학과
# 공통교양 : 7
# 학문기초교양 : 12
# 선택교양 : 12
# 추가이수 교양학점* : 8
# 계 : 39
#
# 학부/과 : 항공교통물류학부
# 공통교양 : 7
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 7
# 계 : 39
#
# 학부/과 : 항공운항학과
# 공통교양 : 7
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 7
# 계 : 39
#
# 학부/과 : 경영학부
# 공통교양 : 7
# 학문기초교양 : 13
# 선택교양 : 12
# 추가이수 교양학점* : 7
# 계 : 39
# * 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨
#
# 5) 2018/2019학번
#
# 대영역 : 필수교양
# 세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
# 학점 : 공과대학 13학점, 항경대학 12학점
#
# 대영역 : 전공기초교양
# 세부영역 : 전공기초
# 학점 : 0~18학점, 각 학부/과 별 상이
#
# 대영역 : 핵심교양
# 세부영역 :
# 1) 철학과 역사
# 2) 문학과 예술
# 3) 인간과 사회
# 4) 자연과 과학
# 5) 실용 및 글로벌
# 학점 : 9 학점, 학부/과 별 지정영역이수(3-1참조)
# 비고 : 12 학점(1)~5) 학부/과 별 지정영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨
#
# 대영역 : 심화교양
# 세부영역 :
# 6) 철학과 역사
# 7) 문학과 예술
# 8) 인간과 사회
# 9) 자연과 과학
# 10) 실용 및 글로벌
# 11) 봉사와 리더십
# 12) 자기개발
# 13) 외국어(영어)
# 학점 : 자유이수
#
# 계 : 24~43 학점
#
# 5-1) 2018/2019학번 핵심교양 지정영역
#
# 학부/과 : 공과대학
# 지정영역 : 철학과 역사, 문학과 예술, 인간과 사회, 실용 및 글로벌
# 영역 택 3
#
# 학부/과 : 항경대학
# 지정영역 : 철학과 역사, 문학과 예술, 인간과 사회, 자연과 과학, 실용 및 글로벌
# 영역 택 3
#
# 2018-19학번 학부(과)별 교양이수학점
# 학부/과 : 항공우주 및 기계공학부
# 필수교양 : 13
# 전공기초교양 : 18(19학번은15)
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 43(19학번은 40)
#
# 학부/과 : 항공전자정보공학부
# 필수교양 : 13
# 전공기초교양 : 12
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 37
#
# 학부/과 : 소프트웨어학과
# 필수교양 : 13
# 전공기초교양 : 12
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 37
#
# 학부/과 : 항공재료공학과
# 필수교양 : 13
# 전공기초교양 : 12
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 37
#
# 학부/과 : 항공교통물류학부
# 필수교양 : 12
# 전공기초교양 : 9
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 33
#
# 학부/과 : 항공운항학과
# 필수교양 : 12
# 전공기초교양 : 6
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 30
#
# 학부/과 : 경영학부
# 필수교양 : 12
# 전공기초교양 : 0
# 핵심교양 : 9
# 심화교양 : 3
# 계 : 24
# 6) 2013~2017학번
#
# 대영역 : 필수교양
# 세부영역 : 국어, 영어, 항공우주특성화
# 학점 : 10 학점
#
# 대영역 : 핵심교양
# 세부영역 :
# 1) 철학과 역사
# 2) 문학과 예술
# 3) 인간과 사회
# 4) 자연과 과학
# 학점 : 6~9 학점, 학부/과 별 지정영역이수 (4-1참조)
# 비고 : 12학점(1)~5) 학부/과 별 지정 영역과 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨
#
# 대영역 : 일반교양
# 세부영역 :
# 6) 철학과 역사
# 7) 문학과 예술, 체육
# 8) 인간과 사회
# 9) 자연과 과학
# 10) 실용 및 글로벌
# 11) 봉사와 리더십
# 12) 자기개발
# 13) 외국어(영어)
# 학점 : 자유이수
#
# 계 : 19~22 학점
#
# 6-1) 2013~2017학번 핵심교양 지정영역
#
# 학부/과 : 항공우주 및 기계공학부, 항공운항학과, 경영학부
# 지정영역 : 철학과 역사, 문학과 예술, 인간과 사회, 자연과 과학
# 학점 : 6 학점(영역 택 2)
#
# 학부/과 : 항공전자정보공학부, 항공전자 및 정보통신공학부, 항공재료공학과
# 지정영역 : 철학과 역사, 문학과 예술, 인간과 사회
# 학점 : 6학점(영역 택 2)
#
# 학부/과 : 소프트웨어학과
# 지정영역 : 철학과 역사, 문학과 예술, 인간과 사회
# 학점 : 9학점(영역별 3학점)
#
# 학부/과 : 항공교통물류학부
# 지정영역 : 인간과 사회, 자연과 과학
# 학점 : 6학점(영역별 3학점)
#
# 학부/과 : 영어학과
# 지정영역 : 철학과 역사, 인간과 사회
# 학점 : 6학점(영역별 3학점)
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 12989
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p class="0" style="mso-pagination: none; mso-padding-alt: 0pt 0pt 0pt 0pt; mso-list: l1 level1 lfo2;"><span style="color: rgb(0, 0, 0); font-family: Arial; font-size: 10pt; mso-fareast-font-family: 맑은 고딕;"><span style="font-family: Arial; font-size: 10pt; font-weight: bold; mso-fareast-font-family: 맑은 고딕;"><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">\xa0</span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">\xa0 </span><o:p></o:p></span></span></p><p class="0" style="line-height: 1.5;"><span style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">&lt; 공통교양 &gt;<br/><br/>■ </span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">KAU SPACE </span><span style="font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">인성과 진로</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">(KAU SPACE Creative Personality &amp; Career)</span></p><p class="0" style="line-height: 1.5;"><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">KAU </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">인재상과 핵심역량에 따른 자아정체성 확립과 생애주기 변화에 따른 계발을 통해 인성을 함양하며</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">, </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">존중</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">, </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">배려</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">, </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">협동하는 가치를 실현하는 공동체 구성원 간의 유대관계의 필요성을 이해하고 인성을 실현하고</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">, </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">기업과 사회가 요구하는 직업 인성역량 체험을 통해 진로지도로 연계하며</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">, </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">자기주도력과 유연성을 가진 </span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">‘KAU SPACE </span><span style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">人</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">’</span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">의 성공하는 대학생활의 실행력을 높인다</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">.</span></p><p class="0" style="line-height: 1.5;"><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);"> </span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);">\xa0</span><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, 0);"> </span><o:p></o:p></p><p class="0" style="line-height: 1.5;"><span style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">■ </span><span style="font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">교양글쓰기</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: Arial; font-size: 10pt; font-weight: bold; color: rgb(0, 0, 0);">(Basic Writing)</span></p><p class="0" style="line-height: 1.5;"><span style="font-family: Arial; font-size: 10pt; color: rgb(0, 0, ...
#
# $(document).ready(function() {
# });
#
# &lt; 공통교양 &gt;■ KAU SPACE 인성과 진로(KAU SPACE Creative Personality &amp; Career)KAU 인재상과 핵심역량에 따른 자아정체성 확립과 생애주기 변화에 따른 계발을 통해 인성을 함양하며, 존중, 배려, 협동하는 가치를 실현하는 공동체 구성원 간의 유대관계의 필요성을 이해하고 인성을 실현하고, 기업과 사회가 요구하는 직업 인성역량 체험을 통해 진로지도로 연계하며, 자기주도력과 유연성을 가진 ‘KAU SPACE 人’의 성공하는 대학생활의 실행력을 높인다.   ■ 교양글쓰기(Basic Writing)논리적인 사고와 정확한 표현의 배양을 목표로 삼는다. 여러 유형의 글쓰기를 통해 사고와 표현의 관계를 이해하며, 올바른 국어생활과 문장기술의 실제를 익히는 시간을 갖는다.   ■ 영어커뮤니케이션Ⅰ·Ⅱ(English Communication Ⅰ·Ⅱ)영어 능력 중에서 생각을 표현하는 기능인 쓰기와 말하기 능력을 향상시키는 것을 목표로 하는 과목이며 외국인 강사의 반복적인 훈련과 교정을 통하여 자신의 사고를 구어체와 문어체로 논리적이고 효과적인 방법으로 표현하는 기술을 학습한다.    ■ 인공지능소개(AI Introduction)AI 탄생의 배경과 역사 그리고 주요 이론들에 대한 다학제적 이해를 통해, AI 시대를 선도할 기초적 소양과 통찰력을 함양한다. AI 기술 현황과 발전 동향을 파악함으로써 사회적, 산업적 및 경제적 파급효과를 이해한다. AI 미래에 대한 인문학적 상상과 사유를 통해 미래 융합 인재로 성장하기 위한 학습 동기를 고양시킨다.   ■ 기업가정신(Entrepreneurship)4차 산업혁명 시대의 기업은 전통적인 사업영역을 지속하기 보다는 새로운 비즈니스 모델을 발굴하고 이를 사업화해야 하는 상황에 직면하게 된다. 첨단 분야에서 사업기회를 인지하고 이를 기존 기업내에서 또는 벤처를 설립해서 사업화하는 전 과정에 대해 학습한다. ■ 꿈꾸는 인공지능(Dreaming AI)본 과목은 인공지능이라는 거대 산맥을 융복합적으로 탐구하려는 전공자 및 비전공자 모두에게 필요한 이정표 역할을 배경으로 한다. 이를 위해 컴퓨터공학을 필두로 철학, 뇌과학, 인지과학, 복잡계과학, 양자역학, 심리학 등 융복합적 교육을 시도한다. 보다 쉽게 인공지능의 본질에 다가설 수 있도록 때로는 영화를 통해 때로는 위인들의 이야기를 통해 때로는 철학적 사상 등을 통해 다양한 형태로 강의를 진행함으로써 인공지능 미래에 대한 통찰의 시간을 갖도록 한다. 교재는 강의 담당자가 집필한 대학 교양 도서 &lt;꿈꾸는 인공지능&gt;으로 한다.   ■ 미래를 만드는 SW(Software creating the future)본 과목은 소프트웨어 전공 관련 학과 신입생을 대상으로 입학 전 SW분야 학습 경험이 없는 신입생들에게 AI/SW의 개념과 사례를 살펴봄으로써 중요성을 인식하고 프로그래밍을 통해 실습하는 기회를 제공한다.    ■ 세상을 바꾸는 SW(Software changing the world)본 과목은 전 학과 신입생을 대상으로 입학 전 SW분야 학습 경험이 없는 신입생들에게 SW의 개념과 사례를 살펴봄으로써 중요성을 인식하고 프로그래밍을 경험하는 기회를 제공한다.  ■ 외국인을 위한 교양글쓰기(Basic Writing for Foreigner)본  수업은 외국인 학생들을 위한 한국어 글쓰기 교육 과목으로 외국인 학생들의 한국어 글쓰기 능력을 향상하는 것을 목적으로 한다. 외국인 학생들의 기초적인 글쓰기 능력을 갖추고, 이를 바탕으로 한국인과 의사소통할 수 있는 기초 능력을 기를 수 있도록 한다. 한국어 능력 2-3급을 기준으로 하되 각 학생의 한국어 실력에 맞춰 강의할 예정이다. ■ 외국인을 위한 기초한국어( Basic Korean Language for Foreigner)본 수업은 외국인 학생들을 위한 기초한국어 교육 과목으로 외국인 학생들의 한국어 능력을 향상시키는 것으로 목적으로 한다. 외국인 학생들의 기초적인 한국어 문법, 말하기, 듣기, 읽기, 쓰기 능력을 갖추고, 이를 바탕으로 한국인과 의사소통할 수 있는 능력을 향상하고 한국 문화 전반에 대한 기본적 이해를 돕고자 한다. 그리하여 외국인 학생들이 여타의 수업을 수강하는 데 도움을 주고자 한다. 맞춤형 수업으로 한국어 능력 4급 이상을 기준으로 하되 각 학생들의 한국어 실력에 맞춰 강의할 예정이다.    &lt; 학문기초교양 &gt;  ■ 항공우주학개론(Introduction to Aeronautics)항공기의 발달과정과 항공기 비행의 기본원리 및 장비의 개요, 운항응용 분야 등을 교수하여 항공학전공의 기틀을 마련한다. ■ 항공우주산업개론(Air and Space Industry) 항공우주분야 특성화 교육으로 항공우주산업에 대한 포괄적인 내용을 쉽게 소개하여 본교 학생들에게 항공우주산업 전반을 이해하게 한다. 강의는 모든 학생에게 필수 과목으로 세부내용은 항공운항, 항공교통 및 항공우주산업에 관한 지식이며 강의를 통하여 학생들에게 전공과 교양의 기초를 견고하게 하는 것을 목표로 한다. ■ 기초 미분적분학(Basic Calculus)대학에서 배우는 수학의 이론과 응용을 이해하기 위한 미분적분학의 기본적인 공식과 개념을 배운다.   ■ 미분적분학(Calculus)함수의 미분과 적분에 대한 기본 개념과 성질을 이해하여 이공학적 문제에 적용 및 응용할 수 있는 수학적 해석력을 배운다. 역함수, 수열, 급수, 편미분, 다중적분 등의 영역의 개념과 성질을 이해하여 수학적 응용력과 사고력을 키운다.   ■ 선형대수학(Linear Algebra)벡터공간, 선형변환, 행렬 등으로 구성된 선형대수의 중요한 내용의 하나가 연립방정식 해법에 대한 이론을 정리 및 체계화하는 것이다. 선형대수의 개념들은 수학의 문제를 해결해 나가는 중요한 도구가 되었을 뿐 아니라, 자연과학이나 사회과학을 설명하고 풀이하는데 응용된다. 따라서 강의는 학생들이 선형대수의 기본개념을 충분히 파악하도록 하며, 예제와 연습문제를 통해 응용력을 가지도록 강의한다.   ■ 현대수학(Modern mathematics)평면이나 혹은 공간상에서 발생하는 움직임에 대한 수학적인 모형을 이해하기 위해 미분과 적분, 그리고 선형변환을 학습한다. 또한, 움직임에 대한 상태의 변환을 이해하기 위해 확률과 통계학을 학습한다. 학습한 내용을 수학적인 프로그램을 이용하여 수강생이 직접 확인한다.   ■ 경영학도를 위한 대학수학(College Mathematics for Business)최적의 경영활동을 위한 정량적 분석에 필요한 관련 수학 이론의 개념을 기초적으로 설명하고, 수학적 해결방법이 경영활동상 효과적인 문제 해결방법으로써 활용될 수 있음을 학습한다.   ■ 통계학입문(Introduction to Statistics)학습자가 표본을 이용하여 모집단의 구조와 특서응ㄹ 파악하기 위하여 기술통계학을 배우고, 모집단의 특성에 따른 표본의 구조는 확률을 통하여 확인한다. 또 표본을 통하여 모집단의 성질을 파악하는 추론통계학에서 학습자는 상관관계, 회구분석, 그리고 분산분석을 배운다. 수업 시간에 제공되는 자료와 학습자가 관심이 있는 운항, 경영, 교통, 스포츠, 심리 등 다양한 자료는 Excel과 R을 이용하여 실습한다.   ■ 일반물리Ⅰ(General Physics I)뉴턴 법칙에 대한 기초 입문 과정이다. 직선및 회전 운동에 대한 뉴턴 법칙의 의미와 적용 방법을 수학적 표현을 통해 공부한다.   ■ 일반물리실험Ⅰ(General Physics experiment I)뉴턴 법칙의 의미와 적용 방법을 실험을 통해 공부한다.   ■ 일반물리Ⅱ(General Physics II)전자기 현상인 가우스 법칙과 암페어 법칙을 배우고 패러데이 법칙과 확장된 암페어 법칙을 통하여 전기및 자기가 서로 연관되어 있음을 이해한다.   ■ 일반물리실험Ⅱ(General Physics experiment II)전자기 현상에 대한 이론을 실험적으로 이해한다.   ■ 일반화학(General Chemistry)화학에 대한 전반적인 이해를 통해 그 지식과 이론을 응용할 수 있는 능력을 배양하고, 응용과학분야 중 가장 기본적이고 응용성이 넓은 화학을 통 ...
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.1",
# "an": "Hancom Office Hangul",
# "av": "11, 0, 0, 5178",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_8"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2022-03-04T09:40:21.932Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D82F6074B870800000002D": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D82F6074B870800000002E": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 10066329,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D82F6074B870800000002F": {
# "id": 0,
# "he": 1000,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D82F6074B870800000002E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 90,
# "r2": 90,
# "r3": 90,
# "r4": 90,
# "r5": 90,
# "r6": 90,
# "r7": 90,
# "s1": -10,
# "s2": -10,
# "s3": -10,
# "s4": -10,
# "s5": -10,
# "s6": -10,
# "s7": -10,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D82F6074B8708000000030": {
# "id": 1,
# "he": 1000,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D82F6074B870800000002E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 90,
# "r2": 90,
# "r3": 90,
# "r4": 90,
# "r5": 90,
# "r6": 90,
# "r7": 90,
# "s1": -10,
# "s2": -10,
# "s3": -10,
# "s4": -10,
# "s5": -10,
# "s6": -10,
# "s7": -10,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D82F6074B8708000000031": {
# "id": 2,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D82F6074B870800000002E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D82F6074B8708000000032": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D82F6074B8708000000033": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D82F6074B8708000000032",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 150,
# "bf": "01D82F6074B870800000002E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D82F6074B8708000000034": {
# "id": 1,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D82F6074B8708000000032",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D82F6074B870800000002E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D82F6074B8708000000035": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D82F6074B8708000000034",
# "cp": "01D82F6074B8708000000031",
# "ns": "01D82F6074B8708000000035",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D82F6074B870800000002B",
# "01D82F6074B870800000002B": {
# "np": "01D82F6074B870800000002C",
# "id": 0,
# "pp": "01D82F6074B8708000000033",
# "si": "01D82F6074B8708000000035",
# "bf": 3,
# "ru": [
# {
# "cp": "01D82F6074B870800000002F",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D82F6074B8708000000029"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D82F6074B870800000002A"
# }
# ,
# {
# "t": "■ 색채학개론(Introduction to color studies)"
# }
# ]
# }
# ]
# },
# "01D82F6074B870800000002C": {
# "np": "",
# "id": -2147483648,
# "pp": "01D82F6074B8708000000033",
# "si": "01D82F6074B8708000000035",
# "bf": 0,
# "ru": [
# {
# "cp": "01D82F6074B8708000000030",
# "ch": [
# {
# "t": "우리는 넘쳐나는 ‘색채의 시대’속에 살고 있다. 현대 사회는 다양한 기술의 발달로 모든 것이 시각화되고 이미지와 영상을 통해 내용을 전달하고 고객의 마음을 사로잡는다. 따라서 요즘은 디자이너가 아니라도 사진, 패션, 소셜 미디어 등 다양한 분야 속에서 색을 선택하고 나를 어필하는 도구로 사용한다. 또한 개개인의 삶의 질과 공공 사회의 품격을 높여주고 기업과 국가에는 경쟁력을 제고하기 위한 필수적인 요소로 색의 가치는 높게 평가되고 있다. 이에 ‘색’에 대한 기본적인 초석을 세워 색의 중요성을 인지하고 색의 역사적, 심리적, 과학적, 문화적인 사용법을 학습하여 색채에 대한 정확한 이해와 표현에 대한 감각과 기법을 훈련하고자 한다. 또한 부가가치의 창출 요소가 혁신적인 기술과 창의적인 아이디어로 이동하며 수행 직무나 자격이 훨씬 다양해진 현대 사회에서 전문 분야별로 색채를 기능적, 효율적, 구조적으로 계획하고 응용하는 방법을 익힐 수 있게 된다."
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D82F6074B8708000000029": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -4,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D82F6074B870800000002D",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D82F6074B870800000002D",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D82F6074B870800000002D",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D82F6074B870800000002A": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->우리는 넘쳐나는 ‘색채의 시대’속에 살고 있다. 현대 사회는 다양한 기술의 발달로 모든 것이 시각화되고 이미지와 영상을 통해 내용을 전달하고 고객의 마음을 사로잡는다. 따라서 요즘은 디자이너가 아니라도 사진, 패션, 소셜 미디어 등 다양한 분야 속에서 색을 선택하고 나를 어필하는 도구로 사용한다. 또한 개개인의 삶의 질과 공공 사회의 품격을 높여주고 기업과 국가에는 경쟁력을 제고하기 위한 필수적인 요소로 색의 가치는 높게 평가되고 있다. 이에 ‘색’에 대한 기본적인 초석을 세워 색의 중요성을 인지하고 색의 역사적, 심리적, 과학적, 문화적인 사용법을 학습하여 색채에 대한 정확한 이해와 표현에 대한 감각과 기법을 훈련하고자 한다. 또한 부가가치의 창출 요소가 혁신적인 기술과 창의적인 아이디어로 이동하며 수행 직무나 자격이 훨씬 다양해진 현대 사회에서 전문 분야별로 색채를 기능적, 효율적, 구조적으로 계획하고 응용하는 방법을 익힐 수 있게 된다.   ■ 서양미술감상(Western Art Appreciation)선사시대부터 프랑스 혁명시기까지 서양 미술의 흐름을 통시적으로 고찰하면서, 각 시대의 미적 이상은 무엇이며 그 표현 양식이 어떻게 변해왔는가를 탐구한다. 시대별 주요 작가와 작품을 감상하면서, 당대 사회경제, 정치, 종교 등의 다양한 문맥과 연결될 미술사적 의의를 살펴본다.   ■ 문학과 인생(Literature and Life)문학에 대한 일반 이론과 작품세계를 통해 문학과 삶 사이의 본질적인 관련을 파악하고 우리의 삶에서 필요한 교양을 함양토록 한다. 문학에 대한 친밀감을 느끼게 하고 보다 쉽게 문학에 접근할 수 있도록 하며 문학 작품이 우리의 삶에 어떤 중요한 의미를 갖는지를 인식할 수 있도록, 한국의 대표적 문학작품들을 감상하고 작품 속에 나타난 인생들의 삶을 특질들을 발견케 한다.   ■ 세계문학감상(Appreciation of World Literature)세계고전문학작품을 감상하는 것으로 중국 한시, 일본 하이쿠, 영미와 유럽의 유명 시들을 감상할 것이며, 중국, 일본, 몽골, 영미와 유럽의 소설을 감상한다. 학생들이 문학적으로나 사상적으로 품위 있고 가치 있는 한국고전문학작품을 감상함으로써, 지성과 감성의 조화로운 품격을 기르는데 도움을 주고자 한다.   ■ 신화의 세계(Love and Arts in Myth)본 강의에서는 동서양의 신화를 탐색한다. 시화에는 인류 정신의 뿌리가 담겨 있다. 거기에는 인류의 보편적 정신이 스며있으며, 동시에 민족 저마다의 특성도 들어있다. 본 강의에서는 한국, 시베리아, 중국, 일본 등 동양의 신화와 그리스로마 신화, 북유럽의 신화 등에 대해 살펴보면서 인류의 정신을 탐색할 것이다.   ■ 영화로 읽는 중국(Discovering China through film)영화는 한 나라와 사회를 반영하는 영향력이 큰 대중문화이자 매체이다. 오락, 예술, 산업과 이데올로기 등이 어우러져 예술로 승화된 중국 영화를 감상하는 것은 중국을 이해하는 가장 대중적이고 쉬운 방법이다. 본 수업은 중국 영화에 투영된 중국 사회, 문화, 역사, 철학, 예술 등을 광범위하게 살펴봄으로써 중국에 대한 흥미와 이해를 증진하고자 한다.   ■ 현대미술의 이해(Understanding of Contemporary Art)19세기 이후 오늘에 이르기까지 서양 현대 미술의 변화를 주요 미술가와 작품을 통해 탐구한다. 각 시대의 사상과 정치적 변화, 문화적 관계망 속에서 미술작품을 살펴 보고, 인간의 창작 활동에 대한 다각적인 이해를 통해 현대 사회에 필요한 인문학적 사고를 기른다.    ■ 일본문학의 이해(Understanding Japanese Literature)본 과목은 일본문학의 주요한 흐름을 살펴보고 일본의 대표적인 문학 작품을 감상함으로써, 일본문학에 대한 지식을 습득하고 작품 감상 능력을 갖추는 것을 목표로 한다. 일본고전문학에 나타난 문학 장르의 특성을 파악하고 일본의 근현대 시기에 전개된 문예사조를 개관한다. 이와 함께 일본의 대표적 문학 자품에 대한 감상을 병행한다. 이와 같이 일본문학을 학습함으로써 일본인과 일본사회에 대한 분석 능력도 함양하도록 한다.   ■ 한국고전문학산책(Appreciation of Korean Classical Literature)한국고전문학작품을 감상하는 것으로 시가, 서사, 교술 작품이 모두 대상이 된다. 향가에서 시조, 가사까지 그리고 고전소설, 고전수필 등을 감상하게 된다. 학생들이 문학적으로나 미학적으로나 사상적으로 품위 있고 가치 있는 한국고전문학작품을 감상함으로써, 지성과 감성의 조화로운 품격을 기르는데 도움을 주고자 한다.   ■ 희곡의 이해(ICU)(Understanding Drama)본 강좌는 우선 문학작품으로서의 희곡의 구성 요소와 그 특징을 살펴보고자 한다. 그리고 두번째로, 희곡 뿐 아니라 연출을 전제한 희곡의 연극적 측면에 대해서도 관심을 가질 것이다. 더 나아가 세 번째로 우리 강좌는 희곡과 연극의 생성과 변화의 이면에서 이러한 모든 변화를 주도한 시대정신에 대해 알아보고자 한다.그리고 이렇게 준비된 이론적 지식을 바탕으로 총 6편의 작품을 분석하고 감상함으로써, 참여자들은 작품에 제시된 갈등과 해소를 경험하고 작가의 세계관 및 시대정신을 만나는 한편, 다양한 방법을 통해 자신의 의견과 타인의 의견을 비교해 봄으로써 의사소통의 방법과 기술에 대해서도 학습하게 될 것이다. ■ 영화로 보는 문학세계(ICU)(Literature and Film)본 강좌는 영화와 문학이라는 예술 장르를 통해서 필요한 기초 지식을 익히고 우리의 선입견을 제거하며 실존적 삶을 영위하는데 필요한 의식지평의 한계를 확대시키는데 기여하는 것을 목표로 하고 있다.   ■ 현대감성의 디자인과 예술(Sensibility of contemporary design and art) 과학기술의 발달과 함께 변화된 현대인의 감성 및 트렌드에 부합하여 디자인과 예술 분야에서 일어난 새로운 창작 기법이나 창의적 발상의 다양한 사례를 살펴본다. 이를 통해 사회의 다양한 현상을 발산적 사고로 접근해 보고 이를 우리의 생활에 대입해 볼 수 있다. 또한, 융합된 산업에서 새롭게 만들어지는 현대 감성을 예술적으로 해석하고 탐구해 보는 과정을 경험한다.  ■ Stories and CultureThis course will have students read and discuss some of the most influential stories from Western Culture over time.  Normally, four stories will be selected for each semester: two before and two after the mid-term.  The four selections for a semester will be made by the instructor and announced before the beginning of the term.  The list of possible stories from which the selection will be made will include the Odyssey, Pygmalion, Romeo and Juliet, Frankenstein, and A Christmas Carol.  To the extent possible, stories will be studied in their original form and in the way they evolved into contemporary tellings.  Class time will be divided into lecture by the instructor, discussion by the whole class with the instructor, discussion in independent small groups of students, and occasionally some viewing of film.  At the end of this course, students should have acquired a deeper appreciation of the storie ...
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.1",
# "an": "Hancom Office Hangul",
# "av": "11, 0, 0, 5178",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_8"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2022-03-04T09:40:41.124Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D82F607E8598400000003D": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D82F607E8598400000003E": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 10066329,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D82F607E8598400000003F": {
# "id": 0,
# "he": 1000,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D82F607E8598400000003E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 90,
# "r2": 90,
# "r3": 90,
# "r4": 90,
# "r5": 90,
# "r6": 90,
# "r7": 90,
# "s1": -10,
# "s2": -10,
# "s3": -10,
# "s4": -10,
# "s5": -10,
# "s6": -10,
# "s7": -10,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D82F607E85984000000040": {
# "id": 1,
# "he": 1000,
# "tc": 16711680,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D82F607E8598400000003E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 90,
# "r2": 90,
# "r3": 90,
# "r4": 90,
# "r5": 90,
# "r6": 90,
# "r7": 90,
# "s1": -10,
# "s2": -10,
# "s3": -10,
# "s4": -10,
# "s5": -10,
# "s6": -10,
# "s7": -10,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D82F607E85984000000041": {
# "id": 2,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D82F607E8598400000003E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D82F607E85984000000042": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D82F607E85984000000043": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D82F607E85984000000042",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 150,
# "bf": "01D82F607E8598400000003E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D82F607E85984000000044": {
# "id": 1,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D82F607E85984000000042",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D82F607E8598400000003E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D82F607E85984000000045": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D82F607E85984000000044",
# "cp": "01D82F607E85984000000041",
# "ns": "01D82F607E85984000000045",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D82F607E85984000000038",
# "01D82F607E85984000000038": {
# "np": "01D82F607E85984000000039",
# "id": 0,
# "pp": "01D82F607E85984000000043",
# "si": "01D82F607E85984000000045",
# "bf": 3,
# "ru": [
# {
# "cp": "01D82F607E8598400000003F",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D82F607E85984000000036"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D82F607E85984000000037"
# }
# ,
# {
# "t": "■ 고양학산책(Introductionof Goyang Studies)"
# }
# ]
# }
# ]
# },
# "01D82F607E85984000000039": {
# "np": "01D82F607E8598400000003A",
# "id": -2147483648,
# "pp": "01D82F607E85984000000043",
# "si": "01D82F607E85984000000045",
# "bf": 0,
# "ru": [
# {
# "cp": "01D82F607E85984000000040",
# "ch": [
# {
# "t": "고양학산책은 항공대학교가 자리하고 있는 지역인 고양의 역사, 인물, 마을, 민속, 문화, 예술 등에 대해 폭넓게 이해하는 한편, 이를 바탕으로 지역의 현재와 미래를 조망하는 것을 목표로 한다. 이 수업에서는 다양한 주제의 현장 답사를 통해, 고양 지역 곳곳을 자기 발로 직접 밟아가며 느끼고 배월볼 수 있도록 한다."
# }
# ]
# }
# ]
# },
# "01D82F607E8598400000003A": {
# "np": "01D82F607E8598400000003B",
# "id": -2147483648,
# "pp": "01D82F607E85984000000043",
# "si": "01D82F607E85984000000045",
# "bf": 0,
# "ru": [
# {
# "cp": "01D82F607E85984000000040",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D82F607E8598400000003B": {
# "np": "01D82F607E8598400000003C",
# "id": -2147483648,
# "pp": "01D82F607E85984000000043",
# "si": "01D82F607E85984000000045",
# "bf": 0,
# "ru": [
# {
# "cp": "01D82F607E8598400000003F",
# "ch": [
# {
# "t": "■ 공학도를 위한 경영마인드(Business Thinking)"
# }
# ]
# }
# ]
# },
# "01D82F607E8598400000003C": {
# "np": "",
# "id": -2147483648,
# "pp": "01D82F607E85984000000043",
# "si": "01D82F607E85984000000045",
# "bf": 0,
# "ru": [
# {
# "cp": "01D82F607E85984000000040",
# "ch": [
# {
# "t": "공대생들이 기업경영에 대한 이해를 높이기 위해 경영의 기초 개면을 학습하고, 특히 공학도에게 필요한 기술과 경영이 결합하여 새로운 사업기회를 창출하는 역량을 함양한다. "
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D82F607E85984000000036": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -4,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# ...
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004DC": {
# "np": "01D71FAE548A9DA0000004DD",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004DD": {
# "np": "01D71FAE548A9DA0000004DE",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ Current social issues and English reading "
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004DE": {
# "np": "01D71FAE548A9DA0000004DF",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "본 강좌를 외국어로서 영어를 학습하는 대학생의 영어읽기능력(reading comprehension skills)함양을 위해 사회전반의 동시대 이슈를 다루는 영어지문을 읽고 이해하는 연습을 한다. 본 교과목의 수강생은 영어지문을 통합적으로 이해하기 위하여 어휘와 문법을 포함하는 언어적 지식을 활용하며 또한 글쓴이의 논지와 이슈의 키워드를 파악하는 비판적 긁읽기를 연습하게 된다."
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004DF": {
# "np": "01D71FAE548A9DA0000004E0",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E0": {
# "np": "01D71FAE548A9DA0000004E1",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ FATS(Fundamentals of the Air Transport System)"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E1": {
# "np": "01D71FAE548A9DA0000004E2",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "본 강좌는 ICAO에서 개발한 항공운송system에 관한 기본내용을 영어로 된 사전 online 강의를 수강하고 그에 대한 보충강의  및 사례발표등을 통하여 학습하는 과정이다. 항공기, 항행, 공항시설, 안전과 보안 등에 관한 내용으로 구성되어 있으며, 항공관련교수, 관제사, 운항관리사, 조종사 및 항공에 관련된 업종에 종사하고자 하는 모든 이들을 위해 기본지식 교육과 case study 등을 실행한다. "
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E2": {
# "np": "01D71FAE548A9DA0000004E3",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E3": {
# "np": "01D71FAE548A9DA0000004E4",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ English for Engineering"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E4": {
# "np": "01D71FAE548A9DA0000004E5",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "English for Engineering is a vocabulary building course that uses the skills of reading and writing to explore new English language. Coursework is designed to help students to better understand English language textbooks and other course materials during their study of aerospace and mechanical engineering. Student will study word roots, parts of speech, common forms and collocations, and functional expressions seen everyday technical English texts. Individual and group assignments help students notice and discover common language patterns; and in-class peer teaching and activities help clarify and reinforce the meaning of new vocabulary and expressoins."
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E5": {
# "np": "01D71FAE548A9DA0000004E6",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E6": {
# "np": "01D71FAE548A9DA0000004E7",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ Speaking and Interaction"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E7": {
# "np": "01D71FAE548A9DA0000004E8",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "This course gives students opportunities, strategies, and technique to improve their interaction skills. By performing group tasks and activites, focused on achieving selected goals, students learn and practice new functional expressions, descriptive vocabulary, natural pronunciation and useful grammar tools in new ways. Coursework involves analyzing and creating new English media:helping students task a more global, holistic, technology-oriented approach to learning English."
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E8": {
# "np": "01D71FAE548A9DA0000004E9",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004E9": {
# "np": "01D71FAE548A9DA0000004EA",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ Speaking Conversation and Accuracy"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004EA": {
# "np": "01D71FAE548A9DA0000004EB",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "This course is designed to help students develop better speaking habits and become more comfortable conversing in English. Emphasis is placed on learning and employing new intermediate to advanced vocabulary, idioms and sentence structures in a smooth, natural manner. The class material is centered on American television, which allows students to listen to, study and replicate relevant language in themed discussions."
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004EB": {
# "np": "01D71FAE548A9DA0000004EC",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004EC": {
# "np": "01D71FAE548A9DA0000004ED",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ Speaking for Argumentation and Opinion"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004ED": {
# "np": "01D71FAE548A9DA0000004EE",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "This course provides students with a selection of engaging and controversial topics that allow for in-class discussion with opposing points of view. Students are given strategies and tools that enable them to analyze the topics, formulate opinions, organize arguments and effectively engage in discussions with classmates. Techniques are also introduced to encourage students to carry out sustained argumentative conversations in a manner that cultivates mutual respect and constructive learning."
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004EE": {
# "np": "01D71FAE548A9DA0000004EF",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004EF": {
# "np": "01D71FAE548A9DA0000004F0",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ Writing from Paragraph to Essay"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004F0": {
# "np": "01D71FAE548A9DA0000004F1",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "In this course, students will learn how to write good paragraphs and essays.  The three hours per week of class time will be divided into three main parts: instruction about grammar and usage problems common among Korean students, instruction about the correct and useful ways of forming and formatting stand-alone paragraphs and five-paragraph essays, and group-discussion time where students consider the topics for the weekly homework writing assignments.  The homework assignments are a key part of the learning process in this course.  They will be carefully corrected by the instructor and returned to the students promptly.  Grading will be based mostly from the scores received in the midterm and final exams."
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004F1": {
# "np": "01D71FAE548A9DA0000004F2",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004F2": {
# "np": "01D71FAE548A9DA0000004F3",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548A9DA0000004F7",
# "ch": [
# {
# "t": "■ Writing Practices for Effective Communication"
# }
# ]
# }
# ]
# },
# "01D71FAE548A9DA0000004F3": {
# "np": "",
# "id": -2147483648,
# "pp": "01D71FAE548AC4B0000004FF",
# "si": "01D71FAE548AC4B000000500",
# "bf": 0,
# "ru": [
# {
# "cp": "01D71FAE548AC4B0000004F8",
# "ch": [
# {
# "t": "Students make use of essential English writing techniques to improve the writing on the sentence, paragraph, and essay level. There is a strong focus on developing new and creative ideas. Using a step-by-step process, students work on generating, organizing, and writing their ideas. Peer review and group discussion is a daily part of the course. Weekly homework consists of journals and short writing assignments in which content and organization are the primary focus."
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D71FAE548A9DA0000002E1": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "01D71FAE548AC4B0000004FC",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 14692344,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D71FAE548A9DA0000004F4",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D71FAE548A9DA0000004F4",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D71FAE548A9DA0000004F4",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D71FAE548A9DA0000002E2": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# ,
# "01D71FAE548A9DA0000002E3": {
# "cc": 11,
# "ci": 1735618336,
# "id": 1612840160,
# "zo": 0,
# "nt": 1,
# "tw": 3,
# "tf": 0,
# "lo": false,
# "swi": 22350,
# "she": 1,
# "swr": 4,
# "shr": 2,
# "spr": false,
# "pta": true,
# "pal": false,
# "pvr": 0,
# "phr": 0,
# "pva": 0,
# "ph1": 0,
# "pvo": 15074,
# "ph2": 5669,
# "pfw": false,
# "pao": true,
# "pha": false,
# "ole": 0,
# "ori": 0,
# "oto": 0,
# "obo": 0,
# "ca": { },
# "sc": "선입니다."
# ,
# "rc": {
# "cc": 11,
# "ci": 611084654,
# "hr": "",
# "gl": 0,
# "ii": 539098337,
# "ox": 0,
# "oy": 0,
# "ow": 100,
# "oh": 100,
# "cw": 22350,
# "ch": 0,
# "fh": false,
# "fv": false,
# "ra": 0,
# "rcx": 11175,
# "rcy": 0,
# "rc": false,
# "ri": true,
# "in": {
# "ma": false,
# "rb": false,
# "tm": {
# "e1": 1.000000,
# "e2": 0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 1.000000,
# "e6": 0.000000
# },
# "re": [
# {
# "sm": {
# "e1": 223.500000,
# "e2": 0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 0.000000,
# "e6": 0.000000
# },
# "ro": {
# "e1": 1.000000,
# "e2": -0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 1.000000,
# "e6": 0.000000
# }
# }
# ]
# }
# ,
# "ls": {
# "co": 32768,
# "wi": 169,
# "st": 1,
# "ec": 1,
# "al": 0,
# "hs": 0,
# "ts": 0,
# "he": true,
# "ta": true,
# "h1": 4,
# "t1": 4,
# "os": 0
# },
# "fb": { },
# "sh": {
# "ty": 0,
# "co": 11711154,
# "ox": 0,
# "oy": 0,
# "al": 0
# },
# "so": "",
# "li": 0
# ,
# "sx": 0,
# "sy": 0,
# "ex": 100,
# "ey": 100,
# "ir": false
# }
# }
# ,
# "01D71FAE548A9DA0000002E5": {
# "cc": 11,
# "ci": 1735618336,
# "id": 1612840162,
# "zo": 1,
# "nt": 1,
# "tw": 3,
# "tf": 0,
# "lo": false,
# "swi": 22350,
# "she": 1,
# "swr": 4,
# "shr": 2,
# "spr": false,
# "pta": true,
# "pal": false,
# "pvr": 0,
# "phr": 0,
# "pva": 0,
# "ph1": 0,
# "pvo": 15074,
# "ph2": 5669,
# "pfw": false,
# "pao": true,
# "pha": false,
# "ole": 0,
# "ori": 0,
# "oto": 0,
# "obo": 0,
# "ca": { },
# "sc": "선입니다."
# ,
# "rc": {
# "cc": 11,
# "ci": 611084654,
# "hr": "",
# "gl": 0,
# "ii": 539098339,
# "ox": 0,
# "oy": 0,
# "ow": 100,
# "oh": 100,
# "cw": 22350,
# "ch": 0,
# "fh": false,
# "fv": false,
# "ra": 0,
# "rcx": 11175,
# "rcy": 0,
# "rc": false,
# "ri": true,
# "in": {
# "ma": false,
# "rb": false,
# "tm": {
# "e1": 1.000000,
# "e2": 0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 1.000000,
# "e6": 0.000000
# },
# "re": [
# {
# "sm": {
# "e1": 223.500000,
# "e2": 0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 0.000000,
# "e6": 0.000000
# },
# "ro": {
# "e1": 1.000000,
# "e2": -0.000000,
# "e3": 0.000000,
# "e4": 0.000000,
# "e5": 1.000000,
# "e6": 0.000000
# }
# }
# ]
# }
# ,
# "ls": {
# "co": 32768,
# "wi": 169,
# "st": 1,
# "ec": 1,
# "al": 0,
# "hs": 0,
# "ts": 0,
# "he": true,
# "ta": true,
# "h1": 4,
# "t1": 4,
# "os": 0
# },
# "fb": { },
# "sh": {
# "ty": 0,
# "co": 11711154,
# "ox": 0,
# "oy": 0,
# "al": 0
# },
# "so": "",
# "li": 0
# ,
# "sx": 0,
# "sy": 0,
# "ex": 100,
# "ey": 100,
# "ir": false
# }
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->
#
# %%%%%%%%%%%%%%%%%%%
# -------5-------
# 11
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3>연구소 소개</h3></div><div class="article_101"><div class="article_101"><h4 style="text-align: left;">기초학문연구소<br/><br/><div align="right" style="text-align: right;"><a href="/web/cmm/imageSrc.do?path=1e81c620cce40e7798736d68ea20b342&amp;physical=6cc9a9075e8de395a1d1b5d2e0bc6e46b1068ff069c8494e874c3c4207ceb2f2d0409bec8def4267276dc76cf51873f6&amp;contentType=bdbc03257919f336778bcb6e5c07cb8b" target="_blank"><img src="/web/cmm/imageSrc.do?path=1e81c620cce40e7798736d68ea20b342&amp;physical=6cc9a9075e8de395a1d1b5d2e0bc6e46b1068ff069c8494e874c3c4207ceb2f2d0409bec8def4267276dc76cf51873f6&amp;contentType=bdbc03257919f336778bcb6e5c07cb8b" title="???????.png" width="100%"/></a><br style="clear:both;"/><br/></div></h4><p>\xa0 \xa0한국항공대학교 기초학문연구소는 대학부설 자립운영기관으로서 교양교육과 관련된 기초학문분야의 학문적 연구를 수행하기 위해 1996년 설립한 이후, 교양교육에 관한 축적된 학문적 연구를 바탕으로 다양한 교육 프로그램을 개발하여 대학교육의 내실 있는 발전 및 지역사회와의 폭넓은 교류를 도모하고 있다.<br/><br type="_moz"/>\xa0 \xa0한국항공대학교 인문자연학부 교수를 주축으로 하여 연구소 교수 및 박사후 과정 연구원이 협력하여 운영하면서 물리, 수학, 사회학, 철학, 심리학, 언어학, 영어교육, 국어학, 문학을 아우르는 자연과학과 인문학 분야에서 학술 조사 및 연구, 강연회 개최, 전문도서 및 교양도서 간행, 사회교육 프로그램 개발, 그리고 외부기관 위촉사업 활동을 활발히 이어가고 있다.<br/><br/>기초학문에 관한 연구과 교육이 상호작용할 수 있는 다양한 활동을 수행해 가며 급변하는 대학 환경에서 교양교육의 새로운 방향성을 제시해 가는 것을 당면 과제로 삼고 있다.<br/><span style="text-align: center;">\xa0</span>\xa0</p></div></div><div class="article_101"><div align="right" style="text-align: right;">☎ 인문자연학부/기초학문연구소 02-300-0330<br/></div></div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 연구소 소개기초학문연구소   한국항공대학교 기초학문연구소는 대학부설 자립운영기관으로서 교양교육과 관련된 기초학문분야의 학문적 연구를 수행하기 위해 1996년 설립한 이후, 교양교육에 관한 축적된 학문적 연구를 바탕으로 다양한 교육 프로그램을 개발하여 대학교육의 내실 있는 발전 및 지역사회와의 폭넓은 교류를 도모하고 있다.   한국항공대학교 인문자연학부 교수를 주축으로 하여 연구소 교수 및 박사후 과정 연구원이 협력하여 운영하면서 물리, 수학, 사회학, 철학, 심리학, 언어학, 영어교육, 국어학, 문학을 아우르는 자연과학과 인문학 분야에서 학술 조사 및 연구, 강연회 개최, 전문도서 및 교양도서 간행, 사회교육 프로그램 개발, 그리고 외부기관 위촉사업 활동을 활발히 이어가고 있다.기초학문에 관한 연구과 교육이 상호작용할 수 있는 다양한 활동을 수행해 가며 급변하는 대학 환경에서 교양교육의 새로운 방향성을 제시해 가는 것을 당면 과제로 삼고 있다.  ☎ 인문자연학부/기초학문연구소 02-300-0330

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
