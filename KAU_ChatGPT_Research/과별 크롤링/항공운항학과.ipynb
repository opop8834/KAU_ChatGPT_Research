# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "항공운항학과_data"
number_html = 6
url = """http://college.kau.ac.kr/web/pages/gc21901h.do
http://college.kau.ac.kr/web/pages/gc98902h.do
http://college.kau.ac.kr/web/pages/gc2637h.do
http://college.kau.ac.kr/web/pages/gc28755h.do
http://college.kau.ac.kr/web/pages/gc21964h.do
http://college.kau.ac.kr/web/pages/gc70909h.do
http://college.kau.ac.kr/web/pages/gc89856h.do
http://college.kau.ac.kr/web/pages/gc72752h.do
http://college.kau.ac.kr/web/pages/gc57058h.do
http://college.kau.ac.kr/web/pages/gc23221h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 6:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc21901h.do', 'http://college.kau.ac.kr/web/pages/gc98902h.do', 'http://college.kau.ac.kr/web/pages/gc2637h.do', 'http://college.kau.ac.kr/web/pages/gc28755h.do', 'http://college.kau.ac.kr/web/pages/gc21964h.do', 'http://college.kau.ac.kr/web/pages/gc70909h.do', 'http://college.kau.ac.kr/web/pages/gc89856h.do', 'http://college.kau.ac.kr/web/pages/gc72752h.do', 'http://college.kau.ac.kr/web/pages/gc57058h.do', 'http://college.kau.ac.kr/web/pages/gc23221h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 12
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<div class="article_101"> </div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 11
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<strong><span style="font-family: 함초롬바탕; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0</span></strong><img alt="" src="data:image/png;base64,..."/><strong><span style="font-family: 함초롬바탕; font-size: 12pt; mso-fareast-font-family: 함초롬바탕;">\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 </span></strong><h4 align="right" class="sign"><br/></h4>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 83
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교수진</h3>', '</div>', '', '<ul class="prs_list">', '', '<li> <span class="portrait"> <img src="/conts_img/hw_www/introduce/송병흠.jpg"/> </span>', '<h4><span>송병흠교수</span></h4>', '<p>한국항공대 및 영남대 대학원</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>항공교통공학(공항)</li>', '<li>본관 422호</li>', '<li>02)-300-0087<span class="mail"> / <a href="mailto:bhsong@kau.ac.kr">bhsong@kau.ac.kr<br/></a></span></li>', '<li class="contact"> <a href="mailto:bhsong@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '', '<li><span class="portrait"><a href="/web/cmm/imageSrc.do?path=41274e227bd7f4c13de8822dbf8da9ec&amp;physical=f19d0abd019273495a166f9f8c531f5387244cf8dc5df2eff3333f28bc21be88d0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" target="_blank"><img src="/web/cmm/imageSrc.do?path=41274e227bd7f4c13de8822dbf8da9ec&amp;physical=f19d0abd019273495a166f9f8c531f5387244cf8dc5df2eff3333f28bc21be88d0409bec8def4267276dc76cf51873f6&amp;contentType=da462b206e7e7f9d239672271a582daa" title="??%20-IMG_1219___???_??2.jpg" width="100%"/></a><br style="clear:both;"/><br style="clear:both;"/><br/></span><h4><span>장조원교수</span></h4>', '<p>공군사관학교, 서울대 대학원 및 한국과학기술원(KAIST)</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>응용 공기역학</li>', '<li>본관 416호</li>', '<li>02)-300-0082<span class="mail"> / <a href="mailto:jwchang@kau.ac.kr">jwchang@kau.ac.kr</a></span></li>', '<li class="homepage"><a href="http://mercury.kau.ac.kr/aerodynamics/" target="_blank">http://mercury.kau.ac.kr/aerodynamics/</a> </li>', '<li class="contact"> <a href="mailto:jwchang@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="http://mercury.kau.ac.kr/aerodynamics/"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/hw_www/introduce/유병선.jpg"/> </span>', '<h4><span>유병선교수</span></h4>', '<p>한국항공대, 고려대 대학원</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>항공운항학</li>', '<li>본관 418호</li>', '<li>02)-300-0085<span class="mail"> / <a href="mailto:bsyoo@kau.ac.kr">bsyoo@kau.ac.kr<br/></a></span></li>', '<li class="contact"> <a href="mailto:bsyoo@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/hw_www/introduce/이장룡.jpg"/> </span>', '<h4><span>이장룡교수</span></h4>', '<p>공군사관학교, 美 CentralMissouriState Univ. 美 Purdue Univ</p>', '<ul class="prs_info">', '<li><span>전공분야 : 항공안전</span></li>', '<li>본관 524호</li>', '<li>02)-300-0088<span class="mail"> / <a href="mailto:jrherky@kau.ac.kr">jrherky@kau.ac.kr</a></span></li>', '<li class="contact"> <a href="mailto:jrherky@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/hw_www/introduce/김현덕.jpg"/> </span>', '<h4><span>김현덕교수</span></h4>', '<p>상지대, 한국항공대 대학원</p>', '<ul class="prs_info">', '<li><span>전공분야 : 항공운항</span></li>', '<li>본관 525호</li>', '<li>02)-300-0084<span class="mail"> / <a href="mailto:hyeondkim@kau.ac.kr">hyeondkim@kau.ac.kr</a></span></li>', '<li class="contact"> <a href="mailto:hyeondkim@kau.ac.kr"><img src="/cmm_typeA/images/icon_mail.png"/>이메일</a> <a href="#"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/hw_www/introduce/Robert-Hall.jpg"/> </span>', '<h4><span>Robert Hall교수</span></h4>', '<p>University of Alabama</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>영문학, 항공영어</li>', '<li>본관 507호</li>', '<li>02)-300- ...
#
# $(document).ready(function() {
# });
#
# 교수진
#
# 송병흠교수
# 한국항공대 및 영남대 대학원
#
# 전공분야 : 항공교통공학(공항)
# 본관 422호
# 02)-300-0087 / bhsong@kau.ac.kr
# 이메일 홈페이지
#
# 장조원교수
# 공군사관학교, 서울대 대학원 및 한국과학기술원(KAIST)
#
# 전공분야 : 응용 공기역학
# 본관 416호
# 02)-300-0082 / jwchang@kau.ac.kr
# http://mercury.kau.ac.kr/aerodynamics/
# 이메일 홈페이지
#
# 유병선교수
# 한국항공대, 고려대 대학원
#
# 전공분야 : 항공운항학
# 본관 418호
# 02)-300-0085 / bsyoo@kau.ac.kr
# 이메일 홈페이지
#
# 이장룡교수
# 공군사관학교, 美 CentralMissouriState Univ. 美 Purdue Univ
#
# 전공분야 : 항공안전
# 본관 524호
# 02)-300-0088 / jrherky@kau.ac.kr
# 이메일 홈페이지
#
# 김현덕교수
# 상지대, 한국항공대 대학원
#
# 전공분야 : 항공운항
# 본관 525호
# 02)-300-0084 / hyeondkim@kau.ac.kr
# 이메일 홈페이지
#
# Robert Hall교수
# University of Alabama
#
# 전공분야 : 영문학, 항공영어
# 본관 507호
# 02)-300-0339 / tony_hall62@hotmail.com
# 이메일 홈페이지
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 12
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3><img src="data:image/png;base64,..."/></h3>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 11
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<img src="data:image/png;base64,..."/><br/><img src="data:image/png;base64,..."/><br/><img src="data:image/png;base64,..."/><br/><br/><br/>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# %%%%%%%%%%%%%%%%%%%
# -------5-------
# 16
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<p><img src="/conts_img/hw_www/introduce/edu_eq_01.png"/></p>', '<p><img src="/conts_img/hw_www/introduce/edu_eq_02.png"/></p>', '<p><img src="/conts_img/hw_www/introduce/edu_eq_03.png"/></p>', '<p><img src="/conts_img/hw_www/introduce/edu_eq_04.png"/></p>', '<p><img src="/conts_img/hw_www/introduce/edu_eq_05.png"/></p>', '<p><img src="/conts_img/hw_www/introduce/edu_eq_06.png"/></p>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# %%%%%%%%%%%%%%%%%%%
# -------6-------
# 343
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>항공운항학과 운영내규</h3>', '</div>', '<div class="terms">', '<div class="chpt">', '<h4>제 1 장 총 칙</h4>', '<div class="sctn">', '<div class="artc">', '<h5>제1조 (목적)</h5>', "<p>이 운영내규는 항공운항학과(Department of Aeronautical Science and Flight Operation)(이하 '본 학과'로 칭함)의 교육목표를 달성하기 위한 합리적인 학과 운영을 위해 필요한 사항을 규정함을 목적으로 한다.</p>", '</div>', '</div>', '</div>', '<div class="chpt">', '<h4>제 2 장 졸업</h4>', '<div class="sctn">', '<div class="artc">', '<h5>제2조 (졸업학점)</h5>', '<p>졸업학점은 학칙 제 26조(졸업학점)에 따르며, 제 38조의 2(학부의 전공)에 의거 본 내규가 정하는 다음의 최소 요건을 추가로 만족하여야 한다.<br/>① 항공운항학과 학생은 아래의 최소 이수학점을 이수하여야 한다.<br/>&lt;개정 2012.03.01.&gt;&lt;개정 2015.03.01.&gt;&lt;개정, 신설 2018.03.01&gt;&lt;신설 2019.03.01.&gt;&lt;신설 2020.03.01.&gt;</p>', '<table class="table_01">\n<colgroup>\n<col style="width: 20%;"/>\n<col style="width: 50%;"/>\n<col style="width: 30%;"/>\n<col style="width: 30%;"/>\n</colgroup>\n<tbody><tr>\n<th>적용학번</th>\n<th>교과 구분</th>\n<th>최소이수학점<sup>\u200b*)</sup></th>\n<th>세부 내용</th>\n</tr>\n<tr>\n<td rowspan="2">2012학번 이전</td>\n<td>교양필수</td>\n<td>교양필수 13학점</td>\n<td>항공우주학개론(3학점)<br/>\n&lt;개정 2012.03.01.&gt;</td>\n</tr>\n<tr>\n<td>전공이수학점</td>\n<td>57학점</td>\n<td>기초필수과목(11학점) 포함</td>\n</tr>\n<tr>\n<td rowspan="2">2012학번 ~ 2017학번</td>\n<td>교양영역</td>\n<td>교양필수 14학점<br/>영역별 교양이수<br/>(핵심교양 6학점,<br/>일반교양 3학점)</td>\n<td>-영어의 이해2 필수제외<br/>-항공우주산업개론 신설<br/>항공우주학개론(2학점)변경<br/>&lt;개정 2012.03.01&gt;<br type="_moz"/>○ 2013학년도부터 신입학 한 학생들은<br/>전문교양학점의 필수 취득요건도<br/>만족하여야 함</td>\n</tr>\n<tr>\n<td>전공이수학점</td>\n<td>57학점</td>\n<td>기초필수과목(11학점) 포함</td>\n</tr>\n<tr>\n<td rowspan="2">2018학번</td>\n<td><br/><br/><br/>교양필수<br/><br/><br/><br/><br/><span style="color: blue;">(전공기초교양)</span></td>\n<td>교양필수 12학점<br/><span style="color: blue;">교양필수(전공기초) 9학점</span><br/>영역별 교양이수<br/>(핵심교양 9학점,<br/>심화교양 3학점)<br/><br/><br/><br/><span style="color: blue;">미분적분학, 물리, 선형대수학(9 학점)</span></td>\n<td><br/>정보기술개론(2018학년도 교양과목<br/>교과과정개편에 따라 해당과목의<br/>본수강 및 재수강은<br/>\'컴퓨팅적사고와 문제해결(교양필수)\'<br/>과목으로 대체)<br/>&lt;개정 2018.03.01&gt;<br/><br/>기초필수과목의 교양필수(전공기초)로<br/>구분 변경</td>\n</tr>\n<tr>\n<td>전공이수학점</td>\n<td>57학점<sup>\u200b1)</sup></td>\n<td></td>\n</tr>\n<tr>\n<td rowspan="2">2019학번 이후<br/>&lt;신설 2019.03.01.&gt;</td>\n<td>교양영역</td>\n<td>교양필수 12학점<br/>교양필수(전공기초) 9학점<br/>영역별 교양이수<br/>(핵심교양 9학점,<br/>심화교양 3학점)</td>\n<td>○ 2018학년도 이후 개정된 전문교양<br/>학점의 필수 취득요건을 만족하여야 함</td>\n</tr>\n<tr>\n<td>전공이수(전공필수<br/>및 전공선택)</td>\n<td>심화전공이수자(69학점)<br/>다전공 이수자(45학점)</td>\n<td>기본전공(45)+심화전공(24)<br/>기본전공(45)+부전공(24)or복수전공<br/>(42)or융합(36)</td>\n</tr>\n<tr>\n<td rowspan="2">2020학번 이후<br/><span style="color: blue;">&lt;신설 2020.03.01&gt;</span></td>\n<td>교양영역</td>\n<td>교양필수 및 영역별 교양이수 등<br/>총 이수학점<span style="color: blue;">(39학점)</span></td>\n<td>○ 2020학년도 이후 개정된 교양학점의<br/> 필수 취득요건<sup>\u200b<span style="color: red;">1)</span></sup>\u200b을 만족하여야<br/>함(영역별 이수<sup>\u200b<span style="color: red;">2)</span></sup>및 교양 총 이수학점<br/>모두 충하여야 함<br/><span style="color: red;">1)</span><span style="color: blue;"> 공통교양(9)*학문기초교양(11)</span><br/><span style="color: red;">2)</span><span style="color: blue;"> 선택교양(12/영역9+자유이수3)</span></td>\n</tr>\n<tr>\n<td>전공이수(전공필수<br/>및 전공선택)</td>\n<td>심화전공이수자(69학점)<br/>다전공 이수자(45학점)</td>\n<td>기본전공(45)+심화전공(24)<br/>기본전공(45)+부전공(24)or복수전공<br/>(42)or융합(36)</td>\n</tr>\n</tbody></table>*재학 중 해당 학년 / 학기에 개설된 전공필수과목의 전 학점 취득<br/>\xa0주 1) 2017년 2학기부터 전공과목에 기초필수 과목을 제외<br/>\xa0 \xa0 \xa0 \xa0 (단, 2018년 2월 졸업자에 한하여 필요시 포함할 수 있음)</div><div class="artc">', '<ol class="prph">', '<li><span class="num">②</span>\xa0(자격증 취득)항공운항학과 학생은 졸업을 위하여 반드시 자가용 조종사 면장(PPL : Private Pilot License)을 취득해야 한다.<span style="color: blue;"><em>&lt;신설 2014.03.01.&gt;. 2015년 이후 입학생에게 적용<br/>(단, 본교가 인정한 국내외 지정전문교육기관 자가용 조종사과정 이수증도 인정 &lt;신설 2021.08.01&gt;</em></span><br/>\xa0본 대학의 비행교육과정(위탁과정 포함) 이외에 해외 면장취득자는 취득 후 반드시 본 대학의 비행교육과정 1학기 이상 이수<br/>하여야 함)<br/>\xa0다음의 요건에 한하여 예외로  ...
# $(document).ready(function() {
# });
#
# 항공운항학과 운영내규
#
# 제 1 장 총 칙
#
# 제1조 (목적)
# 이 운영내규는 항공운항학과(Department of Aeronautical Science and Flight Operation)(이하 '본 학과'로 칭함)의 교육목표를 달성하기 위한 합리적인 학과 운영을 위해 필요한 사항을 규정함을 목적으로 한다.
#
# 제 2 장 졸업
#
# 제2조 (졸업학점)
# 졸업학점은 학칙 제 26조(졸업학점)에 따르며, 제 38조의 2(학부의 전공)에 의거 본 내규가 정하는 다음의 최소 요건을 추가로 만족하여야 한다.① 항공운항학과 학생은 아래의 최소 이수학점을 이수하여야 한다.&lt;개정 2012.03.01.&gt;&lt;개정 2015.03.01.&gt;&lt;개정, 신설 2018.03.01&gt;&lt;신설 2019.03.01.&gt;&lt;신설 2020.03.01.&gt;
# 적용학번 : 2012학번 이전
# 교과 구분 : 교양필수
# 최소이수학점 : 교양필수 13학점
# 세부 내용 : 항공우주학개론(3학점)
#
# 적용학번 : 2012학번 이전
# 교과 구분 : 전공이수학점
# 최소이수학점 : 57학점
# 세부 내용 : 기초필수과목(11학점) 포함
#
# 적용학번 : 2012학번 ~ 2017학번
# 교과 구분 : 교양영역
# 최소이수학점 : 교양필수 14학점, 영역별 교양이수 (핵심교양 6학점, 일반교양 3학점)
# 세부 내용 : -영어의 이해2 필수제외, 항공우주산업개론 신설, 항공우주학개론(2학점)변경, ○ 2013학년도부터 신입학 한 학생들은 전문교양학점의 필수 취득요건도 만족하여야 함
#
# 적용학번 : 2012학번 ~ 2017학번
# 교과 구분 : 전공이수학점
# 최소이수학점 : 57학점
# 세부 내용 : 기초필수과목(11학점) 포함
#
# 적용학번 : 2018학번
# 교과 구분 : 교양필수 (전공기초교양)
# 최소이수학점 : 교양필수 12학점, 교양필수(전공기초) 9학점, 영역별 교양이수 (핵심교양 9학점, 심화교양 3학점)
# 세부 내용 : 정보기술개론(2018학년도 교양과목 교과과정개편에 따라 해당과목의 본수강 및 재수강은 '컴퓨팅적사고와 문제해결(교양필수)' 과목으로 대체), 기초필수과목의 교양필수(전공기초)로 구분 변경
#
# 적용학번 : 2018학번
# 교과 구분 : 전공이수학점
# 최소이수학점 : 57학점
# 세부 내용 :
#
# 적용학번 : 2019학번 이후
# 교과 구분 : 교양영역
# 최소이수학점 : 교양필수 12학점, 교양필수(전공기초) 9학점, 영역별 교양이수 (핵심교양 9학점, 심화교양 3학점)
# 세부 내용 : ○ 2018학년도 이후 개정된 전문교양 학점의 필수 취득요건을 만족하여야 함
#
# 적용학번 : 2019학번 이후
# 교과 구분 : 전공이수(전공필수 및 전공선택)
# 최소이수학점 : 심화전공이수자(69학점), 다전공 이수자(45학점)
# 세부 내용 : 기본전공(45)+심화전공(24), 기본전공(45)+부전공(24)or복수전공(42)or융합(36)
#
# 적용학번 : 2020학번 이후
# 교과 구분 : 교양영역
# 최소이수학점 : 교양필수 및 영역별 교양이수 등 (39학점)
# 세부 내용 : ○ 2020학년도 이후 개정된 교양학점의 필수 취득요건(공통교양(9)*학문기초교양(11), 선택교양(12/영역9+자유이수3))을 만족하여야 함
#
# 적용학번 : 2020학번 이후
# 교과 구분 : 전공이수(전공필수 및 전공선택)
# 최소이수학점 : 심화전공이수자(69학점), 다전공 이수자(45학점)
# 세부 내용 : 기본전공(45)+심화전공(24), 기본전공(45)+부전공(24)or복수전공(42)or융합(36)
#
# ② (자격증 취득)항공운항학과 학생은 졸업을 위하여 반드시 자가용 조종사 면장(PPL : Private Pilot License)을 취득해야 한다.&lt;신설 2014.03.01.&gt;. 2015년 이후 입학생에게 적용(단, 본교가 인정한 국내외 지정전문교육기관 자가용 조종사과정 이수증도 인정 &lt;신설 2021.08.01&gt; 본 대학의 비행교육과정(위탁과정 포함) 이외에 해외 면장취득자는 취득 후 반드시 본 대학의 비행교육과정 1학기 이상 이수하여야 함) 다음의 요건에 한하여 예외로 적용한다가. MPC/CPC 교육과정 중 평가 탈락자.&lt;개정 2021.08.01&gt;나. &lt;삭제&gt;&lt;개정 2022.08.01&gt;다. 순수외국인 학생 &lt;신설 2020.08.01.&gt;라. 입학 후 항공종사자 신체검사 부적격 판정자(신체검사 관련 증빙자료 제출 필수)&lt;신설 2022.08.01.&gt;
#
# 제3조 (졸업 및 학위)
#
# 졸업 및 학위수여는 학칙 제28조(졸업 및 학위)에 의거하여 이수 요건을 만족한 학생에 대하여 학위와 이수한 전공을 표기한다.
#
# 제4조 (졸업인증)
#
# 대학의 졸업인증제는 학칙 시행세칙 제34조의 3(졸업인증제)에 의해 모든 졸업생에 대해 기본적으로 적용된다.
#
# 제 3 장 교과과정
#
# 제5조 (교과과정의 편성 및 심의)
# 교과과정 편셩은 학칙 제18조(교과편성)에 따른다.①교과과정 개편의 필요성이 있다고 판단될 경우에는 학부장이 교과과정 개편안을 학과 교수회의에 상정하여 의결한다.
#
# 제 4 장 교과목운영
#
# 제6조 (선택필수과목) 삭제&lt;2020.02.01.&gt;
#
# 제7조 (타 전공교과 공유 및 학점인증(Codeshare))
# 타 전공교과 공유 및 학점인증((Codeshare)이하 'Codeshare'로 칭함)는 학칙 시행세칙 제8조 (수강신청)에 따른다.&lt;신설 2019.02.01.&gt;
#
# ①
# 항공운항학과에서는 인정하는 Codeshare 과목을 본 학과 학생이 이수할 경우, 해당 과목은 전공이수학점으로 인정가능하다. 단, Codeshare 과목이 복수/부전공, 연계/융합전공 등에 포함될 경우, 복수/부전공, 연계/융합전공 이수학점과 본 학부 전공이수학점으로의 중복인정은 불가하다.? 항공운항학과에서 인정하는 Codeshare 과목은 다음과 같다.
# 주전공 학부(과) : 경영학부
# 학수코드 : BD4236
# 교과목명 : 응용통계분석
# 학점 : 3
# 학년 : 2
# 학기 : 1
# 이수구분 : 전선
#
# 주전공 학부(과) : 항공교통물류학부
# 학수코드 : AT4251
# 교과목명 : 통계분석응용
# 학점 : 3
# 학년 : 2
# 학기 : 2
# 이수구분 : 전선
#
# 주전공 학부(과) : 항공교통물류학부
# 학수코드 : ST4307
# 교과목명 : 항공기성능
# 학점 : 3
# 학년 : 2
# 학기 : 2
# 이수구분 : 전선
# 비고 : 항공기성능(FO4203)과 동일과목
# ? Codeshare 과목 중 항공교통물류학부의 항공기성능(ST4307) 과목은 본 학과의 항공기성능(FO4203) 과목과 동일 및 대체과목으로 지정하여, 본 학부 전공선택 과목으로 인정하되, 두 과목의 중복이수는 인정하지 않는다.
#
# 제8조 (전공필수과목 이수)&lt;신설 2020.02.01.&gt;
#
# ①
# 항공운항학과의 전공필수과목 이수는 항공운항학과 개설 과목 이수를 필요로 한다.(교과과정 운영을 위하여 해당학년/해당학기 과목의 이수를 기본으로 권고하나, 재학 중 이수 시기를 조정할 수 있다.)? 비행입과예정자 및 졸업대상자의 경우, 전공필수 미이수 과목에 대하여 타학과 개설의 동일 또한 대체과목에 한하여 이수가 가능하며, 수강 전 반드시 담당교수 승인을 득한 후, 이수하도록 한다.
#
# 제 5 장 장학금
#
# 제7조 (장학금의 지급)
# 장학금의 지급은 학칙 제61조(장학금의 지급)에 따르며, 다음 각 호의 조건을 모두 만족하는 자 중 성적순으로 지급한다.
#
# ①
# 직전학기 이수학점이 12학점 이상, 평점평균 2.75이상인 자
#
# 제8조 (장학 배정)
# 항공운항학과의 장학배정 기준은 다음 각 호와 같다.
#
# ①
# 장학배정은 별도의 여건이 발생하지 않는 한 성적 우수를 기본원칙으로 한다.
#
# ②
# 타 장학금과 이중수혜자는 전액장학에서 제외되며, 동점자의 경우 차순의 장학금에 배정한다.
#
# ③
# 시험 응시 중 부정행위자는 장학생 배정에서 제외한다.
#
# ④
# 상기 각 호 및 그 외 사항이 발생 시에는 학과 교수회의에서 논의 후 결정한다.
#
# 제9조 (동점자 처리규정)
# 제7조 제1항을 만족하는 자로서 두 명 이상의 성적이 동일한 경우 다음과 같이 우선순위를 정한다.
#
# ①
# 직전학기 이수학점이 많은 자 (ROTC학점은 이수학점에 포함하지 않는다)&lt;신설 2022.08.01.&gt;
#
# ②
# 전공이수학점이 많은 자
#
# ③
# 총 누적평점이 높은 자
#
# ④
# 총 이수학점이 많은 자
#
# 제 6장 재입학
#
# 제10조 (재입학)
# 재입학은 학칙 제11조(재입학)에 근거하여 다음 방식으로 심사하여 허가여부를 결정한다.&lt;개정 2009.02.01&gt;
#
# 제11조 (재입학 절차)
# 재입학절차는 다음의 각 호와 같다.
#
# ①
# 학과에서 재입학 신청자에 대한 서류심사 및 심층면접을 실시한다.
#
# ②
# 서류심사 및 심층면접에 따라 학과 재입학 심의위원회에서 재입학 허가 여부를 결정한다.
#
# 제12조 (재입학 심사)
# 재입학 심사는 재입학 심의위원회에서 서류심사 및 심층면접을 통하여 심사하며, 그 내용은 아래의 항과 같다.
#
# ①
# 재입학 심의위원회는 학과 교수 가운데 학과장 1인을 포함한 3인의 위원으로 학과장이 구성한다.
#
# ②
# 심층면접은 재입학 신청자의 수학능력여부, 잔여재학기간 내 졸업가능여부 등을 종합 심사하며, 면접방식 및 출제범위는 아래의 각 호와 같다.
#
# 1. 심층면접은 본 학과 전공기초학문분야에 대한 지식을 평가하기 위한 구두평가 방식으로 실시한다.
#
# 2. 구체적인 출제범위와 방법은 학과교수회의에서 결정하며, 별도의 공고가 없으면 직전학기에 준하여 시행한다.
#
# ③
# 재입학 허가 여부는 서류심사 및 심층면접 결과에 따라 학부 교수회의에서 결정한다.
#
# 제 7장 타 대학교 학점교류
#
# 제13조(타 대학교 학점교류)
# ① 타 대학교 학점교류는 학칙 시행세칙 제11조(학점인정)에 따르며, 국내 타 대학교 학점교류 중인 대상자는 각 호를 따른다. &lt;신설 2009.08.01.&gt;
#
# 1. 7학기 미만의 재학생으로, 지도교수 및 학과장의 사전승인을 득한 자로 한다.
#
# 2. 신청과목 및 학점은 본 대학에서 개설되지 않는 과목을 대상으로, 전공과목 이수에 지장을 초래하지 않는 범위에 한한다.
#
# ② 타 대학교 학점교류로 이수한 성적은 이수학점으로는 인정하되, 본 대학의 성적장학배정의 성적산출 및 전공이수학점에서는 제외한다.
#
# 제 8장 학부교수회의
#
# 제14조(구성과 소집)
# ① 본 학부의 교육과 운영에 관한 중요 사항을 심의하기 위하여 본 학부의 전임 교수전원으로 학부교수회의를 구성하며, 학부 전임교원은 연구년 및 사전 출장허가를 득한 경우를 제외하고는 학부교수회의에 참석해야 한다.
# ② 학부교수회의는 학부장 또는 학부 전임교원의 요청에 의해 필요하다고 인정되는 경우 학부장이 이를 소집하고, 그 의장이 된다.
#
# 제15조(심의사항)
# 학부교수회의는 다음 사항을 심의한다.
#
# 1. 교학에 관한 중요한 사항
#
# 2. 학부 관련 규정의 제정 및 개정에 관한 사항
#
# 3. 신임교원 초빙분야 결정 및 학부 추천에 대한 인준
#
# 4. 학부의 공간 활용 결정 및 변경
#
# 5. 교과과정 수립 및 개편
#
# 6. 특별 목적의 학부위원회 설치 및 운영
#
# 7. 기타 학부장이 필요하다고 인정하는 사항
#
# 제 9 장 전 과
#
# 제16조(전과)
# 전과는 학칙 제36조 및 시행세칙 제7장(전과)에 근거하여 다음 방식으로 심사하여 허가여부를 결정한다.
#
# ①
# 본 학과 전과신청자의 제출서류는 다음의 각 호와 같다.
#
# 1. 전과신청서(학교 소정의 양식)
#
# 2. 전과지원서(항공운항학과 소정의 양식)
#
# 3. 성적증명서(열람용)
#
# 4. 공인외국어성적
#
# 5. 전공과 관련한 자격증(자격소지자에 한하여 제출)
#
# ②
# 본 학과의 전과심사 및 허가 절차는 다음 각 호와 같다.
#
# 1. 전과 신청자의 심사절차는 서류심사, 신체검사, 구슬면접으로 실시한다.(신체검사는 본 대학에서 지정한 전문의료기간에 의뢰하여 실시함.)
#
# 2. 전과허가신청심의는 학과장을 포함한 2명 이상의 학과 교수로 구성된 전과심의위원회를 운영한다.
#
# ③
# 전과허가신청의 심사는 서류전형, 신체검사, 구슬면접으로 구분하되, 그 내용은 아래 각 호에 따른다.
#
# 1. 서류전형은 학부(과) 성적증명서와 공인외국어성적을 기준으로 하며, 학부(과) 성적 평점평균 3.50/4.50 이상, TOEIC 800점 이상(혹은 이에 상응하는 공인 외국어 성적)의 점수를 취득한 자를 대상으로 전과심의위원회에서 선발한다.
#
# 2. 신체검사는 본 대학에서 지정한 전문의료기관에 실시한 후, 취득한 항공종사자 제1종 신체검사증명서를 제출하는 것으로 하며, 동인 신체검사기관의 사전검사자의 경우, 유효기간내의 항공종사자 제1종 신체검사증명서를 제출할 수 있다.
#
# 3. 구슬면접은 신체검사 합격자에 한하여 학과장을 포함한 2인 이상의 학과교원이 실시한다.&lt;신설 2016.11.24.&gt;
#
# - 부 칙 -
#
# 1. (시행일) 본 내규는 2007년 7월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2009년 2월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2008년 8월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2015년 3월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2016년 12월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2018년 2월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2018년 3월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2019년 9월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2020년 2월 1일부터 시행한다.
#
# 1. (시행일) 본 내규는 2020년 8월 1일부터 시행한다.1. (시행일) 본 내규는 2021년 8월 1일부터 시행한다.
#
# %%%%%%%%%%%%%%%%%%%
# -------7-------
# 39
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교과과정</h3>', '</div>', '<ul class="menu_tab menu_tab4">', '<li><a class="selected" href="#panel_01">교과과정 개요</a></li>', '<li><a href="#panel_02">교과 과정표</a></li>', '<li><a href="#panel_03">교과목 Flow-Chart</a></li>', '', '<li><a href="http://kau.ac.kr/web/pages/gc1962b.do">진로별 교과과정 로드맵</a></li>', '</ul>', '<ul class="panel">', '<li id="panel_01">', '<div class="article_303">', '<h5><span style="font-size: 16pt;">학과교육 + 조종실기교육</span></h5>', '</div>', '<table class="table_01" style="min-width: 440px;">\n<colgroup>\n<col style="width: 30%;"/>\n<col style="width: 70%;"/>\n</colgroup>\n<tbody><tr>\n<th>구 분</th>\n<th>교 과 목</th>\n</tr>\n<tr>\n<td><span style="font-size: 14pt;">전공기초교양</span></td><td><div align="left" style="text-align: left;">●\xa0 \xa0 \xa0 선형대수학</div><div align="left" style="text-align: left;">●\xa0 \xa0 \xa0 일반물리Ⅰ+ 일반물리실험Ⅰ</div><div align="left" style="text-align: left;">●\xa0 \xa0 \xa0 미적분학</div></td>\n</tr>\n<tr>\n<td><span style="font-size: 14pt;">교양필수</span></td>\n<td><div align="left">●\xa0 \xa0 \xa0 교양글쓰기</div><div align="left">●\xa0 \xa0 \xa0 영어 커뮤니케이션\xa0Ⅰ,Ⅱ</div><div align="left">●\xa0 \xa0 \xa0 항공우주학 개론<br/><div align="left">●\xa0 \xa0 \xa0 컴퓨팅적 사고와 문제해결</div><div align="left">●\xa0 \xa0 \xa0 항공우주산업개론(2019년 입학자까지 필수)<br/>●\xa0\xa0\xa0\xa0\xa0 KAU SPACE 인성과 진로(2020년 이후 입학자 필수)<br/>●\xa0\xa0\xa0\xa0\xa0 인공지능 소개(2021년 이후\xa0입학자 필수)<br/></div></div></td>\n</tr>\n<tr>\n<td><span style="font-size: 14pt;">전공선택</span></td>\n<td><div align="left">●\xa0\xa0\xa0\xa0\xa0 항공기초역학<br/>●\xa0\xa0\xa0\xa0\xa0 국제항공법<br/>●\xa0\xa0\xa0\xa0\xa0 항공교육론<br/>●\xa0\xa0\xa0\xa0\xa0 항공교육론</div><div align="left">●\xa0 \xa0 \xa0 비행의 이해<br/>●\xa0\xa0\xa0\xa0\xa0 고성능항공기시스템<br/>●\xa0\xa0\xa0\xa0\xa0 항행안전시설<br/>●\xa0\xa0\xa0\xa0\xa0 모의비행실습(BATD)<br/>●\xa0\xa0\xa0\xa0\xa0 항공기성능<br/>●\xa0\xa0\xa0\xa0\xa0 항공교육론<br/></div><div align="left"><div align="left">●\xa0 \xa0 \xa0 항공영어 Ⅰ,Ⅱ<br/>●\xa0 \xa0 \xa0 CNS/ATM<br/>●\xa0\xa0\xa0\xa0\xa0 비행관리시스템(FMS)<br/>●\xa0\xa0\xa0\xa0\xa0 계기비행실습(FTD_Analog/Glass Cockpit)<br/>●\xa0\xa0\xa0\xa0\xa0 조종실기교육(교육과정별 운항실습 교과목)<br/><table border="0" cellpadding="0" cellspacing="0" style="width: 401px; height: 137px; border-collapse: collapse;" width="401"><colgroup><col style="width: 71pt; mso-width-source: userset; mso-width-alt: 3040;" width="95"/><col span="2" style="width: 117pt; mso-width-source: userset; mso-width-alt: 4992;" width="156"/></colgroup><tbody><tr height="27" style="height: 20.25pt; mso-height-source: userset;"><td height="54" rowspan="2" style="border-width: 0.5pt 0.5pt 2pt; border-style: solid solid double; border-color: windowtext windowtext black; width: 71pt; height: 40.5pt; background-color: transparent;" width="95"><p align="center" style="text-align: center; line-height: 1;"><strong><span style="font-family: 함초롬돋움; font-size: 11pt;">교육과정</span></strong></p></td><td colspan="2" style="border-width: 0.5pt 0.5pt 0.5pt 0px; border-style: solid solid solid none; border-color: windowtext windowtext windowtext black; width: 234pt; background-color: transparent;" width="312"><p align="center" style="line-height: 1;"><strong><span style="font-family: 함초롬돋움; font-size: 11pt;">이수학기</span></strong></p></td></tr><tr height="27" style="height: 20.25pt; mso-height-source: userset;"><td height="27" style="border-width: 0px 0.5pt 2pt 0px; border-style: none solid double none; border-color: black windowtext windowtext black; height: 20.25pt; background-color: transparent;"><p align="center" style="line-height: 1;"><span style="font-family: 함초롬돋움; font-size: 11pt;">4학년 1학기(1st)</span></p></td><td style="border-width: 0px 0.5pt 2pt 0px; border-style: none solid double none; border-color: black windowtext windowtext black; background-color: transparent;"><p align="center" style="line-height: 1;"><span style="font-family: 함초롬돋움; font-size: 11p ...
# $(document).ready(function() {
# });
#
# 교과과정
#
# 교과과정 개요
# 교과 과정표
# 교과목 Flow-Chart
#
# 진로별 교과과정 로드맵
#
# 학과교육 + 조종실기교육
#
# 구분 : 전공기초교양
# 교과목 : 선형대수학, 일반물리Ⅰ+ 일반물리실험Ⅰ, 미적분학
#
# 구분 : 교양필수
# 교과목 : 교양글쓰기, 영어 커뮤니케이션 Ⅰ,Ⅱ, 항공우주학 개론, 컴퓨팅적 사고와 문제해결, 항공우주산업개론(2019년 입학자까지 필수), KAU SPACE 인성과 진로(2020년 이후 입학자 필수), 인공지능 소개(2021년 이후 입학자 필수)
#
# 구분 : 전공선택
# 교과목 : 항공기초역학, 국제항공법, 항공교육론, 비행의 이해, 고성능항공기시스템, 항행안전시설, 모의비행실습(BATD), 항공기성능, 항공교육론, 항공영어 Ⅰ,Ⅱ, CNS/ATM, 비행관리시스템(FMS), 계기비행실습(FTD_Analog/Glass Cockpit), 조종실기교육(교육과정별 운항실습 교과목)
#
# 구분 : 전공선택
# 교과목 : 해외운항실습(PPL), 운항실습(UPP)Ⅰ, 운항실습(UPP)Ⅱ
#
# 전공필수
# ●      항공안전개론●      국내항공법●      항송 시스템 및 장비●      항공 추진장치●      항공기상학 Ⅰ,Ⅱ●      항공역학●      기초공중항법학●      계기비행론 Ⅰ,Ⅱ●      ATC Communications Ⅰ,Ⅱ●      항공운항정보 및 절차 Ⅰ,Ⅱ●      항공인적요인과 CRM  교 과 과 정 표
# 2022학년도                                                                                                                                                     항공+경영대학      항공운항학과
# 이수구분 : 교양필수
# 학수번호 : RC7102
# 교과목명 : 선형대수학
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : RC7160
# 교과목명 : 일반 물리 Ⅰ
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : RC7161
# 교과목명 : 일반 물리 실험 Ⅰ
# 학점 : 1
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : GS115
# 교과목명 : 영어커뮤니케이션 Ⅰ
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양선택
# 학수번호 : GS2663
# 교과목명 : 기초미적분학
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : GS1140
# 교과목명 : KAU SPACE 인성과 진로
# 학점 : 1
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : RC7103
# 교과목명 : 미분적분학
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : GS1138
# 교과목명 : 컴퓨팅적 사고와 문제해결
# 학점 : 2
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : GS1107
# 교과목명 : 항공우주학개론
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 : 양학기 개설
#
# 이수구분 : 교양필수
# 학수번호 : GS1141
# 교과목명 : 인공지능 소개
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 : O
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 : 양학기 개설
#
# 이수구분 : 교양필수
# 학수번호 : GS1134
# 교과목명 : 교양글쓰기
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 교양필수
# 학수번호 : GS1136
# 교과목명 : 영어커뮤니케이션 Ⅱ
# 학점 : 2
# 시수 : 총 2시수, 이론 2시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO4252
# 교과목명 : 항공안전개론
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3108
# 교과목명 : 국내항공법
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3206
# 교과목명 : 항공기상학Ⅰ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3216
# 교과목명 : 항공기시스템 및 장비
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3253
# 교과목명 : ATC Radio CommunicationⅠ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3211
# 교과목명 : 항공역학
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO4241
# 교과목명 : 항공기상학Ⅱ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : Pm
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3254
# 교과목명 : ATC Radio CommunicationⅡ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3109
# 교과목명 : 항공기추진장치
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3302
# 교과목명 : 항공운항정보 및 절차Ⅰ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3306
# 교과목명 : 계기비행론Ⅰ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3319
# 교과목명 : 기초공중항법학
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3317
# 교과목명 : 항공운항정보 및 절차Ⅱ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO4385
# 교과목명 : 계기비행론Ⅱ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공필수
# 학수번호 : FO3320
# 교과목명 : 항공인적요인과 C.R.M.
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4123
# 교과목명 : 항공기초역학
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4103
# 교과목명 : 국제항공법
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4247
# 교과목명 : 비행의 이해
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : Pm
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4388
# 교과목명 : 항공영어Ⅰ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4503
# 교과목명 : 모의비행실습(BATD)
# 학점 : 1
# 시수 : 총 2시수, 이론 2시수
# 1학년 :
# 2학년 : O
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : BD4236
# 교과목명 : 응용통계분석
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : 경영 코드쉐어
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4118
# 교과목명 : 항공교육론
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4389
# 교과목명 : 항공영어Ⅱ
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4253
# 교과목명 : 고성능 항공기 시스템
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 : 2021-2 신규
#
# 이수구분 : 전공선택
# 학수번호 : FO4309
# 교과목명 : 항행안전시설
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : AT4251
# 교과목명 : 통계분석응용
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : 교통 코드쉐어
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : ST4307
# 교과목명 : 항공기성능
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : 교통 코드쉐어
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : SW4208
# 교과목명 : AI 입문
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : 융합 코드쉐어
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4106
# 교과목명 : 항공운항업무론
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4203
# 교과목명 : 항공기성능
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4383
# 교과목명 : 항공기사고조사개론
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4414
# 교과목명 : 비행관리시스템(FMS)
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4708
# 교과목명 : 계기비행실습(RTD)
# 학점 : 3
# 시수 : 총 4시수, 이론 4시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) : FL
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4757
# 교과목명 : 계기비행실습(FTD_Glass Cockpit)
# 학점 : 3
# 시수 : 총 4시수, 이론 4시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 2021-2 신규
#
# 이수구분 : 전공선택
# 학수번호 : FO3352
# 교과목명 : CNS/ATM
# 학점 : 3
# 시수 : 총 3시수, 이론 3시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4809
# 교과목명 : 운항실습(MPC)Ⅰ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4815
# 교과목명 : 운항실습(CPC_J) Ⅰ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4811
# 교과목명 : 운항실습(CPC_U) Ⅰ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4813
# 교과목명 : 운항실습(APP) Ⅰ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4810
# 교과목명 : 운항실습(MPC) Ⅱ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4816
# 교과목명 : 운항실습(CPC_J) Ⅱ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 :
#
# 이수구분 : 전공선택
# 학수번호 : FO4812
# 교과목명 : 운항실습(CPC_U) Ⅱ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4814
# 교과목명 : 운항실습(APP) Ⅱ
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4500
# 교과목명 : 해외운항실습(PPL)
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 : O
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# 이수구분 : 전공선택
# 학수번호 : FO4501
# 교과목명 : 해외운항실습(KPP)
# 학점 : 12
# 시수 : 총 24시수, 이론 24시수
# 1학년 :
# 2학년 : O
# 3학년 : O
# 4학년 :
# 강좌유형(FL/PT/Pm으료 표시) :
# 비고 : 양학기 개설
#
# %%%%%%%%%%%%%%%%%%%
# -------8-------
# 131
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교과목 안내</h3> </div>', '<div class="terms">', '<div class="chpt">', '<div class="sctn">', '<div class="article_303">', '<h5><span style="font-size: 16pt;">국내항공법</span></h5>', '<p>국내항공법규정 및 령을 연구, 교육함으로써 항공종사자의 법률 실무능력을 배양하고, 특히 항공기 안전과 효율적 운영을 도모하며, 체약 당사국의 주요 항공법을 강의한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공안전개론</span></h5>', '<p>항공안전에 대한 전반적인 개념을 이해하고 항공사고에 영향을 미치는 다양한 원인과 위험요소들을 예측하고 이해하며, 이를 관리하기 위해 개발된 다양한 시스템의 원리를 알고 적용할 수 있는 능력을 배양한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공기상학\xa0Ⅰ,Ⅱ</span></h5>', '<p>항공기의 활동영역인 대기 속의 제현상을 이해하고, 활용할 수 있도록 대기운동의 원리와 항공기운항과 관련성을 연구, 강의한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공기 시스템 및 장비</span></h5>', '<p>안전하고도 효율적인 항공기 운항을 위하여 항공기 시스템의 이해와 항공기 운항방법(정상비행절차, 비상처치절차, 성능계산, 중량배분 등)과 응용방법에 관한 내용을 강의한다. 항공기에 장착되어 있는 비행계기, 직독식계기, 자이로계기, 엔진계기, 항법계기, 압력계기, 온도계기, 유량/액량계기, 경고장치, 오토파일럿, 자동비행조종장치, EFIS, FMS 등 항공기 운용에 필요한 항공장비의 원리와 기능을 학습한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">ATC Radio Communications \xa0Ⅰ</span></h5>', '<p>조종사 관제사 간의 ATC Radio Communication(항공교통무선통신)을 위한 전문용어(Phraseology)의 이해와 항공무선통신절차를 교육한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공역학</span></h5>', '<p>공기의 흐름(공기의 성질, 양력, 항력, 저속비행, 고속비행), 비행성능(수평비행, 글라이딩 및 착륙 비행, 이륙 및 상승 비행, 선회기동), 정적/동적 안정성 및 조종성 등 비행기 조종에 필수적인 공기역학과 비행역학의 기본 지식을 심도 있게 학습한다.</p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">ATC Radio Communications \xa0Ⅱ</span></h5>', '<p>TC Radio Communications(I)에서 배운 항공무선통신 전문용어를 활용하여 비행환경(공역) 별 조종사/ATC 간의 항공무선통신 내용 및 기법을 강의함 * VFR 환경에 대한 교육 후 IFR과 관련된 무선통신내용을 소개함 조종사와 관제사 간에 사용되는 항공무선통신 용어의 이해, 비행방식과 운항환경 별 구사되는 패턴을 심화학습하여 ATC 무선통화 능력을 향상시킨다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공기 추진장치</span></h5>', '<p>항공기 추진장치에 대한 열역학 및 기초이론, 왕복엔진의 구조 및 성능, 연료, 점화시동 및 냉각 등 왕복기관뿐만 아니라 압축기, 연소기, 터빈, 노즐 등 제트엔진 관련 지식을 파악할 수 있도록 강의한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공운항정보 및 절차\xa0Ⅰ,Ⅱ</span></h5>', '<p>항공운항에 필수적인 비행정보의 수집 및 사용 방법과 이러한 항공정보를 이용하여ATC 절차를 포함한 모든 가용할 수 있는 안전한 비행절차 및 운항방법(VFR, IFR, 비상절차, 특수비행 등)을 교육한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">기초공중항법학</span></h5>', '<p>지문, 추측, 무선, 최신항법 등에 관한 기초이론을 강의하고 지문 및 추축 항법을 위한 항법계획을 실습한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">계기비행론\xa0Ⅰ</span></h5>', '<p>계기비행과 관련되는 인체의 항공생리 항공등화시설, 항공전자장비, 자세계기비행 및 계기항법에 대한 기본지식과 응용에 관하여 강의한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">계기비행론\xa0Ⅱ</span></h5>', '<p>계기비행과 관련되는 각종 항공전자장비 및 비행정보 간행물의 이용과 항법장비를 활용하는 계기비행의 이론과 ATC 절차에 관하여 교육한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공인적요인과 C.R.M.</span></h5>', '<p>다양한 비행환경에서 근무하는 승무원의 인적 한계를 이해하고 항공기 운항에 영향을 미치는 인적 요소를 분석하고, 이에 대한 개념을 정리하여 실제운항 시 이를 바탕으로 안전운항에 적용할 수 있는 능력을 부여하기 위한 내용을 강의한다. 승무원 자원관리를 통해 항공안전을 확보하는데 필요한 의사소통기술과 리더십, Teamwork, 상황판단 및 의사결정기술 등을 이해하고 이에 대한 최신개념의 TEM 모델을 활용한 교육 및 실습을 통하여 운항승무원이로서 가져야할 기본 CRM 기술을 습득하도록 강의한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">항공기초역학</span></h5>', '<p>항공기에 작용하는 힘을 이해하기 위해 필요한 힘과 모멘트의 기본 원리, 힘의 평형 등에 관한 기초 이론을 학습한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">국제항공법</span></h5>', '<p>국제 민간항공의 발전에 대처하기 위한 국제항공법의 이론과 실무 능력을 함양케 하고 항공종사자로서의 필수적인 항공법 실무 능력과 항공사업 관련 제법규를 강의한다. 여기에 미연방 항공법에 대한 이해를 통하여 미국에서의 항공종사자 자격관리와 항공기 운항절차에 관한 지식을 습득한다.<br/></p></div>', '<div class="article_303">', '<h5><span style="font-size: 16pt;">통계학개론</span></h5>', '<p>기술통계와 추측통계의 기초개념과 방법에 대하여 강의한다. 즉, 집단의 분포, 특성치, 이론분포, 추측과 검정, 상관분석, 지수, 시계열분 ...
#
# $(document).ready(function() {
# });
#
# 교과목 안내
#
# 국내항공법
# 국내항공법규정 및 령을 연구, 교육함으로써 항공종사자의 법률 실무능력을 배양하고, 특히 항공기 안전과 효율적 운영을 도모하며, 체약 당사국의 주요 항공법을 강의한다.
#
# 항공안전개론
# 항공안전에 대한 전반적인 개념을 이해하고 항공사고에 영향을 미치는 다양한 원인과 위험요소들을 예측하고 이해하며, 이를 관리하기 위해 개발된 다양한 시스템의 원리를 알고 적용할 수 있는 능력을 배양한다.
#
# 항공기상학 Ⅰ,Ⅱ
# 항공기의 활동영역인 대기 속의 제현상을 이해하고, 활용할 수 있도록 대기운동의 원리와 항공기운항과 관련성을 연구, 강의한다.
#
# 항공기 시스템 및 장비
# 안전하고도 효율적인 항공기 운항을 위하여 항공기 시스템의 이해와 항공기 운항방법(정상비행절차, 비상처치절차, 성능계산, 중량배분 등)과 응용방법에 관한 내용을 강의한다. 항공기에 장착되어 있는 비행계기, 직독식계기, 자이로계기, 엔진계기, 항법계기, 압력계기, 온도계기, 유량/액량계기, 경고장치, 오토파일럿, 자동비행조종장치, EFIS, FMS 등 항공기 운용에 필요한 항공장비의 원리와 기능을 학습한다.
#
# ATC Radio Communications  Ⅰ
# 조종사 관제사 간의 ATC Radio Communication(항공교통무선통신)을 위한 전문용어(Phraseology)의 이해와 항공무선통신절차를 교육한다.
#
# 항공역학
# 공기의 흐름(공기의 성질, 양력, 항력, 저속비행, 고속비행), 비행성능(수평비행, 글라이딩 및 착륙 비행, 이륙 및 상승 비행, 선회기동), 정적/동적 안정성 및 조종성 등 비행기 조종에 필수적인 공기역학과 비행역학의 기본 지식을 심도 있게 학습한다.
#
# ATC Radio Communications  Ⅱ
# TC Radio Communications(I)에서 배운 항공무선통신 전문용어를 활용하여 비행환경(공역) 별 조종사/ATC 간의 항공무선통신 내용 및 기법을 강의함 * VFR 환경에 대한 교육 후 IFR과 관련된 무선통신내용을 소개함 조종사와 관제사 간에 사용되는 항공무선통신 용어의 이해, 비행방식과 운항환경 별 구사되는 패턴을 심화학습하여 ATC 무선통화 능력을 향상시킨다.
#
# 항공기 추진장치
# 항공기 추진장치에 대한 열역학 및 기초이론, 왕복엔진의 구조 및 성능, 연료, 점화시동 및 냉각 등 왕복기관뿐만 아니라 압축기, 연소기, 터빈, 노즐 등 제트엔진 관련 지식을 파악할 수 있도록 강의한다.
#
# 항공운항정보 및 절차 Ⅰ,Ⅱ
# 항공운항에 필수적인 비행정보의 수집 및 사용 방법과 이러한 항공정보를 이용하여ATC 절차를 포함한 모든 가용할 수 있는 안전한 비행절차 및 운항방법(VFR, IFR, 비상절차, 특수비행 등)을 교육한다.
#
# 기초공중항법학
# 지문, 추측, 무선, 최신항법 등에 관한 기초이론을 강의하고 지문 및 추축 항법을 위한 항법계획을 실습한다.
#
# 계기비행론 Ⅰ
# 계기비행과 관련되는 인체의 항공생리 항공등화시설, 항공전자장비, 자세계기비행 및 계기항법에 대한 기본지식과 응용에 관하여 강의한다.
#
# 계기비행론 Ⅱ
# 계기비행과 관련되는 각종 항공전자장비 및 비행정보 간행물의 이용과 항법장비를 활용하는 계기비행의 이론과 ATC 절차에 관하여 교육한다.
#
# 항공인적요인과 C.R.M.
# 다양한 비행환경에서 근무하는 승무원의 인적 한계를 이해하고 항공기 운항에 영향을 미치는 인적 요소를 분석하고, 이에 대한 개념을 정리하여 실제운항 시 이를 바탕으로 안전운항에 적용할 수 있는 능력을 부여하기 위한 내용을 강의한다. 승무원 자원관리를 통해 항공안전을 확보하는데 필요한 의사소통기술과 리더십, Teamwork, 상황판단 및 의사결정기술 등을 이해하고 이에 대한 최신개념의 TEM 모델을 활용한 교육 및 실습을 통하여 운항승무원이로서 가져야할 기본 CRM 기술을 습득하도록 강의한다.
#
# 항공기초역학
# 항공기에 작용하는 힘을 이해하기 위해 필요한 힘과 모멘트의 기본 원리, 힘의 평형 등에 관한 기초 이론을 학습한다.
#
# 국제항공법
# 국제 민간항공의 발전에 대처하기 위한 국제항공법의 이론과 실무 능력을 함양케 하고 항공종사자로서의 필수적인 항공법 실무 능력과 항공사업 관련 제법규를 강의한다. 여기에 미연방 항공법에 대한 이해를 통하여 미국에서의 항공종사자 자격관리와 항공기 운항절차에 관한 지식을 습득한다.
#
# 통계학개론
# 기술통계와 추측통계의 기초개념과 방법에 대하여 강의한다. 즉, 집단의 분포, 특성치, 이론분포, 추측과 검정, 상관분석, 지수, 시계열분석을 대상으로 한다.
#
# 항공기성능
# 항공기 엔진에 대한 열역학적 기초이론과 엔진의 각 구성품을 사이클 해석 및 성능 등을 강의한다.
#
# 비행의 이해
# 본 강의는 비행기의 탄생 및 진화과정, 비행기에 숨어있는 과학, 항공기 사고율 및 비행시간, 비행과 관련된 제 물리현상과 이를 지배하는 기본 법칙, 항공기술 및 우주비행, 미국의 NASA 등 항공기에 관련된 지식을 교육한다.
#
# 항공교육론
# 비행교육과 관련된 기초 지식과 항공교육심리의 이론을 학습하며, 교과일람 및 교안작성 등 비행교원의 교수활동을 실습한다.
#
# 항공영어 Ⅰ,Ⅱ
# 항공종사자가 운항환경 별 사용하게 되는 특수 항공영어의 이해 및 구사능력을 배양토록 교육한다.
#
# 한행안전시설
# 현재 사용되고 있는 항행 안전시설들의 설치기준, 작동원리 그리고 항행시의 공중항법에 사용되는 이용 방법 등에 관하여 강의한다.
#
# 모의비행실습(BATD)
# 비행실습장비(BATD)를 이용, 기초 계기항법에 대한 교육훈련과, 다양한 계기접근훈련 및 비상상황하에서의 조치절차를 교육훈련시킨다.
#
# 항공전자시스템
# 항공기에 탑재되는 첨단 전자장비와 기술을 조종사가 이해하고 운영할 수 있도록 각 전자시스템의 개념과 원리를 알아본다. 특히 항공기의 자동화 특성을 이해하기 위해 소형기 및 대형기의 오토파일럿, 독립항법장치, CNS/ATM기반의 성능기반 항법, 항공기 충돌 감시 방법들에 주안점을 두어 학습한다.
#
# 항공기사고조사개론
# 항공기 사고조사와 관련한 항공기 시스템, 인적요소 및 비행기록 등에 대한 조사 절차와 기술을 강의하고, 최종 보고서 작성능력을 부여한다.
#
# 비행관리시스템(FMS)
# 최첨단 항공기의 기본 장비인 비행관리 시스템의 기본개념 및 운영 철학을 이해하고 각 비행단계별 비행특성 및 성능에 따라 효율적으로 비행할 수 있는 지식 및 기술을 습득하여 장차 민항조종사서 최첨단 항공기로전환에 도움이 되도록 강의한다.
#
# 안전관리시스템(SMS)
# ICAO에서 권장하는 항공안전관리를 위한 국가조직의 SSP 및 그에 상응하는 이익집단 특히 항공사의 SMS 안전관리시스템에 관한 내용을 교육하며 안전도 향상을 위한 각종절차 및 안전 위험 요소에 대한 수집과 관리, 이에 대한 대응방안 등에 대하여 교육하고 연구함으로써 항공안전관리자로서 필요한 자질을 향상시킨다
#
# 항공운항업무론
# 운항관리업무의 개요, 항공기 시스템 및 항공기 이착륙 성능, 비행계획서, 항공기 중량 및 무게중심관리, 운항 중인 항공기 모니터링, 비상항공기에 대한 지원업무 등의 이해를 통하여 장차 항공사 조종사로서 종합통제와 관련된 지식을 함양하기 위함.
#
# 계기비행실습(FTD)
# 모의 비행훈련 장치를 이용, 자세계기비행, 기초 계기항법에 대한 교육훈련과, 다양한 계기접근훈련 및 비상상황하에서의 조치절차를 교육훈련시킨다.
#
# 해외운항실습
# 해외에서 자가용 조종사과정(공중조작, 이착륙, 항법 및 비상절차 등)에 대한 이론과 실습을 통하여 자가용 조종사 과정을 이수시킨다.
#
# 운항실습(MPC) Ⅰ
# 정석 MPC과정 : 자가용 조종사과정(공중조작, 이착륙, 항법 및 비상절차 등)에 대한 이론과 실습을 통하여 자가용 조종사 과정을 이수시킨다.
#
# 운항실습(MPC) Ⅱ
# 정석 MPC 과정 : 계기비행증명 과정(자세계기비행, 항법, 출발 및 도착, 접근, 체공대기 및 비상절차 등)을 교육한다.
#
# 운항실습(CPC_J) Ⅰ
# 정석 CPC 과정 : 자가용 조종사과정(공중조작, 이착륙, 항법 및 비상절차 등)에 대한 이론과 실습을 통하여 자가용 조종사 과정을 이수시킨다.
#
# 운항실습(CPC_J) Ⅱ
# 정석 CPC 과정 : 계기비행증명 과정(자세계기비행, 항법, 출발 및 도착, 접근, 체공대기 및 비상절차 등)을 교육한다.
#
# 운항실습(CPC_U) Ⅰ
# 울진 CPC 과정 : 자가용 조종사과정(공중조작, 이착륙, 항법 및 비상절차 등)에 대한 이론과 실습을 통하여 자가용 조종사 과정을 이수시킨다.
# * 경력자 입과학생은 별도의 교육과정에 의한다
#
# 운항실습(CPC_U) Ⅱ
# 울진 CPC 과정 : 계기비행증명 과정(자세계기비행, 항법, 출발 및 도착, 접근, 체공대기 및 비상절차 등)을 교육한다.
# * 경력자 입과학생은 별도의 교육과정에 의한다
#
# 운항실습(APP) Ⅰ,Ⅱ
# APP 과정 : 해외에서 자가용조종사 과정(공중조작, 이착륙, 항법, 비상절차 등), 계기비행증명과 사업용 조종사 과정을 이수시키고 항공운송산업의 기간요원의 자질을 부여한다.
#
# 해외운항실습(KPP)
# 해외에서 자가용조종사 과정(공중조작, 이착륙, 항법, 비상절차 등), 계기비행증명과 사업용 조종사 과정을 이수시키고 항공운송산업의 기간요원의 자질을 부여한다.
#
# %%%%%%%%%%%%%%%%%%%
# -------9-------
# 38
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>졸업요건<br/><p class="0"><span style="font-family: 함초롬바탕; font-size: 12pt;"><br/></span></p><p class="0"><span style="font-family: 함초롬바탕; letter-spacing: 0pt; font-size: 12pt; color: rgb(58, 50, 195);">▪</span><span style="font-size: 12pt; font-family: 함초롬바탕; color: rgb(58, 50, 195);">공통 졸업요건</span></p><p class="0"><span style="font-family: 함초롬바탕; letter-spacing: 0pt; font-size: 11pt;">• </span><span style="font-family: 함초롬바탕; font-size: 11pt;">총 이수학점 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">: 130</span><span style="font-family: 함초롬바탕; font-size: 11pt;">학점 이상</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">(2012</span><span style="font-family: 함초롬바탕; font-size: 11pt;">학번까지 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">: 140</span><span style="font-family: 함초롬바탕; font-size: 11pt;">학점 이상</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">)</span></p><p class="0"><span style="font-family: 함초롬바탕; letter-spacing: 0pt; font-size: 11pt;">• </span><span style="font-family: 함초롬바탕; font-size: 11pt;">전 학년 성적 평점평균 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">2.00 </span><span style="font-family: 함초롬바탕; font-size: 11pt;">이상</span></p><p class="0"><span style="font-family: 함초롬바탕; letter-spacing: 0pt; font-size: 11pt;">※</span><span style="font-family: 함초롬바탕; font-size: 11pt;">단</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">, </span><span style="font-family: 함초롬바탕; font-size: 11pt;">조기졸업은 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">4.00 </span><span style="font-family: 함초롬바탕; font-size: 11pt;">이상 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">/ </span><span style="font-family: 함초롬바탕; font-size: 11pt;">학석사연계과정생은 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt;">3.50</span><span style="font-family: 함초롬바탕; font-size: 11pt;">이상<br/></span><span style="font-family: 함초롬바탕; letter-spacing: 0pt; font-size: 11pt;">• </span><span style="font-family: 함초롬바탕; font-size: 11pt;">졸업인증 통과\xa0</span><span style="font-family: 함초롬바탕; font-size: 11pt;"><br/></span></p><p class="0"><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">\xa0 \xa0- 2017</span><span style="font-size: 11pt; font-family: 함초롬바탕;">학년도 이전 신입생</span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">: </span><span style="font-size: 11pt; font-family: 함초롬바탕;">영어인증<br/></span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">\xa0 \xa0- 2018</span><span style="font-size: 11pt; font-family: 함초롬바탕;">학년도 이후 신입생 </span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">: SPACE </span><span style="font-size: 11pt; font-family: 함초롬바탕;">인증 중 </span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">2</span><span style="font-size: 11pt; font-family: 함초롬바탕;">개 이상 인증 취득</span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">(“S(</span><span style="font-size: 11pt; font-family: 함초롬바탕;">글로벌소통역량인증</span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">)”</span><span style="font-size: 11pt; font-family: 함초롬바탕;">분야는 필수 인증 취득</span><span lang="EN-US" style="font-size: 11pt; letter-spacing: 0pt;">)</span><span style="font-size: 12px;">(☞</span><em style="font-size: 12px;"><span style="color: rgb(0, 117, 200);"><a href="https://www.kau.ac.kr/web/pages/gc40674h.do"><u><span style="color: blue;">졸업인증</span></u></a></span></em><span style="font-size: 12px;">\xa0\xa0참조)<br/></span><a href="https://www.kau.ac.kr/web/pages/gc40674h.do" style="font-size: 12px;"><u>※ 2014학년도 이전 학사편입학생, 2014학년도 1학기 이전 순수외국인전형 입학생, 북한귀순동포, 계약학과 입학생, 학군제휴 군위탁생은 제외.</u></a></p></h3></div><div class="article_303"><a href="https://www.kau.ac.kr/web ...
# $(document).ready(function() {
# });
#
# 졸업요건▪공통 졸업요건• 총 이수학점 : 130학점 이상(2012학번까지 : 140학점 이상)• 전 학년 성적 평점평균 2.00 이상※단, 조기졸업은 4.00 이상 / 학석사연계과정생은 3.50이상• 졸업인증 통과    - 2017학년도 이전 신입생: 영어인증   - 2018학년도 이후 신입생 : SPACE 인증 중 2개 이상 인증 취득(“S(글로벌소통역량인증)”분야는 필수 인증 취득)(☞졸업인증  참조)※ 2014학년도 이전 학사편입학생, 2014학년도 1학기 이전 순수외국인전형 입학생, 북한귀순동포, 계약학과 입학생, 학군제휴 군위탁생은 제외.
#
# }-->◎ 2018학번
# 교과분류 : 교양영역
# 최소이수학점 : 33학점
# 비고 : 2018학년도부터 신입학 한 학생들은 2018학년도 이후 개정된 전문교양학점의 필수 취득요건을 만족하여야 함
# - 필수교양 : 12학점
# - 전공기초교양 : 9학점
# - 핵심교양 : 9학점 / 5개 영역(철학과 역사, 문학과 예술, 인간과 사회, 자연과 과학, 실용 및 글로벌)
# - 심화교양 : 3학점(핵심교양 이수영역과 중복 불가)
#
# 전공 이수학점 : 57학점
# 전공필수(45학점)를 포함하여 전공과목 57학점 필수 이수
# <!--[data-hwpjson]{
# }-->◎ 2019학번
# 교과분류 : 교양영역
# 최소이수학점 : 33학점
# 비고 : 2018학년도부터 신입학 한 학생들은 2018학년도 이후 개정된 전문교양학점의 필수 취득요건을 만족하여야 함
# - 필수교양 : 12학점
# - 전공기초교양 : 9학점
# - 핵심교양 : 9학점 / 5개 영역(철학과 역사, 문학과 예술, 인간과 사회, 자연과 과학, 실용 및 글로벌)
# - 심화교양 : 3학점(핵심교양 이수영역과 중복 불가)
#
# 전공(전공필수 및 전공선택)
# - 심화전공 이수자 : 69학점
# - 기본전공(45학점) + 심화전공(24학점)
#
# 다전공 이수자 : 45학점
# - 기본전공(45학점) + 다전공(24학점) : 복수/부/융합전공 이수자
# <!--[data-hwpjson]{
# }-->◎ 2020학번
# 교과분류 : 교양영역
# 최소이수학점 : 39학점
# 비고 : 2020학년도 이후 개정된 교양학점의 필수 취득요건을 만족하여야 함 (영역별 이수 및 교양 총이수학점 모두 충족)
# - 공통교양 : 7학점
# - 학문기초교양 : 13학점
# - 선택교양 : 12학점 (철학과 역사(1)/문학과 예술(2)/인간과 사회(3)/자연과 과학(4)/세계와 문화(5) 영역 중 최소 3개 영역(9학점) 이수 & (1)~(5) 영역 중 이수 중복되지 않는 영역 및 소양, 자기계발영역에서 3학점 이상 이수)
# - 추가이수 교양학점 : 7학점
#
# 전공(전공필수 및 전공선택)
# 심화전공 이수자 : 69학점
# 기본전공(45학점) + 심화전공(24학점)
#
# 다전공 이수자 : 45학점
# 기본전공(45학점) + 다전공(24학점) : 복수/부/융합전공 이수자
# <!--[data-hwpjson]{
# }-->◎ 2021학번
# 교과분류 : 교양영역
# 최소이수학점 : 39학점
# 비고 : 2020학년도 이후 개정된 교양학점의 필수 취득요건을 만족하여야 함 (영역별 이수 및 교양 총이수학점 모두 충족)
# - 공통교양 : 9학점
# - 학문기초교양 : 13학점
# - 선택교양 : 12학점 (철학과 역사(1)/문학과 예술(2)/인간과 사회(3)/자연과 과학(4)/세계와 문화(5) 영역 중 최소 3개 영역(9학점) 이수 & (1)~(5) 영역 중 이수 중복되지 않는 영역 및 소양, 자기계발영역에서 3학점 이상 이수)
# - 추가이수 교양학점 : 5학점
#
# 교과분류 : 전공(전공필수 및 전공선택)
# 심화전공 이수자 : 69학점
# 기본전공(45학점) + 심화전공(24학점)
#
# 다전공 이수자 : 45학점
# 기본전공(45학점) + 다전공(24학점) : 복수/부/융합전공 이수자
# <!--[data-hwpjson]{
# }-->◎ 2022학번
# 교과분류 : 교양영역
# 최소이수학점 : 39학점
# 비고 : 2022학년도 이후 개정된 교양학점의 필수 취득요건을 만족하여야 함 (영역별 이수 및 교양 총이수학점 모두 충족)
# - 공통교양 : 7학점
# - 학문기초교양 : 13학점
# - 선택교양 : 12학점 (철학과 역사(1)/문학과 예술(2)/인간과 사회(3)/자연과 과학(4)/세계와 문화(5) 영역 중 최소 3개 영역(9학점) 이수 & (1)~(5) 영역 중 이수 중복되지 않는 영역 및 소양, 자기계발영역에서 3학점 이상 이수)
# - 추가이수 교양학점 : 7학점
#
# 교과분류 : 전공
# 심화전공 이수자 : 69학점
# 기본전공(45학점) + 심화전공(24학점)
#
# 교과분류 : 다전공
# 다전공 이수자 : 45학점
# 기본전공(45학점) + 다전공(24학점) : 복수/부/융합전공 이수자
# <!--[data-hwpjson]{
# }-->◎ 2023학번
# 교과분류 : 교양영역
# 최소이수학점 : 39학점
# 비고 : 2023학년도 이후 개정된 교양학점의 필수 취득요건을 만족하여야 함 (영역별 이수 및 교양 총이수학점 모두 충족)
# - 공통교양 : 11학점
# - 학문기초교양 : 15학점
# - 선택교양 : 12학점 (철학과 역사(1)/문학과 예술(2)/인간과 사회(3)/자연과 과학(4)/세계와 문화(5) 영역 중 최소 3개 영역(9학점) 이수 & (1)~(5) 영역 중 이수 중복되지 않는 영역 및 소양, 자기계발영역에서 3학점 이상 이수)
# - 추가이수 교양학점 : 1학점
#
# 전공(전공필수 및 전공선택)
# 심화전공 이수자 : 69학점
# 기본전공(45학점) + 심화전공(24학점)
#
# 다전공 이수자 : 45학점
# 기본전공(45학점) + 다전공(24학점) : 복수/부/융합전공 이수자
# ▪편입학 졸업요건   • 총 이수학점 : 130학점 이상(2012학번까지 : 140학점 이상 / 전적대학 인정학점 포함)• 전공이수학점 : 57학점 이상 이수• 전공필수 및 지정 선수과목 모두 이수 ※ 지정 선수과목은 편입학번에 따라 상이할 수 있으므로, 반드시 본인 학번의 지정 선수과목을 이수할 것• 평점 평균 : 전 학년 성적 평점평균 2.00 이상• 졸업인증 통과 - 2017학년도 이전 편입생 : 영어인증 - 2018학년도 이후 편입생 : SPACE 인증 중 2개 이상 인증 취득(“S(글로벌소통역량인증)”분야는 필수 인증 취득)   <!--[data-hwpjson]{
#
# 학부(과) : 항공운항학과
# 대상학년도 : 2001학년도~2010학년도 신입생
# TOEIC : 600
# TOEIC SPEAKING : Level 5 이상 (120점)
# TOEFL PBT : 500
# TOEFL IBT : 61
# TEPS : 480
# OPIc : IL 이상
#
# 학부(과) : 항공운항학과
# 대상학년도 : 2011학년도 이후 신입생
# TOEIC : 800
# TOEIC SPEAKING : Level 6 이상 (140점)
# TOEFL PBT : 570
# TOEFL IBT : 88
# TEPS : 700
# OPIc : IM(Mid3)이상
#
# 학부(과) : 항공운항학과
# 대상학년도 : 외국인학생
# TOPIK : 4급 이상
#
# 학부(과) : 항공운항학과
# 대상학년도 : 2014학년도 2학기이후 신(편)입생
# TOPIK : 4급 이상
#
# 본교에서 주관하는 모의 TOEIC포함
# 유효한 성적만 인정함.
# 외국인학생이란 : 외국인학생 특별전형으로 입학한 학생(모집정원에 제한이 없는 전형)

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
