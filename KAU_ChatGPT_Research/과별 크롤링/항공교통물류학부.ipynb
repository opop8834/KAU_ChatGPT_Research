# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "항공교통물류학부_data"
number_html = 6
url = """http://college.kau.ac.kr/web/pages/gc53017h.do
http://college.kau.ac.kr/web/pages/gc12999h.do
http://college.kau.ac.kr/web/pages/gc96336h.do
http://college.kau.ac.kr/web/pages/gc82284h.do
http://college.kau.ac.kr/web/pages/gc44982h.do
http://college.kau.ac.kr/web/pages/gc40336h.do
http://college.kau.ac.kr/web/pages/gc3153h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 6:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc53017h.do', 'http://college.kau.ac.kr/web/pages/gc12999h.do', 'http://college.kau.ac.kr/web/pages/gc96336h.do', 'http://college.kau.ac.kr/web/pages/gc82284h.do', 'http://college.kau.ac.kr/web/pages/gc44982h.do', 'http://college.kau.ac.kr/web/pages/gc40336h.do', 'http://college.kau.ac.kr/web/pages/gc3153h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 53
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>항공교통물류학부 소개</h3>', '</div>', '<div class="article_101">', '<span class="img_fl" style="margin-right: 1.5rem;">', '<img src="/cmm_typeA/images/sample/sub_101_01.jpg"/>', '</span>', '<h4 style="color: rgb(60, 82, 155); font-weight: 700;">1. 교육목표</h4>', '<li>', '<p>', '- 항공교통물류분야 산업 발전에 기여하는 학문적 탐구능력을 가진 혁신인재', '양성', '</p>', '</li>', '<li>', '<p>', '- 국제화, 특성화, 실용화를 바탕으로 다양한 지식을 실무에 응용할 수 있는', '항공교통물류분야 전문인재 양성', '</p>', '</li>', '<li><p>- 글로벌 산업과 사회에 기여하는 사회적 책무성을 갖춘 인재 양성</p></li>', '</div>', '<hr style="border: 1px solid rgb(222, 222, 222); border-image: none;"/>', '<div class="article_101">', '<span class="img_fr" style="margin-left: 1.5rem;">', '<img src="/cmm_typeA/images/sample/sub_101_02.jpg"/>', '</span>', '<h4 style="color: rgb(60, 82, 155); font-weight: 700;">2. 산학 및 국제협력</h4>', '<li>', '<p>', '- 변화하는 산업환경에 효과적으로 대응하고 수요자 중심의 교육과정 운영을', '위해 대한항공, 인천국제공항공사, 한진, 한국교통연구원 등 항공교통물류 분야', '주요 기관과 산학협의체를 운영하고 있으며, 또한 홍콩폴리텍 대학교 등', '항공교통물류 분야의 국제적 우수기관과 협력관계를 구축하고 교환학생 파견,', '공동연구 수행 등을 진행하고 있습니다.', '</p>', '</li>', '</div>', '<hr style="border: 1px solid rgb(222, 222, 222); border-image: none;"/>', '<div class="article_101">', '<h4 style="color: rgb(60, 82, 155); font-weight: 700;">3. 주요 외국 협력기관</h4>', '<table class="table_01">\n<tbody><tr>\n<th>기관명</th>\n<th>협력형태</th>\n<th>MOU 체결일자</th>\n</tr>\n<tr>\n<td>University of Central Florida</td>\n<td>공동연구</td>\n<td>2020. 05 ~ 현재</td>\n</tr>\n<tr>\n<td>Ho Chi Minh City University of Technology</td>\n<td>교환학생</td>\n<td>2019. 06 ~ 현재</td>\n</tr>\n<tr>\n<td>Electronic Navigation Research Institute</td>\n<td>공동연구, 인턴쉽</td>\n<td>2016. 03 ~ 현재</td>\n</tr>\n<tr>\n<td>University of Vaasa</td>\n<td>교환학생</td>\n<td>2015. 04 ~ 현재</td>\n</tr>\n<tr>\n<td>Hong Kong Polytechnic University</td>\n<td>교환학생</td>\n<td>2008. 09 ~ 현재</td>\n</tr>\n<tr>\n<td>Embry-Riddle Aeronautical University</td>\n<td>교환학생</td>\n<td>1994. 07 ~ 현재</td>\n</tr>\n</tbody></table><br/><h4 style="color: rgb(60, 82, 155);"><span style="font-size: 11pt;">문의 : 항공교통물류학부 행정실(T. 02-300-0150 / 0340)</span></h4><div><br/></div><br/>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 항공교통물류학부 소개
#
# 1. 교육목표
#
# - 항공교통물류분야 산업 발전에 기여하는 학문적 탐구능력을 가진 혁신인재
# 양성
#
# - 국제화, 특성화, 실용화를 바탕으로 다양한 지식을 실무에 응용할 수 있는
# 항공교통물류분야 전문인재 양성
#
# - 글로벌 산업과 사회에 기여하는 사회적 책무성을 갖춘 인재 양성
#
# 2. 산학 및 국제협력
#
# - 변화하는 산업환경에 효과적으로 대응하고 수요자 중심의 교육과정 운영을
# 위해 대한항공, 인천국제공항공사, 한진, 한국교통연구원 등 항공교통물류 분야
# 주요 기관과 산학협의체를 운영하고 있으며, 또한 홍콩폴리텍 대학교 등
# 항공교통물류 분야의 국제적 우수기관과 협력관계를 구축하고 교환학생 파견,
# 공동연구 수행 등을 진행하고 있습니다.
#
# 3. 주요 외국 협력기관
# 기관명 : University of Central Florida
# 협력형태 : 공동연구
# MOU 체결일자 : 2020. 05 ~ 현재
#
# 기관명 : Ho Chi Minh City University of Technology
# 협력형태 : 교환학생
# MOU 체결일자 : 2019. 06 ~ 현재
#
# 기관명 : Electronic Navigation Research Institute
# 협력형태 : 공동연구, 인턴쉽
# MOU 체결일자 : 2016. 03 ~ 현재
#
# 기관명 : University of Vaasa
# 협력형태 : 교환학생
# MOU 체결일자 : 2015. 04 ~ 현재
#
# 기관명 : Hong Kong Polytechnic University
# 협력형태 : 교환학생
# MOU 체결일자 : 2008. 09 ~ 현재
#
# 기관명 : Embry-Riddle Aeronautical University
# 협력형태 : 교환학생
# MOU 체결일자 : 1994. 07 ~ 현재
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 40
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>학장 인사말</h3>', '</div>', '<div class="article_102">', '<h4>항공교통물류학부를 소개합니다</h4>', '<p>', '우리 학부는 1988년 항공관리학과로 신설된 이후에 항공교통 및 물류분야에', '특성화된 교육과 연구에 많은 노력을 기울여 왔습니다. 국토교통부 지정', '항공교통관제 교육원을 운영하고 있으며, 2002년 교육개혁 우수대학으로 선정된', '이래 2010년 국토교통부 물류특성화인력 양성사업, 2014년 교육부 대학 특성화', '사업, 2020년 해운항만물류 전문인력 양성사업 등의 다양한 정부지원을 통해 학부', '교육 및 연구 인프라를 지속적으로 개선해 왔습니다. 이와 같은 노력을 통해', '항공교통 및 물류분야에서 국내 최고의 위상을 가진 학부로 성장할 수 있었으며,', '수많은 졸업생들이 관련 산업에 진출하여 활약하고 있습니다.', '</p>', '</div>', '<div class="article_102">', '<p>', '항공운송산업과 물류 산업이 국가 경제에서 차지하는 비중이 날로 높아지고', '있습니다. 인공지능, 무인항공기, IoT 등 새로운 기술의 도입이 가속화되고', '있으며, 세계화로 인해 국제적 스탠다드에 부합하는 인재에 대한 수요가 높아지고', '있습니다. 우리 학부는 앞으로도 항공교통 및 물류분야의 교육과 연구에서 세계', '최고 수준의 경쟁력을 갖춘 학부로 발전하도록 전 구성원이 노력하겠으며, 많은', '관심과 성원을 부탁드립니다. 감사합니다.', '</p>', '<br/>', '<h4 class="sign" style="text-align: center;">', '한국항공대학교 항공교통물류학부 학부장 <span>이 금 진</span>', '</h4>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 학장 인사말
#
# 항공교통물류학부를 소개합니다
#
# 우리 학부는 1988년 항공관리학과로 신설된 이후에 항공교통 및 물류분야에
# 특성화된 교육과 연구에 많은 노력을 기울여 왔습니다. 국토교통부 지정
# 항공교통관제 교육원을 운영하고 있으며, 2002년 교육개혁 우수대학으로 선정된
# 이래 2010년 국토교통부 물류특성화인력 양성사업, 2014년 교육부 대학 특성화
# 사업, 2020년 해운항만물류 전문인력 양성사업 등의 다양한 정부지원을 통해 학부
# 교육 및 연구 인프라를 지속적으로 개선해 왔습니다. 이와 같은 노력을 통해
# 항공교통 및 물류분야에서 국내 최고의 위상을 가진 학부로 성장할 수 있었으며,
# 수많은 졸업생들이 관련 산업에 진출하여 활약하고 있습니다.
#
# 항공운송산업과 물류 산업이 국가 경제에서 차지하는 비중이 날로 높아지고
# 있습니다. 인공지능, 무인항공기, IoT 등 새로운 기술의 도입이 가속화되고
# 있으며, 세계화로 인해 국제적 스탠다드에 부합하는 인재에 대한 수요가 높아지고
# 있습니다. 우리 학부는 앞으로도 항공교통 및 물류분야의 교육과 연구에서 세계
# 최고 수준의 경쟁력을 갖춘 학부로 발전하도록 전 구성원이 노력하겠으며, 많은
# 관심과 성원을 부탁드립니다. 감사합니다.
#
# 한국항공대학교 항공교통물류학부 학부장 이 금 진
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 386
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교수진</h3>', '</div>', '', '<ul class="prs_list">', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김병종.jpg"/>', '', '</span>', '', '<h4>김병종<span>교수</span></h4>', '', '<p>Virginia Tech</p>', '', '', '<ul class="prs_info">', '<li><span>전공분야 : </span>교통학</li>', '', '<li>', '주요경력 :', '<div>', '<div>- ICAO항행위원회 항공위원</div>', '</div>', '</li>', '<li>', '', '', '</li>', '<li>본관 421호 / bjkim@kau.ac.kr</li>', '', '</ul>', '', '</li>', '', '<li>', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김상현.jpg"/>', '</span>', '<h4>김상현<span>교수</span></h4>', '<p>Georgia Tech</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>항공우주공학(항공교통관리)</li>', '<li>', '주요경력 :', '<div>', '<div>- 한국항공우주연구원 선임연구원</div>', '<div>- 한국교통연구원 부연구위원</div>', '</div>', '</li>', '<li>본관 424호 / sanghyun@kau.ac.kr / <a href="https://sites.google.com/view/atmlab">https://sites.google.com/view/atmlab</a></li>', '</ul>', '</li>', '<li>', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김선이.jpg"/>', '</span>', '<h4>김선이<span>교수</span></h4>', '<p>뮌헨대</p>', '<ul class="prs_info">', '<li>전공분야 : 민사법, 항공사법</li>', '<li>', '주요경력 :', '<div>', '<div>- 법무부 전문위원실 전문위원</div>', '<div>- 국가고시 출제위원</div>', '</div>', '</li>', '<li>본관 317호 / ksiso@kau.ac.kr</li>', '</ul>', '</li>', '<li>', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김원규.jpg"/>', '</span>', '<h4>김원규<span>교수</span></h4>', '<p>Virginia Tech</p>', '<ul class="prs_info">', '<li>전공분야 : 교통공학</li>', '<li>', '주요경력 :', '<div>', '<div>- 교통개발연구원 교통모형팀장</div>', '<div>- 경찰청 교통안전시설 중앙심의위원</div>', '</div>', '</li>', '<li>본관 417호 / wkim@kau.ac.kr</li>', '</ul>', '</li>', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김카이.jpg"/>', '', '</span>', '', '<h4>김카이<span>교수<br/><p style="font-weight: 400;"><span style="font-size: 9pt;">University of Nebraska at Lincoln</span></p><ul class="prs_info" style="font-weight: 400;"></ul></span></h4><ul class="prs_info"><li><span><p>전공분야 : 생산관리, 공급 물류관리</p></span></li>', '', '<li>', '주요경력 :', '<div>', '<div>- 브라이언트 대학 조교수</div>', '<div>- 단국대학교 조교수</div>', '</div>', '</li>', '<li>', '', '', '</li>', '<li>본관 409호 / kaikim@kau.ac.kr</li>', '', '</ul>', '', '</li>', '', '', '<li>', '', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김현미.jpg"/>', '', '</span>', '', '<h4>김현미<span>교수</span></h4>', '', '<p>University of Maryland</p>', '', '', '<ul class="prs_info">', '<li><span>전공분야 : </span>교통공학, 첨단교통</li>', '', '<li>', '주요경력 :', '<div>', '<div>- 미국 메릴랜드주립대 Research Scientist</div>', '<div>- 한국교통연구원 부연구위원</div>', '</div>', '</li>', '<li>', '', '', '</li>', '<li>본관 419호 / hmkim@kau.ac.kr</li>', '', '</ul>', '', '</li>', '', '<li>', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/김휘양.jpg"/>', '</span>', '<h4>김휘양<span>교수</span></h4>', '<p>한국항공대</p>', '<ul class="prs_info">', '<li><span style="font-size: 8pt;">전공분야 :</span><span style="font-size: 8pt;"> 항공교통관리(ATM), 공역/비행절차 설계, 도심항공교통(UAM)</span><br/></li><li style="font-size: 8pt;"><span style="font-size: 8pt;">주요경력 :</span><div><div><span style="font-size: 8pt;">- 국토교통부 항공교통정책 담당</span></div><div><span style="font-size: 8pt;">- 전 ICAO 항행위원회 SASP 전문위원</span><br/><span style="font-size: 8pt;">- 현 ICAO 항행위원회 ATMRPP 자문위원</span></div></div></li>', '<li>본관 407호 / igreenbee@kau.ac.kr</li>', '</ul>', '</li>', '<li>', '<span class="portrait">', '<img src="/conts_img/attll_www/introduce/prof/백호종.jpg"/>', '</span>', '<h4>백호종<span>교수</span></h4>', '<p>Virginia Tech</p>', '<ul class="prs_info">', '<li>전공분야 : 통계학, 항공교통 시뮬레이션</li>', '<li>', '주요경력 :', '<div>', '<div>- Virginia Tech 연구교수</div>', '<div>- 미주리주립대 조교수</div>', '</div>', '</li>', '<li>본관 408호 / hbaik@kau.ac.kr</li>', '</ul>', '</li>', '< ...
#
# $(document).ready(function() {
# });
#
# 교수진
#
# 김병종교수
#
# Virginia Tech
#
# 전공분야 : 교통학
#
# 주요경력 :
#
# - ICAO항행위원회 항공위원
#
# 본관 421호 / bjkim@kau.ac.kr
#
# 김상현교수
# Georgia Tech
#
# 전공분야 : 항공우주공학(항공교통관리)
#
# 주요경력 :
#
# - 한국항공우주연구원 선임연구원
# - 한국교통연구원 부연구위원
#
# 본관 424호 / sanghyun@kau.ac.kr / https://sites.google.com/view/atmlab
#
# 김선이교수
# 뮌헨대
#
# 전공분야 : 민사법, 항공사법
#
# 주요경력 :
#
# - 법무부 전문위원실 전문위원
# - 국가고시 출제위원
#
# 본관 317호 / ksiso@kau.ac.kr
#
# 김원규교수
# Virginia Tech
#
# 전공분야 : 교통공학
#
# 주요경력 :
#
# - 교통개발연구원 교통모형팀장
# - 경찰청 교통안전시설 중앙심의위원
#
# 본관 417호 / wkim@kau.ac.kr
#
# 김카이교수University of Nebraska at Lincoln전공분야 : 생산관리, 공급 물류관리
#
# 주요경력 :
#
# - 브라이언트 대학 조교수
# - 단국대학교 조교수
#
# 본관 409호 / kaikim@kau.ac.kr
#
# 김현미교수
#
# University of Maryland
#
# 전공분야 : 교통공학, 첨단교통
#
# 주요경력 :
#
# - 미국 메릴랜드주립대 Research Scientist
# - 한국교통연구원 부연구위원
#
# 본관 419호 / hmkim@kau.ac.kr
#
# 김휘양교수
# 한국항공대
#
# 전공분야 : 항공교통관리(ATM), 공역/비행절차 설계, 도심항공교통(UAM)주요경력 :- 국토교통부 항공교통정책 담당- 전 ICAO 항행위원회 SASP 전문위원- 현 ICAO 항행위원회 ATMRPP 자문위원
# 본관 407호 / igreenbee@kau.ac.kr
#
# 백호종교수
# Virginia Tech
#
# 전공분야 : 통계학, 항공교통 시뮬레이션
#
# 주요경력 :
#
# - Virginia Tech 연구교수
# - 미주리주립대 조교수
#
# 본관 408호 / hbaik@kau.ac.kr
#
# 송보미교수
# 서울대
#
# 전공분야 : 산업공학, 데이터 애널리틱스
#
# 주요경력 :
#
# - 한국생산기술연구원 선임연구원
#
# 본관 411호 / bmsong@kau.ac.kr/ https://scmda.kau.ac.kr/
#
# 이금진교수
# Georgia Tech
#
# 전공분야 : 항공교통관리, 저고도 무인교통관리
#
# 주요경력 :
#
# - 일본전자항법연구소(ENRI) 연구원
# - 한국교통연구원(KOTI) 부연구위원
#
# 본관 425호 / keumjin.lee@kau.ac.kr / https://atmcl.kau.ac.kr
#
# 이기영교수
# 한국항공대
#
# 전공분야 : 글로벌SCM, 국제복합운송
#
# 주요경력 :
#
# - (주)한진 임원
#
# 본관 401호 / kiyounglee@kau.ac.kr
#
# 장영재교수
# 한국항공대
#
# 전공분야 : 항공교통
#
# 주요경력 :
#
# - 대한항공 임원
#
# 본관 402호 / yjjang@kau.ac.kr
#
# 장윤석교수
# Imperial College London
#
# 전공분야 : SCE, Automation
#
# 주요경력 :
#
# - 케임브리지대 연구교수
#
# 본관 413호 / yoonchang@kau.ac.kr
#
# 채준재교수
# Texas A&amp;M대
#
# 전공분야 : 산업공학, 물류공학
#
# 주요경력 :
#
# - 삼성전자 책임연구원
#
# 본관 412호 / jchae@kau.ac.kr
#
# 황호원교수
# Mainz대
#
# 전공분야 : 형사법
#
# 주요경력 :
#
# - 한국 형사정책위원회 위원
#
# 본관 324호 / howonhwang@kau.ac.kr
#
# 명예교수
#
# 유광의교수
#
# Loughborough대
#
# 전공분야 : 통계학, 항공안전보안
#
# 주요경력 :
#
# - 국제민간항공기구(ICAO) 항공보안감시관
# - 한국항공보안포럼회장
#
# keyoo@kau.ac.kr
#
# 이영혁교수
# Pennsylvania State University
#
# 전공분야 : 교통경제학, 항공정책론, 화물운송론
#
# 주요경력 :
#
# - (현)세계항공교통학회(ATRS) network committee 위원
#
# yhlee@kau.ac.kr
#
# 이헌수교수
# Pennsylvania State University
#
# 전공분야 : 물류, SCM
#
# 주요경력 :
#
# -국토교통부 국가물류정책위원-한국물류산업정책연구원 원장
#
# 본관 414호 / hslee@kau.ac.kr
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 67
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>졸업요건</h3>', '</div>', '<div class="article_303">', '<h4 style="font-size: 1.1rem;">1. 졸업학점</h4>', '<p>', '정규 8학기이상 등록한 재학생 또는 수료생(단, 조기졸업자는 졸업예정학기에', '포함)', '</p>', '<p>※ 졸업학점을 모두 이수하였어도 휴학중에는 졸업 불가함.</p>', '<table class="table_01">\n<tbody>\n<tr>\n<th>대상학번</th>\n<th>졸업이수학점</th>\n</tr>\n<tr>\n<td>2012학번까지</td>\n<td>\n총\xa0140학점 이상\n(단,\xa0학석사연계과정생은\xa0134학점,\xa0대학원과목\xa06학점)\n</td>\n</tr>\n<tr>\n<td>2013학번까지</td>\n<td>\n총\xa0130학점 이상\n(단,\xa0학석사연계과정생은\xa0124학점,\xa0대학원과목\xa06학점)\n</td>\n</tr>\n<tr>\n<td>2018학번까지</td>\n<td>\n총 130학점 이상, 전공 60학점(세부전공 40학점) 이상\n</td>\n</tr>\n<tr>\n<td>2019학번부터</td>\n<td>\n총\xa0130학점 이상, 기본전공 45학점 + 심화전공 24학점 또는\n다전공(복수/부/연계.융합) 이수\n</td>\n</tr>\n</tbody>\n</table>', '<h5>교양과정 영역별 이수</h5>', '<ul>', '<li></li>', '<li>- 2013학번 이후 필수 졸업요건</li>', '<li>- 교양필수(전공기초교양, 필수교양, 항공우주특성화분야) 모두 이수,</li>', '<li>', '- 핵심교양, 역량강화 영역별 과목이수', '<ul>', '<li>', ': 2013-2017년 입학자 : 핵심교양 2영역 각 1과목, 일반교양 1 과목 이수', '</li>', '<li>', ': 2018년 이후 입학자 : 핵심교양 3영역 각 1과목, 일반교양 1과목 이수', '</li>', '</ul>', '</li>', '</ul>', '<h5>', '교양이수학점은 학교 홈페이지의 교양과정 이수<a href="https://www.kau.ac.kr/web/pages/gc15707h.do">(링크)</a>', '부분을 참고', '</h5>', '<h5>', '입학년도 기준의 졸업요건을 따르는 것이 원칙(단, 편입생·전과생·1학년 1학기로', '복학한 자는 그러하지 아니함)', '</h5>', '</div>', '<div class="article_303">', '<h4 style="font-size: 1.1rem;">2. 졸업인증</h4>', '<table class="table_01" style="margin-bottom: 1rem;">\n<thead>\n<tr>\n<th class="tg-c3ow">대상구분</th>\n<th class="tg-c3ow">졸업인증제 취득 요건</th>\n<th class="tg-0lax">비고</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td class="tg-c3ow">2017학년도 이전 신·편입학생</td>\n<td class="tg-gzu2">\n‘영어분야’ 인증 취득\n</td>\n<td class="tg-axus" rowspan="2">\n공인 영어 취득기준은 동일<br/>(단, 입학년도/입학전형별로 상이)\n</td>\n</tr>\n<tr>\n<td class="tg-c3ow">2018학년도 이후 신·편입학생</td>\n<td class="tg-c3ow">\nSPACE인증 5개 분야 중 2개 이상 인증 취득<br/><span style="color: red;">(단, ‘글로벌소통역량인증’은 필수 인증 취득)</span><br/>\n</td>\n</tr>\n</tbody>\n</table>', '<h5 style="color: red; font-size: 0.8rem;">', "3학년 이내에 SPACE인증 5개 분야를 모두 인증 취득한 경우에는 'SPACE 장학'", '지급(2018학년도 이후 신/편입학생 해당)', '<a href="https://www.kau.ac.kr/web/pages/gc40674h.do" style="font-size: 0.8rem; margin-bottom: 1.5rem; display: inline-block;">(SPACE 인증 목록 : 링크 하단 참고)</a>', '</h5>', '<h4 style="font-size: 1.1rem;">', '3. 영어분야 인증점수 기준표 - 항공교통물류학부', '</h4>', '<div class="scroller">', '<table class="table_01">\n<tbody>\n<tr>\n<th rowspan="2">학부(과)</th>\n<th rowspan="2">대상학년도</th>\n<th rowspan="2">TOEIC</th>\n<th rowspan="2">TOEIC<br/>SPEAKING</th>\n<th colspan="2">TOEFL</th>\n<th rowspan="2">NEW TEPS<br/>(TEPS)</th>\n<th rowspan="2">OPIc</th>\n</tr>\n<tr>\n<th>PBT</th>\n<th>IBT</th>\n</tr>\n<tr>\n<td rowspan="3">항공교통물류학부</td>\n<td>2001학년도~2004학년도 신입생</td>\n<td>600</td>\n<td>Level 5 이상<br/>(120점)</td>\n<td>500</td>\n<td>61</td>\n<td>257 <br/>(480)</td>\n<td>IL 이상</td>\n</tr>\n<tr>\n<td>2005학년도~2011학년도 신입생</td>\n<td>700</td>\n<td>Level 6 이상<br/>(130점)</td>\n<td>520</td>\n<td>68</td>\n<td>327 <br/>(600)</td>\n<td>IM이상</td>\n</tr>\n<tr>\n<td>2012학년도 이후 신입생</td>\n<td>800</td>\n<td>Level 6 이상<br/>(140점)</td>\n<td>570</td>\n<td>88</td>\n<td>386 <br/>(700)</td>\n<td>IM (Mid3)이상</td>\n</tr>\n<tr>\n<td>*외국인학생</td>\n<td>2014학년도 2학기이후 신(편)입생</td>\n<td colspan="6">TOPIK 4급이상</td>\n</tr>\n</tbody>\n</table>', '</div>', '<h5>본교에서 주관하는 모의 TOEIC포함, 유효한 성적만 인정함.</h5>', '<h5>', '외국인학생이란 : 외국인학생 특별전형으로 입학한 학생(모집정원에 제한이 없는', '전형)', '</h5>', '</div>', '</div>', '</body>']
# $(document).ready(function() {
# });
#
# 졸업요건
#
# 1. 졸업학점
#
# 정규 8학기이상 등록한 재학생 또는 수료생(단, 조기졸업자는 졸업예정학기에
# 포함)
#
# ※ 졸업학점을 모두 이수하였어도 휴학중에는 졸업 불가함.
# 대상학번 : 2012학번까지
# 졸업이수학점 : 총 140학점 이상 (단, 학석사연계과정생은 134학점, 대학원과목 6학점)
#
# 대상학번 : 2013학번까지
# 졸업이수학점 : 총 130학점 이상 (단, 학석사연계과정생은 124학점, 대학원과목 6학점)
#
# 대상학번 : 2018학번까지
# 졸업이수학점 : 총 130학점 이상, 전공 60학점(세부전공 40학점) 이상
#
# 대상학번 : 2019학번부터
# 졸업이수학점 : 총 130학점 이상, 기본전공 45학점 + 심화전공 24학점 또는 다전공(복수/부/연계.융합) 이수
# 교양과정 영역별 이수
#
# - 2013학번 이후 필수 졸업요건
# - 교양필수(전공기초교양, 필수교양, 항공우주특성화분야) 모두 이수,
#
# - 핵심교양, 역량강화 영역별 과목이수
#
# : 2013-2017년 입학자 : 핵심교양 2영역 각 1과목, 일반교양 1 과목 이수
#
# : 2018년 이후 입학자 : 핵심교양 3영역 각 1과목, 일반교양 1과목 이수
#
# 교양이수학점은 학교 홈페이지의 교양과정 이수(링크)
# 부분을 참고
#
# 입학년도 기준의 졸업요건을 따르는 것이 원칙(단, 편입생·전과생·1학년 1학기로
# 복학한 자는 그러하지 아니함)
#
# 2. 졸업인증
# 대상구분 : 2017학년도 이전 신·편입학생
# 졸업인증제 취득 요건 : ‘영어분야’ 인증 취득
# 비고 : 공인 영어 취득기준은 동일 (단, 입학년도/입학전형별로 상이)
#
# 대상구분 : 2018학년도 이후 신·편입학생
# 졸업인증제 취득 요건 : SPACE인증 5개 분야 중 2개 이상 인증 취득 (단, ‘글로벌소통역량인증’은 필수 인증 취득)
# 비고 : 공인 영어 취득기준은 동일 (단, 입학년도/입학전형별로 상이)
#
# 3학년 이내에 SPACE인증 5개 분야를 모두 인증 취득한 경우에는 'SPACE 장학'
# 지급(2018학년도 이후 신/편입학생 해당)
# (SPACE 인증 목록 : 링크 하단 참고)
#
# 3. 영어분야 인증점수 기준표 - 항공교통물류학부
#
# 학부(과) : 항공교통물류학부
# 대상학년도 : 2001학년도~2004학년도 신입생
# TOEIC : 600
# TOEIC SPEAKING : Level 5 이상 (120점)
# TOEFL PBT : 500
# TOEFL IBT : 61
# NEW TEPS (TEPS) : 257 (480)
# OPIc : IL 이상
#
# 학부(과) : 항공교통물류학부
# 대상학년도 : 2005학년도~2011학년도 신입생
# TOEIC : 700
# TOEIC SPEAKING : Level 6 이상 (130점)
# TOEFL PBT : 520
# TOEFL IBT : 68
# NEW TEPS (TEPS) : 327 (600)
# OPIc : IM 이상
#
# 학부(과) : 항공교통물류학부
# 대상학년도 : 2012학년도 이후 신입생
# TOEIC : 800
# TOEIC SPEAKING : Level 6 이상 (140점)
# TOEFL PBT : 570
# TOEFL IBT : 88
# NEW TEPS (TEPS) : 386 (700)
# OPIc : IM (Mid3) 이상
#
# 외국인학생
# 대상학년도 : 2014학년도 2학기 이후 신(편)입생
# TOPIK : 4급 이상
#
# 본교에서 주관하는 모의 TOEIC포함, 유효한 성적만 인정함.
#
# 외국인학생이란 : 외국인학생 특별전형으로 입학한 학생(모집정원에 제한이 없는
# 전형)
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 173
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>졸업생 현황</h3>', '</div>', '<style>', '@media (max-width: 800px) {', '.custom-container {', 'display: none;', '}', '}', '</style>', '<script src="https://cdn.jsdelivr.net/npm/chart.js@2.8.0"></script>', '<div class="article_304">', '<div>', '<ul class="crs" style="padding-top: 0">', '<li>', '<h4>1. 항공교통전공 주요 진로</h4>', '<div class="crs_box">', '<img src="/cmm_typeA/images/crs_01.png"/>', '<ul>', '<li>국토교통부 소속 관제사 및 연구원</li>', '<li>교통 관련 공공기관 국책연구소</li>', '<li>공항공사 (인천국제공항공사, KAC 등)</li>', '<li>민항사 소속 운항관리사 및 관제사</li>', '</ul>', '</div>', '</li>', '<li>', '<h4>2. 물류전공 주요 진로</h4>', '<div class="crs_box">', '<img src="/cmm_typeA/images/crs_02.png"/>', '<ul>', '<li>제조 및 서비스업의 물류관리부서</li>', '<li>교통 관련 공공기관 국책연구소</li>', '<li>운송 및 물류전문회사</li>', '<li>민간항공사 (대한항공, 아시아나항공 등)</li>', '</ul>', '</div>', '</li>', '<li>', '<h4>3. 그 외 진로</h4>', '<div class="crs_box">', '<img src="/cmm_typeA/images/crs_03.png"/>', '<ul>', '<li>프리랜서, 벤처기업 창업</li>', '<li>대학원 진학</li>', '<li>전문직 및 공무원</li>', '<li>공군 장교 임관</li>', '</ul>', '</div>', '</li>', '</ul>', '</div>', '<hr style="border: 0.5px solid #cdcdcd; margin-bottom: 1.5rem"/>', '<div class="custom-container" style="text-align: center">', '<div class="chart-container" style="', 'display: inline-block;', 'position: relative;', 'width: 40%;', 'margin: 0 1rem;', '">', '<canvas id="myChart1" style="width: 10%"> </canvas>', '</div>', '<div class="chart-container" style="', 'display: inline-block;', 'position: relative;', 'width: 40%;', 'margin: 0 1rem;', '">', '<canvas id="myChart2" style="width: 10%"> </canvas>', '</div>', '</div>', '<script>', 'var ctx1 = document.getElementById("myChart1");', 'var ctx2 = document.getElementById("myChart2");', 'Chart.Legend.prototype.afterFit = function () {', 'this.height = this.height + 10;', '};', 'var myChart1 = new Chart(ctx1, {', 'type: "pie",', 'data: {', 'labels: ["학군단", "관제사", "항공사", "공항공사", "대학원", "기타"],', 'datasets: [', '{', 'data: [28, 23, 17, 9, 5, 19],', 'backgroundColor: [', '"rgba(255, 99, 132, 0.6)",', '"rgba(54, 162, 235, 0.6)",', '"rgba(255, 206, 86, 0.6)",', '"rgba(55, 215, 70, 0.6)",', '"rgba(138, 80, 238, 0.6)",', '"rgba(238, 238, 80, 0.6)",', '],', 'borderColor: [', '"rgba(255, 99, 132, 1)",', '"rgba(54, 162, 235, 1)",', '"rgba(255, 206, 86, 1)",', '"rgba(55, 215, 70, 1)",', '"rgba(138, 80, 238, 1)",', '"rgba(238, 238, 80, 1)",', '],', 'borderWidth: 1,', '},', '],', '},', 'options: {', 'title: { display: true, text: "[항공교통전공 졸업자 주요 취업처]" },', 'tooltips: {', 'callbacks: {', 'title: function (tooltipItems, data) {', 'return "";', '},', 'label: function (tooltipItem, data) {', 'return `${data.labels[tooltipItem.index]} : ${', 'data.datasets[0].data[tooltipItem.index]', '}%`;', '},', '},', '},', 'legend: { display: true, onClick: null },', '},', '});', 'var myChart2 = new Chart(ctx2, {', 'type: "pie",', 'data: {', 'labels: ["기업", "공사,국책연구소 등", "장교", "기타"],', 'datasets: [', '{', 'data: [66, 19, 10, 5],', 'backgroundColor: [', '"rgba(255, 99, 132, 0.6)",', '"rgba(54, 162, 235, 0.6)",', '"rgba(255, 206, 86, 0.6)",', '"rgba(55, 215, 70, 0.6)",', '],', 'borderColor: [', '"rgba(255, 99, 132, 1)",', '"rgba(54, 162, 235, 1)",', '"rgba(255, 206, 86, 1)",', '"rgba(55, 215, 70, 1)",', '],', 'borderWidth: 1,', '},', '],', '},', 'options: {', 'title: { display: true, text: "[물류전공 졸업자 주요 취업처]" },', 'tooltips: {', 'callbacks: {', 'title: function (tooltipItems, data) {', 'return "";', '},', 'label: function (tooltipItem, data) {', 'return `${data.labels[tooltipItem.index]} : ${', 'data.datasets[0].data[tooltipItem.index]', '}%`;', '},', '},', '},', 'legend: { display: true, onClick: null },', '},', '});', '</script>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 졸업생 현황
#
# @media (max-width: 800px) {
# .custom-container {
# display: none;
# }
# }
#
# 1. 항공교통전공 주요 진로
#
# 국토교통부 소속 관제사 및 연구원
# 교통 관련 공공기관 국책연구소
# 공항공사 (인천국제공항공사, KAC 등)
# 민항사 소속 운항관리사 및 관제사
#
# 2. 물류전공 주요 진로
#
# 제조 및 서비스업의 물류관리부서
# 교통 관련 공공기관 국책연구소
# 운송 및 물류전문회사
# 민간항공사 (대한항공, 아시아나항공 등)
#
# 3. 그 외 진로
#
# 프리랜서, 벤처기업 창업
# 대학원 진학
# 전문직 및 공무원
# 공군 장교 임관
#
# <div class="chart-container" style="
# display: inline-block;
# position: relative;
# width: 40%;
# margin: 0 1rem;
# ">
#
# <div class="chart-container" style="
# display: inline-block;
# position: relative;
# width: 40%;
# margin: 0 1rem;
# ">
#
# var ctx1 = document.getElementById("myChart1");
# var ctx2 = document.getElementById("myChart2");
# Chart.Legend.prototype.afterFit = function () {
# this.height = this.height + 10;
# };
# var myChart1 = new Chart(ctx1, {
# type: "pie",
# data: {
# labels: ["학군단", "관제사", "항공사", "공항공사", "대학원", "기타"],
# datasets: [
# {
# data: [28, 23, 17, 9, 5, 19],
# backgroundColor: [
# "rgba(255, 99, 132, 0.6)",
# "rgba(54, 162, 235, 0.6)",
# "rgba(255, 206, 86, 0.6)",
# "rgba(55, 215, 70, 0.6)",
# "rgba(138, 80, 238, 0.6)",
# "rgba(238, 238, 80, 0.6)",
# ],
# borderColor: [
# "rgba(255, 99, 132, 1)",
# "rgba(54, 162, 235, 1)",
# "rgba(255, 206, 86, 1)",
# "rgba(55, 215, 70, 1)",
# "rgba(138, 80, 238, 1)",
# "rgba(238, 238, 80, 1)",
# ],
# borderWidth: 1,
# },
# ],
# },
# options: {
# title: { display: true, text: "[항공교통전공 졸업자 주요 취업처]" },
# tooltips: {
# callbacks: {
# title: function (tooltipItems, data) {
# return "";
# },
# label: function (tooltipItem, data) {
# return `${data.labels[tooltipItem.index]} : ${
# data.datasets[0].data[tooltipItem.index]
# }%`;
# },
# },
# },
# legend: { display: true, onClick: null },
# },
# });
# var myChart2 = new Chart(ctx2, {
# type: "pie",
# data: {
# labels: ["기업", "공사,국책연구소 등", "장교", "기타"],
# datasets: [
# {
# data: [66, 19, 10, 5],
# backgroundColor: [
# "rgba(255, 99, 132, 0.6)",
# "rgba(54, 162, 235, 0.6)",
# "rgba(255, 206, 86, 0.6)",
# "rgba(55, 215, 70, 0.6)",
# ],
# borderColor: [
# "rgba(255, 99, 132, 1)",
# "rgba(54, 162, 235, 1)",
# "rgba(255, 206, 86, 1)",
# "rgba(55, 215, 70, 1)",
# ],
# borderWidth: 1,
# },
# ],
# },
# options: {
# title: { display: true, text: "[물류전공 졸업자 주요 취업처]" },
# tooltips: {
# callbacks: {
# title: function (tooltipItems, data) {
# return "";
# },
# label: function (tooltipItem, data) {
# return `${data.labels[tooltipItem.index]} : ${
# data.datasets[0].data[tooltipItem.index]
# }%`;
# },
# },
# },
# legend: { display: true, onClick: null },
# },
# });
#
# %%%%%%%%%%%%%%%%%%%
# -------5-------
# 42
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>전공소개</h3>', '</div>', '<div class="article_401" style="', 'background-color: #f5f7fa;', 'border-radius: 8px;', 'box-shadow: 2px 2px 4px #373737;', '">', '<span class="img">', '<img src="/conts_img/attll_www/major/01.png"/>', '</span>', '<h4>항공교통전공 (Air Transportation Major)</h4>', '<p>', '항공교통전공은 국내외 항공운송 활동의 기반이 되는 항공교통관리, 운항관리,', '공역, 공항 등에 관한 시스템 설계 및 관리, 운영 전문가를 양성하는 것을 목표로', '한다.', '<br style="height: 1rem;"/>', '본 전공에는 국토교통부 지정 전문교육기관인 항공교통관제교육원이 부설되어', '있으며, 국제민간항공기구(ICAO)의 기준에 따라 민간항공교통관제사를 양성하고', '있다. 개인항공기, 무인항공기 등 발전하는 항공교통 패러다임에 부합하는 최신', '교육 및 연구환경을 학생들에게 제공함으로써 항공분야의 미래를 이끌어갈 세계적', '인재를 양성하고자 한다.', '<br style="height: 1rem;"/>', '항공교통전공은 항공운송분야의 창의적 인재 양성을 목표로 글로벌 항공교통관리,', '항공기상학, 항공교통시스템 분석 등의 교과목을 통한 체계적 이론 교육을', '제공하고 있으며, 항공교통관제 실습, 항공사 운항관리 현장실습 등을 통해', '산업현장에서 필요로 하는 실무능력을 학생들이 효과적으로 배양할 수 있도록', '한다. 본 전공자들은 재학 중에 항공교통관제사와 운항관리사 면허를 취득할 수', '있으며, 졸업 후에는 국토교통부, 항공사, 공항공사, 항공교통 관련 연구소와', '기업체 등으로 진출하고 있다.', '</p>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 전공소개
#
# <div class="article_401" style="
# background-color: #f5f7fa;
# border-radius: 8px;
# box-shadow: 2px 2px 4px #373737;
# ">
#
# 항공교통전공 (Air Transportation Major)
#
# 항공교통전공은 국내외 항공운송 활동의 기반이 되는 항공교통관리, 운항관리,
# 공역, 공항 등에 관한 시스템 설계 및 관리, 운영 전문가를 양성하는 것을 목표로
# 한다.
#
# 본 전공에는 국토교통부 지정 전문교육기관인 항공교통관제교육원이 부설되어
# 있으며, 국제민간항공기구(ICAO)의 기준에 따라 민간항공교통관제사를 양성하고
# 있다. 개인항공기, 무인항공기 등 발전하는 항공교통 패러다임에 부합하는 최신
# 교육 및 연구환경을 학생들에게 제공함으로써 항공분야의 미래를 이끌어갈 세계적
# 인재를 양성하고자 한다.
#
# 항공교통전공은 항공운송분야의 창의적 인재 양성을 목표로 글로벌 항공교통관리,
# 항공기상학, 항공교통시스템 분석 등의 교과목을 통한 체계적 이론 교육을
# 제공하고 있으며, 항공교통관제 실습, 항공사 운항관리 현장실습 등을 통해
# 산업현장에서 필요로 하는 실무능력을 학생들이 효과적으로 배양할 수 있도록
# 한다. 본 전공자들은 재학 중에 항공교통관제사와 운항관리사 면허를 취득할 수
# 있으며, 졸업 후에는 국토교통부, 항공사, 공항공사, 항공교통 관련 연구소와
# 기업체 등으로 진출하고 있다.
#
# %%%%%%%%%%%%%%%%%%%
# -------6-------
# 60
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>전공소개</h3>', '</div>', '<div class="article_401" style="', 'background-color: #f5f7fa;', 'border-radius: 8px;', 'box-shadow: 2px 2px 4px #373737;', '">', '<span class="img">', '<img src="/conts_img/attll_www/major/02.png"/>', '</span>', '<h4>물류전공 (Logistics major)</h4>', '<p>', '전 세계가 항공, 해운 등으로 인해 물리적으로 연결되고 데이터의 활용을 통해', '디지털적으로도 연결되어 초연결 사회로 발전하고 있다. 이러한 환경 속에서', '인천국제공항과 같은 인프라 투자를 통한 물류 시설의 경쟁력 및 물류 및', '공급사슬의 경쟁력을 갖춘 기업이 국가 경제 발전을 위해 필수적인 상황이다.', '</p>', '<br/>', '<p>', '특히, 과거의 물리적인 연결에서 더 발전한 디지털적인 연결로 변해가는 상황에서', '인프라와 정보의 연결이 요구되는 물류 분야는 관련 분야의 고급인재에 대한', '수요가 전 세계적으로 매우 높다.', '</p>', '</div>', '<div class="article_401 article_401_r" style="', 'background-color: #f5f7fa;', 'border-radius: 8px;', 'box-shadow: 2px 2px 4px #373737;', '">', '<span class="img">', '<img src="/conts_img/attll_www/major/03.png"/>', '</span>', '<p style="text-align: left;">', '따라서 물류 전공에서는 이러한 물류의 중심국가로의 세계에서의 위치를 공고히', '하고 물류 패러다임이 변화하는 시대에 부응할 수 있는 물류 및 공급사슬의 혁신', '우수 인재 양성을 그 목표로 한다.', '</p>', '<br/>', '<p style="text-align: left;">', '본 전공에서는 물류 전문가 양성을 위해 물류 정보 데이터 분석, 최적화 분석,', '교통분석/교통공학, 첨단 교통이론, 물류 및 공급사슬관리 등 물류 분야', '전공과목을 통해 이론적 학습 뿐 아니라 현장 경험을 위한 다양한 국내외', '현장실습 및 인턴 프로그램을 통해 현장 친화 인재를 양성한다. 본 전공자들은', '재학 중에 물류관리사, CPIM, 교통기사 등의 자격증을 취득 가능하며, 졸업 후', '제조 및 서비스 관련된 대부분의 모든 기업의 제조 및 물류 부서, SI 기업,', '항공사, 물류 전문기업, 컨설팅 기업, 도로공사, 서울메트로 공사, 교통 관련', '공공기관, 국책연구소 등으로 진출한다.', '</p>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 전공소개
#
# <div class="article_401" style="
# background-color: #f5f7fa;
# border-radius: 8px;
# box-shadow: 2px 2px 4px #373737;
# ">
#
# 물류전공 (Logistics major)
#
# 전 세계가 항공, 해운 등으로 인해 물리적으로 연결되고 데이터의 활용을 통해
# 디지털적으로도 연결되어 초연결 사회로 발전하고 있다. 이러한 환경 속에서
# 인천국제공항과 같은 인프라 투자를 통한 물류 시설의 경쟁력 및 물류 및
# 공급사슬의 경쟁력을 갖춘 기업이 국가 경제 발전을 위해 필수적인 상황이다.
#
# 특히, 과거의 물리적인 연결에서 더 발전한 디지털적인 연결로 변해가는 상황에서
# 인프라와 정보의 연결이 요구되는 물류 분야는 관련 분야의 고급인재에 대한
# 수요가 전 세계적으로 매우 높다.
#
# <div class="article_401 article_401_r" style="
# background-color: #f5f7fa;
# border-radius: 8px;
# box-shadow: 2px 2px 4px #373737;
# ">
#
# 따라서 물류 전공에서는 이러한 물류의 중심국가로의 세계에서의 위치를 공고히
# 하고 물류 패러다임이 변화하는 시대에 부응할 수 있는 물류 및 공급사슬의 혁신
# 우수 인재 양성을 그 목표로 한다.
#
# 본 전공에서는 물류 전문가 양성을 위해 물류 정보 데이터 분석, 최적화 분석,
# 교통분석/교통공학, 첨단 교통이론, 물류 및 공급사슬관리 등 물류 분야
# 전공과목을 통해 이론적 학습 뿐 아니라 현장 경험을 위한 다양한 국내외
# 현장실습 및 인턴 프로그램을 통해 현장 친화 인재를 양성한다. 본 전공자들은
# 재학 중에 물류관리사, CPIM, 교통기사 등의 자격증을 취득 가능하며, 졸업 후
# 제조 및 서비스 관련된 대부분의 모든 기업의 제조 및 물류 부서, SI 기업,
# 항공사, 물류 전문기업, 컨설팅 기업, 도로공사, 서울메트로 공사, 교통 관련
# 공공기관, 국책연구소 등으로 진출한다.

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
