# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "자유전공학부_공학계열_data"
number_html = 6
url = """http://college.kau.ac.kr/web/pages/gc91871h.do
http://college.kau.ac.kr/web/pages/gc97040h.do
http://college.kau.ac.kr/web/pages/gc45627h.do
http://college.kau.ac.kr/web/pages/gc6724h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 6:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc91871h.do', 'http://college.kau.ac.kr/web/pages/gc97040h.do', 'http://college.kau.ac.kr/web/pages/gc45627h.do', 'http://college.kau.ac.kr/web/pages/gc6724h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 1340
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<span id="husky_bookmark_start_1677132236111"></span><span id="husky_bookmark_end_1677132236111"></span><span id="husky_bookmark_start_1677132232599"></span><span id="husky_bookmark_end_1677132232599"></span><div class="sub_tit">', '<h3>\u200b인사말</h3>', '</div>', '<div class="article_101"><span style="font-family: 나눔고딕, NanumGothic; font-size: 11pt;"><span style="color: rgb(0, 117, 200);"><span style="font-size: 18pt; font-family: Verdana;"><b><span style="font-family: Verdana; color: rgb(0, 0, 0); font-size: 18pt;">자유전공학부_공학계열</span></b></span></span></span><span style="color: rgb(172, 172, 172); font-family: 나눔고딕, NanumGothic; font-size: 11pt;"><br/><br/></span><p class="0" style="line-height: 2;"><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">자유전공학부_공학계열(이하 공학계열)</span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">은 대학 신입생으로서 공과대학 및 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">AI</span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">융합대학 내에 개설된 다양한 전공을 탐색하고</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">, </span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">자신의 적성에 맞는 진로를 자유롭게 선택할 수 있는 모집단위입니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">.</span></p><p class="0" style="letter-spacing: -0.2pt; line-height: 2;"><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">1학년 기간 동안 다양한 기초 및 전공탐색과목 등을 이수하여 자신의 진로를 결정한 학생들은 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">2</span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">학년 진입 시 공과대학 및 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">AI</span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">융합대 내에 설치된 학부</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">(</span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">과</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">)</span><span style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">를 선택하여 소속을 변경할 수 있습니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: -0.2pt; font-size: 11pt;">.</span></p><p class="0" style="letter-spacing: -0.2pt; line-height: 2;"><span style="font-family: Verdana; font-size: 11pt;"> </span><span style="font-family: Verdana; font-size: 11pt;">\xa0</span><span style="font-family: Verdana; font-size: 11pt;"> </span><o:p></o:p></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 11pt;">공학계열은 공과대학 및 </span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">AI</span><span style="font-family: Verdana; font-size: 11pt;">융합대학 내 학부</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">(</span><span style="font-family: Verdana; font-size: 11pt;">과</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">) </span><span style="font-family: Verdana; font-size: 11pt;">기초 과목 및 첨단학과를 대상으로 한 차별적 전공 교과 수강을 통해 다채로운 전공 탐색 기회를 제공하고</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">, </span><span style="font-family: Verdana; font-size: 11pt;">학생들의 주도적 학습역량을 이끌어내 눈부시게 발전하는 시대에 함께 갈 수 있는 인재를 양성하고자 합니다</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">. </span></p><p class="0" style="line-height: 2;"><span style="font-family: Verdana; font-size: 11pt;"> </span><span style=" ...
#
# $(document).ready(function() {
# });
#
# ​인사말
#
# 자유전공학부_공학계열자유전공학부_공학계열(이하 공학계열)은 대학 신입생으로서 공과대학 및 AI융합대학 내에 개설된 다양한 전공을 탐색하고, 자신의 적성에 맞는 진로를 자유롭게 선택할 수 있는 모집단위입니다.1학년 기간 동안 다양한 기초 및 전공탐색과목 등을 이수하여 자신의 진로를 결정한 학생들은 2학년 진입 시 공과대학 및 AI융합대 내에 설치된 학부(과)를 선택하여 소속을 변경할 수 있습니다.   공학계열은 공과대학 및 AI융합대학 내 학부(과) 기초 과목 및 첨단학과를 대상으로 한 차별적 전공 교과 수강을 통해 다채로운 전공 탐색 기회를 제공하고, 학생들의 주도적 학습역량을 이끌어내 눈부시게 발전하는 시대에 함께 갈 수 있는 인재를 양성하고자 합니다.    학문의 경계를 넘어 확장적이고 창의적인 사고를 통해 글로벌 융복합 리더를 양성하는데 최선을 다하겠습니다. <!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 10418",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2023-04-27T14:05:59.450Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D978C5F7DD34A00000009D": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D978C5F7DD34A00000009E": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D978C5F7DD34A00000009F": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D978C5F7DD34A00000009E",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D978C5F7DD34A0000000A0": {
# "id": 1,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D978C5F7DD34A00000009E",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D978C5F7DD34A0000000A1": {
# "id": 2,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D978C5F7DD34A00000009E",
# "f1": "함초롬돋움",
# "t1": 1,
# "f2": "함초롬돋움",
# "t2": 1,
# "f3": "함초롬돋움",
# "t3": 1,
# "f4": "함초롬돋움",
# "t4": 1,
# "f5": "함초롬돋움",
# "t5": 1,
# "f6": "함초롬돋움",
# "t6": 1,
# "f7": "함초롬돋움",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": -2,
# "s2": -2,
# "s3": -2,
# "s4": -2,
# "s5": -2,
# "s6": -2,
# "s7": -2,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D978C5F7DD34A0000000A2": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D978C5F7DD34A0000000A3": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D978C5F7DD34A0000000A2",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D978C5F7DD34A00000009E",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D978C5F7DD34A0000000A4": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D978C5F7DD34A0000000A3",
# "cp": "01D978C5F7DD34A00000009F",
# "ns": "01D978C5F7DD34A0000000A4",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D978C5F7DD34A000000096",
# "01D978C5F7DD34A000000096": {
# "np": "01D978C5F7DD34A000000097",
# "id": 0,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 3,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A1",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D978C5F7DD34A000000094"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D978C5F7DD34A000000095"
# }
# ,
# {
# "t": "공학계열(자유전공)은 대학 신입생으로서 공과대학 및 AI융합대학 내에 개설된 다양한 전공을 탐색하고, 자신의 적성에 맞는 진로를 자유롭게 선택할 수 있는 모집단위입니다."
# }
# ]
# }
# ]
# },
# "01D978C5F7DD34A000000097": {
# "np": "01D978C5F7DD34A000000098",
# "id": -2147483648,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A1",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D978C5F7DD34A000000098": {
# "np": "01D978C5F7DD34A000000099",
# "id": -2147483648,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A1",
# "ch": [
# {
# "t": "1학년 기간 동안 다양한 기초 및 전공탐색과목 등을 이수하여 자신의 진로를 결정한 학생들은 2학년 진입 시 공과대학 및 AI융합대 내에 설치된 학부(과)를 선택하여 소속을 변경할 수 있습니다. "
# }
# ]
# }
# ]
# },
# "01D978C5F7DD34A000000099": {
# "np": "01D978C5F7DD34A00000009A",
# "id": -2147483648,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A1",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D978C5F7DD34A00000009A": {
# "np": "01D978C5F7DD34A00000009B",
# "id": -2147483648,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A0",
# "ch": [
# {
# "t": "공학계열은 공과대학 및 AI융합대학 내 학부(과) 기초 과목 및 첨단학과를 대상으로 한 차별적 전공 교과 수강을 통해 다채로운 전공 탐색 기회를 제공하고, 학생들의 주도적 학습역량을 이끌어내 눈부시게 발전하는 시대에 함께 갈 수 있는 인재를 양성하고자 합니다. "
# }
# ]
# }
# ]
# },
# "01D978C5F7DD34A00000009B": {
# "np": "01D978C5F7DD34A00000009C",
# "id": -2147483648,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A0",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D978C5F7DD34A00000009C": {
# "np": "",
# "id": -2147483648,
# "pp": "01D978C5F7DD34A0000000A3",
# "si": "01D978C5F7DD34A0000000A4",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C5F7DD34A0000000A0",
# "ch": [
# {
# "t": "학문의 경계를 넘어 확장적이고 창의적인 사고를 통해 글로벌 융복합 리더를 양성하는데 최선을 다하겠습니다. "
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D978C5F7DD34A000000094": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D978C5F7DD34A00000009D",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D978C5F7DD34A00000009D",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D978C5F7DD34A00000009D",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D978C5F7DD34A000000095": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }--> <!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 10418",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2023-04-27T13:58:00.054Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D978C4DB828EF00000008C": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D978C4DB828EF00000008D": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 10066329,
# "al": 0,
# "hs": -1
# }
# }
# },
# "01D978C4DB828EF00000008E": {
# "id": 3,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 0,
# "al": 0,
# "hs": -1
# }
# }
# }
# },
# "cp": {
# "01D978C4DB828EF00000008F": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D978C4DB828EF00000008D",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D978C4DB828EF000000090": {
# "id": 1,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D978C4DB828EF00000008E",
# "f1": "맑은 고딕",
# "t1": 1,
# "f2": "맑은 고딕",
# "t2": 1,
# "f3": "맑은 고딕",
# "t3": 1,
# "f4": "맑은 고딕",
# "t4": 1,
# "f5": "맑은 고딕",
# "t5": 1,
# "f6": "맑은 고딕",
# "t6": 1,
# "f7": "맑은 고딕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D978C4DB828EF000000091": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": { },
# "bu": { },
# "pp": {
# "01D978C4DB828EF000000092": {
# "id": 0,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D978C4DB828EF000000091",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D978C4DB828EF00000008D",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D978C4DB828EF000000093": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D978C4DB828EF000000092",
# "cp": "01D978C4DB828EF00000008F",
# "ns": "01D978C4DB828EF000000093",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D978C4DB828EF000000089",
# "01D978C4DB828EF000000089": {
# "np": "01D978C4DB828EF00000008A",
# "id": 0,
# "pp": "01D978C4DB828EF000000092",
# "si": "01D978C4DB828EF000000093",
# "bf": 3,
# "ru": [
# {
# "cp": "01D978C4DB828EF000000090",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D978C4DB828EF000000087"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D978C4DB828EF000000088"
# }
# ,
# {
# "t": "공학계열은 ‘공과대학’ 및 ‘AI융합대학’에 개설된 다양한 전공을 탐색하고, 자신의 적성에 맞는 진로를 자유롭게 선택하고자 하는 수험생들을 위한 모집단위입니다."
# }
# ]
# }
# ]
# },
# "01D978C4DB828EF00000008A": {
# "np": "01D978C4DB828EF00000008B",
# "id": -2147483648,
# "pp": "01D978C4DB828EF000000092",
# "si": "01D978C4DB828EF000000093",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C4DB828EF000000090",
# "ch": [
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D978C4DB828EF00000008B": {
# "np": "",
# "id": -2147483648,
# "pp": "01D978C4DB828EF000000092",
# "si": "01D978C4DB828EF000000093",
# "bf": 0,
# "ru": [
# {
# "cp": "01D978C4DB828EF000000090",
# "ch": [
# {
# "t": " 1학년 기간 동안 각 학부(과)에서 필요로 하는 공통 기초 교과 과정을 통하여 전공에 대한 기초 지식을 습득합니다. 이와 동시에, 전공탐색세미나 교과 과정을 통해, 각 학부(과)의 특징 및 진로분야, 자신과의 적성 등을 확인하여 2학년 진급시 자신의 진로를 결정하게 됩니다. 자신의 진로를 결정한 학생들은 2학년에 진급할 때 ‘공과대학’ 및 ‘AI융합대학’ 내 자신이 희망하는 학부(과)를 제한 없이 자유롭게 선택하여 소속을 변경할 수 있습니다. "
# }
# ]
# }
# ]
# }
# },
# "sl": { },
# "cs": {
# "01D978C4DB828EF000000087": {
# "cc": 2,
# "ci": 1936024420,
# "td": 0,
# "tv": false,
# "sc": 1134,
# "ts": 8000,
# "ms": "",
# "os": "",
# "gl": 0,
# "gc": 0,
# "gw": false,
# "ns": 0,
# "np": 0,
# "ni": 0,
# "nt": 0,
# "ne": 0,
# "hh": false,
# "hf": false,
# "hm": false,
# "fb": false,
# "hb": false,
# "fi": false,
# "hi": false,
# "hp": false,
# "he": false,
# "sl": false,
# "lr": 0,
# "lc": 0,
# "ld": 0,
# "ls": 0,
# "pp": {
# "ls": false,
# "wi": 59528,
# "he": 84188,
# "gt": 0,
# "ml": 8504,
# "mr": 8504,
# "mt": 5668,
# "mb": 4252,
# "mh": 4252,
# "mf": 4252,
# "mg": 0
# },
# "fn": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": -1,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 283
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "en": {
# "at": 0,
# "au": "",
# "ap": "",
# "ac": ")",
# "as": false,
# "ll": 0,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "sa": 850,
# "sb": 567,
# "st": 0
# ,
# "nt": 0,
# "nn": 1,
# "pp": 0,
# "pb": false
# },
# "pb": [
# {
# "ty": 0,
# "bf": "01D978C4DB828EF00000008C",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 1,
# "bf": "01D978C4DB828EF00000008C",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# },
# {
# "ty": 2,
# "bf": "01D978C4DB828EF00000008C",
# "tb": true,
# "hi": false,
# "fi": false,
# "fa": 0,
# "ol": 1417,
# "or": 1417,
# "ot": 1417,
# "ob": 1417
# }
# ],
# "mp": [ ]
# }
# ,
# "01D978C4DB828EF000000088": {
# "cc": 2,
# "ci": 1668246628,
# "ty": 0,
# "la": 0,
# "co": 1,
# "ss": true,
# "sg": 0,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "cs": [ ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->◎ 자유전공학부_공학계열 모집단위 진로◎ 희망 학과별 주요 진출분야
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 53
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>구성원</h3>', '</div>', '<ul class="prs_list">', '<li>', '<span class="portrait"><img src="/conts_img/eng_www/prof/오병태_교수님.jpg"/></span>', '<h4>오병태\xa0<span>주임교수</span></h4>', '<p>연세대, Univ. of Southern California</p>', '<ul class="prs_info">', '<li><span>전공분야 : </span>Multimedia processing &amp; codec, 3D video system</li>', '<li>전자관 203호 / 02-300-0409</li>', '<li>byungoh@kau.ac.kr</li>', '<li class="homepage"> <a href="http://multimedia.kau.ac.kr">홈페이지</a> </li>', '<li class="contact"><a href="http://multimedia.kau.ac.kr"><img src="/cmm_typeA/images/icon_homepage.png"/>홈페이지</a> </li>', '</ul>', '</li>', '<li>', '<span class="portrait"><img src="/conts_img/eng_www/prof/한지원_직원.jpg"/></span>', '<h4>한지원<span>직원</span></h4>', '<ul class="prs_info">', '<li>기계관 103호</li>', '<li>Tel\xa0 02)300-0450\xa0 //\xa0 Fax\xa0 02)3158-4429</li>', '<li class="homepage">hanjw@kau.ac.kr</li>', '<li>업무시간\xa0 9:00 ~ 18:00<br/>(점심 12:00 ~ 13:00, 방학 중 동일)</li>', '</ul>', '</li>', '<li>', '<span class="portrait"></span>', '<h4>이희정 <span>공학계열 학생회장</span></h4>', '<ul class="prs_info">', '<li>소프트웨어학과</li>', '<li>starstar117@naver.com</li>', '</ul>', '</li>', '<li>', '<span class="portrait"></span>', '<h4>이솔<span>\xa0공학계열 부학생회장</span></h4>', '<ul class="prs_info">', '<li>항공전자정보공학부</li>', '<li>ekmoment1@naver.com</li>', '</ul>', '</li>', '</ul>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 구성원
#
# 오병태 주임교수
# 연세대, Univ. of Southern California
#
# 전공분야 : Multimedia processing &amp; codec, 3D video system
# 전자관 203호 / 02-300-0409
# byungoh@kau.ac.kr
# 홈페이지
# 홈페이지
#
# 한지원직원
#
# 기계관 103호
# Tel  02)300-0450  //  Fax  02)3158-4429
# hanjw@kau.ac.kr
# 업무시간  9:00 ~ 18:00(점심 12:00 ~ 13:00, 방학 중 동일)
#
# 이희정 공학계열 학생회장
#
# 소프트웨어학과
# starstar117@naver.com
#
# 이솔 공학계열 부학생회장
#
# 항공전자정보공학부
# ekmoment1@naver.com
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 6092
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<span id="husky_bookmark_start_1677132236111"></span><span id="husky_bookmark_end_1677132236111"></span><span id="husky_bookmark_start_1677132232599"></span><span id="husky_bookmark_end_1677132232599"></span><div class="sub_tit">', '<h3>\u200b공학계열 운영내규</h3>', '</div><br/><br/>', '<table style="border-collapse:collapse;table-layout:fixed;border-top:none;border-left:none;border-bottom:none;border-right:none;mso-table-overlap:never;"><tbody><tr><td style="width:252.67pt;height:33.63pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:none;border-left:none;border-bottom:solid #6182d6 1.70pt;border-right:none;" valign="middle"><p class="0" style="line-height: 1.8;"><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">1</span><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">조 </span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">(</span><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">목적</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">)</span></p></td></tr></tbody></table>', '<p style="line-height: 1.8;"><span style="font-family: Verdana; font-size: 11pt;">운영 내규는 공학계열 모집단위의 교육 목표를 달성하기 위한 합리적인 운영을 위해 필요한 사항을 규정함을 목적으로 한다</span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;"><span style="font-size: 11pt; font-family: Verdana;">.</span><br/>\xa0</span></p>', '<table style="border-collapse:collapse;table-layout:fixed;border-top:none;border-left:none;border-bottom:none;border-right:none;mso-table-overlap:never;"><tbody><tr><td style="width:252.67pt;height:33.63pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:none;border-left:none;border-bottom:solid #6182d6 1.70pt;border-right:none;" valign="middle"><p class="0" style="line-height: 1.8;"><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">제</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">2</span><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">조 </span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">(</span><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">소속 학부</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">(</span><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">과</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">) </span><span style="font-family: Verdana; font-weight: bold; font-size: 11pt; color: rgb(0, 0, 0);">선택</span><span lang="EN-US" style="letter-spacing: 0pt; font-weight: bold; font-size: 11pt; font-family: Verdana; color: rgb(0, 0, 0);">)</span></p></td></tr></tbody></table>', '<p style="line-height: 1.8;"><span style="font-family: Verdana; letter-spacing: 0pt; font-size: 11pt;">① </span><span style="font-family: Verdana; font-size: 11pt;">공학계열 모집단위생은 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">2</span><span style="font-family: Verdana; font-size: 11pt;">학년 진급 시 공과대학 또는 </span><span lang="EN-US" style="letter-spacing: 0pt; font-size: 11pt; font-family: Verdana;">AI</span><span style="font-family: Verdana; font-size: 11pt;">융합대학  ...
# $(document).ready(function() {
# });
#
# ​공학계열 운영내규
#
# 제1조 (목적)
# 운영 내규는 공학계열 모집단위의 교육 목표를 달성하기 위한 합리적인 운영을 위해 필요한 사항을 규정함을 목적으로 한다.
# 제2조 (소속 학부(과) 선택)
# ① 공학계열 모집단위생은 2학년 진급 시 공과대학 또는 AI융합대학 소속 학부(과) 중 1개를 선택하여 반드시 진입하여야 한다.② &lt;삭제 2023.02.23&gt;
# 제3조 (학부(과) 선택 시기)
# ① 공학계열 모집단위는 1학년 초 학부생을 대상으로 희망 학부(과) 사전 조사를 실시하고, 1학년 말 전공 지도 교수 배정 및 공학계열 모집단위 운영규정 제9조 (주전공 학부(과) 선택)에 따른다. &lt;개정 2023.02.23&gt;② 공학계열 모집단위생은 2학년 진급 전 학부(과)의 주전공을 선택하는 것을 원칙으로 한다.
# 제4조 (운영위원회)
# ① 공학계열 모집단위 운영에 관한 사항을 심의하기 위하여 운영위원회(이하“위원회”라 한다)를 구성하고 운영한다.② 운영위원회 위원장은 공학계열 모집단위 주임교수로 하며, 당연직 위원과 필요에 따라 임명직 위원으로 구성할 수 있다.③ 당연직 위원은 공과대학 및 AI융합대학 소속 학부(과)장으로 하며, 임명직 위원은 본 운영위원회 위원장이 위촉하는 약간 명의 교원으로 한다. &lt;개정 2023.02.23&gt;④ 운영위원회의 기능은 다음 각 호와 같다.   1. 공학계열 운영내규 개정에 관한 사항 &lt;개정 2023.02.23&gt;    2. 교과과정 운영 등 기타 운영에 관한 주요사항 논의⑤ 운영위원회 회의는 위원장이 소집하고 재적위원 과반수 이상의 출석과 출석위원 과반수 이상의 찬성으로 의결한다.
# 제5조 (교과과정 편성 및 심의)
# 교과과정 편성은 학칙 제18조 (교과편성) 및 공학계열 모집단위 운영규정 제7조(교과목 편성)에 따른다.
# 제6조 (필수교양과목 이수)
# ① 1학년 과정 중 필수교양 과목 이수는 매학년도 교무처 교과목 개설계획에 따른다.&lt;개정 2021.07.09&gt;② 해당학년 필수교양 교과목은 해당학년 학기에 이수함을 원칙으로 한다.
# 제7조 (학부(과)별 선이수과목 이수)
# 학부(과)별 선이수 교과목은 자신이 희망하는 학부(과)의 전공필수 과목으로 이수 할 수 있다.&lt;개정 2021.07.09&gt;
# 제8조 (학사지도)
# 공학계열 모집단위 학생은 주임교수에게 수강지도, 학업상담 등의 학사지도를 받는다.
# 제9조 (장학금)
# ① 장학금의 지급은 학칙 제61조(장학금의 지급)에 따르며, 이는 공학계열 모집단위 학생으로서 1학년에 한하고, 각 호의 조건을 모두 만족하는 학생 중에서 선발한다.   1. 직전학기 이수 학점이 12학점 이상인 자   2. 평점평균 3.5 이상인 자 &lt;개정 2023.02.23&gt;② 제 ①항을 만족하는 자로서 두 명 이상의 성적이 동일한 경우 다음 각 호와 같이 우선순위를 정한다.총 이수학점이 많은 자   1. 누적평점이 높은 자   2. 필수학점, 이수학점이 많은 자 (전필, 교필)
# 제10조 (졸업)
# 공학계열 모집단위 학생들의 졸업요건은 선택한 학부(과)의 운영 내규 및 학칙 시행세칙에 따른다. (학점이수 및 졸업요건 등)
# 제11조 (기타)
# 이 내규에 정하지 아니한 사항은 「학칙」, 「학칙시행세칙」 및 학사 규정에 따른다.         부    칙 (시행일) 이 내규는 2021년 3월 31일부터 시행한다.(시행일) 이 내규는 2021년 7월  9일부터 시행한다.<!--[data-hwpjson]{
# "documentPr": {
# "di": "",
# "dp": {
# "dn": "test.hwp",
# "ta": 1,
# "d1": 5,
# "d2": 1,
# "dv": 0,
# "dr": 1,
# "do": 1,
# "vj": "1.0",
# "an": "Hancom Office Hangul",
# "av": "9, 6, 1, 10418",
# "ao": "WIN",
# "ab": "32",
# "ar": "LE",
# "as": "Windows_Unknown_Version"
# },
# "dis": false,
# "ds": {
# "ti": "",
# "la": "ko",
# "cr": "",
# "su": "",
# "de": "",
# "cd": "2023-02-23T13:54:37.632Z",
# "md": "1601-01-01T09:00:00.000Z",
# "pd": "1601-01-01T09:00:00.000Z",
# "ke": ""
# }
# },
# "dh": {
# "do": {
# "pa": 1,
# "fo": 1,
# "en": 1,
# "pi": 1,
# "tb": 1,
# "eq": 1
# },
# "fo": [ ],
# "cd": {
# "tp": 0,
# "lc": {
# "af": false,
# "ui": false,
# "fu": false,
# "dn": false,
# "ul": false,
# "el": false,
# "at": false,
# "tq": false,
# "da": false,
# "dw": false,
# "dj": false,
# "bc": false,
# "bu": false,
# "al": false,
# "ab": false,
# "ap": false,
# "an": false,
# "aa": false,
# "ds": false,
# "de": false,
# "as": false,
# "cp": false,
# "ao": false,
# "et": false,
# "ay": false,
# "am": false,
# "a1": false,
# "bt": false,
# "av": false,
# "dh": false,
# "dp": false,
# "d1": false,
# "mf": false,
# "bl": false,
# "ag": false,
# "dg": false,
# "ae": false,
# "df": false,
# "do": false,
# "dl": false,
# "di": false,
# "d2": false,
# "d3": false,
# "ob": false,
# "d4": false,
# "ev": false,
# "d5": false,
# "d6": false,
# "a2": false,
# "dc": false
# }
# },
# "ld": {
# "pa": "",
# "pi": true,
# "fo": false
# }
# },
# "bf": {
# "01D94742F45EAFC0000000CC": {
# "id": 1,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D94742F45EAFC0000000CD": {
# "id": 2,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 4278190080,
# "al": 0,
# "hs": -1
# }
# }
# },
# "01D94742F45EAFC0000000CE": {
# "id": 3,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 0,
# "lc": 0,
# "rt": 0,
# "rw": 0,
# "rc": 0,
# "tt": 0,
# "tw": 0,
# "tc": 0,
# "bbt": 0,
# "bbw": 0,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": {
# "wb": {
# "fc": 4294967295,
# "hc": 0,
# "al": 0,
# "hs": -1
# }
# }
# },
# "01D94742F45EAFC0000000CF": {
# "id": 4,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 1,
# "lw": 1,
# "lc": 0,
# "rt": 1,
# "rw": 1,
# "rc": 0,
# "tt": 1,
# "tw": 1,
# "tc": 0,
# "bbt": 1,
# "bbw": 1,
# "bbc": 0,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# },
# "01D94742F45EAFC0000000D0": {
# "id": 5,
# "td": false,
# "sh": false,
# "st": 0,
# "sc": 0,
# "si": false,
# "bt": 0,
# "bi": false,
# "cl": 0,
# "bc": false,
# "lt": 0,
# "lw": 5,
# "lc": 14058081,
# "rt": 0,
# "rw": 5,
# "rc": 14058081,
# "tt": 0,
# "tw": 5,
# "tc": 14058081,
# "bbt": 1,
# "bbw": 6,
# "bbc": 14058081,
# "dt": 1,
# "dw": 0,
# "dc": 0,
# "fi": { }
# }
# },
# "cp": {
# "01D94742F45ED6D0000000D1": {
# "id": 0,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CE",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D2": {
# "id": 1,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CE",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D3": {
# "id": 2,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CE",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D4": {
# "id": 3,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CE",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": -2,
# "s2": -2,
# "s3": -2,
# "s4": -2,
# "s5": -2,
# "s6": -2,
# "s7": -2,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D5": {
# "id": 4,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CE",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D6": {
# "id": 5,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CD",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": true,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D7": {
# "id": 6,
# "he": 1100,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CD",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# },
# "01D94742F45ED6D0000000D8": {
# "id": 7,
# "he": 1000,
# "tc": 0,
# "sc": 4294967295,
# "uf": false,
# "uk": false,
# "sm": 0,
# "bf": "01D94742F45EAFC0000000CD",
# "f1": "함초롬바탕",
# "t1": 1,
# "f2": "함초롬바탕",
# "t2": 1,
# "f3": "함초롬바탕",
# "t3": 1,
# "f4": "함초롬바탕",
# "t4": 1,
# "f5": "함초롬바탕",
# "t5": 1,
# "f6": "함초롬바탕",
# "t6": 1,
# "f7": "함초롬바탕",
# "t7": 1,
# "r1": 100,
# "r2": 100,
# "r3": 100,
# "r4": 100,
# "r5": 100,
# "r6": 100,
# "r7": 100,
# "s1": 0,
# "s2": 0,
# "s3": 0,
# "s4": 0,
# "s5": 0,
# "s6": 0,
# "s7": 0,
# "e1": 100,
# "e2": 100,
# "e3": 100,
# "e4": 100,
# "e5": 100,
# "e6": 100,
# "e7": 100,
# "o1": 0,
# "o2": 0,
# "o3": 0,
# "o4": 0,
# "o5": 0,
# "o6": 0,
# "o7": 0,
# "it": false,
# "bo": false,
# "ut": 0,
# "us": 1,
# "uc": 0,
# "st": false,
# "ss": 1,
# "so": 0,
# "ot": 0,
# "ht": 0,
# "hc": 0,
# "hx": 0,
# "hy": 0,
# "em": false,
# "en": false,
# "su": false,
# "sb": false
# }
# },
# "tp": {
# "01D94742F45ED6D0000000D9": {
# "id": 0,
# "al": false,
# "ar": false,
# "tp": [ ]
# }
# },
# "nu": {
# "01D94742F45ED6D0000000DA": {
# "id": 1,
# "sn": 1,
# "ph": [
# {
# "le": 1,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^1."
# },
# {
# "le": 2,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^2."
# },
# {
# "le": 3,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^3)"
# },
# {
# "le": 4,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^4)"
# },
# {
# "le": 5,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "(^5)"
# },
# {
# "le": 6,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "(^6)"
# },
# {
# "le": 7,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 1,
# "st": 1,
# "sf": "^7"
# }
# ]
# },
# "01D94742F45ED6D0000000DB": {
# "id": 2,
# "sn": 1,
# "ph": [
# {
# "le": 1,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^1."
# },
# {
# "le": 2,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^2."
# },
# {
# "le": 3,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^3)"
# },
# {
# "le": 4,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^4)"
# },
# {
# "le": 5,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "(^5)"
# },
# {
# "le": 6,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "(^6)"
# },
# {
# "le": 7,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 1,
# "st": 1,
# "sf": "^7"
# }
# ]
# },
# "01D94742F45ED6D0000000DC": {
# "id": 3,
# "sn": 1,
# "ph": [
# {
# "le": 1,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^1."
# },
# {
# "le": 2,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^2."
# },
# {
# "le": 3,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^3)"
# },
# {
# "le": 4,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^4)"
# },
# {
# "le": 5,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "(^5)"
# },
# {
# "le": 6,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "(^6)"
# },
# {
# "le": 7,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 1,
# "st": 1,
# "sf": "^7"
# }
# ]
# },
# "01D94742F45ED6D0000000DD": {
# "id": 4,
# "sn": 1,
# "ph": [
# {
# "le": 1,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^1."
# },
# {
# "le": 2,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^2."
# },
# {
# "le": 3,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^3)"
# },
# {
# "le": 4,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^4)"
# },
# {
# "le": 5,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "(^5)"
# },
# {
# "le": 6,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "(^6)"
# },
# {
# "le": 7,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 1,
# "st": 1,
# "sf": "^7"
# }
# ]
# },
# "01D94742F45ED6D0000000DE": {
# "id": 5,
# "sn": 0,
# "ph": [
# {
# "le": 1,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^1."
# },
# {
# "le": 2,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^2."
# },
# {
# "le": 3,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "^3)"
# },
# {
# "le": 4,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "^4)"
# },
# {
# "le": 5,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 0,
# "st": 1,
# "sf": "(^5)"
# },
# {
# "le": 6,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 8,
# "st": 1,
# "sf": "(^6)"
# },
# {
# "le": 7,
# "al": 0,
# "ui": true,
# "ai": true,
# "wa": 0,
# "tt": 0,
# "to": 50,
# "cp": "",
# "uf": 1,
# "st": 1,
# "sf": "^7"
# }
# ]
# }
# },
# "bu": { },
# "pp": {
# "01D94742F45ED6D0000000DF": {
# "id": 0,
# "ah": 3,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CD",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E0": {
# "id": 1,
# "ah": 0,
# "av": 0,
# "ht": 2,
# "hi": "01D94742F45ED6D0000000DA",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E1": {
# "id": 2,
# "ah": 0,
# "av": 0,
# "ht": 2,
# "hi": "01D94742F45ED6D0000000DB",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E2": {
# "id": 3,
# "ah": 0,
# "av": 0,
# "ht": 2,
# "hi": "01D94742F45ED6D0000000DC",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E3": {
# "id": 4,
# "ah": 3,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E4": {
# "id": 5,
# "ah": 2,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": false,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E5": {
# "id": 6,
# "ah": 0,
# "av": 0,
# "ht": 2,
# "hi": "01D94742F45ED6D0000000DD",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E6": {
# "id": 7,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CE",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E7": {
# "id": 8,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 160,
# "bf": "01D94742F45EAFC0000000CD",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E8": {
# "id": 9,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 170,
# "bf": "01D94742F45EAFC0000000CD",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# },
# "01D94742F45ED6D0000000E9": {
# "id": 10,
# "ah": 0,
# "av": 0,
# "ht": 0,
# "hi": "",
# "hl": 0,
# "tp": "01D94742F45ED6D0000000D9",
# "kb": 0,
# "kn": true,
# "ko": false,
# "kk": false,
# "kl": false,
# "kp": false,
# "kw": 0,
# "co": 0,
# "fl": false,
# "st": true,
# "sl": false,
# "ae": false,
# "aa": false,
# "mi": 0,
# "ml": 0,
# "mr": 0,
# "mp": 0,
# "mn": 0,
# "lt": 0,
# "lv": 180,
# "bf": "01D94742F45EAFC0000000CD",
# "bl": 0,
# "br": 0,
# "bt": 0,
# "bb": 0,
# "bc": false,
# "bi": false
# }
# },
# "st": {
# "01D94742F45ED6D0000000EA": {
# "id": 0,
# "ty": 0,
# "na": "바탕글",
# "en": "Normal",
# "pp": "01D94742F45ED6D0000000E7",
# "cp": "01D94742F45ED6D0000000D8",
# "ns": "01D94742F45ED6D0000000EA",
# "li": 1042,
# "lf": false
# }
# },
# "mp": { },
# "ro": {
# "hp": "01D94742F45EAFC000000035",
# "01D94742F45EAFC000000035": {
# "np": "01D94742F45EAFC000000036",
# "id": 0,
# "pp": "01D94742F45ED6D0000000E8",
# "si": "01D94742F45ED6D0000000EA",
# "bf": 3,
# "ru": [
# {
# "cp": "01D94742F45ED6D0000000D7",
# "ch": [
# {
# "cc": 2,
# "ci": 1936024420,
# "co": "01D94742F45EAFC000000027"
# }
# ,
# {
# "cc": 2,
# "ci": 1668246628,
# "co": "01D94742F45EAFC000000028"
# }
# ,
# {
# "cc": 11,
# "ci": 1952607264,
# "co": "01D94742F45EAFC000000029"
# }
# ,
# {
# "t": ""
# }
# ]
# }
# ]
# },
# "01D94742F45EAFC000000036": {
# "np": "01D94742F45EAFC000000037",
# "id": -2147483648,
# "pp": "01D94742F45ED6D0000000E6",
# "si": "01D94742F45ED6D0000000EA",
# "bf": 0,
# "ru": [
# {
# "cp": "01D94742F45ED6D0000000D2",
# "ch": [
# {
# "t": "이 운영 내규는 공학계열 모집단위의 교육 목표를 달성하기 위한 합리적인 운영을 위해 필요한 사항을 규정함을 목적으로 한다."
# }
# ]
# }
# ]
# },
# ...
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC00000006E",
# "li": 1
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC00000002A": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672328,
# "zo": 1,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC000000070",
# "li": 2
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC00000002B": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672329,
# "zo": 2,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 48682,
# "she": 20990,
# "swr": 4,
# "shr": 2,
# "spr": false,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 141,
# "ori": 141,
# "oto": 141,
# "obo": 141,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 10,
# "cco": 5,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC000000072",
# "li": 3
# },
# {
# "so": "01D94742F45EAFC000000074",
# "li": 4
# },
# {
# "so": "01D94742F45EAFC000000076",
# "li": 5
# },
# {
# "so": "01D94742F45EAFC000000078",
# "li": 6
# }
# ],
# [
# {
# "so": "01D94742F45EAFC00000007A",
# "li": 7
# },
# {
# "so": "01D94742F45EAFC00000007C",
# "li": 8
# },
# {
# "so": "01D94742F45EAFC00000007E",
# "li": 9
# },
# {
# "so": "01D94742F45EAFC000000080",
# "li": 10
# },
# {
# "so": "01D94742F45EAFC000000082",
# "li": 11
# }
# ],
# [
# {
# "so": "01D94742F45EAFC000000084",
# "li": 12
# },
# {
# "so": "01D94742F45EAFC000000086",
# "li": 13
# }
# ],
# [
# {
# "so": "01D94742F45EAFC000000088",
# "li": 14
# },
# {
# "so": "01D94742F45EAFC00000008A",
# "li": 15
# }
# ],
# [
# {
# "so": "01D94742F45EAFC00000008C",
# "li": 16
# },
# {
# "so": "01D94742F45EAFC00000008E",
# "li": 17
# },
# {
# "so": "01D94742F45EAFC000000090",
# "li": 18
# },
# {
# "so": "01D94742F45EAFC000000092",
# "li": 19
# }
# ],
# [
# {
# "so": "01D94742F45EAFC000000094",
# "li": 20
# },
# {
# "so": "01D94742F45EAFC000000096",
# "li": 21
# }
# ],
# [
# {
# "so": "01D94742F45EAFC000000098",
# "li": 22
# },
# {
# "so": "01D94742F45EAFC00000009A",
# "li": 23
# },
# {
# "so": "01D94742F45EAFC00000009C",
# "li": 24
# },
# {
# "so": "01D94742F45EAFC00000009E",
# "li": 25
# }
# ],
# [
# {
# "so": "01D94742F45EAFC0000000A0",
# "li": 26
# },
# {
# "so": "01D94742F45EAFC0000000A2",
# "li": 27
# },
# {
# "so": "01D94742F45EAFC0000000A4",
# "li": 28
# },
# {
# "so": "01D94742F45EAFC0000000A6",
# "li": 29
# },
# {
# "so": "01D94742F45EAFC0000000A8",
# "li": 30
# }
# ],
# [
# {
# "so": "01D94742F45EAFC0000000AA",
# "li": 31
# },
# {
# "so": "01D94742F45EAFC0000000AC",
# "li": 32
# },
# {
# "so": "01D94742F45EAFC0000000AE",
# "li": 33
# },
# {
# "so": "01D94742F45EAFC0000000B0",
# "li": 34
# }
# ],
# [
# {
# "so": "01D94742F45EAFC0000000B2",
# "li": 35
# },
# {
# "so": "01D94742F45EAFC0000000B4",
# "li": 36
# },
# {
# "so": "01D94742F45EAFC0000000B6",
# "li": 37
# },
# {
# "so": "01D94742F45EAFC0000000B8",
# "li": 38
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC00000002C": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672330,
# "zo": 3,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000BA",
# "li": 39
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC00000002D": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672331,
# "zo": 4,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000BC",
# "li": 40
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC00000002E": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672332,
# "zo": 5,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000BE",
# "li": 41
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC00000002F": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672333,
# "zo": 6,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000C0",
# "li": 42
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC000000030": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672334,
# "zo": 7,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000C2",
# "li": 43
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC000000031": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672335,
# "zo": 8,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000C4",
# "li": 44
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC000000032": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672336,
# "zo": 9,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000C6",
# "li": 45
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC000000033": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672337,
# "zo": 10,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000C8",
# "li": 46
# }
# ]
# ]
# }
# ,
# "01D94742F45EAFC000000034": {
# "cc": 11,
# "ci": 1952607264,
# "id": 1145672338,
# "zo": 11,
# "nt": 2,
# "tw": 1,
# "tf": 0,
# "lo": false,
# "swi": 25267,
# "she": 3363,
# "swr": 4,
# "shr": 2,
# "spr": true,
# "pta": true,
# "pal": false,
# "pvr": 2,
# "phr": 3,
# "pva": 0,
# "ph1": 0,
# "pvo": 0,
# "ph2": 0,
# "pfw": true,
# "pao": false,
# "pha": false,
# "ole": 283,
# "ori": 283,
# "oto": 283,
# "obo": 283,
# "ca": { },
# "sc": ""
# ,
# "pb": 2,
# "rh": true,
# "na": false,
# "ho": false,
# "if": true,
# "sa": false,
# "rc": 1,
# "cco": 1,
# "cs": 0,
# "bf": "01D94742F45EAFC0000000CF",
# "ile": 510,
# "iri": 510,
# "ito": 141,
# "ibo": 141,
# "cl": [ ],
# "tr": [
# [
# {
# "so": "01D94742F45EAFC0000000CA",
# "li": 47
# }
# ]
# ]
# }
# },
# "bi": [ ],
# "bidt": { }
# }-->(시행일) 이 내규는 2023년 2월 23일부터 시행한다.
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 21
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '}--></div><p style="line-height: 1.2;"><span style="font-size: 11pt; color: rgb(0, 0, 255);"><span style="color: rgb(0, 117, 200); font-family: Verdana; font-size: 14pt;"><span style="font-family: 나눔고딕, NanumGothic;"><span style="font-family: Verdana; font-size: 14pt; color: rgb(58, 50, 195);">1. 공학계열 교과과정 (2023학번 기준)</span></span></span></span><span style="font-size: 14pt; text-align: center; color: rgb(0, 0, 0); font-family: Verdana;"><span style="color: rgb(58, 50, 195); font-family: Verdana;">\xa0</span><br/></span></p>', '<table style="border-collapse:collapse;table-layout:fixed;border-top:none;border-left:none;border-bottom:none;border-right:none;mso-table-overlap:never;"><tbody><tr><td style="width:103.40pt;height:26.97pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #3a3c84 1.98pt;border-left:none;border-bottom:solid #3a3c84 1.41pt;border-right:solid #999999 1.41pt;" valign="middle"><p class="0" style="text-align:center;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">구분</span></p></td><td colspan="2" style="width:205.36pt;height:26.97pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #3a3c84 1.98pt;border-left:solid #999999 1.41pt;border-bottom:solid #3a3c84 1.41pt;border-right:solid #999999 1.41pt;" valign="middle"><p class="0" style="text-align:center;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">1</span><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">학기</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">\xa0(</span><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">최대</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">\xa021</span><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">학점 이수 가능</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">)</span></p></td><td colspan="2" style="width:214.86pt;height:26.97pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #3a3c84 1.98pt;border-left:solid #999999 1.41pt;border-bottom:solid #3a3c84 1.41pt;border-right:solid #999999 1.41pt;" valign="middle"><p class="0" style="text-align:center;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">2</span><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">학기</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">\xa0(</span><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">최대</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">\xa018</span><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">학점 이수 가능</span><span lang="EN-US" style="font-family: Verdana; letter-spacing: 0pt; color: rgb(58, 60, 132); font-size: 10pt;">)</span></p></td><td style="width:66.91pt;height:26.97pt;padding:1.41pt 5.10pt 1.41pt 5.10pt;border-top:solid #3a3c84 1.98pt;border-left:solid #999999 1.41pt;border-bottom:solid #3a3c84 1.41pt;border-right:none;" valign="middle"><p class="0" style="text-align:center;mso-pagination:none;text-autospace:none;mso-padding-alt:0pt 0pt 0pt 0pt;"><span style="font-family: Verdana; color: rgb(58, 60, 132); font-size: 10pt;">학점계</span></p></td></tr><tr><td style="width:103.40pt;height:25.53pt;padding:1.41pt 5.10pt 1.4 ...
# $(document).ready(function() {
# });
#
# }-->1. 공학계열 교과과정 (2023학번 기준)
# 구분 : 전필
# 1학기 : 전공탐색세미나(1)
# 학점계 : 15
#
# 구분 : 교필(공통)
# 1학기 : 기업가정신(2), 영어커뮤니케이션 I(2), 인공지능소개(2)
# 2학기 : 교양글쓰기(2), 영어커뮤니케이션 II(2)
# 학점계 : 12
#
# 구분 : 교필(학문기초)
# 1학기 : 코딩입문(Python)(3), 미분적분학(3), 일반물리 I(2)
# 2학기 : 선형대수학(3), 컴퓨터프로그래밍(3), 일반물리 II(2)
# 학점계 : 12
#
# 구분 : 교필(공통)
# 1학기 : 꿈꾸는 인공지능(1), 세상을 바꾸는 SW(1)
# 학점계 : 2
#
# 구분 : 교필(학문기초)
# 1학기 : 항공우주학개론(2), 항공우주산업개론(2)
# 학점계 : 4
# ☞ 다운로드 : 학년도별 교양 교과과정표 (자료실 &gt; 교과과정표) 2. 대체인정과목
# 구분 : 교필 (학문기초)
# 공학계열 교과목 : 컴퓨터프로그래밍
# 희망학부(과) 2학년 진입시 대체인정과목 : 희망학부(과) 2학년 진입시 대체인정과목
# 비고 : 소프트
#
# 구분 : 교필 (학문기초)
# 공학계열 교과목 : 코딩입문 (Python)
# 희망학부(과) 2학년 진입시 대체인정과목 : 프로그래밍입문
# 비고 :
#
# 구분 : 교필 (학문기초)
# 공학계열 교과목 : 미분적분학, 선형대수학
# 희망학부(과) 2학년 진입시 대체인정과목 : 현대수학
# 비고 : 미분적분학과 선형대수학 모두 이수시 "현대수학" 대체 인정
#
# 구분 : 교필 (학문기초)
# 공학계열 교과목 : 컴퓨터프로그래밍
# 희망학부(과) 2학년 진입시 대체인정과목 : 코딩입문 (C/C++)
# 비고 :
#
# 구분 : 교필 (학문기초)
# 공학계열 교과목 : 미분적분학, 선형대수학
# 희망학부(과) 2학년 진입시 대체인정과목 : 현대수학
# 비고 : 미분적분학과 선형대수학 모두 이수시 "현대수학" 대체 인정
# <!--[data-hwpjson]{
# }-->  3. 1학년 수강신청 가능 학점  ① 학기당 최대 21학점 (성적우수자는 최대 21학점까지 수강신청 가능)  ② 일괄 수강신청 과목 학점      - 1학기 (전필, 교양필수) : 15학점         2학기 (교양필수) : 12학점      - 나머지 학점은 진입하고자 하는 학부(과)별 선수 과목 및 교양과목으로 수강신청 가능  ③ 1학년 수료 후에는 진입한 학부(과) 교과과정에 따라 수강 신청   4. 수강신청 변경  ① 일괄 수강신청으로 배정된 과목 이외의 모든 교과목 수강신청은 선착순제임  ② 수강제한 인원이 초과된 과목에 대해서는 수강신청 불가       (단, 해당 학년 필수교과목 등에 한하여 추가 수강신청 가능)  ③ 모든 교과목은 해당 학년/학기에 이수하는 것을 원칙으로 함 (교필/전필 등 필수 교과목)  ④ 수강신청 취소기간 : 학사 공지사항 참조   5. 성적우수장학생 선발 기준  ① 직전학기 12학점 이상 / 평점평균 3.5이상  ② 동점자 처리 기준       - 총 이수학점이 많은 자       - 누적평점이 높은 자       - 필수 이수학점이 많은자(전필, 교필)  ③ 위 조건은 1학년 공학계열 학생으로 한함  ④ 모든 장학금은 등록금 내에서만 수혜 가능   6. 전자출결시스템  ① 개설된 교과목 출석체크는 전자출결시스템으로 진행      - 모바일 학생증(KAU ID)앱 설치      - 학기 중 교과목 출결 체크 및 유고결석 신청 등 가능  ② 유고결석 : 학칙 시행세칙 제 14조의 2에 의거 직계존속 등 사망, 병역법에 의한 각종 징병소집 및 징병검사, 등교가 불가한 질병 등의 이유로 신청 가능 (관련 증빙 서류 첨부 필수)  ③ 수업 당일 진료확인서 등은 유고결석으로 처리 불가   7. 희망 학부(과) 신청  ① 공학계열 재학 중 2개학기 수료 후 희망 학부(과)로 진입이 가능하며, 이후 해당 학부(과) 운영내규에 따라 세부전공 배정, 교과목 수강 및 졸업요건 적용이 이루어짐     ② 각 학부(과) 전공배정시기
# 구분 : 공과대학
# 학부 : 항공우주 및 기계공학부
# 세부전공 : 항공우주공학
# 세부전공배정시기 : 2학년
# 학위 : 공학사
#
# 구분 : 공과대학
# 학부 : 항공우주 및 기계공학부
# 세부전공 : 항공기시스템공학
# 세부전공배정시기 : 2학년
# 학위 : 공학사
#
# 구분 : 공과대학
# 학부 : 항공우주 및 기계공학부
# 세부전공 : 기계공학
# 세부전공배정시기 : 2학년
# 학위 : 공학사
#
# 구분 : 공과대학
# 학부 : 항공전자정보공학부
# 세부전공 : 전자 및 항공전자공학
# 세부전공배정시기 : 3학년
# 학위 : 공학사
#
# 구분 : 공과대학
# 학부 : 항공전자정보공학부
# 세부전공 : 정보통신공학
# 세부전공배정시기 : 3학년
# 학위 : 공학사
#
# 구분 : 공과대학
# 학부 : 항공전자정보공학부
# 세부전공 : 스마트드론공학
# 세부전공배정시기 : -
# 학위 : 공학사
#
# 구분 : AI융합대학
# 학부 : 소프트웨어학과
# 세부전공 : 소프트웨어공학
# 세부전공배정시기 : -
# 학위 : 공학사
#
# 구분 : AI융합대학
# 학부 : 스마트드론공학과
# 세부전공 : 스마트드론공학
# 세부전공배정시기 : -
# 학위 : 공학사
#
# 구분 : AI융합대학
# 학부 : AI자율주행시스템공학과
# 세부전공 : AI자율주행시스템공학
# 세부전공배정시기 : -
# 학위 : 공학사
# <!--[data-hwpjson]{
# }--><!--[data-hwpjson]{
# }-->   8. 졸업요건<!--[data-hwpjson]{
# }--> 희망 학부(과) 진입 후 해당 학부(과) 운영내규에 따라 교과목 취득 및 졸업 가능<!--[data-hwpjson]{

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
