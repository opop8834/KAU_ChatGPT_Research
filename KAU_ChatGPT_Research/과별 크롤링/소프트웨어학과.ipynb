# %%
# html 코드 그대로 크롤링 할시 주석도 같이 추출됨

from bs4 import BeautifulSoup
import sys
import requests
import re
import pandas as pd
import csv
import os
import openai

f_name = "소프트웨어학과_data"
number_html = 6
url = """http://college.kau.ac.kr/web/pages/gc71348h.do
http://college.kau.ac.kr/web/pages/gc24226h.do
http://college.kau.ac.kr/web/pages/gc83710h.do
http://college.kau.ac.kr/web/pages/gc22527h.do
http://college.kau.ac.kr/web/pages/gc72769h.do
http://college.kau.ac.kr/web/pages/gc3553h.do
http://college.kau.ac.kr/web/pages/gc39611h.do
http://college.kau.ac.kr/web/pages/gc87373h.do
http://college.kau.ac.kr/web/pages/gc3009h.do
http://college.kau.ac.kr/web/pages/gc95911h.do
"""

openai.api_key ="API_KEY"

def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

def extract_tables(html_str):
    # 정규표현식 패턴 정의
    pattern = r'(<table.*?>.*?</table>)'
    # 정규표현식으로 <table>...</table> 부분 찾기
    tables = re.findall(pattern, html_str, re.DOTALL)  # re.DOTALL은 줄바꿈 문자도 포함해서 찾도록 합니다.
    return tables

def table_function(table_g):
    sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>대영역</th>
        <th>세부영역</th>
        <th colspan="2">학점</th>
    </tr>
    <tr>
        <td>필수교양</td>
        <td>
            국어<br>
            영어<br>
            소프트웨어<br>
            항공우주특성화
        </td>
        <td colspan="2">
            공과대학 13 학점<br>
            항경대학 12 학점
        </td>
    </tr>
    <tr>
        <td>전공기초교양</td>
        <td>전공기초</td>
        <td colspan="2">0 ~ 18학점, 각 학부(과)별 상이</td>
    </tr>
    <tr>
        <td>핵심교양</td>
        <td>
            1) 철학과 역사<br>
            2) 문학과 예술<br>
            3) 인간과 사회<br>
            4) 자연과 과학<br>
            5) 실용 및 글로벌
        </td>
        <td>9 학점 이상<br>학부(과)별 지정영역이수<br>(4-1 참조)</td>
        <td rowspan="2">12 학점<br>※ 1) ~ 5) 학부(과)별 지정 영역 중<br>3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수<br>※ 세부영역 중복, 대영역 미중복시 인정됨</td>
    </tr>
    <tr>
        <td>심화교양</td>
        <td>
            6) 철학과 역사<br>
            7) 문학과 예술<br>
            8) 인간과 사회<br>
            9) 자연과 과학<br>
            10) 실용 및 글로벌<br>
            11) 봉사와 리더십<br>
            12) 자기계발<br>
            13) 외국어(영어)
        </td>
        <td>자유이수</td>
    </tr>
    <tr>
        <th colspan="2">계</th>
        <th colspan="2">24 ~ 43 학점</th>
    </tr>
</tbody></table>
---------
답 : 
---------
대영역 : 필수교양
세부영역 : 국어, 영어, 소프트웨어, 항공우주특성화
학점 : 공과대학 13 학점, 항경대학 12 학점

대영역 : 전공기초교양
세부영역 : 전공기초
학점 : 0 ~ 18학점, 각 학부(과)별 상이

대영역 : 핵심교양
세부영역 : 
1) 철학과 역사
2) 문학과 예술
3) 인간과 사회
4) 자연과 과학
5) 실용 및 글로벌
학점 : 9 학점 이상, 학부(과)별 지정영역이수 (4-1 참조)
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

대영역 : 심화교양
세부영역 : 
6) 철학과 역사
7) 문학과 예술
8) 인간과 사회
9) 자연과 과학
10) 실용 및 글로벌
11) 봉사와 리더십
12) 자기계발
13) 외국어(영어)
학점 : 자유이수
비고 : 12 학점(1) ~ 5) 학부(과)별 지정 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수, 세부영역 중복, 대영역 미중복시 인정됨

계 : 24 ~ 43 학점
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-16k-0613",
      messages=[
      {"role": "system", "content": f'"{sys}"'},
    ], temperature =  0.001)
    answer = completion['choices'][0]['message']['content']
    if answer.endswith('"'):
        answer = answer[:-1]
        answer = answer
    return answer 

# 홈페이지 주소 가져오기
# url = "https://kau.ac.kr/web/pages/gc15707h.do"
url_split = split_sentences(url)
url_list = []

for i in range(len(url_split)):
    url_list.append(url_split[i].strip())
print(url_list)

for jj in range(len(url_list)):
#     if jj == 11:
#         f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
#         answer_db = csv.writer(f)
#         answer_db.writerow([str(jj), "", url_list[jj]])
#         f.close()
#         continue
    temp_url = url_list[jj]
    html = requests.get(temp_url)
    bs_html = BeautifulSoup(html.content, "html.parser")

    # print(bs_html) # 웹 페이지 출력
    bs_html = str(bs_html)
    split_text = split_sentences(bs_html)
    tp = 0
    tp_noise = 0
    tp_annotation = 0
    temp_list = []
    for i in range(len(split_text)):
        temp_text = split_text[i]
        if "<html lang" in temp_text and tp < number_html:
            tp += 1
        elif "<html lang" in temp_text and tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)
        elif tp == number_html and "</html>" in temp_text:
            break
        elif tp == number_html and "<!--" in temp_text and "-->" in temp_text:
            temp_text = re.sub(r'<!--.*?-->', '', temp_text)
            temp_list.append(temp_text)            
        elif tp == number_html and "<!--" in temp_text and "-->" not in temp_text:
            tp_annotation = 1
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" not in temp_text:
            continue
        elif tp == number_html and tp_annotation == 1 and "-->" in temp_text:
            tp_annotation = 0
            continue
        elif tp == number_html:
            temp_list.append(temp_text)
#             print(temp_text)

    print("%%%%%%%%%%%%%%%%%%%")
    
    # table 태그는 하나의 리스트 원소로 두기
    
    table_tp = 0
    table_temp_str = ""
    re_table_list = []
    for i in range(len(temp_list)):
        if "<table" in temp_list[i] and  "</table>" in temp_list[i] and table_tp == 0:  # 한 줄 table 일 때
            test_str = temp_list[i]
            tables = extract_tables(test_str)
            for table in tables:
                # 해당 table이 test_str에서 시작하는 위치 찾기
                start_index = test_str.find(table)
                # 해당 table의 내용을 출력하기 전까지의 test_str의 내용을 출력
                re_table_list.append(test_str[:start_index].strip())
                # 해당 table 출력
                re_table_list.append(table.strip())
                # 이미 출력된 부분을 test_str에서 제거
                test_str = test_str[start_index + len(table):]
                # 남은 test_str에서 내용 출력
            re_table_list.append(test_str.strip())
        elif "<table" in temp_list[i] and table_tp == 0:
            table_tp = 1
            table_temp_str = table_temp_str + temp_list[i] + "\n"            
        elif "</table>" not in temp_list[i] and table_tp == 1:
            table_temp_str = table_temp_str + temp_list[i] + "\n"
        elif "</table>" in temp_list[i] and table_tp == 1:
            table_tp = 0
            table_temp_str = table_temp_str + temp_list[i] + "\n"
            re_table_list.append(table_temp_str.strip())
            table_temp_str = ""
        else:
            re_table_list.append(temp_list[i])
    
    print(f"-------{jj}-------")
    print(len(re_table_list))
    print(re_table_list)
# #     # table 태그 임의로 변형 (미완성)
    
#     re_table_list2 = []
#     table_temp_str = ""
#     tr_tp = 0
#     for i in range(len(re_table_list)):
#         if "<table" in re_table_list[i]:
#             table_tag_context = split_sentences(re_table_list[i])
#             for j in range(len(table_tag_context):
#                 if "<tr>" not in table_tag_context[i]
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line + "\n"
#                 elif "<tr>" in table_tag_context[i]
#                     tr_tp = 1
#                     temp_line = re.sub('(<([^>]+)>)', '', table_tag_context[i])
#                     temp_line = temp_line.strip()    
#                     table_temp_str = table_temp_str + temp_line
#         else:
#             re_table_list2.append(re_table_list[i])

#  table 태그는 gpt에게 정리
    re_table_list2 = []               
    for i in range(len(re_table_list)):
        if "<table" in re_table_list[i]:
            table_g = re_table_list[i]
            err_count = 0
            try :
                answer = table_function(table_g)
            except Exception as e:
                err_count += 1
                print(err_count)
                if err_count >= 5:
                    print("예외가 연속으로 5번 발생했습니다. 프로그램을 종료합니다.")
                else:
                    print("예외가 발생했습니다. (%s)" % e)
                    answer = table_function(table_g)        
            re_table_list2.append(answer.strip())
        else:
            re_table_list2.append(re_table_list[i])
            
    previous_line = "#$%"
    temp_str = ""
    for i in range(len(re_table_list2)):
        temp_line = re.sub('(<([^>]+)>)', '', re_table_list2[i])
        temp_line = temp_line.strip()
        if previous_line == "" and temp_line == "":
            continue
        else:
            print(temp_line)
            temp_str = temp_str + temp_line + "\n"
        previous_line = temp_line
    temp_str = temp_str.strip()
    f = open(f'{f_name}.csv','a', newline='' , encoding="utf-8-sig")
    answer_db = csv.writer(f)
    answer_db.writerow([str(jj), temp_str, url_list[jj]])
    f.close()
# Out:
# ['http://college.kau.ac.kr/web/pages/gc71348h.do', 'http://college.kau.ac.kr/web/pages/gc24226h.do', 'http://college.kau.ac.kr/web/pages/gc83710h.do', 'http://college.kau.ac.kr/web/pages/gc22527h.do', 'http://college.kau.ac.kr/web/pages/gc72769h.do', 'http://college.kau.ac.kr/web/pages/gc3553h.do', 'http://college.kau.ac.kr/web/pages/gc39611h.do', 'http://college.kau.ac.kr/web/pages/gc87373h.do', 'http://college.kau.ac.kr/web/pages/gc3009h.do', 'http://college.kau.ac.kr/web/pages/gc95911h.do']
# %%%%%%%%%%%%%%%%%%%
# -------0-------
# 51
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<link href="https://fonts.googleapis.com/css2?family=Nanum+Pen+Script&amp;display=swap" rel="stylesheet"/>', '<style>', '.clearfixed::after{', 'display: block;', 'content: "";', 'clear:both;', '}', '.highlight{', '/*text-decoration: underline; */', 'font-size:20pt;', 'font-weight: bold;', 'color: #3c529b;', '}', '.font2{', 'font-size:30pt;', 'color: #3c529b;', "font-family: 'Nanum Pen Script', 'cursive';", '}', '</style>', '<div class="sub_tit">', '<h3>학과 소개</h3>', '</div>', '<div class="article_401">', '<div class="clearfixed">', '<span class="img" style="padding:10 10 10 10; height:90%; opacity: 1;">', '<img src="/conts_img/sw_www/introduce/학과소개_1.jpg"/>', '</span>', '</div>', '<div class="article_101">', '<span class="font2">소프트웨어로 세상을 잇(IT)다</span>', '<br/><br/>', '<p>', '한국항공대학교 소프트웨어학과는 미래 첨단 디지털 시대를 선도할 소프트웨어 인재를 양성하고, 세계 수준의 소프트웨어 분야 연구를 수행하여 국가 경쟁력을 높이기 위해 설립되었습니다.', '소프트웨어는 인간의 상상을 현실화하는 도구로서, 소프트웨어/IT 산업뿐만 아니라 현대 산업의 전 분야에 융합되어 발전을 이끄는 핵심 경쟁력입니다. <br/>', '이러한 시대적 요구에 맞춰, 본 학과는 프로그래밍 언어, 컴퓨터 시스템, 데이터베이스, 알고리즘, 인공지능, 영상처리, 보안, 데이터 분석 등 컴퓨터과학의 기초 이론부터 최신 핵심 기술까지를 포함하는 포괄적 교육과 심도있는 연구를 진행하고 있습니다. <br/>', '특히 빠르게 발전하는 컴퓨팅 기술에 능동적으로 대응할 수 있도록 실습을 강화한 실전형 강의 진행, 혁신 교수법 적용, 최신 기술을 반영하는 교과 개편, 연구실 환경 개선 등을 지속적으로 진행하고 있습니다. <br/>', '학생들의 현장 실무 능력 함양을 위한 현장 실습과 인턴쉽, 산학프로젝트 등 산업체 수요 밀착형 교육, 기술 창업을 꿈꾸는 학생들을 위한 교과 및 프로그램, 대학원 진학을 대비한 학부연구생 제도 등을 제공하여,', '학생들의 졸업 후 진로 선택을 돕는 한편, 글로벌 기업 및 해외 명문 대학과의 국제 교류 프로그램을 통해 학생들의 국제화 역량을 강화할 수 있는 기회를 제공하고 있습니다.', '</p>', '</div>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# .clearfixed::after{
# display: block;
# content: "";
# clear:both;
# }
# .highlight{
# /*text-decoration: underline; */
# font-size:20pt;
# font-weight: bold;
# color: #3c529b;
# }
# .font2{
# font-size:30pt;
# color: #3c529b;
# font-family: 'Nanum Pen Script', 'cursive';
# }
#
# 학과 소개
#
# 소프트웨어로 세상을 잇(IT)다
#
# 한국항공대학교 소프트웨어학과는 미래 첨단 디지털 시대를 선도할 소프트웨어 인재를 양성하고, 세계 수준의 소프트웨어 분야 연구를 수행하여 국가 경쟁력을 높이기 위해 설립되었습니다.
# 소프트웨어는 인간의 상상을 현실화하는 도구로서, 소프트웨어/IT 산업뿐만 아니라 현대 산업의 전 분야에 융합되어 발전을 이끄는 핵심 경쟁력입니다.
# 이러한 시대적 요구에 맞춰, 본 학과는 프로그래밍 언어, 컴퓨터 시스템, 데이터베이스, 알고리즘, 인공지능, 영상처리, 보안, 데이터 분석 등 컴퓨터과학의 기초 이론부터 최신 핵심 기술까지를 포함하는 포괄적 교육과 심도있는 연구를 진행하고 있습니다.
# 특히 빠르게 발전하는 컴퓨팅 기술에 능동적으로 대응할 수 있도록 실습을 강화한 실전형 강의 진행, 혁신 교수법 적용, 최신 기술을 반영하는 교과 개편, 연구실 환경 개선 등을 지속적으로 진행하고 있습니다.
# 학생들의 현장 실무 능력 함양을 위한 현장 실습과 인턴쉽, 산학프로젝트 등 산업체 수요 밀착형 교육, 기술 창업을 꿈꾸는 학생들을 위한 교과 및 프로그램, 대학원 진학을 대비한 학부연구생 제도 등을 제공하여,
# 학생들의 졸업 후 진로 선택을 돕는 한편, 글로벌 기업 및 해외 명문 대학과의 국제 교류 프로그램을 통해 학생들의 국제화 역량을 강화할 수 있는 기회를 제공하고 있습니다.
#
# %%%%%%%%%%%%%%%%%%%
# -------1-------
# 41
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>졸업 후 진로</h3>', '</div>', '<div class="article_303">', '<img src="/conts_img/sw_www/introduce/진로분야.jpg" style="width:auto;"/><br/><br/>', '<br/><br/>', '<h4>IT/SW 분야</h4>', '<h5>관련 직업 : 시스템소프트웨어개발자, 네트워크엔지니어, 데이터베이스개발자, 정보보호전문가, 인공지능전문가, 사물인터넷전문가, 빅데이터전문가, 클라우드시스템엔지니어, 모바일애플리케이션개발자 등</h5>', '<h5>기업/기관 : 삼성 SDS, LG CNS, KT, 삼성전자, SK인포섹, 네이버, 카카오, 넥슨, 엔씨소프트 등</h5>', '<br/>', '<h4>전자/반도체 분야</h4>', '<h5>관련 직업 : 전자부품 연구원, 컴퓨터하드웨어 기술자 및 연구원, 시스템소프트웨어개발자, 반도체공학기술자 등</h5>', '<h5>기업/기관 : SK 하이닉스, 삼성전자, 인텔, 퀄컴 등</h5>', '<br/>', '<h4>경영/금융 분야</h4>', '<h5>관련 직업 : 금융 ICT개발자, 블록체인전문가, 빅데이터전문가, 정보보호전문가 등</h5>', '<h5>기업/기관 : 국민은행, 우리은행, NH농협은행, 하나은행, 신한은행, 한국씨티은행 등</h5>', '<br/>', '<h4>게임/디지털 컨텐츠 분야</h4>', '<h5>관련 직업 : 게임 개발자, 게임 기획자, 가상현실전문가, 홀로그램전문가, 모바일컨텐츠개발자 등</h5>', '<h5>기업/기관 : 넥슨, 넷마블, 엔씨소프트, 컴투스, 스마일게이트 등</h5>', '<br/>', '<h4>항공/드론/국방 분야</h4>', '<h5>관련 직업 : 항공관제 시스템 엔지니어, 항공물류시스템 엔지니어, UAM 시스템 엔지니어, 항공기 시스템 개발자, 무인 항공기 시스템 개발자, 군장교 등</h5>', '<h5>기업/기관 : 한국항공우주산업 (KAI), 한국항공우주연구원 (KARI), 국방과학연구소, 인천공항공사, 한국공항공사, 대한항공, 한화, 자이언트 드론 등</h5>', '<br/>', '<h4>정부/공공 분야</h4>', '<h5>관련 직업 : 연구원, 전산직 공무원, 공기업 전산/IT 기술지원직 등</h5>', '<h5>기업/기관 : 과학기술정보통신부 등 정부 및 지방자치단체 공무원, 한국정보화진흥원, 한국인터넷진흥원 등 공공기관</h5>', '<br/>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 졸업 후 진로
#
# IT/SW 분야
# 관련 직업 : 시스템소프트웨어개발자, 네트워크엔지니어, 데이터베이스개발자, 정보보호전문가, 인공지능전문가, 사물인터넷전문가, 빅데이터전문가, 클라우드시스템엔지니어, 모바일애플리케이션개발자 등
# 기업/기관 : 삼성 SDS, LG CNS, KT, 삼성전자, SK인포섹, 네이버, 카카오, 넥슨, 엔씨소프트 등
#
# 전자/반도체 분야
# 관련 직업 : 전자부품 연구원, 컴퓨터하드웨어 기술자 및 연구원, 시스템소프트웨어개발자, 반도체공학기술자 등
# 기업/기관 : SK 하이닉스, 삼성전자, 인텔, 퀄컴 등
#
# 경영/금융 분야
# 관련 직업 : 금융 ICT개발자, 블록체인전문가, 빅데이터전문가, 정보보호전문가 등
# 기업/기관 : 국민은행, 우리은행, NH농협은행, 하나은행, 신한은행, 한국씨티은행 등
#
# 게임/디지털 컨텐츠 분야
# 관련 직업 : 게임 개발자, 게임 기획자, 가상현실전문가, 홀로그램전문가, 모바일컨텐츠개발자 등
# 기업/기관 : 넥슨, 넷마블, 엔씨소프트, 컴투스, 스마일게이트 등
#
# 항공/드론/국방 분야
# 관련 직업 : 항공관제 시스템 엔지니어, 항공물류시스템 엔지니어, UAM 시스템 엔지니어, 항공기 시스템 개발자, 무인 항공기 시스템 개발자, 군장교 등
# 기업/기관 : 한국항공우주산업 (KAI), 한국항공우주연구원 (KARI), 국방과학연구소, 인천공항공사, 한국공항공사, 대한항공, 한화, 자이언트 드론 등
#
# 정부/공공 분야
# 관련 직업 : 연구원, 전산직 공무원, 공기업 전산/IT 기술지원직 등
# 기업/기관 : 과학기술정보통신부 등 정부 및 지방자치단체 공무원, 한국정보화진흥원, 한국인터넷진흥원 등 공공기관
#
# %%%%%%%%%%%%%%%%%%%
# -------2-------
# 224
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교수진<br type="_moz"/>', '</h3>', '</div>', '<h4>연구실 홈페이지 바로가기 -&gt;\xa0<a href="http://research.kau.ac.kr/">http://research.kau.ac.kr/<br/><br/></a> </h4>', '<ul class="prs_list"><li><span class="portrait"><img src="/conts_img/sw_www/introduce/prof/김선옥 교수.jpg"/>', '</span>', '', '<h4><span>김선옥 교수</span></h4>', '', '', '<ul class="prs_info">', '<li>컴퓨터비전, 인공지능 분야</li>', '<li></li>', '', '<li>전자관 406호<br/>', '</li>', '<li>(02)300-0262</li>', '', '', '<li>sunok.kim@kau.ac.kr<br/>', '</li>', '', '</ul>', '', '</li>', '', '', '<li>', '', '<span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/김철기 교수.jpg"/> ', '</span>', '', '<h4><span>김철기 교수</span></h4>', '', '', '<ul class="prs_info">', '<li>안전우선 시스템설계 및 검증 분야</li>', '<li>안전우선 SW 연구실</li>', '', '<li>전자관 408호<br/>', '</li>', '<li>(02)300-0123</li>', '', '', '<li>cheolgi@kau.ac.kr<br/>', '</li>', '', '</ul>', '', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/길현영 교수.jpg"/> </span>', '<h4><span style="font-size: 11pt;">길현영 교수 (학과장)</span></h4>', '<ul class="prs_info">', '<li><br/>', '</li>', '<li>서비스 컴퓨팅 분야</li>', '<li>Web Engineering Lab</li>', '<li>전자관 407호<br/>', '</li>', '<li>(02)300-0426</li>', '<li>hykil@kau.ac.kr</li>', '</ul>', '</li>', '', '<li>', '', '<p><br/>', '</p><ul class="prs_info">', '', '</ul>', '', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/박종서 교수.jpg"/> </span>', '<h4><span>박종서 교수</span></h4>', '<ul class="prs_info">', '<li>임베디드시스템/정보보안 분야</li>', '<li>네트워크 보안 연구실</li>', '<li>전자관 412호<br/>', '</li>', '<li>(02)300-0187</li>', '<li>jspark@kau.ac.kr</li>', '</ul>', '</li>', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/송동호 교수.jpg"/> </span>', '<h4><span>송동호 교수</span></h4>', '<ul class="prs_info">', '<li>운영체제/멀티미디어 시스템 분야</li>', '<li>Airborne Software Lab</li>', '<li>전자관 414호<br/>', '</li>', '<li>(02)300-0186</li>', '<li>dhsong@kau.ac.kr</li>', '</ul>', '</li>', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/온승엽 교수.jpg"/> </span>', '<h4><span>온승엽 교수</span></h4>', '<ul class="prs_info">', '<li>컴퓨터그래픽스/비전 분야</li>', '<li>스마트비젼 연구실</li>', '<li>전자관 410호<br/>', '</li>', '<li>(02)300-0123</li>', '<li>syohn@kau.ac.kr<br/>', '</li>', '</ul>', '</li>', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/이긍해 교수.jpg"/> </span>', '<h4><span>이긍해 교수 (명예 교수)</span></h4>', '<ul class="prs_info">', '<li>프로그래밍언어/인터넷 응용 분야<br/></li></ul>', '<ul class="prs_info">', '</ul><p><br/></p>', '</li>', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/이인복 교수.jpg"/> </span>', '<h4><span>이인복 교수</span></h4>', '<ul class="prs_info">', '<li>알고리즘 분야</li>', '<li>알고리즘 연구실</li>', '<li>전자관 409호<br/>', '</li>', '<li>(02)300-0412</li>', '<li>inboklee@kau.ac.kr</li>', '</ul>', '</li>', '', '<li>', '', '<span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/정재훈 교수.jpg"/></span>', '', '<h4><span>정재훈 교수</span></h4>', '', '', '<ul class="prs_info">', '<li>인공지능의 원리/ 양자 컴퓨팅/ 양자 인공지능 분야</li>', '<li></li>', '', '<li>전자관 404호<br/>', '</li>', '<li>(02)300-0263</li>', '', '', '<li>jhjung@kau.ac.kr<br/>', '</li>', '', '</ul>', '', '</li>', '', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/지승도 교수.jpg"/> </span>', '<h4><span>지승도 교수</span></h4>', '<ul class="prs_info">', '<li>시뮬레이션/지능시스템 분야</li>', '<li>지능시스템 연구실</li>', '<li>전자관 415호<br/>', '</li>', '<li>(02)300-0184</li>', '<li>sdchi@kau.ac.kr</li>', '</ul>', '</li>', '<li> <span class="portrait"> <img src="/conts_img/sw_www/introduce/prof/최영식 교수.jpg"/> </span>', '<h4><span>최영식 교수 (AI융합대학장)</span></h4>', '<ul class="prs_info">', '<li>퍼지이론, 정보검색 분야</li>', '<li>빅테이터 연구실</li>', '<li>전자관 413호<br/>', '</li>', '<li>(02)300-0189</li>', '<li>choimail@kau.ac.kr</li>', '</ul>', '</li>' ...
#
# $(document).ready(function() {
# });
#
# 교수진
#
# 연구실 홈페이지 바로가기 -&gt; http://research.kau.ac.kr/
#
# 김선옥 교수
#
# 컴퓨터비전, 인공지능 분야
#
# 전자관 406호
#
# (02)300-0262
#
# sunok.kim@kau.ac.kr
#
# 김철기 교수
#
# 안전우선 시스템설계 및 검증 분야
# 안전우선 SW 연구실
#
# 전자관 408호
#
# (02)300-0123
#
# cheolgi@kau.ac.kr
#
# 길현영 교수 (학과장)
#
# 서비스 컴퓨팅 분야
# Web Engineering Lab
# 전자관 407호
#
# (02)300-0426
# hykil@kau.ac.kr
#
# 박종서 교수
#
# 임베디드시스템/정보보안 분야
# 네트워크 보안 연구실
# 전자관 412호
#
# (02)300-0187
# jspark@kau.ac.kr
#
# 송동호 교수
#
# 운영체제/멀티미디어 시스템 분야
# Airborne Software Lab
# 전자관 414호
#
# (02)300-0186
# dhsong@kau.ac.kr
#
# 온승엽 교수
#
# 컴퓨터그래픽스/비전 분야
# 스마트비젼 연구실
# 전자관 410호
#
# (02)300-0123
# syohn@kau.ac.kr
#
# 이긍해 교수 (명예 교수)
#
# 프로그래밍언어/인터넷 응용 분야
#
# 이인복 교수
#
# 알고리즘 분야
# 알고리즘 연구실
# 전자관 409호
#
# (02)300-0412
# inboklee@kau.ac.kr
#
# 정재훈 교수
#
# 인공지능의 원리/ 양자 컴퓨팅/ 양자 인공지능 분야
#
# 전자관 404호
#
# (02)300-0263
#
# jhjung@kau.ac.kr
#
# 지승도 교수
#
# 시뮬레이션/지능시스템 분야
# 지능시스템 연구실
# 전자관 415호
#
# (02)300-0184
# sdchi@kau.ac.kr
#
# 최영식 교수 (AI융합대학장)
#
# 퍼지이론, 정보검색 분야
# 빅테이터 연구실
# 전자관 413호
#
# (02)300-0189
# choimail@kau.ac.kr
#
# 최차봉 교수
#
# Embedded SW / IoT 분야
# 산학협력 중점교수
# 전자관 403호
#
# (02)300-0182
# gen1223@kau.ac.kr
#
# 황수찬 교수
#
# 데이터베이스 분야
# 데이타베이스 연구실
# 전자관 411호
#
# (02)300-0183
# schwang@kau.ac.kr
#
# 김형래 교수
#
# 클라우드 컴퓨팅, 기업경영, 창업 및 진로 멘토링
# 전자관 402호
# (02)300-0185
# hasla0110@kau.ac.kr
#
# 엄태훈 교수
#
# 소프트웨어 정의 네트워킹, 보안 분석, 네트워크 보안
# 전자관 417호
# (02)300-0265
# th.eom@kau.ac.kr
#
# %%%%%%%%%%%%%%%%%%%
# -------3-------
# 31
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>행정실</h3>', '</div>', '<ul class="prs_list">', '<li>', '<span class="portrait">', '<img src="/conts_img/sw_www/introduce/증명사진_김윤애.jpg"/>', '</span>', '<h4>김윤애</h4>', '<ul class="prs_info">', '<li>담당업무 : 학과 업무 총괄</li>', '<li>전자관 416호</li>', '<li>(02)300-0180</li>', '<li>yakim@kau.ac.kr</li>', '</ul>', '</li>', '</ul>', '<br/>', '<br/>', '<br/>', '<br/>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 행정실
#
# 김윤애
#
# 담당업무 : 학과 업무 총괄
# 전자관 416호
# (02)300-0180
# yakim@kau.ac.kr
#
# %%%%%%%%%%%%%%%%%%%
# -------4-------
# 16
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교육 목표</h3>', '</div>', '<div class="article_101" style="width: auto;">', '<img src="/conts_img/sw_www/introduce/교육목표2.jpg"/>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 교육 목표
# %%%%%%%%%%%%%%%%%%%
# -------5-------
# 35
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교육 과정</h3>', '</div>', '<ul class="menu_tab menu_tab2">', '<li>', '<a class="selected" href="#panel_01">교과 과정</a>', '</li>', '<li>', '<a href="#panel_02">교과목 체계도</a>', '</li>', '</ul>', '<ul class="panel">', '<li id="panel_01">', '<div class="article_303">', '<div class="scroller">', '<table class="table_01">\n<tbody>\n<tr>\n<th colspan="2" rowspan="2">이수구분</th>\n<th colspan="4" rowspan="2">교과목명</th>\n<th rowspan="2">학점</th>\n<th>시수</th>\n<th colspan="2">1학년</th>\n<th colspan="2">2학년</th>\n<th colspan="2">3학년</th>\n<th colspan="2">4학년</th>\n<th colspan="2">전공분류<br/>기본/심화</th>\n<th colspan="3" rowspan="2">비고</th>\n</tr>\n<tr>\n<th>총</th>\n<th>1학기</th>\n<th>2학기</th>\n<th>1학기</th>\n<th>2학기</th>\n<th>1학기</th>\n<th>2학기</th>\n<th>1학기</th>\n<th>2학기</th>\n<th colspan="2"></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">KAU SPACE 인성과진로</th>\n<th>1</th>\n<th>1</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3">2020학번부터 적용</th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">기업가정신</th>\n<th>2</th>\n<th>2</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3">2021학번부터 적용</th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">영어커뮤니케이션 Ⅰ</th>\n<th>2</th>\n<th>2</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3"><br/></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">코딩입문</th>\n<th>3</th>\n<th>4</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3"><br/></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">인공지능소개</th>\n<th>2</th>\n<th>2</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"><br/></th>\n<th colspan="3">2021학번부터 적용<br/></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">항공우주산업개론</th>\n<th>2</th>\n<th>2</th>\n<th>O</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3">~2020학번까지<br/>/<br/>2023학번부터<br/>교양필수</th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">항공우주학개론</th>\n<th>2</th>\n<th>2</th>\n<th>O</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3">2020학번만<br/>교양선택</th>\n</tr>\n<tr>\n<th colspan="2">전공필수</th>\n<th colspan="4">이산수학</th>\n<th>3</th>\n<th>3</th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2">기본</th>\n<th colspan="3"></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">교양글쓰기</th>\n<th>2</th>\n<th>2</th>\n<th></th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3"></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">영어커뮤니케이션Ⅱ</th>\n<th>2</th>\n<th>2</th>\n<th></th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3"></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">현대수학</th>\n<th>3</th>\n<th>3</th>\n<th></th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n<th colspan="3" rowspan="2">2021학번부터<br/>적용</th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">History of Technology</th>\n<th>3</th>\n<th>3</th>\n<th></th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th colspan="2"></th>\n</tr>\n<tr>\n<th colspan="2">교양필수</th>\n<th colspan="4">미분적분학</th>\n<th>3</th>\n<th>3</th>\n<th></th>\n<th>O</th>\n<th></th>\n<th></th>\n<th></th>\n<th></th>\n<th></ ...
# $(document).ready(function() {
# });
#
# 교육 과정
#
# 교과 과정
#
# 교과목 체계도
#
# 이수구분 : 교양필수
# 교과목명 : KAU SPACE 인성과진로
# 학점 : 1
# 시수 : 1
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : 2020학번부터 적용
#
# 이수구분 : 교양필수
# 교과목명 : 기업가정신
# 학점 : 2
# 시수 : 2
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : 2021학번부터 적용
#
# 이수구분 : 교양필수
# 교과목명 : 영어커뮤니케이션 Ⅰ
# 학점 : 2
# 시수 : 2
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 코딩입문
# 학점 : 3
# 시수 : 4
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 인공지능소개
# 학점 : 2
# 시수 : 2
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : 2021학번부터 적용
#
# 이수구분 : 교양필수
# 교과목명 : 항공우주산업개론
# 학점 : 2
# 시수 : 2
# 1학년 : O
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : ~2020학번까지 / 2023학번부터 교양필수
#
# 이수구분 : 교양필수
# 교과목명 : 항공우주학개론
# 학점 : 2
# 시수 : 2
# 1학년 : O
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : 2020학번만 교양선택
#
# 이수구분 : 전공필수
# 교과목명 : 이산수학
# 학점 : 3
# 시수 : 3
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 교양글쓰기
# 학점 : 2
# 시수 : 2
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 영어커뮤니케이션Ⅱ
# 학점 : 2
# 시수 : 2
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 현대수학
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : 2021학번부터 적용
#
# 이수구분 : 교양필수
# 교과목명 : History of Technology
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 미분적분학
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : ~2020학번까지 교양필수
#
# 이수구분 : 교양필수
# 교과목명 : 선형대수학
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 교양필수
# 교과목명 : 꿈꾸는 인공지능
# 학점 : 1
# 시수 : 1
# 1학년 : O (동계)
# 2학년 : O (하계)
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 : 2022학번부터 적용
#
# 이수구분 : 교양필수
# 교과목명 : 미래를 만드는 SW
# 학점 : 1
# 시수 : 1
# 1학년 : O (동계)
# 2학년 : O (하계)
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 :
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 프로그래밍입문
# 학점 : 3
# 시수 : 4
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 확률통계론
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 자료구조
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : SW산업과커리어전략
# 학점 : 1
# 시수 : 1
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 디지털논리
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 시스템프로그래밍
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : AI프로그래밍
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : IT and Software English
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 오픈소스SW입문
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 : O
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 객체지향프로그래밍
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : AI입문
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 컴퓨터구조론
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 알고리즘해석및설계
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 임베디드 SW 입문
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : Adventure Design
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 : O
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 산학프로젝트
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 컴퓨터운영체제및실습
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 컴퓨터네트워크
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 문제해결기법
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 프로그래밍언어와컴파일러
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : IoT
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 데이터사이언스기초
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 수치해석
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 : Codeshare (항전정)
#
# 이수구분 : 전공선택
# 교과목명 : TA인턴쉽 I
# 학점 : 2
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : ICT학점이수인턴제
# 학점 : 12
# 시수 : 24
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 소프트장기현장실습
# 학점 : 15
# 시수 : 30
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 소프트단기현장실습1
# 학점 : 3
# 시수 : 6
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 : 계절학기
#
# 이수구분 : 전공선택
# 교과목명 : 소프트단기현장실습2
# 학점 : 3
# 시수 : 6
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 : 계절학기
#
# 이수구분 : 전공선택
# 교과목명 : 경영정보관리
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 : Codeshare (경영학부)
#
# 이수구분 : 전공선택
# 교과목명 : 소프트웨어공학
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 딥러닝
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 딥러닝응용
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 데이터베이스기초
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 정보보호
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 데이터사이언스응용
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 웹SW스튜디오및재능기부
# 학점 : 3
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : TA인턴쉽 II
# 학점 : 2
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 종합설계프로젝트 I
# 학점 : 3
# 시수 : 3
# 1학년 : O
# 2학년 :
# 3학년 :
# 4학년 :
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : 창업종합설계 I
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공필수
# 교과목명 : AI융합 Capstone Design  I
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : TA인턴쉽 III
# 학점 : 2
# 시수 : 4
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 블록체인기술
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 프로젝트 X 1
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 프로젝트 X 1-1
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 프로젝트 X 2
# 학점 : 6
# 시수 : 6
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 프로젝트 X 3
# 학점 : 9
# 시수 : 9
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 컴퓨터비전
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 영상처리
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 : Codeshare (항전정)
#
# 이수구분 : 전공선택
# 교과목명 : 양자 컴퓨터 개론
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 심화
# 비고 :
#
# 이수구분 : 전공선택
# 교과목명 : 프론트엔드 프로그래밍
# 학점 : 3
# 시수 : 3
# 1학년 :
# 2학년 :
# 3학년 :
# 4학년 : O
# 전공분류 기본/심화 : 기본
# 비고 :
#
# %%%%%%%%%%%%%%%%%%%
# -------6-------
# 15
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit"><h3><span style="font-family: 돋움, Dotum;">교과목 안내</span></h3></div><div class="terms"><div class="chpt"><h4></h4><div class="sctn"><div class="article_303"><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">이산수학 (Discrete Mathematics)</span></h5><p><span style="font-family: 굴림체,GulimChe;">컴퓨터공학의 기초가 되는 수학적 기본 지식을 익히고, 이산적 모델링을 할 수 있는 능력을 갖춘다. 구체적으로는 논리, 증명, 집합, 함수, 정수, 수학적 귀납법, 추론, 확률, 관계, 그래프, 트리, 부울 대수, 계산 모델링을 배운다.</span></p><div><br/></div></div><div class="article_303"><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">프로그래밍 입문 (Intoduction to Computer Programming)\xa0</span></h5><p><span style="font-family: 굴림체,GulimChe;">프로그래밍 입문 교과에서는 ‘컴퓨팅적사고와 문제해결’ 교과에서 배운 개념을 바탕으로 학생들에게 본격적인 프로그래밍을 교육한다. C와 같은 절차적 언어를 기반으로, 문제를 분석하여 프로그램으로 구현하는 방법을 강의한다. 첫 프로그래밍 교과에서 공부한 프로그래밍 개념을 심화시켜 프로그래밍 수준을 한 단계 상승시킬 수 있도록 하는 것이 목표이다.</span></p><div><br/></div></div><div class="article_303"><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">확률통계론 ( Probability and Statistics )</span><br/></h5><p><span style="font-family: 굴림체,GulimChe;">인공지능, 머신러닝 이론에 토대가 되는 기초 수학, 즉, 선형대수, 미적분, 확률과통계를 핵심 주제별로 학습하고, 파이썬 프로그래밍을 통하여 이러한 수학적 개념이 인공지능에 어떻게 활용되는지 학습한다.</span></p><div><br/></div></div><div class="article_303"><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">디지털논리 (Digital logic Design)</span><br/></h5><p><span style="font-family: 굴림체,GulimChe;">디지털 논리회로는 디지털 시스템의 구성 및 동작원리와 논리회로의 분석 및 설계 방법에 대한 기본지식을 다룬다. 디지털 시스템을 구성하는 이진논리의 기본 개념을 파악하고, 부울함수의 간소화 방법과 부울함수의 구현방법을 통해 조합논리회로와 순차논리회로의 분석과정 및 설계과정을 수행한다.</span></p><div><br/></div></div><div class="article_303"><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">자료구조 (Data Structure)</span><br/></h5><p><span style="font-family: 굴림체,GulimChe;">C++ 프로그래밍 언어와 함께 효율적인 알고리즘과 자료구조의 설계 및 분석에 대해 학습한다. 배열, 연결리스트, 스택, 큐, 그래프 등의 기본적인 자료구조와 관련된 알고리즘을 습득한다.</span></p><div><br/></div></div><div class="article_303"><div><strong><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">임베디드 SW 입문 (Introduction to Embedded SW)</span><br/></strong></div></div><div class="article_303"><p><span style="font-family: 굴림체,GulimChe;">제한된 환경에서 긴 시간 별도의 관리 없이 운용되는 임베디드 SW가 가지는 특징을 이해하고, 이를 위한 프로그래밍을 할 수 있다. 센서 등 외부장치를 이용한 정보를 수집하고 이해할 수 있다. 임베디드 시스템에 필수적인 개발환경을 이해하고 사용한다.</span><br/></p><div><br/></div></div><div class="article_303"><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">AI 프로그래밍 (</span><span style="font-family: 굴림체,GulimChe; font-size: 18pt;">AI Programming)</span><br/></h5><p class="0" style="line-height: 175%; mso-pagination: none; mso-padding-alt: 0pt 0pt 0pt 0pt;"><span style="font-family: 굴림체,GulimChe;">머신러닝 기반의 소프트웨어의 구조와 특징을 소개하고 이를 구현하기 위한 프로그래밍 도구들을 익히고 실습함으로써</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체,GulimChe;">, </span><span style="font-family: 굴림체,GulimChe;">머신러닝</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체,GulimChe;">, </span><span style="font-family: 굴림체,GulimChe;">딥러닝 응용</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체,GulimChe;">, </span><span style="font-family: 굴림체,GulimChe;">컴퓨터비전</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체,GulimChe;">, </span><span style="font-family: 굴림체,GulimChe;">데이터 사이언스 등을 학습하기 위한 프로그래밍 기초를 쌓는다</span><span lang="EN-US" style="letter-spacing: 0pt; font-family: 굴림체,GulimChe;">.<br/><br/></span></p><div><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">AI입문 (Artificial Intelligence: The Basics)</span><br/></h5><p><span style="font-family: 굴림체,GulimChe;">미래 기술의 핵심으로 떠오르는 인공지능의 주요 이론들과 기술적 발전 동향 그리고 사회적 파급효과를 이해한다. 이를 통해 상상하는 것이 곧 현실이 된다는 IT적 상상력과 융합적 사고능력을 함양한다. 또한 인공지능시대의 도래에 선제적으로 대응할 미래 통찰력을 기른다.</span><br/><br/></p><h5><span style="font-family: 굴림체,GulimChe; font-size: 21.33px;">객체지향프로그래밍 (Object-Oriented Programm ...
# $(document).ready(function() {
# });
#
# 교과목 안내이산수학 (Discrete Mathematics)컴퓨터공학의 기초가 되는 수학적 기본 지식을 익히고, 이산적 모델링을 할 수 있는 능력을 갖춘다. 구체적으로는 논리, 증명, 집합, 함수, 정수, 수학적 귀납법, 추론, 확률, 관계, 그래프, 트리, 부울 대수, 계산 모델링을 배운다.프로그래밍 입문 (Intoduction to Computer Programming) 프로그래밍 입문 교과에서는 ‘컴퓨팅적사고와 문제해결’ 교과에서 배운 개념을 바탕으로 학생들에게 본격적인 프로그래밍을 교육한다. C와 같은 절차적 언어를 기반으로, 문제를 분석하여 프로그램으로 구현하는 방법을 강의한다. 첫 프로그래밍 교과에서 공부한 프로그래밍 개념을 심화시켜 프로그래밍 수준을 한 단계 상승시킬 수 있도록 하는 것이 목표이다.확률통계론 ( Probability and Statistics )인공지능, 머신러닝 이론에 토대가 되는 기초 수학, 즉, 선형대수, 미적분, 확률과통계를 핵심 주제별로 학습하고, 파이썬 프로그래밍을 통하여 이러한 수학적 개념이 인공지능에 어떻게 활용되는지 학습한다.디지털논리 (Digital logic Design)디지털 논리회로는 디지털 시스템의 구성 및 동작원리와 논리회로의 분석 및 설계 방법에 대한 기본지식을 다룬다. 디지털 시스템을 구성하는 이진논리의 기본 개념을 파악하고, 부울함수의 간소화 방법과 부울함수의 구현방법을 통해 조합논리회로와 순차논리회로의 분석과정 및 설계과정을 수행한다.자료구조 (Data Structure)C++ 프로그래밍 언어와 함께 효율적인 알고리즘과 자료구조의 설계 및 분석에 대해 학습한다. 배열, 연결리스트, 스택, 큐, 그래프 등의 기본적인 자료구조와 관련된 알고리즘을 습득한다.임베디드 SW 입문 (Introduction to Embedded SW)제한된 환경에서 긴 시간 별도의 관리 없이 운용되는 임베디드 SW가 가지는 특징을 이해하고, 이를 위한 프로그래밍을 할 수 있다. 센서 등 외부장치를 이용한 정보를 수집하고 이해할 수 있다. 임베디드 시스템에 필수적인 개발환경을 이해하고 사용한다.AI 프로그래밍 (AI Programming)머신러닝 기반의 소프트웨어의 구조와 특징을 소개하고 이를 구현하기 위한 프로그래밍 도구들을 익히고 실습함으로써, 머신러닝, 딥러닝 응용, 컴퓨터비전, 데이터 사이언스 등을 학습하기 위한 프로그래밍 기초를 쌓는다.AI입문 (Artificial Intelligence: The Basics)미래 기술의 핵심으로 떠오르는 인공지능의 주요 이론들과 기술적 발전 동향 그리고 사회적 파급효과를 이해한다. 이를 통해 상상하는 것이 곧 현실이 된다는 IT적 상상력과 융합적 사고능력을 함양한다. 또한 인공지능시대의 도래에 선제적으로 대응할 미래 통찰력을 기른다.객체지향프로그래밍 (Object-Oriented Programming)Kotlin 언어를 기반으로 객체지향 프로그래밍에 대하여 공부한다. Object, Class, Inheritance, Polymorphism, Late Binding 객체지향 모델링 등에 대하여 배우고 이를 이용한 모바일 프로그래밍의 기초를 학습한다.시스템프로그래밍 (System Programming)어셈블리어 프로그래밍,시스템구조,어셈블러,로더,매크로 및 운영체제의 구조에 대해 강의하고 이러한 소프트웨어의 제작을 위한 프로그래밍 기법을 학습한다. 또한 프로젝트를 통해 직접 이러한 소프트웨어의 개념을 정리하고 익혀 실제로 쓰이는 지식을 습득한다.컴퓨터네트워크 (Computer Networks)컴퓨터간의 망구성 이론 및 종류를 이해하고 ISO/OSI 모델에 관하여 각 계층별로 상세하게 설명한다. 그리고 TCP/IP에 관하여 설명을 하며 이를 UNIX시스템 상에서 응용프로그램들을 Term Project 를 통하여 실습하게 된다. 컴퓨터구조론 (Computer System Architectures)이 강의는 현대 컴퓨팅 시스템 구조를 설계하기 위한 기본 개념들을 소개한다. 컴퓨터 시스템의 구성을 이해하기 위하여 필요한 명령어집합구조, 연산장치, 메모리 장치, 입출력장치, 제어장치 등의 역할과 동작원리를 이해하고, 설계시 고려해야 될 사항을 배운다. 더불어 MIPS 프로그래밍을 통해 컴퓨터의 동작 원리를 터득한다.알고리즘해석및설계 (Analysis and Design of Algorithms)전자계산에 대한 알고리즘에 체계적인 구조와 분석 방법, 연산의 모델, 복잡도, 하한계, 축소성, P 및 NP Complete문제, Sets 및 Strings Graph 등을 이용한 탐색 등을 학습한다.Adventure Design공학설계 절차에 따라 드론, AI/SW기술 기반 서비스 등을 디자인하고 설계하는 팀 프로젝트형 수업을 진행하며, 이를 통해 항공/기계, 전자, 소프트웨어 등 다양한 분야에 대한 융합적 역량을 기른다. 드론, AI/SW 서비스 등과 연관된 개방형 문제에 대한 해결능력을 함양하기 위한 자기 주도형 프로젝트를 수행함으로써 창의적 디자인/설계의 개념과 방법론, 팀 조직과 협업 등을 학습한다IT and Software EnglishThis course is designed to help software and IT focused students to understand, discuss, and present various software and IT related topics through English at an international level. Formal language used in writing and presentations, such as email inquiries and technology demonstrations, will be introduced, analyzed, and then done in turn by students. In addition, casual settings with discussion of software problems and solutions in online communities will also be covered. Students will be given multiple opportunities throughout the semester to use and improve their English in all of these areas, in groups as well as by themselves.컴퓨터운영체제및실습 (Computer Operating System and Lab)운영 체제의 정의, 기능, 오퍼레이션에 관하여 상세한 설명을 한다. 구체적으로는 프로세스 스케쥴링, 메모리 관리, 화일 관리, 프로세스간 통신, 입출력 관리, 데드락등이 포함된다. 그리고 실제 운영체제를 시뮬레이션해 봄으로써 컴퓨터를 운영하는 주 프로그램의 내부 동작에 관하여 상세하게 배우게 된다.산학프로젝트 (Cooperative Projects)학생으로 이루어진 팀이 산업체 현장에서 찾아낸 주제를 프로젝트로 구성하여 진행 계획을 제안하여 산업체 멘토와 학교 교수진의 자문을 바탕으로 자기 주도적으로 실행하여 문제를 해결하고 결과를 도출한다. 주제는 소프트웨어 관련 분야에 한하고 진행 단계별로 담당교수의 승인이 필요하다.문제해결기법 (Problem solving)이 과목에서는 주어진 문제를 제약 조건을 만족하는 컴퓨터 프로그램을 작성하여 해결하는 방법을 학습한다. 기초적인 알고리즘, 자료구조 지식을 복습하고, 보다 발전된 알고리즘 및 자료구조를 C++/Java 등 프로그래밍 언어를 이용하여 구현하는 과정을 배운다. 프로그래밍언어와 컴파일러 (Programming Language and Compilers)컴퓨터 언어의 이론과 설계 구현 방법에 대하여 공부한다. 프로그래밍 언어의 변천사를 살펴보고 구문 이론, 타입 시스템, 실행시간 메모리 구조 등을 배운다. 프로그램을 컴퓨터 상에서 실행하기 위해 필요한 프로그램 번역기와 관련된 이론과 도구에 대해서도 알아본다.데이터사이언스 기초 (Data Science Fundamentals)기업, 정부, 사회 등의 다양한 분야들에서 정보 기술들이 활용됨에 따라 이들 분야로부터 많은 양의 데이터 ...
# 학과 : 소프트웨어학과
# 이수구분 : 교양필수
# 학수번호 : RC7168
# 교과목명 : 현대수학
# 학점 : 3
# 시간 : 3
# 비고 :
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3101
# 교과목명 : 이산수학
# 학점 : 3
# 시간 : 4
# 비고 :
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3106
# 교과목명 : 프로그래밍입문
# 학점 : 3
# 시간 : 4
# 비고 :
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3201
# 교과목명 : 확률통계론
# 학점 : 3
# 시간 : 3
# 비고 :
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3210
# 교과목명 : 자료구조
# 학점 : 3
# 시간 : 3
# 비고 :
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3207
# 교과목명 : SW산업과 커리어전략
# 학점 : 1
# 시간 : 1
# 비고 :
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공선택
# 교과목명 : 전공과목 전부 중 택
# 비고 :
#
# 계 : 28
# 부전공과목 일람표
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3106
# 교과목명 : 프로그래밍 입문
# 학점 : 3
# 시간 : 4
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3210
# 교과목명 : 자료구조
# 학점 : 3
# 시간 : 3
#
# 학과 : 소프트웨어학과
# 이수구분 : 전공필수
# 학수번호 : SW3302
# 교과목명 : 컴퓨터운영체제및실습
# 학점 : 3
# 시간 : 4
#
# 계 : 9 학점, 11 시간
#
# %%%%%%%%%%%%%%%%%%%
# -------7-------
# 20
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>졸업요건</h3>', '</div>', '<div class="article_303">', '<h4>전공 졸업요건<br/></h4></div><div class="article_303">', '<div class="scroller">', '<table class="table_01">\n<tbody><tr>\n<th rowspan="2">학부(과)</th>\n<th rowspan="2">학번 구분</th>\n<th colspan="2">학칙/학칙 시행세칙</th>\n<th rowspan="2">학과운영내규<br/>전공학점(전필+전선)</th><th rowspan="2">비고</th>\n</tr>\n<tr>\n<th>졸업학점</th>\n<th>편입생<br/>졸업학점</th>\n</tr>\n<tr>\n<td rowspan="5">소프트웨어학과</td>\n<td>2012학번까지</td>\n<td>140</td><td>70</td>\n<td rowspan="5">60학점<br/>(4학년에 개설된 전공선택\xa0\xa0<br/>2과목 이상 이수/단,인턴쉽 과목은 <br/>1과목으로만 인정함)</td>\n<td rowspan="5">전 학년 평점 평균<br/>2.00 이상</td>\n</tr>\n<tr>\n<td rowspan="2">2013학번 이후<br/>~<br/>2018학번 까지</td>\n<td><br/>130<br/><br/></td><td><br/>65<br/><br/></td>\n</tr>\n<tr>\n</tr>\n<tr>\n<td>2014학번 까지<br/></td>\n<td colspan="2">졸업인증제 기준 점수 600점</td>\n</tr>\n<tr>\n<td>2015학번 이후<br/></td>\n<td colspan="2">졸업인증제 기준 점수 650점<br/></td>\n</tr>\n</tbody></table></div><h5><div class="article_303" style="color: rgb(0, 0, 0); text-transform: none; text-indent: 0px; letter-spacing: normal; font-family: 돋움, Dotum, Helvetica, sans-serif; font-size: 12px; font-style: normal; word-spacing: 0px; white-space: normal; orphans: 2; widows: 2; text-decoration-style: initial; text-decoration-color: initial; -webkit-text-stroke-width: 0px; font-variant-caps: normal; font-variant-ligatures: normal;"><p style="margin: 0px; padding: 0px;"><b>2019학번부터 적용</b><span style="font-weight: 400;">: 주전공(기본)이수 학점을 반드시 취득해야하며, 교과과정의 전공필수 교과목은 반드시 이수해야 한다. 단일(심화)전공 및 다전공 중 1개의 전공을 선택하여 아래표와 같이 전공학점을 취득해야한다.</span><br/>', '</p></div></h5></div><div class="article_303">', '<div class="scroller">', '<table class="table_01">\n<tbody><tr>\n<th rowspan="2">주전공</th>\n<th colspan="5">단일전공 및 다전공</th>\n</tr>\n<tr>\n<th rowspan="1">단일전공</th>\n<th colspan="4">다전공</th>\n</tr>\n<tr>\n<td>기본전공</td>\n<td>심화전공<br/>(<span style="color: rgb(255, 0, 0);">4학년에 개설된 전공선택 2과목\xa0이수</span>)</td>\n<td>복수전공<br/>(<span style="color: rgb(255, 0, 0);">4학년에 개설된 전공선택 2과목\xa0이수</span>)</td>\n<td>부전공<br/>(<span style="color: rgb(255, 0, 0);">4학년에 개설된 전공선택 2과목\xa0이수</span>)</td>\n<td colspan="2">연계융합전공<br/>(<span style="color: rgb(255, 0, 0);">4학년에 개설된 전공선택 2과목\xa0이수</span>)</td>\n</tr>\n<tr>\n<td>45학점</td>\n<td>24학점이상</td>\n<td>42학점이상</td>\n<td>24학점이상</td>\n<td colspan="2">36학점이상</td>\n</tr>\n<tr>\n<td><b>총이수학점</b></td><td><b>69학점</b></td><td><b>87학점</b></td><td><b>69학점</b></td><td colspan="2"><b>81학점</b></td>\n</tr>\n<tr>\n</tr>\n</tbody></table></div><h5><div class="article_303" style="color: rgb(0, 0, 0); text-transform: none; text-indent: 0px; letter-spacing: normal; font-family: 돋움, Dotum, Helvetica, sans-serif; font-size: 12px; font-style: normal; word-spacing: 0px; white-space: normal; orphans: 2; widows: 2; text-decoration-style: initial; text-decoration-color: initial; -webkit-text-stroke-width: 0px; font-variant-caps: normal; font-variant-ligatures: normal;"><div class="article_303"><div class="scroller"><span style="font-size: 11pt;">AI융합전공 안내</span><br/><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ai_www"><span style="font-size: 11pt;">한국항공대학교 AI융합전공 (kau.ac.kr)</span></a><br/><br/><span style="font-size: 11pt;">교양 졸업이수학점은 아래 링크를 참고하기 바람</span><br/><a href="http://college.kau.ac.kr/web/pages/gc51336h.do"><span style="font-size: 11pt;">http://college.kau.ac.kr/web/pages/gc51336h.do</span></a><br/>\xa0</div></div></div></h5></div>', '</div>', '</body>']
# $(document).ready(function() {
# });
#
# 졸업요건
#
# 전공 졸업요건
#
# 학부(과) : 소프트웨어학과
# 학번 구분 : 2012학번까지
# 학칙/학칙 시행세칙 - 졸업학점 : 140, 편입생 졸업학점 : 70
# 학과운영내규 전공학점(전필+전선) : 60학점 (4학년에 개설된 전공선택 2과목 이상 이수/단,인턴쉽 과목은 1과목으로만 인정함)
# 비고 : 전 학년 평점 평균 2.00 이상
#
# 학부(과) : 소프트웨어학과
# 학번 구분 : 2013학번 이후 ~ 2018학번 까지
# 학칙/학칙 시행세칙 - 졸업학점 : 130, 편입생 졸업학점 : 65
#
# 학부(과) : 소프트웨어학과
# 학번 구분 : 2014학번 까지
# 학칙/학칙 시행세칙 - 졸업인증제 기준 점수 : 600점
#
# 학부(과) : 소프트웨어학과
# 학번 구분 : 2015학번 이후
# 학칙/학칙 시행세칙 - 졸업인증제 기준 점수 : 650점
#
# 2019학번부터 적용 : 주전공(기본)이수 학점을 반드시 취득해야하며, 교과과정의 전공필수 교과목은 반드시 이수해야 한다. 단일(심화)전공 및 다전공 중 1개의 전공을 선택하여 아래표와 같이 전공학점을 취득해야한다.
#
# 주전공 : 기본전공 45학점, 심화전공 24학점 이상, 복수전공 42학점 이상, 부전공 24학점 이상, 연계융합전공 36학점 이상
# 단일전공 : 69학점
# 다전공 : 87학점
# 복수전공 : 69학점
# 연계융합전공 : 81학점
#
# AI융합전공 안내 : 한국항공대학교 AI융합전공 (kau.ac.kr)
# 교양 졸업이수학점은 아래 링크를 참고하기 바람 : http://college.kau.ac.kr/web/pages/gc51336h.do
#
# %%%%%%%%%%%%%%%%%%%
# -------8-------
# 35
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>교육 사업단</h3>', '</div>', '<div class="article_501" style="width: auto;">', '<h4>4차산업혁명 혁신 선도 대학 사업(Linc+ 사업)</h4>', '<span class="img" style="background: linear-gradient(to left, transparent, rgb(255, 255, 255)), url(/conts_img/sw_www/introduce/drone.jpg); background-repeat: no-repeat; background-size: 100%;"></span>', '<br/>', '<div>', '<button onclick="location.href=\'http://research.kau.ac.kr/index/main.php\'" type="button">', 'Linc+사업 소개 페이지 바로가기', '</button>', '<br/><br/>', '<h2 class="sub_index">사업 목표</h2><br/>', '<p>', '- 초지능·초연결 시대의 드론산업을 선도할 AI융합인재 양성', '</p>', '<br/><br/>', '<h2 class="sub_index">사업 내용<br/><br type="_moz"/></h2><p>', '■ AI 일반 교육<br/>딥러닝 프로그래밍과 센서 AI 응용<br/><br/>■ AI 드론 전문 교육<br/>', '비행교육원 무인기조종자 양성과정과 연계한 드론 전문 교육<br/><br/>■ 드론 설계/제작 교육\xa0<br/>오픈소스 기반 드론 제작 및 실습<br/><br/>■ MOOC 강의 제공 : AI 드론 시스템 디자인 (센서, 제어, 자율)<br/><br/>', '</p>', '<img alt="linc_01" src="/conts_img/sw_www/introduce/linc_01.jpg" style="width: auto;"/>', '<img alt="linc_02" src="/conts_img/sw_www/introduce/linc_02.jpg" style="width: auto;"/>', '</div>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 교육 사업단
#
# 4차산업혁명 혁신 선도 대학 사업(Linc+ 사업)
#
# Linc+사업 소개 페이지 바로가기
#
# 사업 목표
#
# - 초지능·초연결 시대의 드론산업을 선도할 AI융합인재 양성
#
# 사업 내용
# ■ AI 일반 교육딥러닝 프로그래밍과 센서 AI 응용■ AI 드론 전문 교육
# 비행교육원 무인기조종자 양성과정과 연계한 드론 전문 교육■ 드론 설계/제작 교육 오픈소스 기반 드론 제작 및 실습■ MOOC 강의 제공 : AI 드론 시스템 디자인 (센서, 제어, 자율)
#
# %%%%%%%%%%%%%%%%%%%
# -------9-------
# 18
# ['<head>', '</head>', '<script type="text/javascript">', '$(document).ready(function() {', '});', '</script>', '<body>', '<div class="sub_conts">', '<div class="sub_tit">', '<h3>연구실</h3>', '</div>', '<div class="article_303">', '<div class="scroller">', '<table class="table_01">\n<tbody>\n<tr>\n<th colspan="2">연구실</th>\n<th>담당 교수</th>\n<th colspan="3">연구 분야</th>\n<th>링크</th>\n</tr>\n\n<tr>\n<td colspan="2">안전우선 SW 연구실</td>\n<td>김철기</td>\n<td colspan="3">안전우선 시스템설계 및 검증</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">Web Engineering Lab.</td>\n<td>길현영</td>\n<td colspan="3">Service computing<br/>Model checking<br/>Automated planning &amp; controller synthesis<br/>Knowledge representation &amp; reasoning</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">네트워크 보안 연구실</td>\n<td>박종서</td>\n<td colspan="3">Network Security<br/>Blockchain, Federated Learning<br/>Embedded System</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">Airborne Software Lab.</td>\n<td>송동호</td>\n<td colspan="3">airborne pilot and mission computing<br/>optimal planning, A.I. gaming<br/>Decision Support System</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">스마트비젼 연구실</td>\n<td>온승엽</td>\n<td colspan="3">데이터 사이언스, 인공지능, 컴퓨터 비젼</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">유비쿼터스 연구실</td>\n<td>이긍해</td>\n<td colspan="3">프로그래밍언어/인터넷 응용</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">알고리즘 연구실</td>\n<td>이인복</td>\n<td colspan="3">data compression<br/>intrusion detection<br/>design and analysis of algorithms</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">지능시스템 연구실</td>\n<td>지승도</td>\n<td colspan="3">Autonomous Multi-Agent<br/>Artificial Mind, Brain-Mind Modeling<br/>Emotional AI War Game Modeling &amp; Simulation</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">빅테이터 연구실</td>\n<td>최영식</td>\n<td colspan="3">Aerial Robotics<br/>Machine Learning, Computer Vision</td>\n<td></td>\n</tr>\n<tr>\n<td colspan="2">데이터베이스 연구실</td>\n<td>황수찬</td>\n<td colspan="3">Database systems<br/>Big data, Realtime databases<br/>Data center standards</td>\n<td></td>\n</tr>\n</tbody>\n</table>', '</div>', '</div>', '</div>', '</body>']
#
# $(document).ready(function() {
# });
#
# 연구실
#
# 연구실 : 안전우선 SW 연구실
# 담당 교수 : 김철기
# 연구 분야 : 안전우선 시스템설계 및 검증
#
# 연구실 : Web Engineering Lab.
# 담당 교수 : 길현영
# 연구 분야 : Service computing, Model checking, Automated planning & controller synthesis, Knowledge representation & reasoning
#
# 연구실 : 네트워크 보안 연구실
# 담당 교수 : 박종서
# 연구 분야 : Network Security, Blockchain, Federated Learning, Embedded System
#
# 연구실 : Airborne Software Lab.
# 담당 교수 : 송동호
# 연구 분야 : airborne pilot and mission computing, optimal planning, A.I. gaming, Decision Support System
#
# 연구실 : 스마트비젼 연구실
# 담당 교수 : 온승엽
# 연구 분야 : 데이터 사이언스, 인공지능, 컴퓨터 비젼
#
# 연구실 : 유비쿼터스 연구실
# 담당 교수 : 이긍해
# 연구 분야 : 프로그래밍언어/인터넷 응용
#
# 연구실 : 알고리즘 연구실
# 담당 교수 : 이인복
# 연구 분야 : data compression, intrusion detection, design and analysis of algorithms
#
# 연구실 : 지능시스템 연구실
# 담당 교수 : 지승도
# 연구 분야 : Autonomous Multi-Agent, Artificial Mind, Brain-Mind Modeling, Emotional AI War Game Modeling & Simulation
#
# 연구실 : 빅테이터 연구실
# 담당 교수 : 최영식
# 연구 분야 : Aerial Robotics, Machine Learning, Computer Vision
#
# 연구실 : 데이터베이스 연구실
# 담당 교수 : 황수찬
# 연구 분야 : Database systems, Big data, Realtime databases, Data center standards

# %%
import re
import csv
import pandas as pd


def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
#     sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
#     sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences


page_indexList = []
pageList = []
data = pd.read_csv('test3.csv', header=None, encoding="UTF-8")
for i in range(len(data)):
    page_indexList.append(data.iloc[i][0])
    pageList.append(data.iloc[i][1])

temp_str = ""
for i in range(len(page_indexList)):
    if page_indexList[i] == 41:
        temp_page = split_sentences(pageList[i])
        for j in range(len(temp_page)):
            if "// 팝업 띄우기" in temp_page[j]:
                temp_str = temp_str.strip()
                break
            else:
                temp_str = temp_str + temp_page[j] + "\n"
        temp_str = temp_str.strip()
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], temp_str])
        f.close()    
        temp_str = ""
    else:
        f = open(f'test3_filter.csv','a', newline='' , encoding="UTF-8")
        answer_db = csv.writer(f)
        answer_db.writerow([page_indexList[i], pageList[i]])
        f.close()

# %%
import os
import openai

openai.api_key ="API_KEY"
table_g = """                            <table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>-</td><td colspan="2">10~13학점</td></tr><tr><td>학문기초교양</td><td>-</td><td colspan="2">13~21학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양<br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div></h5><h5>1-1) 2023학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td>21</td><td>12</td><td>-</td><td>44</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td>20</td><td>12</td><td>-</td><td>43</td></tr><tr><td>신소재공학과</td><td>11</td><td>17</td><td>12</td><td>-</td><td>40</td></tr><tr><td>소프트웨어학과</td><td>13</td><td>13</td><td>12</td><td>1</td><td>39</td></tr><tr><td>스마트드론공학과</td><td>10</td><td>19</td><td>12</td><td>-</td><td>41</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>16</td><td>12</td><td>-</td><td>40</td></tr><tr><td>항공교통물류학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>항공운항학과</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr><tr><td>경영학부</td><td>11</td><td>15</td><td>12</td><td>1</td><td>39</td></tr></tbody></table></div></h5>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<strong>&nbsp;&nbsp;&nbsp;<br><span style="color: rgb(0, 0, 0);"><span style="color: rgb(58, 50, 195);">※ 년도별 교양교과과정표를 확인하여 소속 학부(과)별 필수이수 과목을 확인할 것</span>(</span></strong><a href="http://college.kau.ac.kr/web/index.do?siteFlag=ct_www"><span style="color: rgb(0, 0, 0);">한국항공대학교 인문자연학부 (kau.ac.kr)</span></a><span style="color: rgb(0, 0, 0);">)</span><strong><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </strong><h5><br>2) 2022학번<br><br> <div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">11~13학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </h5><h5>2-1) 2022학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>11</td><td> 20 </td><td> 12 </td><td>- </td><td> 43</td></tr><tr><td>항공전자정보공학부</td><td>11</td><td> 18</td><td> 12 </td><td> - </td><td>41</td></tr><tr><td>신소재공학과</td><td>11</td><td> 15</td><td> 12 </td><td>1</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>13</td><td> 12</td><td> 12 </td><td>2</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>12</td><td> 18</td><td> 12 </td><td>-</td><td>42</td></tr><tr><td>AI자율주행시스템공학과</td><td>12</td><td>15</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>항공교통물류학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>항공운항학과</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>경영학부</td><td>11</td><td> 13 </td><td> 12 </td><td>3</td><td> 39 </td></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br><br>3) 2021학번<br><br> </p><div class="scroller"><table class="table_01"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th></tr><tr><td>공통교양</td><td>- </td><td colspan="2">9~11학점</td></tr><tr><td>학문기초교양</td><td>- </td><td colspan="2">12~20학점</td></tr><tr><td rowspan="2">선택교양</td><td>1) 철학과 역사<br>2) 문학과 예술<br>3) 인간과 사회<br>4) 자연과 과학<br>5)세계와 문화</td><td>9 학점 이상<br>(최소 3개 영역 선택)</td><td rowspan="2">12 학점<br>※ 1)~5) 영역 중 3개 선택 후 중복되지 않는 나머지 4개 영역에서 3학점 이상 이수</td></tr><tr><td>6) 소양     <br>7) 자기계발</td><td>자유이수</td></tr><tr><td colspan="2">계</td><td colspan="2">39 학점 이상</td></tr></tbody></table></div><!--2-1) 학부 ( 과 ) 별 교양이수학점 -->     </div></h5><h5>3-1) 2021학번 학부(과) 별 교양이수학점</h5><h5><div class="scroller"><table class="table_01"><tbody><tr><th>학부/과</th><th>공통교양</th><th>학문기초교양</th><th>선택교양</th><th>추가이수<br>교양학점*</th><th>계</th></tr><tr><td>항공우주 및 기계공학부</td><td>9 </td><td> 20 </td><td> 12 </td><td>- </td><td> 41</td></tr><tr><td>항공전자정보공학부</td><td>9 </td><td> 18</td><td> 12 </td><td>-</td><td> 39 </td></tr><tr><td>신소재공학과</td><td>9</td><td> 15</td><td> 12 </td><td>3</td><td> 39 </td></tr><tr><td>소프트웨어학과</td><td>11</td><td>12</td><td> 12 </td><td>4</td><td> 39 </td></tr><tr><td>스마트드론공학과</td><td>10</td><td>15</td><td> 12 </td><td>2</td><td> 39</td></tr><tr><td>항공교통물류학부</td><td>9</td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>항공운항학과</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr><td>경영학부</td><td>9 </td><td> 13 </td><td> 12 </td><td> 5 </td><td> 39 </td></tr><tr></tr></tbody></table><p>* 졸업에 필요한 추가이수 교양학점은 공통교양, 학문기초교양, 선택교양 모든 교과목 포함됨<br><br>4) 2020 학번</p></div></h5><strong>
                            </strong><strong>
                                </strong><strong>
                                    </strong><strong>
                                    </strong><strong>
                                    </strong><table class="table_nrm center"><tbody><tr><th>대영역</th><th>세부영역</th><th colspan="2">학점</th>
                                </tr>
                                <tr>
                                    <td>공통교양</td>
                                    <td>-</td>
                                    <td colspan="2">7 학점</td>
                                </tr>
                                <tr>
                                    <td>학문기초교양</td>
                                    <td>-</td>
                                    <td colspan="2">12 ~ 20학점, 각 학부(과)별 상이</td>
                                </tr>
                                <tr>
                                    <td rowspan="2">선택교양</td>
                                    <td>
                                        1) 철학과 역사<br>
                                        2) 문학과 예술<br>
                                        3) 인간과 사회<br>
                                        4) 자연과 과학<br>
                                        5) 세계와 문화
                                    </td>
                                    <td>9 학점 이상<br>(최소 3개 영역 선택)</td>
                                    <td rowspan="2">12 학점<br>※ 1) ~ 5) 영역 중 3개 선택 후 중복되지 않는 영역에서 3학점 이상 이수</td>
                                </tr>
                                <tr>
                                    <td>
                                        6) 소양<br>
                                        5) 자기계발
                                    </td>
                                    <td>자유이수</td>
                                </tr>
                                <tr>
                                    <th colspan="2">계</th>
                                    <th colspan="2">39 학점 이상</th>
                                </tr>
                            </tbody></table>"""

sys = f"""다음의 맥락들을 사용하여 마지막 답변을 생성하세요. 답변을 꾸며내려 하지 마십시오.
답변을 제공할 때는 다음 형식으로 제공되어야 합니다:
테이블: [테이블 태그와 내용이 주어짐]
답: [테이블 내용 반환]

답을 결정하는 방법:

- 테이블에 있는 내용으로만 답변을 생성합니다.
- 충분한 수준의 자세한 내용을 포함하여 답변을 생성합니다.
- 자신감이 과하지 않도록 주의하세요!

예시 #1
테이블:
---------
<table class="table_nrm center">
    <tbody><tr>
        <th>이수구분</th>
        <th>학점인정</th>
        <th>비고</th>
    </tr>
    <tr>
        <td>교양 선택</td>
        <td>1학점</td>
        <td>“P”(Pass), “NP”(Non-Pass)</td>
    </tr>
</tbody></table>
---------
답 : 
---------
이수구분 : 교양선택
학점인정 : 1학점
비고 :“P”(Pass), “NP”(Non-Pass)
---------

예시 #2
테이블:
---------
<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>
---------
답 : 
---------
편의시설 : 식당
위치 : 1층 학생식당 내
전화번호 : -

편의시설 : 편의점(GS)
위치 : 1층 학생식당 내
전화번호 : 02-3158-0336

편의시설 : 우리은행
위치 : 1층(운영시간) 09:30~15:30
전화번호 : 02-3158-3656

편의시설 : 블루포트(take out coffee)
위치 : 1층 중앙로비
전화번호 : -
---------

예시 #3
테이블:
---------
<table class="table_nrm">
    <tbody><tr>
        <th colspan="2">구분</th>
        <th>비고</th>
    </tr>
    <tr>
        <td class="ta_center">공통서류</td>
        <td class="ta_center">전과신청서 각 1부<br>성적증명서 1부</td>
        <td class="ta_center" rowspan="3">전과 희망 학부(과) 사무실</td>
    </tr>
    <tr>
        <td class="ta_center">경영학부<br>항공교통물류학부</td>
        <td class="ta_center">토익성적증명서 1부</td>
    </tr>
    <tr>
        <td class="ta_center">항공운항학과</td>
        <td class="ta_center">전과지원서 1부<br>토익성적증명서 1부<br>항공신체검사증명서 1부</td>
    </tr>
</tbody></table>
---------
답 : 
---------
구분 : 공통서류 - 전과신청서 각 1부, 성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 경영학부, 항공교통물류학부 - 토익성적증명서 1부
비고 : 전과 희망 학부(과) 사무실

구분 : 항공운항학과 - 전과지원서 1부, 토익성적증명서 1부, 항공신체검사증명서 1부
비고 : 전과 희망 학부(과) 사무실
---------

시작!
테이블:
---------
{table_g}
---------
답 : 
"""
completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
if answer.endswith('"'):
    answer = answer[:-1]
    answer = answer
print(answer)

# %%
ass1 = """
함수 이름: [table_to_text]
입력: ["<table></table>"]
규칙: [당신이 정리하는 역할을 하길 바랍니다. 나는 <table> 태그를 포함한 입력 양식을 제공할 것이며 당신은 <table>을 감지하고 텍스트로 정리할것입니다.]
table_to_text(<table class="table_nrm center">
                                    <tbody><tr>
                                        <th rowspan="2">증명서 종류</th>
                                        <th rowspan="2">발급방법</th>
                                        <th colspan="2">수수료</th>
                                        <th rowspan="2">발급 시 관련부서</th>
                                    </tr>
                                    <tr>
                                        <th>국문</th>
                                        <th>영문</th>
                                    </tr>
                                    <tr>
                                        </tr><tr>
                                            <td>성적/재학/휴학/재적증명서<br>제적/졸업예정/졸업/수료증명서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>주민센터 내 FAX민원, <br>우체국 우편발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>학적부, 사실증명원</td>
                                            <td>방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>교무팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>장학수혜확인서</td>
                                            <td>인터넷발급(<a style="color: blue;" href="http://hangkong.certpia.com/" target="_blank"><b>바로가기클릭☞</b></a>), <br>학생회관발급기<br>* 대학원은 방문 발급만 해당</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>재학 1,200원<br>졸업 1,500원</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>교육비납입증명서</td>
                                            <td>종합정보시스템에서 출력가능</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>재무팀</td>
                                        </tr>
                                        <tr>
                                            <td>교외장학지원 관련 추천서</td>
                                            <td>방문발급</td>
                                            <td>없음</td>
                                            <td>영문발급 無</td>
                                            <td>학생지원팀, 대학원행정실</td>
                                        </tr>
                                        <tr>
                                            <td>실무경력확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공교통관제교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>비행교육원 이수증명서</td><td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원</td>
                                        </tr>
                                        <tr>
                                            <td>공학교육인증 참여확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급</td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>공학교육혁신센터</td>
                                        </tr>
                                        <tr>
                                            <td>항공정비사 정비실습확인서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>항공우주 및 기계공학부</td>
                                        </tr>
                                        <tr>
                                            <td>운항관리경력증명서</td>
                                            <td>인터넷발급<br>학생회관발급기, 방문발급<br></td>
                                            <td>재학 600원<br>졸업 1,000원</td>
                                            <td>영문발급 無</td>
                                            <td>비행교육원<br></td>
                                        </tr>
                                </tbody></table>)
"""

# %%
import os
import openai

openai.api_key ="API_KEY"


# 테이블 태그 임의로 지정하기
table_g = """<table class="table_nrm center">
<tbody>
  <tr>
    <th>편의시설</th>
    <th>위치</th>
    <th>전화번호</th>
  </tr>
  <tr>
    <td>식당</td>
    <td>1층 학생식당 내</td>
    <td>-</td>
  </tr>
  <tr>
    <td>편의점(GS)</td>
    <td>1층 학생식당 내</td>
    <td>02-3158-0336</td>
  </tr>
  <tr>
    <td>우리은행</td>
    <td>1층(운영시간) 09:30~15:30</td>
    <td>02-3158-3656</td>
  </tr>
  <tr>
    <td>블루포트(take out coffee)</td>
    <td>1층 중앙로비</td>
    <td>-</td>
  </tr>
</tbody>
</table>"""


# (텍스트 + 테이블 태그)를 입력으로 주었을 때 문제가 발생하는지 파악
full = f"""               

사회봉사 과목이수안내
1. 사회봉사 이수방법
이론교육(4시간) + 봉사활동(34시간 이상)

{table_g}

※ 수강신청 시 본인 최대수강신청 학점에 미포함
※ 재학 중 1회 1학점씩 총 2회 2학점까지 이수 가능
※ 성적산출시 취득학점에 포함, 평점평균 산정에 미포함
※ 연속 2회 “NP”일 경우 수강신청 불가

3. 사회봉사활동 인정기간
수강신청 직전학기 기말시험 시작일 ~ 수강신청 학기 기말시험 전까지(※ 헌혈은 기간제한 없음)

4. 사회봉사활동 기관 인정 범위
가. 시·도 및 시·군·구 자원봉사센터, 청소년활동진흥센터, 기타 사회복지관, 지역아동센터, 사회복지법인 사회복지봉사활동인증관리(VMS) 및
       1365자원봉사포털에 등록되어 ‘사회복지 봉사활동 실적 인증서(VMS)’ 및 ‘자원봉사활동 확인서(1365)’가 출력되는 기관
VMS 출력 시 필히 ‘봉사자 실적 내역정보’ 출력하여 제출
니. 비영리민간단체(봉사활동확인서 제출 시 ‘비영리민간단체등록증’ 사본 첨부)
다. 해외봉사 : 인증된 국제 NGO단체
NGO(Non-Governmental Organization 비정부기구)는 지역-국가-국제적으로 조직된 자발적인 비영리 시민단체
라. 자원봉사센터 및 시민단체와 연계하여 하는 농촌봉사활동
마. 총학생회 주관 자원봉사
1학기 : 항공산타, 신입생새로배움터, 은익제 등
2학기 : 항공제, 하계방학 중 실시 한 사회봉사활동 등
바. 기타 부서 주관 대외행사 및 교내 자원봉사
입학관리팀 ‘모교입시 설명회’, 국제교류부 ‘Global-Buddy’, 항공우주박물관 ‘안내봉사’ 등
사. 헌혈활동 : 헌혈증 제출
1회 기준 4시간 인정
1학기 최대 2회(8시간)까지만 인정
추후 본교 재학생 중 필요한 학생 및 저소득층, 백혈병 소아암 협회, 관련 사회복지기관 등에게'항공대 재학생' 이름으로 기증

5. 사회봉사활동 미인정 범위
가. 공공기관, 행정기관에서의 봉사활동
공공기관 : 주민센터(구. 동사무소), 시.도.군.구청, 경찰서, 세무서, 소방서, 우체국 등
정부행정기관 : 국세청, 법원, 감사원, 국회 등
나. 도서관(단, 시각장애인을 위한 점자도서관은 인정), 어린이집, 경로당, 종교관련 봉사활동
다. 시·군·구 개최, 지역 개최 봉사활동(단, 교육과학기술부에서 공문화 되어 온 봉사활동은 인정)
라. 제출기간까지 봉사활동확인서가 미발급되거나 기간 및 시간이 정확히 기재되지 않은 봉사활동
   (예 : 중앙일보 '공부의 신')

6. 제출서류
가. “사회봉사”과목 학점인정 서류
수강신청 전원 제출, 미제출시 학점인정 안됨
본교 총학생회 주관 자봉단 활동 시에도 제출
나. 사회봉사활동확인서(봉사활동을 실시한 기관에 양식이 없을 경우 사용)

7. 유의사항
가. 필히 ‘이론교육’ 4시간을 이수해야 봉사활동확인서 제출 시 학점 인정
나. 봉사활동 확인서는 원본을 제출하여야 하며, 제출한 서류는 일체 반환하지 않음
다. 봉사활동 확인서 수정 금지 (수정 시 담당자 날인이 없을 경우 무효 처리)
    * 문의사항 : 02-300-0014
"""


# 테이블과 관련된 질문하기
question ="""혹시 편의시설에 대해 알려줄래?"""



sys = f"""{full}

{question}"""

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo-16k-0613",
  messages=[
  {"role": "system", "content": f'"{sys}"'},
])
answer = completion['choices'][0]['message']['content']
# answer = answer.replace('\"',"")
print(answer)

# %%
import pandas as pd
import openai
import csv
import numpy as np
from time import sleep
import json
import ast
import re
import random
from itertools import *
import sys
delay = 2

openai.api_key ="API_KEY"

def get_embedding(text, model="text-embedding-ada-002"):
    count = 0 # 예외 발생 횟수를 저장할 변수
    max_count = 5 # 예외가 발생한 최대 횟수
    while True:
        try :
            temp = openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']
            count=0
            return temp
        except Exception as e:
            count += 1
            print(count)
            if count >= max_count:
                print("예외가 연속으로 %d번 발생했습니다. 프로그램을 종료합니다." % max_count)
                break
            else:
                print("예외가 발생했습니다. (%s)" % e)
def split_sentences(text):
    sentences = text.split('\n')  # newline('\n')을 기준으로 문자열을 나눕니다.
    sentences = [sentence.strip() for sentence in sentences]  # 각 문장 앞뒤에 있는 공백을 제거합니다.
    sentences = [sentence for sentence in sentences if sentence]  # 빈 문장을 제거합니다.
    return sentences

                
Sec_index = []
SecList = []
    
csv_name = "test3_filter"

data = pd.read_csv(f'{csv_name}.csv', header=None, encoding="UTF-8")
for i in range(len(data)):    
    Sec_index.append(data.iloc[i][0])
    SecList.append(data.iloc[i][1])
    
###########################################################################################
temp_str = ""
for i in range(len(Sec_index)):
    print(f"------------  {i}  -------------")
    temp_manual = SecList[i]
    splitList = split_sentences(temp_manual)
    for j in range(len(splitList)):
        pattern = re.compile(r'\d+\.')
        matches = re.findall(pattern, temp_sentence)
        if matches:
            temp_str = temp_str + splitList[j]
        print(splitList[j])
        print("######################")
